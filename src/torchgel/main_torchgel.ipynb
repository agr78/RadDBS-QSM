# %% [markdown]
# This notebook will show how to use the `gel` package to perform group elastic net regression. Suppose we have feature matrices $A_j$ ($j = 1 \dots p$), each of size $m \times n_j$ (i.e. $m$ $n_j$-dimensional samples), and targets $y$ (a $m$ dimensional vector). Group elastic net finds coefficients $\beta_j$ ($n_j$ dimensional vector), and $\beta_0$ (scalar) by solving the optimization problem
#
# $$ \min_{\beta_0,\dots,\beta_p} \frac{1}{2}\left\|y - \beta_0 - \sum_{j=1}^p A_j\beta_j\right\|^2 + m\sum_{j=1}^p \sqrt{n_j}\left(\lambda_1\|\beta_j\| + \lambda_2\|\beta_j\|^2\right). $$
#
# We will test this with some generated data.

# %%
m_tr = 100  # number of samples
ns = [10, 20, 5, 200, 1, 20]  # group sizes

# data distribution parameters
X_scale = 2.0
X_bias = 3.0

# coefficient distribution parameters
β_scale = 0.125
β_bias = 6.0

# true support
support = [0, 1, 0, 1, 1, 0]

# %%
# Generate data
import torch

A_trs = [torch.randn(m_tr, n_j)*X_scale + X_bias for n_j in ns]
βs = [s_j*(torch.randn(n_j, 1)*β_scale + β_bias) for s_j, n_j in zip(support, ns)]
y_tr = sum([A_j@β_j for A_j, β_j in zip(A_trs, βs)])[:, 0]

# %% [markdown]
# We will now use `gel` to solve group elastic net with a single pair of regularization values. There are two steps to this. First, `make_A` is used to convert the features as needed by the library. This, and other parameters are passed to gel_solve.
#
# There are two implementations, `gelfista` and `gelcd`, which use proximal gradient descent and coordinate descent respectively. Refer to the respective source files for details on these methods. Here, we will use `gelfista`. `gelcd` is used in the same way.

# %%
from gel.gelfista import make_A, gel_solve

# %%
A_conv_tr = make_A(
    A_trs,
    torch.tensor(ns),  # note that this needs to be a LongTensor
    device=torch.device("cpu"),
    dtype=torch.float32,
)

# %%
print(A_conv_tr.shape)
# Out:
# torch.Size([6, 200, 100])

# %%
print(y_tr.shape)  # note that y should be one dimensional
# Out:
# torch.Size([100])

# %%
l_1 = 1.0  # λ_1
l_2 = 0.1  # λ_2

# %%
b_0, B = gel_solve(
    A_conv_tr,
    y_tr,
    l_1,
    l_2,
    ns,
    b_init=None,     # initialization value - useful if solving multiple instances
    t_init=None,     # initial step size for line search - default (None) is to use previous iteration's value
    ls_beta=0.99,    # line search shrinkage factor - default (None) is to not perform line search and use t_init
    max_iters=5000,  # maximum iterations - default (None) is unlimited
    rel_tol=1e-5,    # relative change in b_0, B to stop the algorithm (default 1e-6)
    verbose=True,    # verbosity (default False)
)
# Out:
# Solving gel with FISTA (l_1 1, l_2 0.1): 5000it [00:13, 369.66it/s, t=3.6e-10, rel change=2.1e-05]

# %% [markdown]
# The returned `b_0` is a scalar, and `B` is a matrix. Each row of `B` is the coefficient vector for the corresponding group, padded with 0s. So we will first extract the vectors.

# %%
βhats = [B[j, :ns[j]] for j in range(len(ns))]

# %%
print(b_0)
# Out:
# 84.1146011352539

# %%
print([βhat_j.norm() for βhat_j in βhats])
# Out:
# [tensor(28.2263), tensor(42.1783), tensor(16.8806), tensor(64.7575), tensor(16.1196), tensor(26.3584)]

# %% [markdown]
# This is the solution for a single (l_1, l_2) pair. But practically, we want to use a grid of values. So now, we will use the `gelpaths` module to sweep over multiple regularization values and pick the best based on validation results.

# %%
# First, we generate validation data.
m_val = 30
A_vals = [torch.randn(m_val, n_j)*X_scale + X_bias for n_j in ns]
y_val = sum([A_j@β_j for A_j, β_j in zip(A_vals, βs)])[:, 0]

# %%
# We need to standardize the data to prevent repeated computations.
A_tr_μs = [A_j.mean(dim=0, keepdim=True) for A_j in A_trs]
A_tr_σs = [A_j.std(dim=0, keepdim=True) for A_j in A_trs]
A_tr_stans = [(A_j - A_μ_j) / A_σ_j for A_j, A_μ_j, A_σ_j in zip(A_trs, A_tr_μs, A_tr_σs)]
A_val_stans = [(A_j - A_μ_j) / A_σ_j for A_j, A_μ_j, A_σ_j in zip(A_vals, A_tr_μs, A_tr_σs)]

y_tr_μ = y_tr.mean()
y_tr_σ = y_tr.std()
y_tr_stan = (y_tr - y_tr_μ) / y_tr_σ

# %% [markdown]
# `gelpaths` follows a 2-step procedure. For each (l_1, l_2) pair, the corresponding group elastic net problem is solved; this is then used to find the support by finding non-zero coefficient vectors. The support is then used to solve ridge regression over a range of regularization values.
#
# For each ridge solution, a summary function is called. This is where we will compute the validation error, to find the optimal regularization values. Note that the summary function expects the features as a single matrix.

# %%
X_val = torch.cat(A_val_stans, dim=1).t()  # note the transpose

def summary(_support, _b):
    if _support is None:
        # empty support, so just use the computed training mean
        yhat_val = y_tr_μ
        _support_set = {}
    else:
        X_val_supp = X_val[_support]
        yhat_val = (X_val_supp.t() @ _b) * y_tr_σ + y_tr_μ  # we have to rescale
        _support_set = set([s.item() for s in _support])
        
    rmse = ((y_val - yhat_val) ** 2).mean().sqrt().item()

    # compute group support
    group_support = []
    start_idx = 0
    for n_j in ns:
        group_idxs = range(start_idx, start_idx + n_j)
        if all(i in _support_set for i in group_idxs):
            group_support.append(1)
        elif not any(i in _support_set for i in group_idxs):
            group_support.append(0)
        else:
            # This shouldn't happen! Groups are either all in or all out.
            raise AssertionError
        start_idx += n_j

    return group_support, rmse

# %% [markdown]
# There are two implementations in `gelpaths`. `gel_paths` requires manually specifying regularization values, and `gel_paths2` picks them automatically. We will use `gel_paths2` here.

# %%
from gel.gelpaths import gel_paths2

l_rs = torch.logspace(-10, 10, 100).tolist()  # regularization strengths for ridge regression

summaries = gel_paths2(
    gel_solve,
    {
        # arguments to gel_solve
        "t_init": None,
        "ls_beta": 0.99,
        "max_iters": 3000,
        "rel_tol": 1e-5,
    },
    make_A,                                   # we don't explicitly call make_A here
    A_tr_stans,                               # we need to pass the standardized A values
    y_tr_stan,                                # note: standardized ouput vector
    ks=[0.01, 0.1, 0.3, 0.5, 0.7, 0.9, 0.99], # this is a list of values to trade-off
                                              #   between l_1 and l_2 regularizations, with
                                              #   l_1 = k*l and l_2 = (1 - k)*l
    n_ls=50,                                  # number of l values for each k value
    l_eps=1e-5,                               # ratio of minimum to maximum l value;
                                              #    n_ls number of l values are generated
                                              #    according to this ratio, for each k
    l_rs=l_rs,                                # ridge regularization values
    summ_fun=summary,                         # the summary function
    supp_thresh=1e-4,                         # norm threshold for considering coefficient vectors
                                              #     to be 0 (default 1e-6)
    device=torch.device("cpu"),               # pytorch device (default cpu)
    verbose=True,                             # verbosity (default False)
    ls_grid=None,                             # override l value computation with a fixed grid
                                              #     (default is None)
    aux_rel_tol=1e-3,                         # tolerance for solving auxiliary problems
                                              #     to get better initializations (default 1e-3)
    dtype=torch.float32,                      # torch dtype (default float32)
)
# Out:
# Solving gel with FISTA (l_1 0.13, l_2 13): 41it [00:00, 167.84it/s, t=0.046, rel change=9.3e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 10681.77it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 10): 6it [00:00, 33.93it/s, t=0.014, rel change=2.1e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 16376.96it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 8.2): 6it [00:00, 47.77it/s, t=0.052, rel change=2.4e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 16231.20it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 6.5): 6it [00:00, 45.43it/s, t=0.041, rel change=7.3e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 7477.01it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 5.2): 7it [00:00, 90.16it/s, t=0.3, rel change=1.9e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 6615.62it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 4.1): 8it [00:00, 101.69it/s, t=0.28, rel change=7.5e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 8250.33it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 3.2): 8it [00:00, 109.92it/s, t=0.28, rel change=6e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 10970.95it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 2.5): 10it [00:00, 132.09it/s, t=0.25, rel change=9.4e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 12863.20it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 2): 9it [00:00, 106.69it/s, t=0.28, rel change=9.7e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 12838.00it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 1.6): 12it [00:00, 122.48it/s, t=0.24, rel change=8e-06]
# Support size: 1
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 6467.20it/s]
#
# Solving gel with FISTA (l_1 0.013, l_2 1.3): 13it [00:00, 92.70it/s, t=0.1, rel change=7.6e-06]
# Support size: 16
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5224.72it/s]
#
# Solving gel with FISTA (l_1 0.01, l_2 1): 14it [00:00, 123.06it/s, t=0.19, rel change=9.2e-06]
# Support size: 16
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5167.44it/s]
#
# Solving gel with FISTA (l_1 0.0079, l_2 0.79): 15it [00:00, 147.49it/s, t=0.26, rel change=5.3e-06]
# Support size: 36
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3274.47it/s]
#
# Solving gel with FISTA (l_1 0.0063, l_2 0.62): 17it [00:00, 140.30it/s, t=0.2, rel change=8.2e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3903.71it/s]
#
# Solving gel with FISTA (l_1 0.005, l_2 0.49): 18it [00:00, 150.60it/s, t=0.22, rel change=6.9e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 798.41it/s]
#
# Solving gel with FISTA (l_1 0.0039, l_2 0.39): 20it [00:00, 158.06it/s, t=0.22, rel change=6e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3912.38it/s]
#
# Solving gel with FISTA (l_1 0.0031, l_2 0.31): 23it [00:00, 93.92it/s, t=0.016, rel change=9.9e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3587.76it/s]
#
# Solving gel with FISTA (l_1 0.0025, l_2 0.24): 27it [00:00, 196.74it/s, t=0.13, rel change=8.4e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3828.74it/s]
#
# Solving gel with FISTA (l_1 0.0019, l_2 0.19): 29it [00:00, 227.91it/s, t=0.17, rel change=9.1e-06]
# Support size: 256
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 750.15it/s]
#
# Solving gel with FISTA (l_1 0.13, l_2 1.2): 113it [00:00, 218.49it/s, t=0.046, rel change=9.9e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 12378.06it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 0.95): 11it [00:00, 113.23it/s, t=0.27, rel change=4.9e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 7585.87it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 0.75): 13it [00:00, 115.49it/s, t=0.19, rel change=5.3e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 7814.26it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 0.59): 15it [00:00, 116.17it/s, t=0.18, rel change=8.1e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3964.71it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 0.47): 15it [00:00, 147.76it/s, t=0.22, rel change=8.8e-06]
# Support size: 15
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3307.05it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 0.37): 20it [00:00, 137.76it/s, t=0.14, rel change=8.8e-06]
# Support size: 35
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3127.81it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 0.29): 22it [00:00, 151.12it/s, t=0.18, rel change=6.2e-06]
# Support size: 55
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3814.63it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 0.23): 24it [00:00, 142.21it/s, t=0.13, rel change=8e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3748.26it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 0.18): 28it [00:00, 153.23it/s, t=0.16, rel change=7.7e-06]
# Support size: 56
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3408.09it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 0.14): 30it [00:00, 172.40it/s, t=0.14, rel change=8.6e-06]
# Support size: 256
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 811.00it/s]
#
# Solving gel with FISTA (l_1 0.13, l_2 0.31): 176it [00:00, 303.22it/s, t=0.046, rel change=9.9e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 10840.52it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 0.25): 19it [00:00, 139.31it/s, t=0.26, rel change=5e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 10574.85it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 0.19): 23it [00:00, 120.65it/s, t=0.15, rel change=9.3e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 4274.15it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 0.15): 26it [00:00, 183.02it/s, t=0.12, rel change=6.8e-06]
# Support size: 30
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5320.43it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 0.12): 27it [00:00, 227.06it/s, t=0.2, rel change=6.6e-06]
# Support size: 55
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3305.83it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 0.096): 36it [00:00, 209.59it/s, t=0.1, rel change=7.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 719.71it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 0.076): 36it [00:00, 192.54it/s, t=0.14, rel change=7.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 590.99it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 0.06): 41it [00:00, 152.39it/s, t=0.03, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 713.14it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 0.047): 47it [00:00, 133.10it/s, t=0.014, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 735.68it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 0.038): 52it [00:00, 189.35it/s, t=0.086, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 721.93it/s]
#
# Solving gel with FISTA (l_1 0.013, l_2 0.03): 54it [00:00, 175.21it/s, t=0.075, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 760.40it/s]
#
# Solving gel with FISTA (l_1 0.01, l_2 0.023): 71it [00:00, 155.47it/s, t=0.0053, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 752.58it/s]
#
# Solving gel with FISTA (l_1 0.0079, l_2 0.019): 64it [00:00, 136.26it/s, t=0.0046, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.21it/s]
#
# Solving gel with FISTA (l_1 0.0063, l_2 0.015): 67it [00:00, 109.46it/s, t=0.00041, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 736.19it/s]
#
# Solving gel with FISTA (l_1 0.005, l_2 0.012): 73it [00:00, 116.15it/s, t=0.00041, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 740.87it/s]
#
# Solving gel with FISTA (l_1 0.0039, l_2 0.0092): 63it [00:00, 105.55it/s, t=0.0002, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 745.02it/s]
#
# Solving gel with FISTA (l_1 0.0031, l_2 0.0072): 68it [00:00, 95.53it/s, t=0.00011, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 723.41it/s]
#
# Solving gel with FISTA (l_1 0.0025, l_2 0.0057): 84it [00:00, 127.42it/s, t=0.00057, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 748.05it/s]
#
# Solving gel with FISTA (l_1 0.0019, l_2 0.0045): 72it [00:00, 125.63it/s, t=0.0013, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.54it/s]
#
# Solving gel with FISTA (l_1 0.0015, l_2 0.0036): 75it [00:00, 132.10it/s, t=0.0017, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 760.80it/s]
#
# Solving gel with FISTA (l_1 0.0012, l_2 0.0028): 74it [00:00, 114.60it/s, t=0.00035, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 749.95it/s]
#
# Solving gel with FISTA (l_1 0.00096, l_2 0.0022): 81it [00:00, 114.26it/s, t=0.00014, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 728.27it/s]
#
# Solving gel with FISTA (l_1 0.00076, l_2 0.0018): 67it [00:00, 106.75it/s, t=0.00034, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 730.96it/s]
#
# Solving gel with FISTA (l_1 0.0006, l_2 0.0014): 74it [00:00, 125.25it/s, t=0.00065, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 774.94it/s]
#
# Solving gel with FISTA (l_1 0.00047, l_2 0.0011): 66it [00:00, 128.09it/s, t=0.0035, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 799.24it/s]
#
# Solving gel with FISTA (l_1 0.00037, l_2 0.00087): 54it [00:00, 103.22it/s, t=0.00099, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 654.53it/s]
#
# Solving gel with FISTA (l_1 0.0003, l_2 0.00069): 38it [00:00, 90.12it/s, t=0.0017, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 836.16it/s]
#
# Solving gel with FISTA (l_1 0.00023, l_2 0.00055): 59it [00:00, 102.91it/s, t=0.0017, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 782.91it/s]
#
# Solving gel with FISTA (l_1 0.00019, l_2 0.00043): 38it [00:00, 105.31it/s, t=0.0014, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 773.13it/s]
#
# Solving gel with FISTA (l_1 0.00015, l_2 0.00034): 49it [00:00, 93.50it/s, t=0.0045, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 768.06it/s]
#
# Solving gel with FISTA (l_1 0.00012, l_2 0.00027): 35it [00:00, 141.04it/s, t=0.028, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.86it/s]
#
# Solving gel with FISTA (l_1 9.2e-05, l_2 0.00021): 28it [00:00, 83.54it/s, t=0.012, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 785.69it/s]
#
# Solving gel with FISTA (l_1 7.2e-05, l_2 0.00017): 31it [00:00, 140.12it/s, t=0.039, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 685.25it/s]
#
# Solving gel with FISTA (l_1 5.7e-05, l_2 0.00013): 22it [00:00, 63.37it/s, t=0.0091, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 750.86it/s]
#
# Solving gel with FISTA (l_1 4.5e-05, l_2 0.00011): 15it [00:00, 102.39it/s, t=0.16, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.04it/s]
#
# Solving gel with FISTA (l_1 3.6e-05, l_2 8.3e-05): 14it [00:00, 99.37it/s, t=0.17, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 757.21it/s]
#
# Solving gel with FISTA (l_1 2.8e-05, l_2 6.6e-05): 13it [00:00, 74.83it/s, t=0.075, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 713.91it/s]
#
# Solving gel with FISTA (l_1 2.2e-05, l_2 5.2e-05): 13it [00:00, 95.02it/s, t=0.16, rel change=7.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 693.21it/s]
#
# Solving gel with FISTA (l_1 1.8e-05, l_2 4.1e-05): 12it [00:00, 63.57it/s, t=0.051, rel change=8.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.13it/s]
#
# Solving gel with FISTA (l_1 1.4e-05, l_2 3.3e-05): 10it [00:00, 65.16it/s, t=0.09, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 753.43it/s]
#
# Solving gel with FISTA (l_1 1.1e-05, l_2 2.6e-05): 10it [00:00, 73.38it/s, t=0.13, rel change=9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 743.93it/s]
#
# Solving gel with FISTA (l_1 8.7e-06, l_2 2e-05): 9it [00:00, 75.31it/s, t=0.2, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 739.73it/s]
#
# Solving gel with FISTA (l_1 6.9e-06, l_2 1.6e-05): 8it [00:00, 73.94it/s, t=0.21, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 740.78it/s]
#
# Solving gel with FISTA (l_1 5.5e-06, l_2 1.3e-05): 7it [00:00, 64.12it/s, t=0.19, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 718.77it/s]
#
# Solving gel with FISTA (l_1 4.3e-06, l_2 1e-05): 6it [00:00, 56.19it/s, t=0.18, rel change=8.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.18it/s]
#
# Solving gel with FISTA (l_1 3.4e-06, l_2 8e-06): 5it [00:00, 49.07it/s, t=0.19, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 757.10it/s]
#
# Solving gel with FISTA (l_1 2.7e-06, l_2 6.3e-06): 4it [00:00, 45.42it/s, t=0.23, rel change=8.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 743.96it/s]
#
# Solving gel with FISTA (l_1 2.1e-06, l_2 5e-06): 3it [00:00, 35.83it/s, t=0.23, rel change=8.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 747.63it/s]
#
# Solving gel with FISTA (l_1 1.7e-06, l_2 3.9e-06): 3it [00:00, 39.21it/s, t=0.26, rel change=7.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 737.06it/s]
#
# Solving gel with FISTA (l_1 1.3e-06, l_2 3.1e-06): 2it [00:00, 24.27it/s, t=0.22, rel change=8.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 755.91it/s]
#
# Solving gel with FISTA (l_1 0.13, l_2 0.13): 3000it [00:08, 337.84it/s, t=0.68, rel change=0.032]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 9614.89it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 0.11): 28it [00:00, 170.27it/s, t=0.22, rel change=7.7e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3575.31it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 0.083): 32it [00:00, 177.25it/s, t=0.18, rel change=9.2e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 3466.88it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 0.066): 35it [00:00, 250.43it/s, t=0.22, rel change=7.5e-06]
# Support size: 30
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 4655.01it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 0.052): 40it [00:00, 206.48it/s, t=0.13, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 753.62it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 0.041): 44it [00:00, 180.40it/s, t=0.16, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 753.41it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 0.033): 58it [00:00, 144.97it/s, t=0.016, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 736.38it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 0.026): 49it [00:00, 165.91it/s, t=0.079, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 732.81it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 0.02): 52it [00:00, 151.86it/s, t=0.029, rel change=8.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 758.91it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 0.016): 49it [00:00, 132.61it/s, t=0.014, rel change=8.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 738.00it/s]
#
# Solving gel with FISTA (l_1 0.013, l_2 0.013): 47it [00:00, 132.78it/s, t=0.0062, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 740.98it/s]
#
# Solving gel with FISTA (l_1 0.01, l_2 0.01): 81it [00:00, 184.10it/s, t=0.0083, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 790.43it/s]
#
# Solving gel with FISTA (l_1 0.0079, l_2 0.0079): 78it [00:00, 124.68it/s, t=0.00053, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 739.23it/s]
#
# Solving gel with FISTA (l_1 0.0063, l_2 0.0063): 74it [00:00, 148.21it/s, t=0.008, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 761.37it/s]
#
# Solving gel with FISTA (l_1 0.005, l_2 0.005): 75it [00:00, 121.53it/s, t=0.00055, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 730.67it/s]
#
# Solving gel with FISTA (l_1 0.0039, l_2 0.0039): 82it [00:00, 141.94it/s, t=0.0022, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 737.68it/s]
#
# Solving gel with FISTA (l_1 0.0031, l_2 0.0031): 65it [00:00, 126.09it/s, t=0.0027, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 761.64it/s]
#
# Solving gel with FISTA (l_1 0.0025, l_2 0.0025): 67it [00:00, 149.59it/s, t=0.013, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 738.61it/s]
#
# Solving gel with FISTA (l_1 0.0019, l_2 0.0019): 67it [00:00, 107.14it/s, t=0.00029, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 754.36it/s]
#
# Solving gel with FISTA (l_1 0.0015, l_2 0.0015): 52it [00:00, 98.09it/s, t=0.00069, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 758.39it/s]
#
# Solving gel with FISTA (l_1 0.0012, l_2 0.0012): 75it [00:00, 124.63it/s, t=0.00089, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 764.41it/s]
#
# Solving gel with FISTA (l_1 0.00096, l_2 0.00096): 65it [00:00, 122.72it/s, t=0.0019, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 758.90it/s]
#
# Solving gel with FISTA (l_1 0.00076, l_2 0.00076): 62it [00:00, 115.33it/s, t=0.0012, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 674.88it/s]
#
# Solving gel with FISTA (l_1 0.0006, l_2 0.0006): 59it [00:00, 102.40it/s, t=0.00098, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 832.79it/s]
#
# Solving gel with FISTA (l_1 0.00047, l_2 0.00047): 26it [00:00, 61.61it/s, t=0.00068, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 816.54it/s]
#
# Solving gel with FISTA (l_1 0.00037, l_2 0.00037): 32it [00:00, 110.06it/s, t=0.008, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 736.96it/s]
#
# Solving gel with FISTA (l_1 0.0003, l_2 0.0003): 23it [00:00, 49.84it/s, t=0.0019, rel change=8.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 708.43it/s]
#
# Solving gel with FISTA (l_1 0.00023, l_2 0.00023): 32it [00:00, 67.90it/s, t=0.0025, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 705.59it/s]
#
# Solving gel with FISTA (l_1 0.00019, l_2 0.00019): 30it [00:00, 76.73it/s, t=0.012, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 724.62it/s]
#
# Solving gel with FISTA (l_1 0.00015, l_2 0.00015): 32it [00:00, 73.56it/s, t=0.008, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 700.33it/s]
#
# Solving gel with FISTA (l_1 0.00012, l_2 0.00012): 26it [00:00, 92.38it/s, t=0.067, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 709.26it/s]
#
# Solving gel with FISTA (l_1 9.2e-05, l_2 9.2e-05): 16it [00:00, 79.22it/s, t=0.13, rel change=8.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 724.33it/s]
#
# Solving gel with FISTA (l_1 7.2e-05, l_2 7.2e-05): 15it [00:00, 67.54it/s, t=0.13, rel change=8.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 729.56it/s]
#
# Solving gel with FISTA (l_1 5.7e-05, l_2 5.7e-05): 14it [00:00, 73.29it/s, t=0.18, rel change=8.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 727.43it/s]
#
# Solving gel with FISTA (l_1 4.5e-05, l_2 4.5e-05): 13it [00:00, 64.53it/s, t=0.15, rel change=9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 735.69it/s]
#
# Solving gel with FISTA (l_1 3.6e-05, l_2 3.6e-05): 12it [00:00, 58.43it/s, t=0.12, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 696.97it/s]
#
# Solving gel with FISTA (l_1 2.8e-05, l_2 2.8e-05): 11it [00:00, 31.77it/s, t=0.0095, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 720.57it/s]
#
# Solving gel with FISTA (l_1 2.2e-05, l_2 2.2e-05): 11it [00:00, 62.29it/s, t=0.19, rel change=8.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 740.37it/s]
#
# Solving gel with FISTA (l_1 1.8e-05, l_2 1.8e-05): 9it [00:00, 46.68it/s, t=0.12, rel change=9.3e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 703.69it/s]
#
# Solving gel with FISTA (l_1 1.4e-05, l_2 1.4e-05): 9it [00:00, 51.94it/s, t=0.15, rel change=8.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 703.85it/s]
#
# Solving gel with FISTA (l_1 1.1e-05, l_2 1.1e-05): 8it [00:00, 49.76it/s, t=0.19, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 720.52it/s]
#
# Solving gel with FISTA (l_1 8.7e-06, l_2 8.7e-06): 7it [00:00, 47.44it/s, t=0.21, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 696.42it/s]
#
# Solving gel with FISTA (l_1 6.9e-06, l_2 6.9e-06): 6it [00:00, 31.46it/s, t=0.11, rel change=7.3e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 696.39it/s]
#
# Solving gel with FISTA (l_1 5.5e-06, l_2 5.5e-06): 4it [00:00, 27.77it/s, t=0.19, rel change=8.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 737.52it/s]
#
# Solving gel with FISTA (l_1 4.3e-06, l_2 4.3e-06): 4it [00:00, 31.04it/s, t=0.23, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 733.43it/s]
#
# Solving gel with FISTA (l_1 3.4e-06, l_2 3.4e-06): 3it [00:00, 23.64it/s, t=0.23, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 735.52it/s]
#
# Solving gel with FISTA (l_1 2.7e-06, l_2 2.7e-06): 3it [00:00, 23.50it/s, t=0.22, rel change=7.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 733.96it/s]
#
# Solving gel with FISTA (l_1 2.1e-06, l_2 2.1e-06): 2it [00:00, 16.03it/s, t=0.22, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 728.37it/s]
#
# Solving gel with FISTA (l_1 1.7e-06, l_2 1.7e-06): 2it [00:00, 15.75it/s, t=0.21, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 733.84it/s]
#
# Solving gel with FISTA (l_1 1.3e-06, l_2 1.3e-06): 2it [00:00, 15.30it/s, t=0.2, rel change=8.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 707.94it/s]
#
# Solving gel with FISTA (l_1 0.13, l_2 0.057): 169it [00:01, 168.48it/s, t=0.046, rel change=9.8e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5332.19it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 0.045): 38it [00:00, 128.16it/s, t=0.088, rel change=8e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 2888.84it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 0.036): 36it [00:00, 137.73it/s, t=0.19, rel change=9.5e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 4918.45it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 0.028): 42it [00:00, 171.65it/s, t=0.08, rel change=8.6e-06]
# Support size: 230
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 697.54it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 0.022): 44it [00:00, 173.30it/s, t=0.1, rel change=9.2e-06]
# Support size: 235
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 712.19it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 0.018): 46it [00:00, 150.14it/s, t=0.15, rel change=8.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 771.43it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 0.014): 60it [00:00, 131.41it/s, t=0.05, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 703.80it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 0.011): 61it [00:00, 160.65it/s, t=0.0054, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 781.70it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 0.0087): 66it [00:00, 124.24it/s, t=0.001, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 785.61it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 0.0069): 55it [00:00, 114.08it/s, t=0.002, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 801.70it/s]
#
# Solving gel with FISTA (l_1 0.013, l_2 0.0054): 73it [00:00, 176.28it/s, t=0.0052, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 795.39it/s]
#
# Solving gel with FISTA (l_1 0.01, l_2 0.0043): 72it [00:00, 111.83it/s, t=5.3e-05, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 716.43it/s]
#
# Solving gel with FISTA (l_1 0.0079, l_2 0.0034): 82it [00:00, 182.75it/s, t=0.0065, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 772.55it/s]
#
# Solving gel with FISTA (l_1 0.0063, l_2 0.0027): 92it [00:00, 144.87it/s, t=0.002, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 783.08it/s]
#
# Solving gel with FISTA (l_1 0.005, l_2 0.0021): 65it [00:00, 166.66it/s, t=0.0079, rel change=9.3e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 787.15it/s]
#
# Solving gel with FISTA (l_1 0.0039, l_2 0.0017): 67it [00:00, 135.03it/s, t=0.0044, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 756.70it/s]
#
# Solving gel with FISTA (l_1 0.0031, l_2 0.0013): 73it [00:00, 116.88it/s, t=0.00014, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 761.42it/s]
#
# Solving gel with FISTA (l_1 0.0025, l_2 0.0011): 63it [00:00, 134.26it/s, t=0.00049, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 799.85it/s]
#
# Solving gel with FISTA (l_1 0.0019, l_2 0.00083): 65it [00:00, 147.18it/s, t=0.0012, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 761.27it/s]
#
# Solving gel with FISTA (l_1 0.0015, l_2 0.00066): 48it [00:00, 102.79it/s, t=0.0014, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 787.14it/s]
#
# Solving gel with FISTA (l_1 0.0012, l_2 0.00052): 51it [00:00, 131.68it/s, t=0.0012, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 790.19it/s]
#
# Solving gel with FISTA (l_1 0.00096, l_2 0.00041): 46it [00:00, 127.05it/s, t=0.0028, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 747.22it/s]
#
# Solving gel with FISTA (l_1 0.00076, l_2 0.00032): 29it [00:00, 82.49it/s, t=0.00041, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 847.34it/s]
#
# Solving gel with FISTA (l_1 0.0006, l_2 0.00026): 41it [00:00, 109.07it/s, t=0.001, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 774.14it/s]
#
# Solving gel with FISTA (l_1 0.00047, l_2 0.0002): 41it [00:00, 138.36it/s, t=0.01, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 801.37it/s]
#
# Solving gel with FISTA (l_1 0.00037, l_2 0.00016): 50it [00:00, 145.39it/s, t=0.0062, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 764.49it/s]
#
# Solving gel with FISTA (l_1 0.0003, l_2 0.00013): 19it [00:00, 94.76it/s, t=0.014, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 782.92it/s]
#
# Solving gel with FISTA (l_1 0.00023, l_2 0.0001): 28it [00:00, 142.03it/s, t=0.04, rel change=9.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 779.97it/s]
#
# Solving gel with FISTA (l_1 0.00019, l_2 7.9e-05): 17it [00:00, 63.74it/s, t=0.018, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 585.72it/s]
#
# Solving gel with FISTA (l_1 0.00015, l_2 6.3e-05): 17it [00:00, 44.95it/s, t=0.0015, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 735.60it/s]
#
# Solving gel with FISTA (l_1 0.00012, l_2 5e-05): 15it [00:00, 78.55it/s, t=0.06, rel change=8.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 726.55it/s]
#
# Solving gel with FISTA (l_1 9.2e-05, l_2 3.9e-05): 14it [00:00, 94.70it/s, t=0.14, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.58it/s]
#
# Solving gel with FISTA (l_1 7.2e-05, l_2 3.1e-05): 13it [00:00, 94.78it/s, t=0.16, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 754.24it/s]
#
# Solving gel with FISTA (l_1 5.7e-05, l_2 2.5e-05): 13it [00:00, 96.52it/s, t=0.18, rel change=8.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 730.29it/s]
#
# Solving gel with FISTA (l_1 4.5e-05, l_2 1.9e-05): 12it [00:00, 89.81it/s, t=0.18, rel change=9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 745.50it/s]
#
# Solving gel with FISTA (l_1 3.6e-05, l_2 1.5e-05): 11it [00:00, 77.14it/s, t=0.13, rel change=9.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 687.96it/s]
#
# Solving gel with FISTA (l_1 2.8e-05, l_2 1.2e-05): 11it [00:00, 82.29it/s, t=0.18, rel change=8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 720.03it/s]
#
# Solving gel with FISTA (l_1 2.2e-05, l_2 9.6e-06): 9it [00:00, 49.31it/s, t=0.14, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 716.83it/s]
#
# Solving gel with FISTA (l_1 1.8e-05, l_2 7.6e-06): 9it [00:00, 61.56it/s, t=0.19, rel change=8.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 709.70it/s]
#
# Solving gel with FISTA (l_1 1.4e-05, l_2 6e-06): 7it [00:00, 48.79it/s, t=0.2, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 733.30it/s]
#
# Solving gel with FISTA (l_1 1.1e-05, l_2 4.7e-06): 7it [00:00, 48.51it/s, t=0.22, rel change=9.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 718.74it/s]
#
# Solving gel with FISTA (l_1 8.7e-06, l_2 3.7e-06): 4it [00:00, 30.37it/s, t=0.22, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 729.74it/s]
#
# Solving gel with FISTA (l_1 6.9e-06, l_2 3e-06): 5it [00:00, 35.28it/s, t=0.2, rel change=8.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 729.54it/s]
#
# Solving gel with FISTA (l_1 5.5e-06, l_2 2.3e-06): 4it [00:00, 32.09it/s, t=0.24, rel change=8.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 703.77it/s]
#
# Solving gel with FISTA (l_1 4.3e-06, l_2 1.8e-06): 3it [00:00, 25.03it/s, t=0.25, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 720.33it/s]
#
# Solving gel with FISTA (l_1 3.4e-06, l_2 1.5e-06): 3it [00:00, 23.63it/s, t=0.22, rel change=6.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 701.30it/s]
#
# Solving gel with FISTA (l_1 2.7e-06, l_2 1.2e-06): 2it [00:00, 18.93it/s, t=0.22, rel change=8.5e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 730.67it/s]
#
# Solving gel with FISTA (l_1 2.1e-06, l_2 9.1e-07): 2it [00:00, 15.82it/s, t=0.21, rel change=8.2e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 707.58it/s]
#
# Solving gel with FISTA (l_1 1.7e-06, l_2 7.2e-07): 2it [00:00, 15.44it/s, t=0.2, rel change=7.7e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.58it/s]
#
# Solving gel with FISTA (l_1 1.3e-06, l_2 5.7e-07): 2it [00:00, 23.39it/s, t=0.2, rel change=6.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.18it/s]
#
# Solving gel with FISTA (l_1 0.13, l_2 0.015): 41it [00:00, 144.12it/s, t=0.046, rel change=9.3e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 12912.70it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 0.012): 43it [00:00, 193.76it/s, t=0.21, rel change=3.1e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5269.76it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 0.0093): 34it [00:00, 177.41it/s, t=0.22, rel change=8.6e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5301.66it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 0.0073): 51it [00:00, 168.58it/s, t=0.073, rel change=8.1e-06]
# Support size: 230
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 760.65it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 0.0058): 86it [00:00, 176.41it/s, t=0.019, rel change=9.3e-06]
# Support size: 235
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 754.26it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 0.0046): 97it [00:00, 154.99it/s, t=0.0025, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 707.05it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 0.0036): 95it [00:00, 167.67it/s, t=0.0072, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 743.10it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 0.0029): 66it [00:00, 132.21it/s, t=0.0035, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 754.88it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 0.0023): 82it [00:00, 126.87it/s, t=0.00057, rel change=9.9e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 743.41it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 0.0018): 81it [00:00, 132.05it/s, t=0.0011, rel change=9.6e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 746.79it/s]
#
# Solving gel with FISTA (l_1 0.013, l_2 0.0014): 105it [00:00, 140.08it/s, t=0.00032, rel change=9.8e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 736.98it/s]
#
# Solving gel with FISTA (l_1 0.01, l_2 0.0011): 73it [00:00, 113.54it/s, t=0.00038, rel change=1e-05]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 728.90it/s]
#
# Solving gel with FISTA (l_1 0.0079, l_2 0.00088): 59it [00:00, 133.64it/s, t=0.0074, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 751.60it/s]
#
# Solving gel with FISTA (l_1 0.0063, l_2 0.0007): 88it [00:00, 123.78it/s, t=0.0002, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 744.14it/s]
#
# Solving gel with FISTA (l_1 0.005, l_2 0.00055): 81it [00:00, 130.56it/s, t=0.00083, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.23it/s]
#
# Solving gel with FISTA (l_1 0.0039, l_2 0.00044): 74it [00:00, 116.73it/s, t=0.00036, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 770.87it/s]
#
# Solving gel with FISTA (l_1 0.0031, l_2 0.00035): 93it [00:00, 152.24it/s, t=0.0025, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 733.24it/s]
#
# Solving gel with FISTA (l_1 0.0025, l_2 0.00027): 87it [00:00, 160.32it/s, t=0.0027, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 746.21it/s]
#
# Solving gel with FISTA (l_1 0.0019, l_2 0.00022): 63it [00:00, 128.78it/s, t=0.00091, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.24it/s]
#
# Solving gel with FISTA (l_1 0.0015, l_2 0.00017): 52it [00:00, 140.87it/s, t=0.0013, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 792.86it/s]
#
# Solving gel with FISTA (l_1 0.0012, l_2 0.00013): 60it [00:00, 128.50it/s, t=0.0012, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 722.36it/s]
#
# Solving gel with FISTA (l_1 0.00096, l_2 0.00011): 51it [00:00, 92.83it/s, t=0.00014, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 771.85it/s]
#
# Solving gel with FISTA (l_1 0.00076, l_2 8.4e-05): 62it [00:00, 143.52it/s, t=0.0025, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 777.97it/s]
#
# Solving gel with FISTA (l_1 0.0006, l_2 6.7e-05): 62it [00:00, 161.81it/s, t=0.0083, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 683.10it/s]
#
# Solving gel with FISTA (l_1 0.00047, l_2 5.3e-05): 26it [00:00, 88.71it/s, t=0.0084, rel change=9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 747.76it/s]
#
# Solving gel with FISTA (l_1 0.00037, l_2 4.2e-05): 25it [00:00, 109.77it/s, t=0.026, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 654.33it/s]
#
# Solving gel with FISTA (l_1 0.0003, l_2 3.3e-05): 25it [00:00, 120.80it/s, t=0.036, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 642.86it/s]
#
# Solving gel with FISTA (l_1 0.00023, l_2 2.6e-05): 19it [00:00, 100.69it/s, t=0.046, rel change=1e-05]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 818.49it/s]
#
# Solving gel with FISTA (l_1 0.00019, l_2 2.1e-05): 16it [00:00, 71.88it/s, t=0.049, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 838.70it/s]
#
# Solving gel with FISTA (l_1 0.00015, l_2 1.6e-05): 15it [00:00, 83.47it/s, t=0.17, rel change=1e-05]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 804.65it/s]
#
# Solving gel with FISTA (l_1 0.00012, l_2 1.3e-05): 14it [00:00, 68.84it/s, t=0.12, rel change=9.5e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 730.49it/s]
#
# Solving gel with FISTA (l_1 9.2e-05, l_2 1e-05): 14it [00:00, 62.64it/s, t=0.044, rel change=8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 842.14it/s]
#
# Solving gel with FISTA (l_1 7.2e-05, l_2 8e-06): 13it [00:00, 74.23it/s, t=0.1, rel change=8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 714.55it/s]
#
# Solving gel with FISTA (l_1 5.7e-05, l_2 6.4e-06): 12it [00:00, 96.88it/s, t=0.15, rel change=8.5e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 698.05it/s]
#
# Solving gel with FISTA (l_1 4.5e-05, l_2 5e-06): 11it [00:00, 90.40it/s, t=0.14, rel change=8.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 768.78it/s]
#
# Solving gel with FISTA (l_1 3.6e-05, l_2 4e-06): 10it [00:00, 82.13it/s, t=0.14, rel change=9.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 680.84it/s]
#
# Solving gel with FISTA (l_1 2.8e-05, l_2 3.1e-06): 9it [00:00, 52.64it/s, t=0.18, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 714.57it/s]
#
# Solving gel with FISTA (l_1 2.2e-05, l_2 2.5e-06): 9it [00:00, 46.87it/s, t=0.13, rel change=7.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.50it/s]
#
# Solving gel with FISTA (l_1 1.8e-05, l_2 2e-06): 7it [00:00, 32.19it/s, t=0.085, rel change=7.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 776.56it/s]
#
# Solving gel with FISTA (l_1 1.4e-05, l_2 1.6e-06): 6it [00:00, 80.45it/s, t=0.17, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 757.18it/s]
#
# Solving gel with FISTA (l_1 1.1e-05, l_2 1.2e-06): 6it [00:00, 42.32it/s, t=0.22, rel change=9.2e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 732.63it/s]
#
# Solving gel with FISTA (l_1 8.7e-06, l_2 9.7e-07): 4it [00:00, 28.02it/s, t=0.19, rel change=8.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 439.52it/s]
#
# Solving gel with FISTA (l_1 6.9e-06, l_2 7.7e-07): 3it [00:00, 23.81it/s, t=0.22, rel change=9.5e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 718.01it/s]
#
# Solving gel with FISTA (l_1 5.5e-06, l_2 6.1e-07): 3it [00:00, 24.04it/s, t=0.22, rel change=8.3e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 738.49it/s]
#
# Solving gel with FISTA (l_1 4.3e-06, l_2 4.8e-07): 3it [00:00, 23.23it/s, t=0.21, rel change=7.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 709.67it/s]
#
# Solving gel with FISTA (l_1 3.4e-06, l_2 3.8e-07): 2it [00:00, 15.50it/s, t=0.2, rel change=8.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 735.20it/s]
#
# Solving gel with FISTA (l_1 2.7e-06, l_2 3e-07): 2it [00:00, 15.79it/s, t=0.2, rel change=8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 731.54it/s]
#
# Solving gel with FISTA (l_1 2.1e-06, l_2 2.4e-07): 2it [00:00, 15.75it/s, t=0.21, rel change=6.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 729.29it/s]
#
# Solving gel with FISTA (l_1 1.7e-06, l_2 1.9e-07): 2it [00:00, 15.60it/s, t=0.2, rel change=5.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 746.03it/s]
#
# Solving gel with FISTA (l_1 1.3e-06, l_2 1.5e-07): 2it [00:00, 17.09it/s, t=0.21, rel change=5.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 728.64it/s]
#
# Solving gel with FISTA (l_1 0.13, l_2 0.0013): 351it [00:01, 310.58it/s, t=0.046, rel change=9.9e-06]
# Support size: 0
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 10531.31it/s]
#
# Solving gel with FISTA (l_1 0.11, l_2 0.0011): 39it [00:00, 207.83it/s, t=0.21, rel change=5e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 4607.66it/s]
#
# Solving gel with FISTA (l_1 0.083, l_2 0.00084): 54it [00:00, 229.02it/s, t=0.15, rel change=9.5e-06]
# Support size: 10
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 5217.90it/s]
#
# Solving gel with FISTA (l_1 0.066, l_2 0.00067): 70it [00:00, 187.72it/s, t=0.026, rel change=9.5e-06]
# Support size: 210
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 756.50it/s]
#
# Solving gel with FISTA (l_1 0.052, l_2 0.00053): 92it [00:00, 187.87it/s, t=0.037, rel change=9.8e-06]
# Support size: 235
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 725.37it/s]
#
# Solving gel with FISTA (l_1 0.041, l_2 0.00042): 75it [00:00, 178.60it/s, t=0.0045, rel change=9.8e-06]
# Support size: 235
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 777.08it/s]
#
# Solving gel with FISTA (l_1 0.033, l_2 0.00033): 78it [00:00, 173.45it/s, t=0.0034, rel change=9.4e-06]
# Support size: 255
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 764.56it/s]
#
# Solving gel with FISTA (l_1 0.026, l_2 0.00026): 112it [00:00, 153.47it/s, t=0.00079, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 762.90it/s]
#
# Solving gel with FISTA (l_1 0.02, l_2 0.00021): 90it [00:00, 125.96it/s, t=0.00024, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 765.23it/s]
#
# Solving gel with FISTA (l_1 0.016, l_2 0.00016): 68it [00:00, 168.46it/s, t=0.031, rel change=8.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 837.32it/s]
#
# Solving gel with FISTA (l_1 0.013, l_2 0.00013): 107it [00:00, 172.61it/s, t=0.00065, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 749.27it/s]
#
# Solving gel with FISTA (l_1 0.01, l_2 0.0001): 73it [00:00, 134.15it/s, t=0.00019, rel change=1e-05]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 736.84it/s]
#
# Solving gel with FISTA (l_1 0.0079, l_2 8e-05): 67it [00:00, 122.41it/s, t=0.0013, rel change=1e-05]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 679.02it/s]
#
# Solving gel with FISTA (l_1 0.0063, l_2 6.3e-05): 94it [00:00, 129.68it/s, t=7.7e-05, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 777.46it/s]
#
# Solving gel with FISTA (l_1 0.005, l_2 5e-05): 71it [00:00, 124.59it/s, t=0.00013, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 754.13it/s]
#
# Solving gel with FISTA (l_1 0.0039, l_2 4e-05): 92it [00:00, 132.75it/s, t=0.00024, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 752.64it/s]
#
# Solving gel with FISTA (l_1 0.0031, l_2 3.1e-05): 94it [00:00, 160.09it/s, t=0.00052, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 746.32it/s]
#
# Solving gel with FISTA (l_1 0.0025, l_2 2.5e-05): 78it [00:00, 99.15it/s, t=0.00098, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 753.48it/s]
#
# Solving gel with FISTA (l_1 0.0019, l_2 2e-05): 71it [00:00, 140.38it/s, t=0.00065, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 739.21it/s]
#
# Solving gel with FISTA (l_1 0.0015, l_2 1.5e-05): 51it [00:00, 119.46it/s, t=0.00075, rel change=1e-05]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 791.66it/s]
#
# Solving gel with FISTA (l_1 0.0012, l_2 1.2e-05): 45it [00:00, 92.69it/s, t=0.0014, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 755.67it/s]
#
# Solving gel with FISTA (l_1 0.00096, l_2 9.7e-06): 42it [00:00, 99.25it/s, t=0.00032, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 755.84it/s]
#
# Solving gel with FISTA (l_1 0.00076, l_2 7.7e-06): 47it [00:00, 102.51it/s, t=0.0021, rel change=9.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 773.68it/s]
#
# Solving gel with FISTA (l_1 0.0006, l_2 6.1e-06): 37it [00:00, 106.09it/s, t=0.0033, rel change=9.6e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 744.64it/s]
#
# Solving gel with FISTA (l_1 0.00047, l_2 4.8e-06): 33it [00:00, 74.89it/s, t=0.0015, rel change=9.5e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 756.79it/s]
#
# Solving gel with FISTA (l_1 0.00037, l_2 3.8e-06): 41it [00:00, 95.94it/s, t=0.0094, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 734.63it/s]
#
# Solving gel with FISTA (l_1 0.0003, l_2 3e-06): 30it [00:00, 150.94it/s, t=0.053, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 791.53it/s]
#
# Solving gel with FISTA (l_1 0.00023, l_2 2.4e-06): 40it [00:00, 94.53it/s, t=0.0076, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 736.21it/s]
#
# Solving gel with FISTA (l_1 0.00019, l_2 1.9e-06): 17it [00:00, 111.43it/s, t=0.073, rel change=9.2e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 783.07it/s]
#
# Solving gel with FISTA (l_1 0.00015, l_2 1.5e-06): 25it [00:00, 61.64it/s, t=0.0048, rel change=9.2e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 779.10it/s]
#
# Solving gel with FISTA (l_1 0.00012, l_2 1.2e-06): 14it [00:00, 85.96it/s, t=0.039, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 802.30it/s]
#
# Solving gel with FISTA (l_1 9.2e-05, l_2 9.2e-07): 14it [00:00, 36.70it/s, t=0.0061, rel change=8.1e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 778.10it/s]
#
# Solving gel with FISTA (l_1 7.2e-05, l_2 7.3e-07): 13it [00:00, 71.24it/s, t=0.19, rel change=8.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 694.08it/s]
#
# Solving gel with FISTA (l_1 5.7e-05, l_2 5.8e-07): 12it [00:00, 107.29it/s, t=0.13, rel change=8.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 803.23it/s]
#
# Solving gel with FISTA (l_1 4.5e-05, l_2 4.6e-07): 11it [00:00, 62.75it/s, t=0.14, rel change=8.5e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 783.29it/s]
#
# Solving gel with FISTA (l_1 3.6e-05, l_2 3.6e-07): 10it [00:00, 106.41it/s, t=0.16, rel change=8.6e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 767.11it/s]
#
# Solving gel with FISTA (l_1 2.8e-05, l_2 2.9e-07): 9it [00:00, 53.29it/s, t=0.18, rel change=9.3e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 739.79it/s]
#
# Solving gel with FISTA (l_1 2.2e-05, l_2 2.3e-07): 8it [00:00, 54.07it/s, t=0.22, rel change=9.7e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 744.92it/s]
#
# Solving gel with FISTA (l_1 1.8e-05, l_2 1.8e-07): 6it [00:00, 35.49it/s, t=0.15, rel change=9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 730.14it/s]
#
# Solving gel with FISTA (l_1 1.4e-05, l_2 1.4e-07): 6it [00:00, 40.69it/s, t=0.21, rel change=1e-05]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 756.57it/s]
#
# Solving gel with FISTA (l_1 1.1e-05, l_2 1.1e-07): 4it [00:00, 31.26it/s, t=0.21, rel change=9.8e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 742.27it/s]
#
# Solving gel with FISTA (l_1 8.7e-06, l_2 8.8e-08): 5it [00:00, 38.13it/s, t=0.22, rel change=9.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 806.52it/s]
#
# Solving gel with FISTA (l_1 6.9e-06, l_2 7e-08): 3it [00:00, 53.67it/s, t=0.26, rel change=9.2e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 759.39it/s]
#
# Solving gel with FISTA (l_1 5.5e-06, l_2 5.5e-08): 2it [00:00, 14.83it/s, t=0.2, rel change=9.9e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 679.62it/s]
#
# Solving gel with FISTA (l_1 4.3e-06, l_2 4.4e-08): 3it [00:00, 32.51it/s, t=0.2, rel change=6.3e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 760.04it/s]
#
# Solving gel with FISTA (l_1 3.4e-06, l_2 3.4e-08): 2it [00:00, 24.58it/s, t=0.21, rel change=8.6e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 775.13it/s]
#
# Solving gel with FISTA (l_1 2.7e-06, l_2 2.7e-08): 2it [00:00, 24.38it/s, t=0.21, rel change=7.4e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 776.07it/s]
#
# Solving gel with FISTA (l_1 2.1e-06, l_2 2.2e-08): 2it [00:00, 25.01it/s, t=0.22, rel change=6.5e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 756.93it/s]
#
# Solving gel with FISTA (l_1 1.7e-06, l_2 1.7e-08): 2it [00:00, 24.59it/s, t=0.23, rel change=6e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 765.37it/s]
#
# Solving gel with FISTA (l_1 1.3e-06, l_2 1.3e-08): 2it [00:00, 25.83it/s, t=0.23, rel change=5.1e-06]
# Support size: 245
# Solving ridge regressions: 100%|██████████| 100/100 [00:00<00:00, 712.44it/s]

# %% [markdown]
# Let us analyze the results.

# %%
best_summ = min(summaries.items(), key=lambda z: z[1][1])
print(best_summ)
# Out:
# ((0.006283248122781515, 0.0006981386803090571, 0.019179102033376694), ([0, 1, 1, 1, 0, 1], 126.50753021240234))

# %%
best_support_hat = best_summ[1][0]
print(best_support_hat)
# Out:
# [0, 1, 1, 1, 0, 1]

# %% [markdown]
# We were able to correctly identify the support! Now, we can perform a more thorough ridge regression on the identified support. For this we will use the `ridgepaths` module.

# %%
X_tr_best_supp_hat = torch.cat(
    [A_j for A_j, s_j in zip(A_tr_stans, best_support_hat) if s_j == 1],
    dim=1,
).t()

X_val_best_supp_hat = torch.cat(
    [A_j for A_j, s_j in zip(A_val_stans, best_support_hat) if s_j == 1],
    dim=1,
).t()

def summary_best_supp_hat(support, b):
    # support is ignored
    yhat_val = (X_val_best_supp_hat.t() @ b) * y_tr_σ + y_tr_μ
    rmse = ((y_val - yhat_val) ** 2).mean().sqrt().item()
    return rmse

# %%
from gel.ridgepaths import ridge_paths

l_rs_big = torch.logspace(-20, 20, 10000).tolist()

ridge_summaries = ridge_paths(
    X_tr_best_supp_hat,  # X needs to be pre-indexed using the support
    y_tr_stan,
    1,                   # this doesn't matter in this case since it is ignored; just shouldn't be None
    l_rs_big,
    summary_best_supp_hat,
    verbose=True,
)
# Out:
# Solving ridge regressions: 100%|██████████| 10000/10000 [00:01<00:00, 8660.86it/s]

# %%
best_ridge_summ = min(ridge_summaries.items(), key=lambda z: z[1])
print(best_ridge_summ)
# Out:
# (0.007075953762978315, 126.38697052001953)

# %% [markdown]
# The validation RMSE doesn't change much, but the identified best lambda value _has_ changed. So now, using the identified support and ridge regularization value, we can train a final ridge regression model using the training and validation data combined to further increase performance. This can be tested using a separate test set if available.

# %%
def dummy_summary(support, b):
    # Just return b
    return b

# %%
# Combine training and validation data.
A_trvals = [torch.cat([A_j_tr, A_j_val], dim=0) for A_j_tr, A_j_val in zip(A_trs, A_vals)]
y_trval = torch.cat([y_tr, y_val])

# Compute combined statistics.
A_trval_μs = [A_j.mean(dim=0, keepdim=True) for A_j in A_trvals]
A_trval_σs = [A_j.std(dim=0, keepdim=True) for A_j in A_trvals]
y_trval_μ = y_trval.mean().item()
y_trval_σ = y_trval.std().item()

# Standardize data using combined statistics.
A_trval_stans = [(A_j - A_j_μ) / A_j_σ for A_j, A_j_μ, A_j_σ in zip(A_trvals, A_trval_μs, A_trval_σs)]
y_trval_stan = (y_trval - y_trval_μ) / y_trval_σ

# Project to support.
X_trval_best_supp_hat = torch.cat([
    A_j_trval
    for A_j_trval, s_j in zip(A_trval_stans, best_support_hat)
    if s_j == 1
], dim=1).t()
print(X_trval_best_supp_hat.shape)
# Out:
# torch.Size([245, 130])

# %%
best_lambda = best_ridge_summ[0]
final_summary = ridge_paths(
    X_trval_best_supp_hat,
    y_trval_stan,
    1,
    [best_lambda],
    dummy_summary,
)
final_b = final_summary[best_lambda]

# %% [markdown]
# Here, since we know the true β, we can evaluate by comparing to it. We will assume knowledge of the fact that all features have the same normal distribution, and compute how well we estimate its parameters.

# %%
from math import sqrt

X_trval = torch.cat(A_trvals, dim=1)
X_bias_hat = X_trval.mean().item()
X_scale_hat = X_trval.std().item()

supplen = sum(n_j for n_j, s_j in zip(ns, best_support_hat) if s_j == 1)
β_bias_hat = y_trval_μ / (X_bias_hat * supplen)
β_scale_hat = sqrt((((y_trval_σ ** 2) / supplen) - (β_bias_hat * X_scale_hat) ** 2) / ((X_bias_hat ** 2) + (X_scale_hat ** 2)))

# %%
X_scale_hat, X_bias_hat  # true values (2, 3)
# Out:
# (2.011165142059326, 2.9753780364990234)

# %%
β_scale_hat, β_bias_hat  # true values (0.125, 6)
# Out:
# (1.2438122893823327, 5.436703976089316)

# %% [markdown]
# We are able to estimate the parameters reasonably well, with most of the error in the scale parameter. And it should be noted again, that we did perfectly recover the support. To conclude, we compute the error on the combined training validation data.

# %%
yhat_trval = y_trval_σ * (X_trval_best_supp_hat.t() @ final_b) + y_trval_μ
rmse = ((yhat_trval - y_trval) ** 2).mean().sqrt().item()
print(rmse)
# Out:
# 13.222792625427246
