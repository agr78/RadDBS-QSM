# %%
# Preliminary data notebook for
# NIH: Imaging Guided Intervention Surgery Study Section

# Exploratory aim: evaluate presurgical scans between STN and GPi targets
#   Given retrospective GPi acquisitions?
#   Search for radiomic differentiators for STN versus GPi selection in presurgical scans

# %%
# Import libraries
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNetCV
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle

# %matplotlib widget

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2
rextract = 0
# Load data
# fig, ax = plt.subplots(2,5)
segs = []
qsms = []
voxel_sizes = []
trackers = []
directory = 'F:\dbs\stn-dbs\Cornell_anonymized'
case_list = []
for filename in os.listdir(directory):
    f = os.path.join(directory,filename)
    print(f)
 
    seg = nib.load(f+'/Rh Mri Brain With Without Contrast/seg.nii.gz')
                
    voxel_size = seg.header['pixdim'][0:3]
    voxel_sizes.append(voxel_size)
    segs.append(seg.get_fdata())

    qsm = nib.load(f+'/Rh Mri Brain With Without Contrast/qsm.nii.gz')
    qsms.append(qsm.get_fdata())
        
    case_list.append(filename)
    n_cases = len(segs)

    label_min = np.partition(np.unique(seg.get_fdata().ravel()), 1)[1]
    label_max = np.amax(seg.get_fdata())
# Out:
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 01
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 02
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 03
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 04
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 05
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 06
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 07
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 08
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 09
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 10
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 11
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 12
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 13
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 14
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 15
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 16
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 17
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 18
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 19
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 20
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 21
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 22
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 23
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 24
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 25
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 26
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 27
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 28
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 29
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 30
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 31
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 32
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 33
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 34
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 35
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 36
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 37
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 40
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 39
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 42
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 44
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 45
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 41
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 47
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 46
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 48
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 49
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 50
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 51
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 52
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 53
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 54
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 55
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 56
# F:\dbs\stn-dbs\Cornell_anonymized\Anonymized - 57

# %%
# Define feature extraction
extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.enableAllFeatures()
extractor.enableAllImageTypes()

# Generate feature structure Phi from all ROIs and all cases
if rextract == 1:
    Phi = []

    # Training cases
    for i in range(n_cases):
        seg_sitk = sitk.GetImageFromArray(segs[i])
        seg_sitk.SetSpacing(voxel_sizes[i].tolist())
        qsm_sitk = sitk.GetImageFromArray(qsms[i])
        qsm_sitk.SetSpacing(voxel_sizes[i].tolist())
        for j in range(int(label_min),int(label_max+1)):
            featureVector = extractor.execute(qsm_sitk,seg_sitk,label=j)
            Phi.append(featureVector)
    # Save feature vector
    with open('../features/Phi_57', 'wb') as fp:  
        pickle.dump(Phi, fp)

# %%
with open('../features/Phi_57', "rb") as fp:  
    Phi = pickle.load(fp)

# %%
# %%html
# <style>
# .cell-output-ipywidget-background {
#    background-color: transparent !important;
# }
# .jp-OutputArea-output {
#    background-color: transparent;
# }
# </style>
# Out:
# <style>
# .cell-output-ipywidget-background {
#    background-color: transparent !important;
# }
# .jp-OutputArea-output {
#    background-color: transparent;
# }
# </style>

# %%
# UPDRS features
subject_id = np.array((1,2,3,6,9,10,11,12,13,15,16,20,25,26,27,28,29,34,35,41,43,44,45,46,52,54))
pre_updrs_iii_off = np.array((65,22,45,63,63,27,57,42,54,67,33,27,50,77,43,31,56,81,40,28,52,32,33,18,58,63))
pre_updrs_iii_on = np.array((54,7,13,32,21,14,11,14,28,65,9,4,26,55,14,8,24,20,17,0,29,13,26,0,27,36))
post_updrs_iii_off = np.array((11,2,20,3,7,11,15,21,16,21,4,9,15,9,11,4,8,25,13,16,7,26,2,8,19,8))
per_change = (pre_updrs_iii_off-post_updrs_iii_off)/pre_updrs_iii_off
lct_change = (pre_updrs_iii_off-pre_updrs_iii_on)/(pre_updrs_iii_off)

# %%
case_id = np.repeat(subject_id,2)

# %%
n_cases = subject_id.__len__()

# %%
ut = np.zeros((subject_id.__len__()))
for j in np.arange(1,np.max(subject_id)):
    if j in subject_id:
        # Extract numeric feature values
        n_ROIs = 2
        x_row = []
        x_row_t = []
        keys = []
        per_change_train = []
        for i in range(Phi.__len__()//2+1):
            if i in subject_id:
                for ii in range(0,n_ROIs-1):
                    featureVector = Phi[i+ii]
                    for key, value in six.iteritems(featureVector):
                        if 'diagnostic' in key:
                            next
                        else:
                            try:
                                x_row.append(value.ravel())
                            except:
                                x_row.append(value)
                            keys.append(key)
                    if ii == 0 and pre_updrs_iii_off[subject_id == i].__len__()>0:
                        x_row.append((pre_updrs_iii_off[subject_id == i]))
                        x_row.append(post_updrs_iii_off[subject_id == i])
                        x_row.append(pre_updrs_iii_on[subject_id == i])
                        keys.append('pre_updrs_iii_off')
                        keys.append('post_updrs_iii_off')
                        keys.append('pre_updrs_iii_on')
                        per_change_train.append(per_change[subject_id == i])
                        
        jj = int(np.where(subject_id==j)[0])
        X0 = np.array(x_row)
        X = X0.reshape((n_cases,int(len(X0)/(n_cases))))
        X0_t = X[jj,:]
        # Remove the test case
        X = np.delete(X,jj,0)
        per_change_train = np.delete(per_change_train,jj,0)
        # Normalize testing and training cases together
        #   Set with_mean=False to preserve data sparsity
        #   And with_std=False 
        #   However, need a significant number of samples to do this
        scaler = StandardScaler()
        X_all = np.vstack((X,X0_t))
        X_all_t = scaler.fit_transform(X_all)
        X_t = X_all_t[X.shape[0]:,:]
        X = X_all_t[:X.shape[0]]

        if (sum(sum(np.isnan(X))))>0:
            print('NaN detected in feature vector')

        # Cross-validation for model selection
        cv = KFold(X.shape[0]-2)
        # Identify most important features
        # Do not assume data is centered, fit_intercept=True
        clf_in = ElasticNetCV(fit_intercept=True,cv=cv,max_iter=10000).fit(X,np.ravel(per_change_train))
        sfm = SelectFromModel(clf_in,max_features=100,threshold=min(abs(clf_in.coef_[abs(clf_in.coef_)>0])))
        # Initialize pipeline
        clf = Pipeline([('ElasticSelect',sfm),('SVR',SVR(C=0,epsilon=0,kernel='rbf'))])
        # Select the optimal number of clusters with grid search
        Cs = ((1e-1,1,10))
        epsilons = ((0.01,0.1,1))
        clf_nsvr = GridSearchCV(clf,{'SVR__C':Cs,'SVR__epsilon':epsilons},n_jobs=-1,cv=cv,scoring='neg_mean_squared_error',error_score='raise')
        clf_nsvr.fit(X,np.ravel(per_change_train))
        ut[jj] = clf_nsvr.best_estimator_.predict(X_t)
        print('Predicted percentage change of',ut[jj],'for case',j)
        print('True percentage change',per_change_train[jj])
        #print(clf_nsvr.best_estimator_.get_params('SVR__epsilon'))
        #print(clf_nsvr.best_estimator_.get_params('SVR__C'))
# Out:
# Predicted percentage change of 0.8284339504795926 for case 1
# True percentage change [0.90909091]
# Predicted percentage change of 0.682836860936603 for case 2
# True percentage change [0.55555556]
# Predicted percentage change of 0.6835988093874968 for case 3
# True percentage change [0.95238095]
# Predicted percentage change of 0.8254548194837658 for case 6
# True percentage change [0.88888889]
# Predicted percentage change of 0.7811116562203237 for case 9
# True percentage change [0.59259259]
# Predicted percentage change of 0.8379069264486496 for case 10
# True percentage change [0.73684211]
# Predicted percentage change of 0.6016437442689411 for case 11
# True percentage change [0.5]
# Predicted percentage change of 0.804636415334454 for case 12
# True percentage change [0.7037037]
# Predicted percentage change of 0.6544114328250118 for case 13
# True percentage change [0.68656716]
# Predicted percentage change of 0.5730195290696691 for case 15
# True percentage change [0.87878788]
# Predicted percentage change of 0.7907113317688914 for case 16
# True percentage change [0.66666667]
# Predicted percentage change of 0.7710998945925525 for case 20
# True percentage change [0.7]
# Predicted percentage change of 0.7768351575192917 for case 25
# True percentage change [0.88311688]
# Predicted percentage change of 0.8174708026639521 for case 26
# True percentage change [0.74418605]
# Predicted percentage change of 0.7357581525954647 for case 27
# True percentage change [0.87096774]
# Predicted percentage change of 0.6820934783637382 for case 28
# True percentage change [0.85714286]
# Predicted percentage change of 0.8297900043777725 for case 29
# True percentage change [0.69135802]
# Predicted percentage change of 0.593815323439264 for case 34
# True percentage change [0.675]
# Predicted percentage change of 0.6563569847444181 for case 35
# True percentage change [0.42857143]
# Predicted percentage change of 0.5640471342322633 for case 41
# True percentage change [0.86538462]
# Predicted percentage change of 0.6734927437207349 for case 43
# True percentage change [0.1875]
# Predicted percentage change of 0.6574643796909906 for case 44
# True percentage change [0.93939394]
# Predicted percentage change of 0.7601695226765862 for case 45
# True percentage change [0.55555556]
# Predicted percentage change of 0.751767835439147 for case 46
# True percentage change [0.67241379]
# Predicted percentage change of 0.6090876090854751 for case 52
# True percentage change [0.87301587]

# %%
plt.style.use('dark_background')
[fig,ax] = plt.subplots(1,2,sharex=True, sharey=True)
ax[0].scatter(per_change,lct_change)
z = np.polyfit(per_change,lct_change,1)
p = np.poly1d(z)
r2_score(per_change,p(per_change))
ax[0].set_title('Medication response')
ax[0].set_xlabel("UPDRS-III pre/post DBS percent improvement")
ax[0].set_ylabel("UPDRS-III percent improvement")
ax[1].scatter(per_change,ut)
z = np.polyfit(per_change,ut,1)
p = np.poly1d(z)
ax[1].plot(per_change,p(per_change),"r--")
ax[1].set_title('ElasticNet prediction')
ax[1].set_xlabel("UPDRS-III pre/post DBS percent improvement")
ax[1].set_ylabel("Predicted UPDRS-III percent improvement")
fig.set_size_inches(12, 6)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
r2_score(per_change,p(per_change))
# Out:
# 0.03395990302570906

# %%
z = np.polyfit(per_change,lct_change,1)
p = np.poly1d(z)
r2_score(per_change,p(per_change))
# Out:
# -1.8041590503366502

# %%
feats = clf_nsvr.best_estimator_.steps[0][1].get_support()
for k in range(feats.__len__()-1):
    if feats[k] == True:
        print(keys[k])
# Out:
# original_glszm_SizeZoneNonUniformityNormalized
# gradient_glcm_InverseVariance
# lbp-3D-k_glszm_ZoneEntropy
# logarithm_gldm_DependenceNonUniformity
# logarithm_glszm_LargeAreaLowGrayLevelEmphasis
# wavelet-LLH_glcm_MCC
# wavelet-LHL_glcm_Imc2
# wavelet-LHL_glrlm_LongRunLowGrayLevelEmphasis
# wavelet-LHH_glszm_SizeZoneNonUniformityNormalized
# wavelet-LHH_glszm_SmallAreaLowGrayLevelEmphasis
# wavelet-HLH_firstorder_Skewness
# wavelet-HLH_gldm_SmallDependenceLowGrayLevelEmphasis
# wavelet-HHH_glcm_Correlation
# wavelet-HHH_glszm_SmallAreaHighGrayLevelEmphasis
# wavelet-LLL_glszm_SmallAreaLowGrayLevelEmphasis
# pre_updrs_iii_off
# post_updrs_iii_off

# %%
fig,ax = plt.subplots(1,1)
plt.plot(feats)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
clf_nsvr.best_estimator_.steps[1][1].support_vectors_.shape
# Out:
# (22, 18)

# %%
np.array(clf_nsvr.best_estimator_.predict(X))
# Out:
# array([0.82295902, 0.89895091, 0.56580724, 0.9427499 , 0.87908569,
#        0.60224021, 0.72654313, 0.50998163, 0.70932246, 0.67681168,
#        0.86869704, 0.67719633, 0.70977643, 0.87295476, 0.75039199,
#        0.86097138, 0.84705202, 0.70128255, 0.68522171, 0.43903841,
#        0.85508804, 0.19722995, 0.92956507, 0.56552659, 0.86260895])

# %%
cases = np.linspace(1,n_cases-1,n_cases-1)
fig,ax = plt.subplots(1,1)
sv_ind = clf_nsvr.best_estimator_.steps[1][1].support_
# Plot remaining data
plt.scatter(cases, per_change_train, label="data", zorder=2, c="c", edgecolors=(0, 0, 0))
# Plot support vectors
plt.scatter(
    cases[sv_ind],
    per_change[sv_ind],
    s=50,
    c="m",
    label="SVR support vectors",
    zorder=2,
    edgecolors=(0, 0, 0))


plt.plot(cases,np.array(clf_nsvr.best_estimator_.predict(X))),
plt.style.use('dark_background')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
X_SVR = clf_nsvr.best_estimator_.steps[1][1].support_vectors_
fig,ax = plt.subplots(1,1)
im_svr = plt.imshow(X_SVR)
plt.xticks([])
plt.yticks([])
plt.xlabel('Selected feature index')
plt.ylabel('Class')
plt.title('Support vectors weights');
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)
plt.colorbar(im_svr,cax=cax,orientation='vertical')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
X_Lasso = clf_nsvr.best_estimator_.steps[0][1]._transform(X_t)
fig,ax = plt.subplots(1,1)
plt.stem(X_Lasso.ravel())
plt.xticks([])
plt.yticks([])
plt.xlabel('Selected feature index')
plt.ylabel('Feature weight index')
plt.title('Lasso feature weights');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
