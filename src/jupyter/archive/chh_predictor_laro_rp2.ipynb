# %%
# Preliminary data notebook for
# NIH: Imaging Guided Intervention Surgery Study Section

# Exploratory aim: evaluate presurgical scans between STN and GPi targets
#   Given retrospective GPi acquisitions?
#   Search for radiomic differentiators for STN versus GPi selection in presurgical scans

# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
from sklearn.linear_model import QuantileRegressor

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (15,5)
def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0]//2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()
    

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index-1) % volume.shape[0] 
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index+1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2
visualize = 1
# Load data
nrows = 256
ncols = 256
nslices = 160
segs = []
qsms = []
voxel_sizes = []
trackers = []
q_directory = '/home/ali/RadDBS-QSM/data/nii/chh/qsm/'
q_directory = os.listdir(q_directory)
q_directory = sorted(q_directory)
s_directory = '/home/ali/RadDBS-QSM/data/nii/chh/seg/'
s_directory = os.listdir(s_directory)
s_directory = sorted(s_directory)
case_list = []
d_count = 0
if visualize == 1:
    for filename in q_directory:
    
        seg_filename = s_directory[d_count]
        seg = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/seg/'+seg_filename)
        voxel_size = seg.header['pixdim'][0:3]
        voxel_sizes.append(voxel_size)
        segs.append(seg.get_fdata()[:nrows,:ncols,:nslices])
        qsm = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/qsm/'+filename)
        qsms.append(qsm.get_fdata()[:nrows,:ncols,:nslices])

        print('Appending arrays with segmentation',seg_filename,'and QSM',filename)
        case_list.append(filename)
        n_cases = len(segs)
        d_count = d_count+1

        qsms_wl = np.asarray(qsms)
        segs_wl = np.asarray(segs)
# Out:
# Appending arrays with segmentation 01.nii.gz and QSM QSM_e10_imaginary_01.nii.gz
# Appending arrays with segmentation 02.nii.gz and QSM QSM_e10_imaginary_02.nii.gz
# Appending arrays with segmentation 03.nii.gz and QSM QSM_e10_imaginary_03.nii.gz
# Appending arrays with segmentation 04.nii.gz and QSM QSM_e10_imaginary_04.nii.gz
# Appending arrays with segmentation 05.nii.gz and QSM QSM_e10_imaginary_05.nii.gz
# Appending arrays with segmentation 06.nii.gz and QSM QSM_e10_imaginary_06.nii.gz
# Appending arrays with segmentation 07.nii.gz and QSM QSM_e10_imaginary_07.nii.gz
# Appending arrays with segmentation 08.nii.gz and QSM QSM_e10_imaginary_08.nii.gz
# Appending arrays with segmentation 09.nii.gz and QSM QSM_e10_imaginary_09.nii.gz
# Appending arrays with segmentation 10.nii.gz and QSM QSM_e10_imaginary_10.nii.gz
# Appending arrays with segmentation 11.nii.gz and QSM QSM_e10_imaginary_11.nii.gz
# Appending arrays with segmentation 12.nii.gz and QSM QSM_e10_imaginary_12.nii.gz
# Appending arrays with segmentation 13.nii.gz and QSM QSM_e10_imaginary_13.nii.gz
# Appending arrays with segmentation 14.nii.gz and QSM QSM_e10_imaginary_14.nii.gz
# Appending arrays with segmentation 16.nii.gz and QSM QSM_e10_imaginary_16.nii.gz
# Appending arrays with segmentation 18.nii.gz and QSM QSM_e10_imaginary_18.nii.gz
# Appending arrays with segmentation 19.nii.gz and QSM QSM_e10_imaginary_19.nii.gz
# Appending arrays with segmentation 20.nii.gz and QSM QSM_e10_imaginary_20.nii.gz
# Appending arrays with segmentation 21.nii.gz and QSM QSM_e10_imaginary_21.nii.gz
# Appending arrays with segmentation 22.nii.gz and QSM QSM_e10_imaginary_22.nii.gz
# Appending arrays with segmentation 23.nii.gz and QSM QSM_e10_imaginary_23.nii.gz
# Appending arrays with segmentation 24.nii.gz and QSM QSM_e10_imaginary_24.nii.gz
# Appending arrays with segmentation 25.nii.gz and QSM QSM_e10_imaginary_25.nii.gz
# Appending arrays with segmentation 26.nii.gz and QSM QSM_e10_imaginary_26.nii.gz
# Appending arrays with segmentation 27.nii.gz and QSM QSM_e10_imaginary_27.nii.gz
# Appending arrays with segmentation 28.nii.gz and QSM QSM_e10_imaginary_28.nii.gz
# Appending arrays with segmentation 29.nii.gz and QSM QSM_e10_imaginary_29.nii.gz
# Appending arrays with segmentation 30.nii.gz and QSM QSM_e10_imaginary_30.nii.gz
# Appending arrays with segmentation 31.nii.gz and QSM QSM_e10_imaginary_31.nii.gz
# Appending arrays with segmentation 32.nii.gz and QSM QSM_e10_imaginary_32.nii.gz
# Appending arrays with segmentation 33.nii.gz and QSM QSM_e10_imaginary_33.nii.gz
# Appending arrays with segmentation 34.nii.gz and QSM QSM_e10_imaginary_34.nii.gz
# Appending arrays with segmentation 35.nii.gz and QSM QSM_e10_imaginary_35.nii.gz
# Appending arrays with segmentation 36.nii.gz and QSM QSM_e10_imaginary_36.nii.gz
# Appending arrays with segmentation 37.nii.gz and QSM QSM_e10_imaginary_37.nii.gz

# %%
if visualize == 1:
    qsms_wl[qsms_wl < m1] = m1
    qsms_wl[qsms_wl > m2] = m2
    multi_slice_viewer(np.hstack(((np.vstack(qsms_wl[:n_cases//2,:,:,:]+100*segs_wl[:n_cases//2,:,:,:]).T),
                                  (np.vstack(qsms_wl[(n_cases-n_cases//2):,:,:,:]+100*segs_wl[(n_cases-n_cases//2):,:,:,:]).T))))
    
    label_min = np.partition(np.unique(seg.get_fdata().ravel()), 1)[1]
    label_max = np.amax(seg.get_fdata())

# %%
df = pd.read_csv('/home/ali/RadDBS-QSM/data/xlxs/updrs_iii_chh.csv')
df
# Out:
#     subjects    LCT   Unnamed: 2                     UPDRSⅢ  \
# 0        NaN     NaN         NaN  Preoperative Off-Medicine
# 1        1.0  62.26%         NaN                         53
# 2        2.0  75.00%         NaN                         32
# 3        3.0  51.72%         NaN                         58
# 4        4.0  22.58%         NaN                         62
# 5        5.0  55.88%         NaN                         34
# 6        6.0  75.44%         NaN                         57
# 7        7.0  84.00%         NaN                        100
# 8        8.0  41.86%         NaN                         43
# 9        9.0  72.58%         NaN                         62
# 10      10.0  81.25%         NaN                         64
# 11      11.0  70.21%         NaN                         94
# 12      12.0  63.95%         NaN                         86
# 13      13.0  89.55%         NaN                         67
# 14      14.0  88.46%         NaN                         26
# 15      15.0  62.50%         NaN                         72
# 16      16.0  48.00%         NaN                         25
# 17      17.0  14.29%         NaN                         98
# 18      18.0  36.62%         NaN                         71
# 19      19.0  54.90%         NaN                         51
# 20      20.0  81.63%         NaN                         49
# 21      21.0  71.43%         NaN                         49
# 22      22.0  90.32%         NaN                         31
# 23      23.0  65.85%         NaN                         41
# 24      24.0  74.29%         NaN                         35
# 25      25.0  83.61%         NaN                         61
# 26      26.0  58.97%         NaN                         78
# 27      27.0   5.88%         NaN                         51
# 28      28.0  76.67%         NaN                         60
# 29      29.0  81.01%         NaN                         79
# 30      30.0  62.35%         NaN                         85
# 31      31.0  27.91%         NaN                         43
# 32      32.0  31.48%         NaN                         54
# 33      33.0  80.33%         NaN                         61
# 34      34.0  40.74%         NaN                         54
# 35      35.0  16.13%         NaN                         93
# 36      36.0  59.26%         NaN                         54
# 37      37.0  61.40%         NaN                         57
# 38      38.0  95.92%         NaN                         49
# 39      39.0  79.35%         NaN                         92
# 40      40.0  50.00%         NaN                         54
#
#                   Unnamed: 4                                       Unnamed: 5  \
# 0   Preoperative On-Medicine  Postoperative  Off-Medicine &Off-Stimulation\n
# 1                         20                                               40
# 2                          8                                               26
# 3                         28                                               52
# 4                         48                                               61
# 5                         15                                               44
# 6                         14                                               55
# 7                         16                                               68
# 8                         25                                               48
# 9                         17                                               56
# 10                        12                                               33
# 11                        28                                               31
# 12                        31                                               28
# 13                         7                                               64
# 14                         3                                               31
# 15                        27                                               72
# 16                        13                                               17
# 17                        84                                               86
# 18                        45                                               49
# 19                        23                                               37
# 20                         9                                               20
# 21                        14                                               42
# 22                         3                                               46
# 23                        14                                               43
# 24                         9                                               21
# 25                        10                                               60
# 26                        32                                               64
# 27                        48                                               45
# 28                        14                                               68
# 29                        15                                               79
# 30                        32                                               92
# 31                        31                                               31
# 32                        37                                               64
# 33                        12                                               53
# 34                        32                                               64
# 35                        78                                               69
# 36                        22                                               57
# 37                        22                                               56
# 38                         2                                               58
# 39                        19                                              NaN
# 40                        27                                               34
#
#                                      Unnamed: 6  \
# 0   Postoperative  Off-Medicine &On-Stimulation
# 1                                            15
# 2                                            17
# 3                                            18
# 4                                            36
# 5                                            29
# 6                                            32
# 7                                            12
# 8                                            26
# 9                                            25
# 10                                           12
# 11                                           34
# 12                                           27
# 13                                           19
# 14                                           18
# 15                                           44
# 16                                            8
# 17                                           43
# 18                                           47
# 19                                           21
# 20                                            3
# 21                                            8
# 22                                           28
# 23                                           24
# 24                                           15
# 25                                           21
# 26                                           29
# 27                                           27
# 28                                           43
# 29                                           32
# 30                                           40
# 31                                            6
# 32                                           28
# 33                                           21
# 34                                           36
# 35                                           47
# 36                                           12
# 37                                           11
# 38                                           14
# 39                                           63
# 40                                            9
#
#                                     Unnamed: 7  Unnamed: 8
# 0   Postoperative  On-Medicine &On-Stimulation         NaN
# 1                                            7         NaN
# 2                                           10         NaN
# 3                                           20         NaN
# 4                                           28         NaN
# 5                                           22         NaN
# 6                                           16         NaN
# 7                                          NaN         NaN
# 8                                           26         NaN
# 9                                           11         NaN
# 10                                         NaN         NaN
# 11                                          43         NaN
# 12                                          18         NaN
# 13                                         NaN         NaN
# 14                                          17         NaN
# 15                                          38         NaN
# 16                                           8         NaN
# 17                                          34         NaN
# 18                                          46         NaN
# 19                                          18         NaN
# 20                                         NaN         NaN
# 21                                         NaN         NaN
# 22                                         NaN         NaN
# 23                                          24         NaN
# 24                                         NaN         NaN
# 25                                          17         NaN
# 26                                          21         NaN
# 27                                          20         NaN
# 28                                         NaN         NaN
# 29                                          28         NaN
# 30                                         NaN         NaN
# 31                                         NaN         NaN
# 32                                          25         NaN
# 33                                          15         NaN
# 34                                          29         NaN
# 35                                          44         NaN
# 36                                         NaN         NaN
# 37                                         NaN         NaN
# 38                                          12         NaN
# 39                                         NaN         NaN
# 40                                           8         NaN

# %%
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]
#subject_id_corr = np.asarray(subject_id[np.logical_and(subject_id != 15.0, subject_id != 17.0)])

# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][:2])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
for i in range(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 01_roi_combined.nii for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 02_roi_combined.nii for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 03_roi_combined.nii for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 04_roi_combined.nii for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 05_roi_combined.nii for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 06_roi_combined.nii for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 07_roi_combined.nii for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 08_roi_combined.nii for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 09_roi_combined.nii for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 10_roi_combined.nii for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 11_roi_combined.nii for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 13_roi_combined.nii for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 14_roi_combined.nii for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 16_roi_combined.nii for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 18_roi_combined.nii for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 19_roi_combined.nii for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 20_roi_combined.nii for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 21_roi_combined.nii for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 22_roi_combined.nii for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 23_roi_combined.nii for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 24_roi_combined.nii for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 25_roi_combined.nii for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 26_roi_combined.nii for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 27_roi_combined.nii for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 28_roi_combined.nii for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 29_roi_combined.nii for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 30_roi_combined.nii for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 31_roi_combined.nii for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 32_roi_combined.nii for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 33_roi_combined.nii for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 34_roi_combined.nii for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 35_roi_combined.nii for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 36_roi_combined.nii for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 37_roi_combined.nii for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 38_roi_combined.nii for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 39_roi_combined.nii for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 40_roi_combined.nii for case 40.0

# %%
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])                                
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])
post_updrs_iii_off =  np.asarray(df[df.columns[6]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])

per_change = (np.asarray(pre_updrs_iii_off).astype(float)-np.asarray(post_updrs_iii_off).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))
lct_change = (np.asarray(pre_updrs_iii_off).astype(float)-(np.asarray(pre_updrs_iii_on)).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))

# %%
logger = logging.getLogger("radiomics")
logger.setLevel(logging.ERROR)

reextract = 0

# Assume all voxel sizes are identical
voxel_size = (0.9,0.9,0.9)
if reextract == 1:
    # Generate feature structure Phi from all ROIs and all cases
    extractor = featureextractor.RadiomicsFeatureExtractor()
    extractor.enableAllFeatures()
    extractor.enableAllImageTypes()
    extractor.enableFeatureClassByName('shape2D',enabled = False)

    seg_labels_all = np.unique(np.asarray(segs))
    Phi_gt = []
    Phi_vd = []
    Phi_lr = []
    seg_labels = []
    reextract = 0
    x_row_gt = []

    keylib = []
    roilib = []
    loop_count = 1
    n_rois = seg_labels_all[seg_labels_all>0].__len__()
    roi_names = np.asarray(['Background','Right substantia nigra','Right subthalamic nucleus',
                            'Left subthalamic nucleus', 'Left substantia nigra', 'Right dentate nucleus', 'Left dentate nucleus'])
    for i in np.arange(subject_id_corr.__len__()):
        seg_sitk = sitk.GetImageFromArray(segs[i])
        seg_sitk.SetSpacing(voxel_size)
        qsm_sitk_gt = sitk.GetImageFromArray(qsms[i])
        qsm_sitk_gt.SetSpacing(voxel_size)
        # Index back since subject 12 is missing ROIs
        for j in seg_labels_all:
            if j>0:
                fv_count = 0
                featureVector_gt = extractor.execute(qsm_sitk_gt,seg_sitk,label=int(j));
                Phi_gt.append(featureVector_gt)
                for key, value in six.iteritems(featureVector_gt):
                    if 'diagnostic' in key:
                        next
                    else:
                        x_row_gt.append(featureVector_gt[key])
                        fv_count = fv_count+1
                        keylib.append(key)
                        roilib.append(roi_names[int(j)])
                x_row_gt.append(pre_updrs_iii_off[i])
                fv_count = fv_count+1
        print('Extracting features for subject',subject_id_corr[i],'and appending feature matrix with vector of length',fv_count,'with UPDRS score',pre_updrs_iii_off[i])
                
    X0_gt = np.array(x_row_gt)
    np.save('./npy/X0_gt_chh_rois_rp.npy',X0_gt)

    K = np.asarray(keylib)
    R = np.asarray(roi_names)
    np.save('./npy/K_chh_rp.npy',K)
    np.save('./npy/R_chh_rp.npy',R)

    print('Saving ground truth feature vector')
    with open('./phi/Phi_mcl_gt_roi_chh_rp', 'wb') as fp:  
        pickle.dump(Phi_gt, fp)

else:
    X0_gt = np.load('./npy/X0_gt_chh_rois_rp.npy')
    K = np.load('./npy/K_chh_rp.npy')
    R = np.load('./npy/R_chh_rp.npy')
    n_rois = R.shape[0]-1
    with open('./phi/Phi_mcl_gt_roi_chh_rp', "rb") as fp:  
        Phi_gt = pickle.load(fp)
# Out:
# Extracting features for subject 1.0 and appending feature matrix with vector of length 1596 with UPDRS score 53
# Extracting features for subject 2.0 and appending feature matrix with vector of length 1596 with UPDRS score 32
# Extracting features for subject 3.0 and appending feature matrix with vector of length 1596 with UPDRS score 58
# Extracting features for subject 4.0 and appending feature matrix with vector of length 1596 with UPDRS score 62
# Extracting features for subject 5.0 and appending feature matrix with vector of length 1596 with UPDRS score 34
# Extracting features for subject 6.0 and appending feature matrix with vector of length 1596 with UPDRS score 57
# Extracting features for subject 7.0 and appending feature matrix with vector of length 1596 with UPDRS score 100
# Extracting features for subject 8.0 and appending feature matrix with vector of length 1596 with UPDRS score 43
# Extracting features for subject 9.0 and appending feature matrix with vector of length 1596 with UPDRS score 62
# Extracting features for subject 10.0 and appending feature matrix with vector of length 1596 with UPDRS score 64
# Extracting features for subject 11.0 and appending feature matrix with vector of length 1596 with UPDRS score 94
# Extracting features for subject 13.0 and appending feature matrix with vector of length 1596 with UPDRS score 67
# Extracting features for subject 14.0 and appending feature matrix with vector of length 1596 with UPDRS score 26
# Extracting features for subject 16.0 and appending feature matrix with vector of length 1596 with UPDRS score 25
# Extracting features for subject 18.0 and appending feature matrix with vector of length 1596 with UPDRS score 71
# Extracting features for subject 19.0 and appending feature matrix with vector of length 1596 with UPDRS score 51
# Extracting features for subject 20.0 and appending feature matrix with vector of length 1596 with UPDRS score 49
# Extracting features for subject 21.0 and appending feature matrix with vector of length 1596 with UPDRS score 49
# Extracting features for subject 22.0 and appending feature matrix with vector of length 1596 with UPDRS score 31
# Extracting features for subject 23.0 and appending feature matrix with vector of length 1596 with UPDRS score 41
# Extracting features for subject 24.0 and appending feature matrix with vector of length 1596 with UPDRS score 35
# Extracting features for subject 25.0 and appending feature matrix with vector of length 1596 with UPDRS score 61
# Extracting features for subject 26.0 and appending feature matrix with vector of length 1596 with UPDRS score 78
# Extracting features for subject 27.0 and appending feature matrix with vector of length 1596 with UPDRS score 51
# Extracting features for subject 28.0 and appending feature matrix with vector of length 1596 with UPDRS score 60
# Extracting features for subject 29.0 and appending feature matrix with vector of length 1596 with UPDRS score 79
# Extracting features for subject 30.0 and appending feature matrix with vector of length 1596 with UPDRS score 85
# Extracting features for subject 31.0 and appending feature matrix with vector of length 1596 with UPDRS score 43
# Extracting features for subject 32.0 and appending feature matrix with vector of length 1596 with UPDRS score 54
# Extracting features for subject 33.0 and appending feature matrix with vector of length 1596 with UPDRS score 61
# Extracting features for subject 34.0 and appending feature matrix with vector of length 1596 with UPDRS score 54
# Extracting features for subject 35.0 and appending feature matrix with vector of length 1596 with UPDRS score 93
# Extracting features for subject 36.0 and appending feature matrix with vector of length 1596 with UPDRS score 54
# Extracting features for subject 37.0 and appending feature matrix with vector of length 1596 with UPDRS score 57
# Extracting features for subject 38.0 and appending feature matrix with vector of length 1596 with UPDRS score 49
# Extracting features for subject 39.0 and appending feature matrix with vector of length 1596 with UPDRS score 92
# Extracting features for subject 40.0 and appending feature matrix with vector of length 1596 with UPDRS score 54
# Saving ground truth feature vector

# %%
n_cases = len(per_change)
n_roisc = Phi_gt.__len__()/n_cases
L = int(len(X0_gt)/n_cases)
n_features = int(L/n_rois)

# %%
n_features
# Out:
# 1596

# %%
x_row_gt = X0_gt.tolist()
X = np.zeros((n_cases,n_rois,n_features)).transpose((0,2,1))
X = X0_gt.reshape((n_cases,n_rois,n_features)).transpose((0,2,1))
ut_ls = np.zeros((subject_id_corr.__len__()))
ut_qr = np.zeros((subject_id_corr.__len__()))
# Normalize testing and training cases together
#   Set with_mean=False to preserve data sparsity
#   And with_std=False 
#   However, need a significant number of samples to do this
X_all = X.reshape(n_cases,((n_features)*n_rois))
scaler = StandardScaler()
X_all_t = scaler.fit_transform(X_all)
#N_train = 30
for j in np.arange(len(subject_id_corr)):
        # Add UPDRS after scaling
        # Might be overwriting a feature here
        X_all_t[j,-1] = pre_updrs_iii_off[int(j)]
        X_in = X_all_t
        X_in = np.delete(X_in,j,axis=0)

        p_per_change = per_change
        per_change_in = np.delete(p_per_change,j,axis=0)
        # Cross-validation for model selection
        #cv = KFold(np.sum(subject_id_corr < N_train+1)-1//2)
        #print('Kfold complete')
        # Identify most important features
        clf_ls = Lasso(alpha=1e-4,max_iter=10000).fit(X_in,per_change_in)
        clf_qr = QuantileRegressor(quantile=0.05, alpha=1).fit(X_in,per_change_in)
        #LassoCV(cv=cv,verbose=1,n_jobs=-1,max_iter=10000).fit(X_in,per_change_in)
        #print('Cross validation complete')
        #print('Grid search complete')
        print('Fit complete')
        ut_ls[j] = clf_ls.predict(X_all_t[j,:].reshape(1, -1))
        ut_qr[j] = clf_qr.predict(X_all_t[j,:].reshape(1, -1))
        print('Lasso predicted percentage change of',ut_ls[j],'and quantile predicted',ut_qr[j],'for case',j)
        print('True percentage change',per_change[j])
        #print('Selected alpha:',clf_ls.alpha_)
        print('Patient ID',str(subject_id_corr[j]),'with pre-surgical UPDRS score',str(pre_updrs_iii_off[int(j)]),'at feature matrix row',str(j))
# Out:
# Fit complete
# Lasso predicted percentage change of 0.6323216398657318 and quantile predicted 0.14705882347655863 for case 0
# True percentage change 0.7169811320754716
# Patient ID 1.0 with pre-surgical UPDRS score 53 at feature matrix row 0
# Fit complete
# Lasso predicted percentage change of 0.4889792880877539 and quantile predicted 0.1470588240086678 for case 1
# True percentage change 0.46875
# Patient ID 2.0 with pre-surgical UPDRS score 32 at feature matrix row 1
# Fit complete
# Lasso predicted percentage change of 0.5802022654090468 and quantile predicted 0.14705882346747765 for case 2
# True percentage change 0.6896551724137931
# Patient ID 3.0 with pre-surgical UPDRS score 58 at feature matrix row 2
# Fit complete
# Lasso predicted percentage change of 0.6066096798381043 and quantile predicted 0.14705882349031923 for case 3
# True percentage change 0.41935483870967744
# Patient ID 4.0 with pre-surgical UPDRS score 62 at feature matrix row 3
# Fit complete
# Lasso predicted percentage change of 0.439593013965039 and quantile predicted 0.28333333303908953 for case 4
# True percentage change 0.14705882352941177
# Patient ID 5.0 with pre-surgical UPDRS score 34 at feature matrix row 4
# Fit complete
# Lasso predicted percentage change of 0.36133846435548184 and quantile predicted 0.14705882420703578 for case 5
# True percentage change 0.43859649122807015
# Patient ID 6.0 with pre-surgical UPDRS score 57 at feature matrix row 5
# Fit complete
# Lasso predicted percentage change of 0.6435085799787703 and quantile predicted 0.14705882351009134 for case 6
# True percentage change 0.88
# Patient ID 7.0 with pre-surgical UPDRS score 100 at feature matrix row 6
# Fit complete
# Lasso predicted percentage change of 0.47436112198601366 and quantile predicted 0.14705882344799334 for case 7
# True percentage change 0.3953488372093023
# Patient ID 8.0 with pre-surgical UPDRS score 43 at feature matrix row 7
# Fit complete
# Lasso predicted percentage change of 0.5066215388061924 and quantile predicted 0.14705882349181137 for case 8
# True percentage change 0.5967741935483871
# Patient ID 9.0 with pre-surgical UPDRS score 62 at feature matrix row 8
# Fit complete
# Lasso predicted percentage change of 0.47507214509029555 and quantile predicted 0.1470588235594744 for case 9
# True percentage change 0.8125
# Patient ID 10.0 with pre-surgical UPDRS score 64 at feature matrix row 9
# Fit complete
# Lasso predicted percentage change of 0.7199854096446814 and quantile predicted 0.14705882367615927 for case 10
# True percentage change 0.6382978723404256
# Patient ID 11.0 with pre-surgical UPDRS score 94 at feature matrix row 10
# Fit complete
# Lasso predicted percentage change of 0.6475036299579464 and quantile predicted 0.14705882356756061 for case 11
# True percentage change 0.7164179104477612
# Patient ID 13.0 with pre-surgical UPDRS score 67 at feature matrix row 11
# Fit complete
# Lasso predicted percentage change of 0.5336151026422827 and quantile predicted 0.14705882365004175 for case 12
# True percentage change 0.3076923076923077
# Patient ID 14.0 with pre-surgical UPDRS score 26 at feature matrix row 12
# Fit complete
# Lasso predicted percentage change of 0.5192309092449952 and quantile predicted 0.14705882346380283 for case 13
# True percentage change 0.68
# Patient ID 16.0 with pre-surgical UPDRS score 25 at feature matrix row 13
# Fit complete
# Lasso predicted percentage change of 0.5811094927065212 and quantile predicted 0.14705882350877664 for case 14
# True percentage change 0.3380281690140845
# Patient ID 18.0 with pre-surgical UPDRS score 71 at feature matrix row 14
# Fit complete
# Lasso predicted percentage change of 0.608227143555476 and quantile predicted 0.14705882344305923 for case 15
# True percentage change 0.5882352941176471
# Patient ID 19.0 with pre-surgical UPDRS score 51 at feature matrix row 15
# Fit complete
# Lasso predicted percentage change of 0.560261297880684 and quantile predicted 0.14705882352634597 for case 16
# True percentage change 0.9387755102040817
# Patient ID 20.0 with pre-surgical UPDRS score 49 at feature matrix row 16
# Fit complete
# Lasso predicted percentage change of 0.7443111856037135 and quantile predicted 0.1470588235252797 for case 17
# True percentage change 0.8367346938775511
# Patient ID 21.0 with pre-surgical UPDRS score 49 at feature matrix row 17
# Fit complete
# Lasso predicted percentage change of 0.42542417423666806 and quantile predicted 0.2833333331708774 for case 18
# True percentage change 0.0967741935483871
# Patient ID 22.0 with pre-surgical UPDRS score 31 at feature matrix row 18
# Fit complete
# Lasso predicted percentage change of 0.7837478819503196 and quantile predicted 0.14705882408699422 for case 19
# True percentage change 0.4146341463414634
# Patient ID 23.0 with pre-surgical UPDRS score 41 at feature matrix row 19
# Fit complete
# Lasso predicted percentage change of 0.6506684865407397 and quantile predicted 0.14705882332748105 for case 20
# True percentage change 0.5714285714285714
# Patient ID 24.0 with pre-surgical UPDRS score 35 at feature matrix row 20
# Fit complete
# Lasso predicted percentage change of 0.7473684698939778 and quantile predicted 0.14705882358873185 for case 21
# True percentage change 0.6557377049180327
# Patient ID 25.0 with pre-surgical UPDRS score 61 at feature matrix row 21
# Fit complete
# Lasso predicted percentage change of 0.6243601398092328 and quantile predicted 0.14705882334526266 for case 22
# True percentage change 0.6282051282051282
# Patient ID 26.0 with pre-surgical UPDRS score 78 at feature matrix row 22
# Fit complete
# Lasso predicted percentage change of 0.6012453433904834 and quantile predicted 0.14705882247495045 for case 23
# True percentage change 0.47058823529411764
# Patient ID 27.0 with pre-surgical UPDRS score 51 at feature matrix row 23
# Fit complete
# Lasso predicted percentage change of 0.46396082797814286 and quantile predicted 0.14705882384648614 for case 24
# True percentage change 0.2833333333333333
# Patient ID 28.0 with pre-surgical UPDRS score 60 at feature matrix row 24
# Fit complete
# Lasso predicted percentage change of 0.6427981189369576 and quantile predicted 0.14705882355072852 for case 25
# True percentage change 0.5949367088607594
# Patient ID 29.0 with pre-surgical UPDRS score 79 at feature matrix row 25
# Fit complete
# Lasso predicted percentage change of 0.6454649046900155 and quantile predicted 0.1470588234983964 for case 26
# True percentage change 0.5294117647058824
# Patient ID 30.0 with pre-surgical UPDRS score 85 at feature matrix row 26
# Fit complete
# Lasso predicted percentage change of 0.5364345601309044 and quantile predicted 0.14705882342060417 for case 27
# True percentage change 0.8604651162790697
# Patient ID 31.0 with pre-surgical UPDRS score 43 at feature matrix row 27
# Fit complete
# Lasso predicted percentage change of 0.5365200285975246 and quantile predicted 0.14705882362729025 for case 28
# True percentage change 0.48148148148148145
# Patient ID 32.0 with pre-surgical UPDRS score 54 at feature matrix row 28
# Fit complete
# Lasso predicted percentage change of 0.7157546437657956 and quantile predicted 0.14705882350776323 for case 29
# True percentage change 0.6557377049180327
# Patient ID 33.0 with pre-surgical UPDRS score 61 at feature matrix row 29
# Fit complete
# Lasso predicted percentage change of 0.6620858400199011 and quantile predicted 0.14705882321099556 for case 30
# True percentage change 0.3333333333333333
# Patient ID 34.0 with pre-surgical UPDRS score 54 at feature matrix row 30
# Fit complete
# Lasso predicted percentage change of 0.5606751582473704 and quantile predicted 0.14705882372044612 for case 31
# True percentage change 0.4946236559139785
# Patient ID 35.0 with pre-surgical UPDRS score 93 at feature matrix row 31
# Fit complete
# Lasso predicted percentage change of 0.6844302063442211 and quantile predicted 0.14705882349879024 for case 32
# True percentage change 0.7777777777777778
# Patient ID 36.0 with pre-surgical UPDRS score 54 at feature matrix row 32
# Fit complete
# Lasso predicted percentage change of 0.5619962625701995 and quantile predicted 0.1470588231639417 for case 33
# True percentage change 0.8070175438596491
# Patient ID 37.0 with pre-surgical UPDRS score 57 at feature matrix row 33
# Fit complete
# Lasso predicted percentage change of 0.6779438242779474 and quantile predicted 0.22447882839996364 for case 34
# True percentage change 0.7142857142857143
# Patient ID 38.0 with pre-surgical UPDRS score 49 at feature matrix row 34
# Fit complete
# Lasso predicted percentage change of 0.4135456154068631 and quantile predicted 0.4464161755011684 for case 35
# True percentage change 0.31521739130434784
# Patient ID 39.0 with pre-surgical UPDRS score 92 at feature matrix row 35
# Fit complete
# Lasso predicted percentage change of 0.7158324235993188 and quantile predicted 0.20504453664036212 for case 36
# True percentage change 0.8333333333333334
# Patient ID 40.0 with pre-surgical UPDRS score 54 at feature matrix row 36

# %%
# %matplotlib inline
# Cross validation results
[fig,ax] = plt.subplots(1,3,sharex=True, sharey=True)
lr_prepost = linregress(lct_change,per_change)
ax[0].scatter(lct_change,per_change,)
ax[0].plot(lct_change,lct_change*lr_prepost.slope+lr_prepost.intercept,'-r')
ax[0].set_title('Predicted response')
ax[0].set_ylabel("DBS response")
ax[0].set_xlabel("LCT response")
text = f"$y={lr_prepost.slope:0.3f}\;x{lr_prepost.intercept:+0.3f}$\n$r = {lr_prepost.rvalue:0.3f}$\n$p = {lr_prepost.pvalue:0.3f}$"
ax[0].text(0.05, 0.95, text,transform=ax[0].transAxes,
     fontsize=14, verticalalignment='top')

lr_pred_ls = linregress(ut_ls,per_change)
ax[1].scatter(ut_ls,per_change)
ax[1].plot(ut_ls,ut_ls*lr_pred_ls.slope+lr_pred_ls.intercept,'-r')
ax[1].set_title('Predicted response')
ax[1].set_ylabel("DBS response")
ax[1].set_xlabel("Model response")
text = f"$y={lr_pred_ls.slope:0.3f}\;x{lr_pred_ls.intercept:+0.3f}$\n$r = {lr_pred_ls.rvalue:0.3f}$\n$p = {lr_pred_ls.pvalue:0.3f}$"
ax[1].text(0.05, 0.95, text,transform=ax[1].transAxes,
     fontsize=14, verticalalignment='top')

lr_pred_qr = linregress(ut_qr,per_change)
ax[2].scatter(ut_qr,per_change)
ax[2].plot(ut_qr,ut_qr*lr_pred_qr.slope+lr_pred_qr.intercept,'-r')
ax[2].set_title('Predicted response')
ax[2].set_ylabel("DBS response")
ax[2].set_xlabel("Model response")
text = f"$y={lr_pred_qr.slope:0.3f}\;x{lr_pred_qr.intercept:+0.3f}$\n$r = {lr_pred_qr.rvalue:0.3f}$\n$p = {lr_pred_qr.pvalue:0.3f}$"
ax[2].text(0.05, 0.95, text,transform=ax[2].transAxes,
     fontsize=14, verticalalignment='top')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
