# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score, roc_curve, auc
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
from sklearn.linear_model import QuantileRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RANSACRegressor
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
import warnings
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
from sklearn.exceptions import ConvergenceWarning
from sklearn import preprocessing as skp
from sklearn import model_selection as sms
from sklearn import feature_selection as skf
from sklearn import linear_model as slm
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util as util
import nibabel as nib
import os
import pickle
patch_sklearn()
# Out:
# Skipping torch import
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (15,5)
def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0]//2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()
    

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index-1) % volume.shape[0] 
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index+1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2
visualize = 1
# Load data
nrows = 256
ncols = 256
nslices = 160
segs = []
qsms = []
laros = []
voxel_sizes = []
trackers = []
q_directory = '/data/Ali/RadDBS-QSM/data/nii/chh/orig/qsm/'
q_directory = os.listdir(q_directory)
q_directory = sorted(q_directory)
qu_directory = '/data/Ali/RadDBS-QSM/data/nii/chh/lr_roi_ft'
qu_directory = os.listdir(qu_directory)
qu_directory = sorted(qu_directory)
s_directory = '/data/Ali/RadDBS-QSM/data/nii/chh/orig/seg/'
s_directory = os.listdir(s_directory)
s_directory = sorted(s_directory)
m_directory = '/data/Ali/RadDBS-QSM/data/nii/chh/masks'
m_directory = os.listdir(m_directory)
m_directory = sorted(m_directory)
case_list = []
d_count = 0
if visualize == 1:
    for filename in q_directory:
    
        seg_filename = s_directory[d_count]
        laro_filename = qu_directory[d_count]
        mask_filename = m_directory[d_count]
        seg = nib.load('/data/Ali/RadDBS-QSM/data/nii/chh/orig/seg/'+seg_filename)
        mask = nib.load('/data/Ali/RadDBS-QSM/data/nii/chh/masks/'+mask_filename)
        voxel_size = seg.header['pixdim'][0:3]
        voxel_sizes.append(voxel_size)
        segs.append(seg.get_fdata()[:nrows,:ncols,:nslices])
        qsm = nib.load('/data/Ali/RadDBS-QSM/data/nii/chh/orig/qsm/'+filename)
        qsms.append(qsm.get_fdata()[:nrows,:ncols,:nslices])

        laro = nib.load('/data/Ali/RadDBS-QSM/data/nii/chh/lr_roi_ft/'+laro_filename)
        laros.append(1000*laro.get_fdata()[:nrows,:ncols,:nslices])
        print('Appending arrays with segmentation',seg_filename,'QSM,',filename,
              'LARO,',laro_filename,'and mask',mask_filename)
        case_list.append(filename)
        n_cases = len(segs)
        d_count = d_count+1
# Out:
# Appending arrays with segmentation 01_roi_combined.nii QSM, 00001_qsm.nii.gz LARO, QSM_lrr_01.nii and mask mask01.nii
# Appending arrays with segmentation 02_roi_combined.nii QSM, 00002_qsm.nii.gz LARO, QSM_lrr_02.nii and mask mask02.nii
# Appending arrays with segmentation 03_roi_combined.nii QSM, 00003_qsm.nii.gz LARO, QSM_lrr_03.nii and mask mask03.nii
# Appending arrays with segmentation 04_roi_combined.nii QSM, 00004_qsm.nii.gz LARO, QSM_lrr_04.nii and mask mask04.nii
# Appending arrays with segmentation 05_roi_combined.nii QSM, 00005_qsm.nii.gz LARO, QSM_lrr_05.nii and mask mask05.nii
# Appending arrays with segmentation 06_roi_combined.nii QSM, 00006_qsm.nii.gz LARO, QSM_lrr_06.nii and mask mask06.nii
# Appending arrays with segmentation 07_roi_combined.nii QSM, 00007_qsm.nii.gz LARO, QSM_lrr_07.nii and mask mask07.nii
# Appending arrays with segmentation 08_roi_combined.nii QSM, 00008_qsm.nii.gz LARO, QSM_lrr_08.nii and mask mask08.nii
# Appending arrays with segmentation 09_roi_combined.nii QSM, 00009_qsm.nii.gz LARO, QSM_lrr_09.nii and mask mask09.nii
# Appending arrays with segmentation 10_roi_combined.nii QSM, 00010_qsm.nii.gz LARO, QSM_lrr_10.nii and mask mask10.nii
# Appending arrays with segmentation 11_roi_combined.nii QSM, 00011_qsm.nii.gz LARO, QSM_lrr_11.nii and mask mask11.nii
# Appending arrays with segmentation 13_roi_combined.nii QSM, 00013_qsm.nii.gz LARO, QSM_lrr_13.nii and mask mask13.nii
# Appending arrays with segmentation 14_roi_combined.nii QSM, 00014_qsm.nii.gz LARO, QSM_lrr_14.nii and mask mask14.nii
# Appending arrays with segmentation 16_roi_combined.nii QSM, 00016_qsm.nii.gz LARO, QSM_lrr_16.nii and mask mask16.nii
# Appending arrays with segmentation 18_roi_combined.nii QSM, 00018_qsm.nii.gz LARO, QSM_lrr_18.nii and mask mask18.nii
# Appending arrays with segmentation 19_roi_combined.nii QSM, 00019_qsm.nii.gz LARO, QSM_lrr_19.nii and mask mask19.nii
# Appending arrays with segmentation 20_roi_combined.nii QSM, 00020_qsm.nii.gz LARO, QSM_lrr_20.nii and mask mask20.nii
# Appending arrays with segmentation 21_roi_combined.nii QSM, 00021_qsm.nii.gz LARO, QSM_lrr_21.nii and mask mask21.nii
# Appending arrays with segmentation 22_roi_combined.nii QSM, 00022_qsm.nii.gz LARO, QSM_lrr_22.nii and mask mask22.nii
# Appending arrays with segmentation 23_roi_combined.nii QSM, 00023_qsm.nii.gz LARO, QSM_lrr_23.nii and mask mask23.nii
# Appending arrays with segmentation 24_roi_combined.nii QSM, 00024_qsm.nii.gz LARO, QSM_lrr_24.nii and mask mask24.nii
# Appending arrays with segmentation 25_roi_combined.nii QSM, 00025_qsm.nii.gz LARO, QSM_lrr_25.nii and mask mask25.nii
# Appending arrays with segmentation 26_roi_combined.nii QSM, 00026_qsm.nii.gz LARO, QSM_lrr_26.nii and mask mask26.nii
# Appending arrays with segmentation 27_roi_combined.nii QSM, 00027_qsm.nii.gz LARO, QSM_lrr_27.nii and mask mask27.nii
# Appending arrays with segmentation 28_roi_combined.nii QSM, 00028_qsm.nii.gz LARO, QSM_lrr_28.nii and mask mask28.nii
# Appending arrays with segmentation 29_roi_combined.nii QSM, 00029_qsm.nii.gz LARO, QSM_lrr_29.nii and mask mask29.nii
# Appending arrays with segmentation 30_roi_combined.nii QSM, 00030_qsm.nii.gz LARO, QSM_lrr_30.nii and mask mask30.nii
# Appending arrays with segmentation 31_roi_combined.nii QSM, 00031_qsm.nii.gz LARO, QSM_lrr_31.nii and mask mask31.nii
# Appending arrays with segmentation 32_roi_combined.nii QSM, 00032_qsm.nii.gz LARO, QSM_lrr_32.nii and mask mask32.nii
# Appending arrays with segmentation 33_roi_combined.nii QSM, 00033_qsm.nii.gz LARO, QSM_lrr_33.nii and mask mask33.nii
# Appending arrays with segmentation 34_roi_combined.nii QSM, 00034_qsm.nii.gz LARO, QSM_lrr_34.nii and mask mask34.nii
# Appending arrays with segmentation 35_roi_combined.nii QSM, 00035_qsm.nii.gz LARO, QSM_lrr_35.nii and mask mask35.nii
# Appending arrays with segmentation 36_roi_combined.nii QSM, 00036_qsm.nii.gz LARO, QSM_lrr_36.nii and mask mask36.nii
# Appending arrays with segmentation 37_roi_combined.nii QSM, 00037_qsm.nii.gz LARO, QSM_lrr_37.nii and mask mask37.nii
# Appending arrays with segmentation 38_roi_combined.nii QSM, 00038_qsm.nii.gz LARO, QSM_lrr_38.nii and mask mask38.nii
# Appending arrays with segmentation 39_roi_combined.nii QSM, 00039_qsm.nii.gz LARO, QSM_lrr_39.nii and mask mask39.nii
# Appending arrays with segmentation 40_roi_combined.nii QSM, 00040_qsm.nii.gz LARO, QSM_lrr_40.nii and mask mask40.nii

# %%
df = pd.read_csv('/data/Ali/RadDBS-QSM/data/xlxs/updrs_iii_chh_cvs.csv')
df
# Out:
#     subjects    LCT   Unnamed: 2                     UPDRSⅢ  \
# 0        NaN     NaN         NaN  Preoperative Off-Medicine
# 1        1.0  62.26%         NaN                         53
# 2        2.0  75.00%         NaN                         32
# 3        3.0  51.72%         NaN                         58
# 4        4.0  22.58%         NaN                         62
# 5        5.0  55.88%         NaN                         34
# 6        6.0  75.44%         NaN                         57
# 7        7.0  84.00%         NaN                        100
# 8        8.0  41.86%         NaN                         43
# 9        9.0  72.58%         NaN                         62
# 10      10.0  81.25%         NaN                         64
# 11      11.0  70.21%         NaN                         94
# 12      12.0  63.95%         NaN                         86
# 13      13.0  89.55%         NaN                         67
# 14      14.0  88.46%         NaN                         26
# 15      15.0  62.50%         NaN                         72
# 16      16.0  48.00%         NaN                         25
# 17      17.0  14.29%         NaN                         98
# 18      18.0  36.62%         NaN                         71
# 19      19.0  54.90%         NaN                         51
# 20      20.0  81.63%         NaN                         49
# 21      21.0  71.43%         NaN                         49
# 22      22.0  90.32%         NaN                         31
# 23      23.0  65.85%         NaN                         41
# 24      24.0  74.29%         NaN                         35
# 25      25.0  83.61%         NaN                         61
# 26      26.0  58.97%         NaN                         78
# 27      27.0   5.88%         NaN                         51
# 28      28.0  76.67%         NaN                         60
# 29      29.0  81.01%         NaN                         79
# 30      30.0  62.35%         NaN                         85
# 31      31.0  27.91%         NaN                         43
# 32      32.0  31.48%         NaN                         54
# 33      33.0  80.33%         NaN                         61
# 34      34.0  40.74%         NaN                         54
# 35      35.0  16.13%         NaN                         93
# 36      36.0  59.26%         NaN                         54
# 37      37.0  61.40%         NaN                         57
# 38      38.0  95.92%         NaN                         49
# 39      39.0  79.35%         NaN                         92
# 40      40.0  50.00%         NaN                         54
#
#                   Unnamed: 4                                       Unnamed: 5  \
# 0   Preoperative On-Medicine  Postoperative  Off-Medicine &Off-Stimulation\n
# 1                         20                                               40
# 2                          8                                               26
# 3                         28                                               52
# 4                         48                                               61
# 5                         15                                               44
# 6                         14                                               55
# 7                         16                                               68
# 8                         25                                               48
# 9                         17                                               56
# 10                        12                                               33
# 11                        28                                               31
# 12                        31                                               28
# 13                         7                                               64
# 14                         3                                               31
# 15                        27                                               72
# 16                        13                                               17
# 17                        84                                               86
# 18                        45                                               49
# 19                        23                                               37
# 20                         9                                               20
# 21                        14                                               42
# 22                         3                                               46
# 23                        14                                               43
# 24                         9                                               21
# 25                        10                                               60
# 26                        32                                               64
# 27                        48                                               45
# 28                        14                                               68
# 29                        15                                               79
# 30                        32                                               92
# 31                        31                                               31
# 32                        37                                               64
# 33                        12                                               53
# 34                        32                                               64
# 35                        78                                               69
# 36                        22                                               57
# 37                        22                                               56
# 38                         2                                               58
# 39                        19                                              NaN
# 40                        27                                               34
#
#                                      Unnamed: 6  \
# 0   Postoperative  Off-Medicine &On-Stimulation
# 1                                            15
# 2                                            17
# 3                                            18
# 4                                            36
# 5                                            29
# 6                                            32
# 7                                            12
# 8                                            26
# 9                                            25
# 10                                           12
# 11                                           34
# 12                                           27
# 13                                           19
# 14                                           18
# 15                                           44
# 16                                            8
# 17                                           43
# 18                                           47
# 19                                           21
# 20                                            3
# 21                                            8
# 22                                           28
# 23                                           24
# 24                                           15
# 25                                           21
# 26                                           29
# 27                                           27
# 28                                           43
# 29                                           32
# 30                                           40
# 31                                            6
# 32                                           28
# 33                                           21
# 34                                           36
# 35                                           47
# 36                                           12
# 37                                           11
# 38                                           14
# 39                                           63
# 40                                            9
#
#                                     Unnamed: 7 Unnamed: 8  \
# 0   Postoperative  On-Medicine &On-Stimulation        age
# 1                                            7         66
# 2                                           10         64
# 3                                           20         67
# 4                                           28         69
# 5                                           22         63
# 6                                           16         67
# 7                                          NaN         58
# 8                                           26         74
# 9                                           11         57
# 10                                         NaN         52
# 11                                          43         68
# 12                                          18         56
# 13                                         NaN         60
# 14                                          17         62
# 15                                          38         56
# 16                                           8         66
# 17                                          34         73
# 18                                          46         52
# 19                                          18         68
# 20                                         NaN         59
# 21                                         NaN         62
# 22                                         NaN         65
# 23                                          24         75
# 24                                         NaN         47
# 25                                          17         63
# 26                                          21         70
# 27                                          20         59
# 28                                         NaN         67
# 29                                          28         66
# 30                                         NaN         72
# 31                                         NaN         71
# 32                                          25         51
# 33                                          15         54
# 34                                          29         66
# 35                                          44         70
# 36                                         NaN         49
# 37                                         NaN         76
# 38                                          12         67
# 39                                         NaN         56
# 40                                           8         69
#
#                  Unnamed: 9              Unnamed: 10 Unnamed: 11
# 0   Gender(male=0,female=1)  Disease duration(years)        LEDD
# 1                         1                        9         825
# 2                         1                        6      856.25
# 3                         1                       15        1350
# 4                         1                        5         350
# 5                         1                       10      751.25
# 6                         1                        5         525
# 7                         0                       10      1087.5
# 8                         1                       10         550
# 9                         1                       10         500
# 10                        0                        6         600
# 11                        1                       11        1450
# 12                        1                       13         600
# 13                        1                       11      856.25
# 14                        0                        5         375
# 15                        0                       12         400
# 16                        0                        8         850
# 17                        1                       15         300
# 18                        1                        7        1200
# 19                        1                       13         575
# 20                        0                       11         700
# 21                        0                        9     1125.75
# 22                        1                        7         875
# 23                        0                       10       862.5
# 24                        1                        7      341.67
# 25                        0                        9         455
# 26                        0                        5         850
# 27                        0                        6         525
# 28                        0                        7        1025
# 29                        0                        7         750
# 30                        0                        7        1075
# 31                        0                       12        1025
# 32                        0                        5         450
# 33                        0                        7         675
# 34                        0                        9      656.25
# 35                        0                        5         NaN
# 36                        0                        6         575
# 37                        1                        4         375
# 38                        0                        7         510
# 39                        1                       10        1100
# 40                        0                        7         450

# %%
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]

# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][:2])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
age = np.nan_to_num(np.asarray(df[df.columns[-4]])[1:][np.in1d(subject_id,case_number)].astype(float))
sex = np.nan_to_num(np.asarray(df[df.columns[-3]])[1:][np.in1d(subject_id,case_number)].astype(float))
dd = np.nan_to_num(np.asarray(df[df.columns[-2]])[1:][np.in1d(subject_id,case_number)].astype(float))
ledd = np.nan_to_num(np.asarray(df[df.columns[-1]])[1:][np.in1d(subject_id,case_number)].astype(float))

for i in np.arange(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 01_roi_combined.nii for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 02_roi_combined.nii for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 03_roi_combined.nii for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 04_roi_combined.nii for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 05_roi_combined.nii for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 06_roi_combined.nii for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 07_roi_combined.nii for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 08_roi_combined.nii for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 09_roi_combined.nii for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 10_roi_combined.nii for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 11_roi_combined.nii for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 13_roi_combined.nii for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 14_roi_combined.nii for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 16_roi_combined.nii for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 18_roi_combined.nii for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 19_roi_combined.nii for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 20_roi_combined.nii for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 21_roi_combined.nii for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 22_roi_combined.nii for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 23_roi_combined.nii for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 24_roi_combined.nii for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 25_roi_combined.nii for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 26_roi_combined.nii for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 27_roi_combined.nii for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 28_roi_combined.nii for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 29_roi_combined.nii for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 30_roi_combined.nii for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 31_roi_combined.nii for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 32_roi_combined.nii for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 33_roi_combined.nii for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 34_roi_combined.nii for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 35_roi_combined.nii for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 36_roi_combined.nii for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 37_roi_combined.nii for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 38_roi_combined.nii for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 39_roi_combined.nii for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 40_roi_combined.nii for case 40.0

# %%
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])                                
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])
post_updrs_iii_off =  np.asarray(df[df.columns[6]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])

per_change = (np.asarray(pre_updrs_iii_off).astype(float)-np.asarray(post_updrs_iii_off).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))
lct_change = (np.asarray(pre_updrs_iii_off).astype(float)-(np.asarray(pre_updrs_iii_on)).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))

# %%
logger = logging.getLogger("radiomics")
logger.setLevel(logging.ERROR)

reextract = 0

# Assume all voxel sizes are identical
voxel_size = (0.9,0.9,0.9)
if reextract == 1:
    # Generate feature structure Phi from all ROIs and all cases
    extractor = featureextractor.RadiomicsFeatureExtractor()
    extractor.enableAllFeatures()
    extractor.enableAllImageTypes()
    extractor.enableFeatureClassByName('shape2D',enabled = False)

    seg_labels_all = np.unique(np.asarray(segs))
    Phi_gt = []
    Phi_vd = []
    Phi_lr = []
    seg_labels = []
    reextract = 0
    x_row_gt = []
    x_row_lr = []

    keylib = []
    roilib = []
    loop_count = 1
    n_rois = seg_labels_all[seg_labels_all>0].__len__()
    roi_names = np.asarray(['Background','Right substantia nigra','Right subthalamic nucleus',
                            'Left subthalamic nucleus', 'Left substantia nigra', 'Right dentate nucleus', 'Left dentate nucleus'])
    for i in np.arange(subject_id_corr.__len__()):
        seg_sitk = sitk.GetImageFromArray(segs[i])
        seg_sitk.SetSpacing(voxel_size)
        qsm_sitk_gt = sitk.GetImageFromArray(qsms[i])
        qsm_sitk_gt.SetSpacing(voxel_size)
        qsm_sitk_lr = sitk.GetImageFromArray(laros[i])
        qsm_sitk_lr.SetSpacing(voxel_size)
        # Index back since subject 12 is missing ROIs
        for j in seg_labels_all:
            if j>0:
                fv_count = 0
                featureVector_gt = extractor.execute(qsm_sitk_gt,seg_sitk,label=int(j));
                featureVector_lr = extractor.execute(qsm_sitk_lr,seg_sitk,label=int(j));
                Phi_gt.append(featureVector_gt)
                Phi_lr.append(featureVector_lr)
                for key, value in six.iteritems(featureVector_gt):
                    if 'diagnostic' in key:
                        next
                    else:
                        x_row_gt.append(featureVector_gt[key])
                        x_row_lr.append(featureVector_lr[key])
                        fv_count = fv_count+1
                        keylib.append(key)
                        roilib.append(roi_names[int(j)])
                x_row_gt.append(pre_updrs_iii_off[i])
                x_row_lr.append(pre_updrs_iii_off[i])
                fv_count = fv_count+1
        print('Extracting features for subject',subject_id_corr[i],'and appending feature matrix with vector of length',fv_count,'with UPDRS score',pre_updrs_iii_off[i])
                
    X0_gt = np.array(x_row_gt)
    X0_lr = np.array(x_row_lr)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/X0_gt_chh_rois_rp.npy',X0_gt)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/X0_lr_chh_rois_rp.npy',X0_lr)

    K = np.asarray(keylib)
    R = np.asarray(roi_names)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/K_chh_rp.npy',K)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/R_chh_rp.npy',R)

    print('Saving ground truth feature vector')
    with open('/home/ali/RadDBS-QSM/data/npy/rp/Phi_mcl_gt_roi_chh_rp', 'wb') as fp:  
        pickle.dump(Phi_gt, fp)
    
    print('Saving undersampled feature vector')
    with open('/home/ali/RadDBS-QSM/data/npy/rp/Phi_mcl_lr_roi_chh_rp', 'wb') as fp:  
        pickle.dump(Phi_lr, fp)

else:
    X0_gt = np.load('/data/Ali/RadDBS-QSM/data/npy/rp/X0_gt_chh_rois_rp.npy')
    X0_lr = np.load('/data/Ali/RadDBS-QSM/data/npy/rp/X0_lr_chh_rois_rp.npy')
    K = np.load('/data/Ali/RadDBS-QSM/data/npy/rp/K_chh_rp.npy')
    R = np.load('/data/Ali/RadDBS-QSM/data/npy/rp/R_chh_rp.npy')
    n_rois = R.shape[0]-1
    with open('/data/Ali/RadDBS-QSM/data/npy/rp/Phi_mcl_gt_roi_chh_rp', "rb") as fp:  
        Phi_gt = pickle.load(fp)
    
    with open('/data/Ali/RadDBS-QSM/data/npy/rp/Phi_mcl_lr_roi_chh_rp', "rb") as fp:  
        Phi_lr = pickle.load(fp)

# %%
n_features = 1596
n_rois = 6
X_all_c = X0_gt.reshape(n_cases,n_rois,n_features)[:,0:4,:]
K_all_c = K.reshape(n_cases,n_rois,n_features-1)[:,0:4,:]
K_all_c = np.char.add(K_all_c[0,:,:].reshape(-1,1),' ')
R_all_c = np.repeat(R[1:5],n_features-1)
K_all_c = np.char.add(np.squeeze(K_all_c),np.squeeze(R_all_c))
K_all_c = np.append(K_all_c,['pre updrs']*5)
R_all_c = np.append(R_all_c,['pre updrs']*5)
K_all_c = np.append(K_all_c,['age'])
R_all_c = np.append(R_all_c,['age'])
K_all_c = np.append(K_all_c,['disease duration'])
R_all_c = np.append(R_all_c,['disease duration'])
K_all_c = np.append(K_all_c,['sex'])
R_all_c = np.append(R_all_c,['sex'])
K_all_c = np.append(K_all_c,['ledd'])
R_all_c = np.append(R_all_c,['ledd'])

# %%
n_cases = len(per_change)
n_roisc = Phi_gt.__len__()/n_cases
L = int(len(X0_gt)/n_cases)
n_features = int(L/n_rois)
subsc = subject_id_corr
pre_updrs_off = pre_updrs_iii_off
results_ls_aug = np.zeros_like(per_change)

results_lgr_aug = np.zeros_like(per_change)
results_lgrp_aug = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
results_lgr = np.zeros_like(per_change)
results_lgrp = np.zeros_like(per_change)
r = 1

# %%
if not sys.warnoptions:
    warnings.simplefilter("ignore",category=ConvergenceWarning)
    os.environ["PYTHONWARNINGS"] = "ignore::UserWarning"

# %%
# Noise compensated LASSO
retrain = 1
K_nz_nc = []
K_nz_nc_lr = []
E_nz_nc = []
E_nz_nc_lr = []
#R_nz_cd = []
if retrain == 1:

  aug = True
  K_nz = []
  c = 0

  for j in np.arange(len(subsc)):
      test_id = subsc[j]
      test_index = subsc == test_id
      train_index = subsc != test_id
      X_train = X_all_c[train_index,:,:]
      X_test = X_all_c[test_index,:,:]
      y_train = per_change[train_index]
      y_test = per_change[test_index]

      y_cat = y_train <= 0.3
      idy = np.where(y_cat==1)
      # Cross validation
                                            
      X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                  X_train,train_index,X_test,
                                                  test_index,pre_updrs_off,age,dd,sex,ledd,
                                                  None,None,None,None,None,False,False,False)
      cvn = 5
      cv_scores = np.zeros((cvn,1))
      cv_lgr_scores = np.zeros((cvn,1))
      rs = 1
      rcfs = 1000
      Mu = np.zeros((4,1))
      Sig = np.zeros((4,1))
      (mu, sigma) = stats.norm.fit(y_train)
      Mu[0,:] = mu
      kappa = stats.skew(y_train)
      D = []
      print('Label distribution of:',mu,sigma,kappa)
      print('Variance prior to noise compensation',np.var(y_train))
      for jj in np.arange(2,cvn):
        # Resample to avoid stratification errors
        while np.sum(y_cat) < cvn:
          np.random.seed(rs)
          idyr = np.random.choice(np.asarray(idy).ravel())
          X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
          y_train = np.append(y_train,y_train[idyr])
          y_cat = y_train <= 0.3
          rs = rs+1
          print('Resampled to size',y_train.shape)
        if aug == True:
          y_train_n = y_train+(1.96*sigma)*np.random.normal(0,1,1)
          Mu[jj-1,:] = np.mean(y_train_n)
          print('Variance of appended data',np.var(y_train_n))
          y_train = np.hstack((y_train,y_train_n))
          D[jj-2,:] = y_train
          y_cat = y_train <= 0.3
          X0_ss0 = np.vstack((X0_ss0,X0_ss0))
      print('Variance after noise compensation',np.var(y_train))
      print('Mean after noise compensation',np.mean(y_train))
      mQ,vQ = util.gmm(D)
      print('Mixture model prediction',muQ,vQ)

#       for jj in np.arange(2,cvn):
#         skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
#         skf_gen = skf_g.split(X0_ss0,y_cat)
#         lasso = slm.LassoLarsCV(max_iter=10000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
#         lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=jj,class_weight=None,penalty='l1',solver='liblinear',random_state=0)
#         with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
#           # Feature selection
#           warnings.filterwarnings("ignore", category=ConvergenceWarning)
#           sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen,n_jobs=1)
#           # Stratifies classifiers automatically
#           sel_lr = skf.RFECV(lgr,step=rcfs,cv=jj,n_jobs=1)
#           X0_ss = sel.fit_transform(X0_ss0,y_train)
#           X0_ssl = sel_lr.fit_transform(X0_ss0,y_cat)
#           est_ls = lasso.fit(X0_ss,y_train)
#           est_lgr = lgr.fit(X0_ssl,y_cat)
#           cv_scores[jj] = est_ls.score(X0_ss,y_train)
#           cv_lgr_scores[jj] = est_lgr.score(X0_ssl,y_cat)
#           print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
          
#       with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
#         best_cv = np.argmax(cv_scores)
#         best_cv_lgr = np.argmax(cv_lgr_scores)

#         # Break any ties
#         if np.sum(cv_scores == best_cv) > 1:
#           cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
#           cv_lgr_scores_tb = np.zeros((np.sum(cv_scores == best_cv_lgr),1))
#           for jjj in (cv_scores == cv_scores[best_cv]):
#             if jjj > 0:
#               print('Breaking tie')
#               skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
#               skf_gen = skf_g.split(X0_ss0,y_cat) 
#               X0_ss = sel.fit_transform(X0_ss0,y_train)
#               X0_ssl = sel_lr.fit_transform(X0_ss0,y_cat)
#               est_ls = lasso.fit(X0_ss,y_train)
#               est_lgr = lgr.fit(X0_ssl,y_cat)
#               lasso = slm.LassoLarsCV(max_iter=10000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
#               lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=jj,class_weight=None,penalty='l1',solver='liblinear',random_state=1)
#               est_ls = lasso.fit(X0_ss,y_train)
#               est_lgr = lgr.fit(X0_ssl,y_cat)
#               cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
#               cv_lgr_scores_tb[jj] = est_lgr.score(sel_lr.fit_transform(X0_ss0,y_cat),y_cat)
#           best_cv = np.argmax(cv_scores_tb)
#           best_cv_lgr = np.argmax(cv_lgr_scores_tb)
        
#         # Fit whole dataset with optimal cv
#         lasso = slm.LassoLarsCV(max_iter=10000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
#         lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=best_cv_lgr,class_weight=None,penalty='l1',solver='liblinear',random_state=0)
#         sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
#         sel_lr = skf.RFECV(lgr,step=rcfs,cv=best_cv)
#         X0_ss = sel.fit_transform(X0_ss0,y_train)
#         X_test_ss = sel.transform(X_test_ss0)
#         X0_ssl = sel_lr.fit_transform(X0_ss0,y_cat)
#         X_test_ssl = sel_lr.transform(X_test_ss0)
#         K_ss = sel.transform(K_all_c.reshape(1,-1))
#         K_ss_lr = sel_lr.transform(K_all_c.reshape(1,-1))
#         # R_ss = sel.transform(R_all_c.reshape(1,-1))


#       # LASSO
#       with warnings.catch_warnings():
#         warnings.filterwarnings("ignore", category=ConvergenceWarning)
#         lasso = slm.LassoLarsCV(max_iter=10000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
#         lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=best_cv_lgr,class_weight=None,penalty='l1',solver='liblinear',random_state=0)
#         est_ls = lasso.fit(X0_ss,y_train)
#         est_lgr = lgr.fit(X0_ssl,y_cat)
#       results_lgr_aug[c] = est_lgr.predict(X_test_ssl)
#       results_lgrp_aug[c] = est_lgr.predict_proba(X_test_ssl)[0][0]
#       results_ls_aug[c] = est_ls.predict(X_test_ss)
#       print('Lasso predicts',str(np.round(results_ls_aug[c],4)),'and logistic regression predicts',results_lgr_aug[c],
#                 'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv,'and',sum(y_cat),'minority cases')
#       K_nz_nc.append(np.squeeze(K_ss)[abs(est_ls.coef_)>0])
#       E_nz_nc.append(est_ls.coef_[abs(est_ls.coef_)>0])
#       K_nz_nc_lr.append(np.squeeze(K_ss_lr)[np.squeeze(abs(est_lgr.coef_)>0)])
#       E_nz_nc_lr.append(est_lgr.coef_[abs(est_lgr.coef_)>0])
#       c=c+1

#   # np.save('results_ls_aug_d_cvs.npy',results_ls_aug)
#   # np.save('results_lgr_aug_d_cvs.npy',results_lgr_aug)
#   # np.save('results_lgrp_aug_d_cvs.npy',results_lgrp_aug)
#   # np.save('results_K_nz_nc_cvs.npy',K_nz_nc)
#   # np.save('results_K_nz_nc_lr_cvs.npy',K_nz_nc_lr)
#   # np.save('beta_nz_nc_cvs.npy',E_nz_nc)
#   # np.save('beta_nz_nc_lr_cvs.npy',E_nz_nc_lr)
# else:
#   results_ls_aug = np.load('results_ls_aug_d.npy')
#   results_lgr_aug = np.load('results_lgr_aug_d.npy')
#   results_lgrp_aug = np.load('results_lgrp_aug_d.npy')
#   K_nz_nc = np.load('results_K_nz_nc.npy',allow_pickle=True)
# Out:
# Label distribution of: 0.5669595264848581 0.20858808082526412 -0.24474920851943865
# Variance prior to noise compensation 0.043508987462366915
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05112804287255427
# Variance of appended data 0.05114931897168323
# Variance of appended data 0.06948657934650121
# Variance after noise compensation 0.10239886603880406
# Mean after noise compensation 0.49292131073113454
# Mixture model prediction 0.5556320735361444
# Label distribution of: 0.5738548357091768 0.20932917254901903 -0.3279210191356042
# Variance prior to noise compensation 0.04381870248005698
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05172984864381298
# Variance of appended data 0.051751276195039594
# Variance of appended data 0.07021906879440742
# Variance after noise compensation 0.10336563879343959
# Mean after noise compensation 0.49927387947969193
# Mixture model prediction 0.5622773696945602
# Label distribution of: 0.5677185809199048 0.20908232478622193 -0.24926099868801613
# Variance prior to noise compensation 0.04371541853801119
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05135732549408303
# Variance of appended data 0.05137870253897709
# Variance of appended data 0.06980296517710487
# Variance after noise compensation 0.10287140624440165
# Mean after noise compensation 0.4935204842632965
# Mixture model prediction 0.5563759508936796
# Label distribution of: 0.5752269235227969 0.2084721065940771 -0.34398027688109245
# Variance prior to noise compensation 0.04346061922777225
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05145254388351355
# Variance of appended data 0.05147379633034871
# Variance of appended data 0.06979067147068153
# Variance after noise compensation 0.10266637010850123
# Mean after noise compensation 0.500781723313047
# Mixture model prediction 0.563569656517116
# Label distribution of: 0.5827907017222488 0.19744836811095323 -0.25025976222641483
# Variance prior to noise compensation 0.0389858580696785
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# Variance of appended data 0.049336824746963236
# Variance of appended data 0.05060622879794644
# Variance of appended data 0.08849552172715537
# Variance after noise compensation 0.09287438638729682
# Mean after noise compensation 0.32499236863462844
# Mixture model prediction 0.4148923737634127
# Label distribution of: 0.5746924331750638 0.20884605172212908 -0.33822865445502964
# Variance prior to noise compensation 0.043616673319922215
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05157623695904256
# Variance of appended data 0.0515975657170614
# Variance of appended data 0.06998021128063804
# Variance after noise compensation 0.10297395672487421
# Mean after noise compensation 0.5001846244560163
# Mixture model prediction 0.563067451260097
# Label distribution of: 0.5624312245980657 0.20344924934212058 -0.28703446866429055
# Variance prior to noise compensation 0.041391597057872355
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.048922145842147616
# Variance of appended data 0.04894238652742834
# Variance of appended data 0.06638725336640638
# Variance after noise compensation 0.09769784431498425
# Mean after noise compensation 0.4898783026479929
# Mixture model prediction 0.5511287892545607
# Label distribution of: 0.5758937568978073 0.20793336707043802 -0.35000008336051325
# Variance prior to noise compensation 0.043236285141249525
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05127018354255225
# Variance of appended data 0.05129132628896593
# Variance of appended data 0.06951365377844679
# Variance after noise compensation 0.10221965534444016
# Mean after noise compensation 0.501544187925957
# Mixture model prediction 0.5641940508136866
# Label distribution of: 0.5702986081106105 0.20999601422390549 -0.27751686488556404
# Variance prior to noise compensation 0.04409832598992672
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05183511136428681
# Variance of appended data 0.05185667565272249
# Variance of appended data 0.07044231813567672
# Variance after noise compensation 0.10380040878043066
# Mean after noise compensation 0.4957430094215321
# Mixture model prediction 0.5588814684604541
# Label distribution of: 0.5643062245980658 0.2060398064467874 -0.25159784666703033
# Variance prior to noise compensation 0.04245240184062962
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05000966179862123
# Variance of appended data 0.05003042122242085
# Variance of appended data 0.06792237393130329
# Variance after noise compensation 0.10003540853970827
# Mean after noise compensation 0.4910260073215353
# Mixture model prediction 0.5530072741296651
# Label distribution of: 0.5691451725886095 0.20973322323580731 -0.2629533781637346
# Variance prior to noise compensation 0.04398802492888099
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.0516791072376572
# Variance of appended data 0.05170061758835621
# Variance of appended data 0.07023977268114158
# Variance after noise compensation 0.10351442630850363
# Mean after noise compensation 0.4947140485269073
# Mixture model prediction 0.5577657017416879
# Label distribution of: 0.5669751715300725 0.2085993111100245 -0.24481874200363993
# Variance prior to noise compensation 0.043513672595576786
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051133175775093194
# Variance of appended data 0.05115445416527429
# Variance of appended data 0.06949368913229888
# Variance after noise compensation 0.10240951988426363
# Mean after noise compensation 0.49293340727041474
# Mixture model prediction 0.5556474369743303
# Label distribution of: 0.5783286604955017 0.20527469945818264 -0.35630765675696446
# Variance prior to noise compensation 0.04213770223764721
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05033994928947291
# Variance of appended data 0.050360554823689264
# Variance of appended data 0.06811987450899855
# Variance after noise compensation 0.09999485523108247
# Mean after noise compensation 0.5044960771602433
# Mixture model prediction 0.5664533041969584
# Label distribution of: 0.5679867801536214 0.20923231991769523 -0.25136542100761594
# Variance prior to noise compensation 0.04377816369814076
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05142869512120355
# Variance of appended data 0.05145010284877547
# Variance of appended data 0.06990081000803927
# Variance after noise compensation 0.10301671452643393
# Mean after noise compensation 0.4937381707092523
# Mixture model prediction 0.5566380505077447
# Label distribution of: 0.5774859976810078 0.2063190239320207 -0.3574795129443696
# Variance prior to noise compensation 0.042567539636261725
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.050708845455760945
# Variance of appended data 0.05072966118248315
# Variance of appended data 0.06867013976752656
# Variance after noise compensation 0.10087027013154393
# Mean after noise compensation 0.5034443546739388
# Mixture model prediction 0.5656751459665649
# Label distribution of: 0.5705357997614644 0.21002096073970725 -0.2807677568009367
# Variance prior to noise compensation 0.04410880395002965
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051855646446524545
# Variance of appended data 0.051877215858731895
# Variance of appended data 0.07046727437372481
# Variance after noise compensation 0.10383329105047745
# Mean after noise compensation 0.49596166390948776
# Mixture model prediction 0.5591100435726155
# Label distribution of: 0.5607985715368413 0.2006390097129064 -0.34802680409786524
# Variance prior to noise compensation 0.04025601221857575
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.047774739991122986
# Variance of appended data 0.047794425370086116
# Variance of appended data 0.06476068960095038
# Variance after noise compensation 0.09521226966524396
# Mean after noise compensation 0.48901349683022677
# Mixture model prediction 0.5494765130603178
# Label distribution of: 0.5636330386570226 0.20518643494540414 -0.26076044933979126
# Variance prior to noise compensation 0.042101473085604565
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.04964752701653195
# Variance of appended data 0.04966811483452287
# Variance of appended data 0.06741216541262206
# Variance after noise compensation 0.0992597406649814
# Mean after noise compensation 0.4905953269104257
# Mixture model prediction 0.5523351322096153
# Label distribution of: 0.5841874969994993 0.19415564179220104 -0.16306203646880674
# Variance prior to noise compensation 0.03769641323974149
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# Variance of appended data 0.046008710210053275
# Variance of appended data 0.047236129126639395
# Variance of appended data 0.08387224576843104
# Variance after noise compensation 0.08810628087558633
# Mean after noise compensation 0.33261587404939813
# Mixture model prediction 0.42053478044106873
# Label distribution of: 0.5753580538663584 0.20837251231034953 -0.34527291849868297
# Variance prior to noise compensation 0.04341910388652677
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05141914222651492
# Variance of appended data 0.051440374372153326
# Variance of appended data 0.06973975249252846
# Variance after noise compensation 0.10258404693335592
# Mean after noise compensation 0.5009301190905707
# Mixture model prediction 0.563692631241578
# Label distribution of: 0.5710026531694943 0.21004110516915736 -0.28733840263675836
# Variance prior to noise compensation 0.04411726586068102
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051884559788910135
# Variance of appended data 0.051906133339031525
# Variance of appended data 0.070499758203598
# Variance after noise compensation 0.10387217587576714
# Mean after noise compensation 0.49639905794301803
# Mixture model prediction 0.5595590711890491
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Variance prior to noise compensation 0.04391234105884889
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051585812909952324
# Variance of appended data 0.05160728625088356
# Variance of appended data 0.07011454368500354
# Variance after noise compensation 0.10333194639999639
# Mean after noise compensation 0.49429890635180374
# Mixture model prediction 0.5572949846113204
# Label distribution of: 0.5694255265923677 0.20981871046638942 -0.2662656536773807
# Variance prior to noise compensation 0.04402389126177855
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.0517255932905597
# Variance of appended data 0.05174712118006388
# Variance of appended data 0.070301392466615
# Variance after noise compensation 0.10360317710988375
# Mean after noise compensation 0.4949589031699504
# Mixture model prediction 0.5580375465406049
# Label distribution of: 0.5738037736176735 0.20935457901382964 -0.3272511581002607
# Variance prior to noise compensation 0.04382933975405784
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.0517376248921692
# Variance of appended data 0.05175905764507274
# Variance of appended data 0.07023133342077743
# Variance after noise compensation 0.10338594996448829
# Mean after noise compensation 0.4992193398660533
# Mixture model prediction 0.5622290832612066
# Label distribution of: 0.5790052986721398 0.2043392189714069 -0.3521164038418525
# Variance prior to noise compensation 0.04175451640984457
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# Variance of appended data 0.052882105755659645
# Variance of appended data 0.05424165906298379
# Variance of appended data 0.09482173557540796
# Variance after noise compensation 0.09951157402866413
# Mean after noise compensation 0.31143405162348026
# Mixture model prediction 0.4046654924383054
# Label distribution of: 0.5703496493519336 0.21000221972805436 -0.27821061318927803
# Variance prior to noise compensation 0.04410093229071002
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051839862879532836
# Variance of appended data 0.051861428442461825
# Variance of appended data 0.07044816937469897
# Variance after noise compensation 0.10380823155047648
# Mean after noise compensation 0.4957898584863651
# Mixture model prediction 0.5589306805572264
# Label distribution of: 0.572169786689569 0.20992345901172824 -0.3042853268818935
# Variance prior to noise compensation 0.04406785864344875
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051890090030071105
# Variance of appended data 0.051911639419831325
# Variance of appended data 0.07048444116118521
# Variance after noise compensation 0.10381948484252951
# Mean after noise compensation 0.4975333107878819
# Mixture model prediction 0.5606766141954196
# Label distribution of: 0.5629738602569804 0.2042678402570905 -0.27346537727473835
# Variance prior to noise compensation 0.041725350563296244
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.04926218573902516
# Variance of appended data 0.04928258963133691
# Variance of appended data 0.06686811993519698
# Variance after noise compensation 0.09843117805655321
# Mean after noise compensation 0.49019374352069206
# Mixture model prediction 0.5516744937114798
# Label distribution of: 0.5735011834458024 0.20949562291124812 -0.3232022231648087
# Variance prior to noise compensation 0.043888416018971865
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051779960658007905
# Variance of appended data 0.05180142229948233
# Variance of appended data 0.0702985963069061
# Variance after noise compensation 0.10349790097325466
# Mean after noise compensation 0.49889845051399273
# Mixture model prediction 0.5619426568490217
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Variance prior to noise compensation 0.04391234105884889
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051585812909952324
# Variance of appended data 0.051607286250883566
# Variance of appended data 0.07011454368500354
# Variance after noise compensation 0.10333194639999639
# Mean after noise compensation 0.4942989063518036
# Mixture model prediction 0.5572949846113204
# Label distribution of: 0.5776164097832509 0.206166083456723 -0.3575627941827524
# Variance prior to noise compensation 0.042504453967884465
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.0506550056536539
# Variance of appended data 0.05067579053118812
# Variance of appended data 0.06858968108478276
# Variance after noise compensation 0.10074209042091815
# Mean after noise compensation 0.503605014721761
# Mixture model prediction 0.5657958349187755
# Label distribution of: 0.5731361230448997 0.20964415222225632 -0.31816132090731236
# Variance prior to noise compensation 0.043950670560988586
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.051822505388325855
# Variance of appended data 0.051843997472563595
# Variance of appended data 0.0703674092256362
# Variance after noise compensation 0.10361380621599078
# Mean after noise compensation 0.4985165624681548
# Mixture model prediction 0.5615964500684301
# Label distribution of: 0.5652707307709053 0.20711530756483246 -0.2442832622694056
# Variance prior to noise compensation 0.042896750627675145
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05047322075734211
# Variance of appended data 0.050494197469784646
# Variance of appended data 0.06857342503566845
# Variance after noise compensation 0.10102258639681087
# Mean after noise compensation 0.49167877450297376
# Mixture model prediction 0.5539658819362545
# Label distribution of: 0.5644585150464088 0.20622109204736833 -0.2500116622013785
# Variance prior to noise compensation 0.04252713880520916
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05008718490544752
# Variance of appended data 0.05010798087597369
# Variance of appended data 0.06803143216156522
# Variance after noise compensation 0.10020100139760048
# Mean after noise compensation 0.491126292661985
# Mixture model prediction 0.5531589763778569
# Label distribution of: 0.5670343992012403 0.20864142707871972 -0.24509142715462312
# Variance prior to noise compensation 0.04353124509344471
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05115245225649613
# Variance of appended data 0.051173739239711184
# Variance of appended data 0.06952038029654925
# Variance after noise compensation 0.1024495037294395
# Mean after noise compensation 0.4929792980537743
# Mixture model prediction 0.5557055866349796
# Label distribution of: 0.5781196303951672 0.20554616966278674 -0.356990224910928
# Variance prior to noise compensation 0.04224922786304311
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.05043609336361382
# Variance of appended data 0.05045675343438457
# Variance of appended data 0.0682630766136988
# Variance after noise compensation 0.10022242067243227
# Mean after noise compensation 0.5042321750959526
# Mixture model prediction 0.566260646474958
# Label distribution of: 0.5637275208943621 0.2053113472299323 -0.2592529006209024
# Variance prior to noise compensation 0.042152749301369835
# Resampled to size (37,)
# Resampled to size (38,)
# Variance of appended data 0.04970026680504459
# Variance of appended data 0.04972087969734576
# Variance of appended data 0.06748654110516919
# Variance after noise compensation 0.09937290414856188
# Mean after noise compensation 0.4906545258330207
# Mixture model prediction 0.5524296217091035

# %%
# Vanilla Lasso
if retrain == 1:
  Js = []
  aug = False
  K_nz_vl = []
  K_nz_vl_lr = []
  err_var = np.zeros_like(per_change)
  rerror = np.zeros_like(per_change)
  kappa = []
  K_nz = []
  E_nz_vl = []
  E_nz_vl_lr = []
  c = 0

  for j in np.arange(len(subsc)):
      test_id = subsc[j]
      test_index = subsc == test_id
      train_index = subsc != test_id
      X_train = X_all_c[train_index,:,:]
      X_test = X_all_c[test_index,:,:]
      y_train = per_change[train_index]
      y_test = per_change[test_index]

      y_cat = y_train <= 0.3
      idy = np.where(y_cat==1)
      # Cross validation
      X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                  X_train,train_index,X_test,
                                                  test_index,pre_updrs_off,age,dd,sex,ledd,None,None,None,None,None,False,False,False)
      cvn = 5
      cv_scores = np.zeros((cvn,1))
      cv_lgr_scores = np.zeros((cvn,1))
      rs = 1
      rcfs = 1000
      (mu, sigma) = stats.norm.fit(y_train)
      kappa = stats.skew(y_train)
      print('Label distribution of:',mu,sigma,kappa)
      for jj in np.arange(2,cvn):
        # Resample to avoid stratification errors
        while np.sum(y_cat) < cvn:
          np.random.seed(rs)
          idyr = np.random.choice(np.asarray(idy).ravel())
          X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
          y_train = np.append(y_train,y_train[idyr])
          y_cat = y_train <= 0.3
          rs = rs+1
          print('Resampled to size',y_train.shape)
        if aug == True:
          y_train_n = y_train+(1.96*sigma)*np.random.normal(0,1,1)
          y_train = np.hstack((y_train,y_train_n))
          y_cat = y_train <= 0.3
          X0_ss0 = np.vstack((X0_ss0,X0_ss0))
        else:
          y_train_n = y_train
          y_train = np.hstack((y_train,y_train_n))
          y_cat = y_train <= 0.3
          X0_ss0 = np.vstack((X0_ss0,X0_ss0))
          
      
      for jj in np.arange(2,cvn):
        skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
        skf_gen = skf_g.split(X0_ss0,y_cat)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
        with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
          warnings.filterwarnings("ignore", category=UserWarning)
          warnings.filterwarnings("ignore", category=ConvergenceWarning)
          lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=jj,class_weight=None,penalty='l1',solver='liblinear',random_state=0)
          print('Found minority samples:',sum(y_cat))
          # Feature selection
          sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen,n_jobs=1)
          # Stratifies classifiers automatically
          sel_lr = skf.RFECV(lgr,step=rcfs,cv=jj,n_jobs=1)
          X0_ss = sel.fit_transform(X0_ss0,y_train)
          X0_ssl = sel_lr.fit_transform(X0_ss0,y_cat)
          est_ls = lasso.fit(X0_ss,y_train)
          est_lgr = lgr.fit(X0_ssl,y_cat)
          cv_scores[jj] = est_ls.score(X0_ss,y_train)
          cv_lgr_scores[jj] = est_lgr.score(X0_ssl,y_cat)
          print('LogisticRegressionCV score for',jj,'is',cv_lgr_scores[jj],'from dataset of size',X0_ss.shape)
          
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
        best_cv = np.argmax(cv_scores)
        best_cv_lgr = np.argmax(cv_lgr_scores)

        # Break any ties
        if np.sum(cv_scores == best_cv) > 1:
          cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
          cv_lgr_scores_tb = np.zeros((np.sum(cv_scores == best_cv_lgr),1))
          for jjj in (cv_scores == cv_scores[best_cv]):
            if jjj > 0:
              print('Breaking tie')
              skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
              skf_gen = skf_g.split(X0_ss0,y_cat) 
              X0_ss = sel.fit_transform(X0_ss0,y_train)
              X0_ssl = sel_lr.fit_transform(X0_ss0,y_cat)
              est_ls = lasso.fit(X0_ss,y_train)
              est_lgr = lgr.fit(X0_ssl,y_cat)
              lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
              lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=jj,class_weight=None,penalty='l1',solver='liblinear',random_state=1)
              est_ls = lasso.fit(X0_ss,y_train)
              est_lgr = lgr.fit(X0_ssl,y_cat)
              cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
              cv_lgr_scores_tb[jj] = est_lgr.score(sel_lr.fit_transform(X0_ss0,y_cat),y_cat)
          best_cv = np.argmax(cv_scores_tb)
          best_cv_lgr = np.argmax(cv_lgr_scores_tb)
        
        # Fit whole dataset with optimal cv
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
        lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=jj,class_weight=None,penalty='l1',solver='liblinear',random_state=0)
        sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
        sel_lr = skf.RFECV(lgr,step=rcfs,cv=best_cv)
        X0_ss = sel.fit_transform(X0_ss0,y_train)
        X_test_ss = sel.transform(X_test_ss0)
        X0_ssl = sel_lr.fit_transform(X0_ss0,y_cat)
        X_test_ssl = sel_lr.transform(X_test_ss0)
        K_ss = sel.transform(K_all_c.reshape(1,-1))
        K_ss_lr = sel_lr.transform(K_all_c.reshape(1,-1))

      # LASSO
      with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
        lgr = slm.LogisticRegressionCV(n_jobs=-1,cv=best_cv_lgr,class_weight=None,penalty='l1',solver='liblinear',random_state=0)
        est_ls = lasso.fit(X0_ss,y_train)
        est_lgr = lgr.fit(X0_ssl,y_cat)
      results_lgr[c] = est_lgr.predict(X_test_ssl)
      results_lgrp[c] = est_lgr.predict_proba(X_test_ssl)[0][0]
      results_ls[c] = est_ls.predict(X_test_ss)
      print('Lasso predicts',str(np.round(results_ls[c],4)),'and logistic regression predicts',results_lgr[c],
                'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv,'and',sum(y_cat),'minority cases')
      K_nz_vl.append(np.squeeze(K_ss)[abs(est_ls.coef_)>0])
      E_nz_vl.append(est_ls.coef_[abs(est_ls.coef_)>0])
      K_nz_vl_lr.append(np.squeeze(K_ss_lr)[np.squeeze(abs(est_lgr.coef_)>0)])
      E_nz_vl_lr.append(est_lgr.coef_[abs(est_lgr.coef_)>0])
      c=c+1

  np.save('results_ls_d_cvs.npy',results_ls)
  np.save('results_lgr_d_cvs.npy',results_lgr)
  np.save('results_lgrp_d_cvs.npy',results_lgrp)
  np.save('results_K_nz_vl_cvs.npy',K_nz_vl)
  np.save('results_K_nz_vl_lr_cvs.npy',K_nz_vl_lr)
  np.save('beta_nz_vl_cvs.npy',E_nz_vl)
  np.save('beta_nz_vl_lr_cvs.npy',E_nz_vl_lr)

    
else:
  results_ls = np.load('results_ls_d.npy')
  results_lgr = np.load('results_lgr_d.npy')
  results_lgrp = np.load('results_lgrp_d.npy')
  K_nz_vl = np.load('results_K_nz_nc.npy',allow_pickle=True)
# Out:
# Label distribution of: 0.5669595264848581 0.20858808082526412 -0.24474920851943865
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 5389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.6617 and logistic regression predicts 0.0 for case with 0.72 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5738548357091768 0.20932917254901903 -0.3279210191356042
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 2389)
# Lasso predicts 0.4924 and logistic regression predicts 0.0 for case with 0.47 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5677185809199048 0.20908232478622193 -0.24926099868801613
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 4389)
# Lasso predicts 0.8319 and logistic regression predicts 0.0 for case with 0.69 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5752269235227969 0.2084721065940771 -0.34398027688109245
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.6723 and logistic regression predicts 0.0 for case with 0.42 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5827907017222488 0.19744836811095323 -0.25025976222641483
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (312, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (312, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (312, 389)
# Lasso predicts 0.4276 and logistic regression predicts 0.0 for case with 0.15 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5746924331750638 0.20884605172212908 -0.33822865445502964
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.4882 and logistic regression predicts 0.0 for case with 0.44 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5624312245980657 0.20344924934212058 -0.28703446866429055
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.7559 and logistic regression predicts 0.0 for case with 0.88 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5758937568978073 0.20793336707043802 -0.35000008336051325
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.4145 and logistic regression predicts 0.0 for case with 0.4 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5702986081106105 0.20999601422390549 -0.27751686488556404
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.5741 and logistic regression predicts 0.0 for case with 0.6 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5643062245980658 0.2060398064467874 -0.25159784666703033
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.4976 and logistic regression predicts 0.0 for case with 0.81 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5691451725886095 0.20973322323580731 -0.2629533781637346
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 5389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 4389)
# Lasso predicts 0.7945 and logistic regression predicts 0.0 for case with 0.64 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5669751715300725 0.2085993111100245 -0.24481874200363993
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.5943 and logistic regression predicts 0.0 for case with 0.72 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5783286604955017 0.20527469945818264 -0.35630765675696446
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.6238 and logistic regression predicts 0.0 for case with 0.31 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5679867801536214 0.20923231991769523 -0.25136542100761594
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 6389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 6389)
# Lasso predicts 0.5076 and logistic regression predicts 0.0 for case with 0.68 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5774859976810078 0.2063190239320207 -0.3574795129443696
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.3711 and logistic regression predicts 0.0 for case with 0.34 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5705357997614644 0.21002096073970725 -0.2807677568009367
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 2389)
# Lasso predicts 0.4496 and logistic regression predicts 0.0 for case with 0.59 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5607985715368413 0.2006390097129064 -0.34802680409786524
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.6615 and logistic regression predicts 0.0 for case with 0.94 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5636330386570226 0.20518643494540414 -0.26076044933979126
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.6824 and logistic regression predicts 0.0 for case with 0.84 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5841874969994993 0.19415564179220104 -0.16306203646880674
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (312, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (312, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (312, 6389)
# Lasso predicts 0.3549 and logistic regression predicts 0.0 for case with 0.1 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5753580538663584 0.20837251231034953 -0.34527291849868297
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 6389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.454 and logistic regression predicts 0.0 for case with 0.41 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5710026531694943 0.21004110516915736 -0.28733840263675836
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.6382 and logistic regression predicts 0.0 for case with 0.57 and selected CV 2 and 40 minority cases
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.7629 and logistic regression predicts 0.0 for case with 0.66 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5694255265923677 0.20981871046638942 -0.2662656536773807
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 6389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 4389)
# Lasso predicts 0.6074 and logistic regression predicts 0.0 for case with 0.63 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5738037736176735 0.20935457901382964 -0.3272511581002607
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.6461 and logistic regression predicts 0.0 for case with 0.47 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5790052986721398 0.2043392189714069 -0.3521164038418525
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (312, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (312, 5389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (312, 2389)
# Lasso predicts 0.3293 and logistic regression predicts 0.0 for case with 0.28 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5703496493519336 0.21000221972805436 -0.27821061318927803
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 3389)
# Lasso predicts 0.6726 and logistic regression predicts 0.0 for case with 0.59 and selected CV 4 and 40 minority cases
# Label distribution of: 0.572169786689569 0.20992345901172824 -0.3042853268818935
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 3389)
# Lasso predicts 0.6184 and logistic regression predicts 0.0 for case with 0.53 and selected CV 4 and 40 minority cases
# Label distribution of: 0.5629738602569804 0.2042678402570905 -0.27346537727473835
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.6011 and logistic regression predicts 0.0 for case with 0.86 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5735011834458024 0.20949562291124812 -0.3232022231648087
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.4549 and logistic regression predicts 0.0 for case with 0.48 and selected CV 2 and 40 minority cases
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 6389)
# Lasso predicts 0.6536 and logistic regression predicts 0.0 for case with 0.66 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5776164097832509 0.206166083456723 -0.3575627941827524
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.5373 and logistic regression predicts 0.0 for case with 0.33 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5731361230448997 0.20964415222225632 -0.31816132090731236
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.4748 and logistic regression predicts 0.0 for case with 0.49 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5652707307709053 0.20711530756483246 -0.2442832622694056
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 4389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.7493 and logistic regression predicts 1.0 for case with 0.78 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5644585150464088 0.20622109204736833 -0.2500116622013785
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 6389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.5938 and logistic regression predicts 0.0 for case with 0.81 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5670343992012403 0.20864142707871972 -0.24509142715462312
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 2389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 2389)
# Lasso predicts 0.7003 and logistic regression predicts 0.0 for case with 0.71 and selected CV 3 and 40 minority cases
# Label distribution of: 0.5781196303951672 0.20554616966278674 -0.356990224910928
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 3389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 1389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.4526 and logistic regression predicts 0.0 for case with 0.32 and selected CV 2 and 40 minority cases
# Label distribution of: 0.5637275208943621 0.2053113472299323 -0.2592529006209024
# Resampled to size (37,)
# Resampled to size (38,)
# Found minority samples: 40
# LogisticRegressionCV score for 2 is [1.] from dataset of size (304, 6389)
# Found minority samples: 40
# LogisticRegressionCV score for 3 is [1.] from dataset of size (304, 5389)
# Found minority samples: 40
# LogisticRegressionCV score for 4 is [1.] from dataset of size (304, 6389)
# Lasso predicts 0.7293 and logistic regression predicts 0.0 for case with 0.83 and selected CV 2 and 40 minority cases

# %%
# SMOGN LASSO
if retrain == 1:
  results_ls_smogn = np.zeros_like(per_change)
  aug = False
  c = 0
  K_nz_smogn = []
  #R_nz_smogn = []
  for j in np.arange(c,len(subsc)):
      test_id = subsc[j]
      test_index = subsc == test_id
      train_index = subsc != test_id
      X_train = X_all_c[train_index,:,:]
      X_test = X_all_c[test_index,:,:]
      y_train = per_change[train_index]
      y_test = per_change[test_index]

      y_cat = y_train <= 0.3
      idy = np.where(y_cat==1)
      # Cross validation
      X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                  X_train,train_index,X_test,
                                                  test_index,pre_updrs_off,age,dd,sex,ledd,None,None,None,None,None,False,False,False)
      X_smogn,y_smogn,idx_kept,sscaler = util.rad_smogn(X0_ss0,y_train,np.amax(y_train),np.amin(y_train),1,0,0.05,0.02)
      X0_ss00 = X0_ss0
      X0_ss0 = np.vstack((X0_ss0,X_smogn))
      y_train = np.hstack((y_train,y_smogn))
      y_train_0 = y_train
      cvn = 5

      cv_scores = np.zeros((cvn,1))
      rs = 1
      rcfs = 1000
      (mu, sigma) = stats.norm.fit(y_train)
      kappa = stats.skew(y_train)
      print('Label distribution of:',mu,sigma,kappa)
      for jj in np.arange(2,cvn):
        # Resample to avoid stratification errors
        while np.sum(y_cat) < cvn:
          np.random.seed(rs)
          idyr = np.random.choice(np.asarray(idy).ravel())
          X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
          y_train = np.append(y_train,y_train[idyr])
          y_cat = y_train <= 0.3
          rs = rs+1
          print('Resampled to size',y_train.shape)

      for jj in np.arange(2,cvn):
        skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
        skf_gen = skf_g.split(X0_ss0,y_cat)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
        with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
          # Feature selection
          warnings.filterwarnings("ignore", category=ConvergenceWarning)
          sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
          X0_sst = sel.fit_transform(X0_ss0,y_train)
          X0_ss = X0_sst
          est_ls = lasso.fit(X0_ss,y_train)
          cv_scores[jj] = est_ls.score(X0_ss,y_train)
          print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
          
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
        best_cv = np.argmax(cv_scores)
        # Break any ties
        if np.sum(cv_scores == best_cv) > 1:
          cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
          for jjj in (cv_scores == cv_scores(best_cv)):
            if jjj > 0:
              skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
              skf_gen = skf_g.split(X0_ss0,y_cat) 
              X0_sst = sel.fit_transform(X0_ss0,y_train)
              X0_ss = X0_sst
              lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
              est_ls = lasso.fit(X0_ss,y_train)
              cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
          best_cv = np.argmax(cv_scores_tb)
        
        # Fit whole dataset with optimal cv
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
        sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
        X0_ss = sel.fit_transform(X0_ss0,y_train)
        X_test_ss = sel.transform(X_test_ss0)
        K_ss = sel.transform(K_all_c.reshape(1,-1))
        #R_ss = sel.transform(R_all_c.reshape(1,-1))
        
      # LASSO
      with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
        est_ls = lasso.fit(X0_ss,y_train)
        results_ls_smogn[c] = est_ls.predict(X_test_ss)
        if results_ls_smogn[c] < 0:
            dx, y_n = cKDTree(X0_ss00.reshape(X0_ss00.shape[0],-1)).query(X_test_ss0.reshape(1,-1),k=15)
            results_ls_smogn[c] = np.mean((y_train_0[y_n]))
            print('Using nearest neighbor')
        print('Lasso predicts',str(np.round(results_ls_smogn[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
        K_nz_smogn.append(np.squeeze(K_ss)[abs(est_ls.coef_)>0])
        #R_nz_smogn.append(np.squeeze(R_ss)[est_ls.coef_>0])
        c=c+1


  np.save('results_ls_smogn_d_cvs.npy',results_ls_smogn)
  np.save('results_K_nz_smogn_cvs.npy',K_nz_smogn)
  np.save('beta_nz_smogn_cvs.npy',est_ls.coef_[abs(est_ls.coef_)>0])

else:
  results_ls_smogn = np.load('results_ls_smogn_d.npy')
  K_nz_smogn = np.load('results_K_nz_smogn.npy',allow_pickle=True)
# Out:
# Prior to SMOGN sampling, mean is 2.2468824132321007e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.23it/s]
# Label distribution of: 0.5097364040438532 0.20332520415073296 0.08237370462348446
# Resampled to size (57,)
# LassoCV score for 2 is [0.97761652] from dataset of size (57, 1389)
# LassoCV score for 3 is [0.99610245] from dataset of size (57, 6389)
# LassoCV score for 4 is [1.] from dataset of size (57, 1389)
# Lasso predicts 0.7726 for case with 0.72 and selected CV 4
# Prior to SMOGN sampling, mean is 4.6248731276487835e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.20it/s]
# Label distribution of: 0.5115571648715442 0.20954433140615836 0.08753124037415931
# Resampled to size (59,)
# LassoCV score for 2 is [1.] from dataset of size (59, 6389)
# LassoCV score for 3 is [0.99806905] from dataset of size (59, 3389)
# LassoCV score for 4 is [1.] from dataset of size (59, 1389)
# Lasso predicts 0.4807 for case with 0.47 and selected CV 2
# Prior to SMOGN sampling, mean is 1.0800061756392543e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
# Label distribution of: 0.5081366629563943 0.20299119391239517 0.10034801500266617
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 389)
# LassoCV score for 3 is [0.99822042] from dataset of size (57, 1389)
# LassoCV score for 4 is [0.9994322] from dataset of size (57, 4389)
# Lasso predicts 0.736 for case with 0.69 and selected CV 2
# Prior to SMOGN sampling, mean is 3.870351650709048e-15 standard deviation is 0.9427168073551743
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.20it/s]
# Label distribution of: 0.5112499379153363 0.2064610733097769 0.047034555526658486
# Resampled to size (59,)
# LassoCV score for 2 is [0.99999739] from dataset of size (59, 3389)
# LassoCV score for 3 is [0.99996763] from dataset of size (59, 3389)
# LassoCV score for 4 is [0.99979551] from dataset of size (59, 4389)
# Lasso predicts 0.5771 for case with 0.42 and selected CV 2
# Prior to SMOGN sampling, mean is 3.4902487907243405e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.19it/s]
# Label distribution of: 0.5245124710039321 0.19657413472543106 0.1466536405359695
# Resampled to size (59,)
# LassoCV score for 2 is [0.99998952] from dataset of size (59, 389)
# LassoCV score for 3 is [0.99945326] from dataset of size (59, 3389)
# LassoCV score for 4 is [0.99965768] from dataset of size (59, 5389)
# Lasso predicts 0.5012 for case with 0.15 and selected CV 2
# Prior to SMOGN sampling, mean is 2.905389611170497e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.20it/s]
# Label distribution of: 0.5125981992164254 0.2092535091239188 0.07414598113452366
# Resampled to size (59,)
# LassoCV score for 2 is [1.] from dataset of size (59, 3389)
# LassoCV score for 3 is [0.99948041] from dataset of size (59, 1389)
# LassoCV score for 4 is [1.] from dataset of size (59, 3389)
# Lasso predicts 0.4819 for case with 0.44 and selected CV 4
# Prior to SMOGN sampling, mean is 4.839267946268247e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.19it/s]
# Label distribution of: 0.5047376481780691 0.19827485576896173 0.055012328364827515
# Resampled to size (57,)
# LassoCV score for 2 is [0.99816633] from dataset of size (57, 5389)
# LassoCV score for 3 is [0.97058928] from dataset of size (57, 6389)
# LassoCV score for 4 is [1.] from dataset of size (57, 3389)
# Lasso predicts 0.6579 for case with 0.88 and selected CV 4
# Prior to SMOGN sampling, mean is 2.7741577394852696e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.19it/s]
# Label distribution of: 0.5144230819640111 0.20839507387811207 0.05461299687433111
# Resampled to size (59,)
# LassoCV score for 2 is [0.99937746] from dataset of size (59, 389)
# LassoCV score for 3 is [1.] from dataset of size (59, 4389)
# LassoCV score for 4 is [0.99956219] from dataset of size (59, 389)
# Lasso predicts 0.6029 for case with 0.4 and selected CV 3
# Prior to SMOGN sampling, mean is 3.586015928724389e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.23it/s]
# Label distribution of: 0.5105399327157689 0.20462804990581882 0.07972078202615673
# Resampled to size (57,)
# LassoCV score for 2 is [0.99865405] from dataset of size (57, 5389)
# LassoCV score for 3 is [0.99813341] from dataset of size (57, 1389)
# LassoCV score for 4 is [0.99689188] from dataset of size (57, 5389)
# Lasso predicts 0.5703 for case with 0.6 and selected CV 2
# Prior to SMOGN sampling, mean is 4.2031270089466355e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.12it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
# Label distribution of: 0.5059430053209263 0.2003366023712236 0.08790467565905537
# Resampled to size (57,)
# LassoCV score for 2 is [0.99998385] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.99995413] from dataset of size (57, 389)
# LassoCV score for 4 is [0.99999929] from dataset of size (57, 5389)
# Lasso predicts 0.6013 for case with 0.81 and selected CV 4
# Prior to SMOGN sampling, mean is 3.346907009975881e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
# Label distribution of: 0.5097984384516254 0.2042386227071266 0.08804261271701913
# Resampled to size (57,)
# LassoCV score for 2 is [0.99961912] from dataset of size (57, 389)
# LassoCV score for 3 is [0.98635762] from dataset of size (57, 3389)
# LassoCV score for 4 is [1.] from dataset of size (57, 6389)
# Lasso predicts 0.8327 for case with 0.64 and selected CV 4
# Prior to SMOGN sampling, mean is 2.96365310222472e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
# Label distribution of: 0.5076587569200735 0.2025312537733321 0.10154636220272316
# Resampled to size (57,)
# LassoCV score for 2 is [0.9993698] from dataset of size (57, 389)
# LassoCV score for 3 is [0.98484509] from dataset of size (57, 5389)
# LassoCV score for 4 is [0.98320937] from dataset of size (57, 5389)
# Lasso predicts 0.5431 for case with 0.72 and selected CV 2
# Prior to SMOGN sampling, mean is 4.9925571523186465e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.19it/s]
# Label distribution of: 0.5185634129603931 0.20515093451807376 0.03444037137440346
# Resampled to size (59,)
# LassoCV score for 2 is [1.] from dataset of size (59, 4389)
# LassoCV score for 3 is [0.99400026] from dataset of size (59, 6389)
# LassoCV score for 4 is [0.99583229] from dataset of size (59, 5389)
# Lasso predicts 0.5934 for case with 0.31 and selected CV 2
# Prior to SMOGN sampling, mean is 3.0616445092363824e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
# Label distribution of: 0.5083090767494978 0.20314114055019158 0.09950654667002419
# Resampled to size (57,)
# LassoCV score for 2 is [0.99971309] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.9963243] from dataset of size (57, 389)
# LassoCV score for 4 is [1.] from dataset of size (57, 2389)
# Lasso predicts 0.4766 for case with 0.68 and selected CV 4
# Prior to SMOGN sampling, mean is 3.050893875680248e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.21it/s]
# Label distribution of: 0.5173881036104899 0.20627467602627408 0.035306236316309594
# Resampled to size (59,)
# LassoCV score for 2 is [0.99788357] from dataset of size (59, 4389)
# LassoCV score for 3 is [0.99903178] from dataset of size (59, 4389)
# LassoCV score for 4 is [0.99932059] from dataset of size (59, 2389)
# Lasso predicts 0.4917 for case with 0.34 and selected CV 4
# Prior to SMOGN sampling, mean is 2.992012532122799e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:02<00:00,  1.23s/it]
# Label distribution of: 0.5106924130627465 0.2046890607816653 0.07777338027100843
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 1389)
# LassoCV score for 3 is [0.99610581] from dataset of size (57, 2389)
# LassoCV score for 4 is [0.99754855] from dataset of size (57, 2389)
# Lasso predicts 0.4839 for case with 0.59 and selected CV 2
# Prior to SMOGN sampling, mean is 3.3062523152636026e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.24it/s]
# Label distribution of: 0.5019386858870488 0.2007805344603679 0.058960327921067215
# Resampled to size (59,)
# LassoCV score for 2 is [0.99997222] from dataset of size (59, 2389)
# LassoCV score for 3 is [0.9999969] from dataset of size (59, 4389)
# LassoCV score for 4 is [0.99973276] from dataset of size (59, 6389)
# Lasso predicts 0.5995 for case with 0.94 and selected CV 3
# Prior to SMOGN sampling, mean is 2.5944862315471148e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:02<00:00,  1.21s/it]
# Label distribution of: 0.5055102429302557 0.19964655375565882 0.07874591176443761
# Resampled to size (57,)
# LassoCV score for 2 is [0.99950652] from dataset of size (57, 5389)
# LassoCV score for 3 is [0.9887592] from dataset of size (57, 2389)
# LassoCV score for 4 is [0.99999999] from dataset of size (57, 6389)
# Lasso predicts 0.6539 for case with 0.84 and selected CV 4
# Prior to SMOGN sampling, mean is 1.2551673603038587e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.22it/s]
# Label distribution of: 0.5283126277083072 0.18861529546545108 0.20020408982736065
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.99999998] from dataset of size (57, 2389)
# LassoCV score for 4 is [0.99999628] from dataset of size (57, 5389)
# Lasso predicts 0.3582 for case with 0.1 and selected CV 2
# Prior to SMOGN sampling, mean is 3.4101751063062355e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.19it/s]
# Label distribution of: 0.513425188242957 0.20891161636341718 0.06466233402217963
# Resampled to size (59,)
# LassoCV score for 2 is [0.99997891] from dataset of size (59, 389)
# LassoCV score for 3 is [0.99999512] from dataset of size (59, 2389)
# LassoCV score for 4 is [0.999611] from dataset of size (59, 3389)
# Lasso predicts 0.475 for case with 0.41 and selected CV 3
# Prior to SMOGN sampling, mean is 4.273809335315703e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.20it/s]
# Label distribution of: 0.5109925331107656 0.204790189812862 0.0737653033785896
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 389)
# LassoCV score for 3 is [0.98344975] from dataset of size (57, 6389)
# LassoCV score for 4 is [0.99991756] from dataset of size (57, 389)
# Lasso predicts 0.68 for case with 0.57 and selected CV 2
# Prior to SMOGN sampling, mean is 2.6185824791729334e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.10it/s]
# r_index: 100%|##########| 2/2 [00:02<00:00,  1.02s/it]
# Label distribution of: 0.5091755872881395 0.203818773909349 0.09359465718968582
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 389)
# LassoCV score for 3 is [1.] from dataset of size (57, 1389)
# LassoCV score for 4 is [0.99740681] from dataset of size (57, 5389)
# Lasso predicts 0.6112 for case with 0.66 and selected CV 2
# Prior to SMOGN sampling, mean is 1.4801892419788109e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.23it/s]
# Label distribution of: 0.50997866602547 0.204347453654204 0.08622234891724401
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 3389)
# LassoCV score for 3 is [1.] from dataset of size (57, 4389)
# LassoCV score for 4 is [0.99749532] from dataset of size (57, 1389)
# Lasso predicts 0.5236 for case with 0.63 and selected CV 2
# Prior to SMOGN sampling, mean is 3.782369454249649e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.19it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.21it/s]
# Label distribution of: 0.5114936868224335 0.2095570509356245 0.08838721750184862
# Resampled to size (59,)
# LassoCV score for 2 is [0.99990601] from dataset of size (59, 6389)
# LassoCV score for 3 is [0.99915561] from dataset of size (59, 3389)
# LassoCV score for 4 is [0.99999996] from dataset of size (59, 2389)
# Lasso predicts 0.577 for case with 0.47 and selected CV 4
# Prior to SMOGN sampling, mean is 1.980217272839708e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.18it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.24it/s]
# Label distribution of: 0.5198226633795406 0.20377586748533957 0.03875161107153991
# Resampled to size (59,)
# LassoCV score for 2 is [0.99999134] from dataset of size (59, 389)
# LassoCV score for 3 is [0.99978487] from dataset of size (59, 1389)
# LassoCV score for 4 is [0.9996679] from dataset of size (59, 4389)
# Lasso predicts 0.177 for case with 0.28 and selected CV 2
# Prior to SMOGN sampling, mean is -9.589688702572577e-16 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.20it/s]
# Label distribution of: 0.5105727449423337 0.20464172721089988 0.07930738688163083
# Resampled to size (57,)
# LassoCV score for 2 is [0.99763929] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.99835704] from dataset of size (57, 4389)
# LassoCV score for 4 is [0.99996367] from dataset of size (57, 4389)
# Lasso predicts 0.5978 for case with 0.59 and selected CV 4
# Prior to SMOGN sampling, mean is 1.0628298760495682e-15 standard deviation is 0.9428828224673803
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
# Label distribution of: 0.5124931333508618 0.20507340217461562 0.052395813406306634
# Resampled to size (57,)
# LassoCV score for 2 is [0.99871717] from dataset of size (57, 4389)
# LassoCV score for 3 is [0.99999999] from dataset of size (57, 1389)
# LassoCV score for 4 is [1.] from dataset of size (57, 389)
# Lasso predicts 0.6357 for case with 0.53 and selected CV 4
# Prior to SMOGN sampling, mean is -1.3382685219877716e-16 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.16it/s]
# Label distribution of: 0.5050864853873714 0.19891654831012504 0.06698689566639242
# Resampled to size (57,)
# LassoCV score for 2 is [0.99998987] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.99889995] from dataset of size (57, 4389)
# LassoCV score for 4 is [0.99978204] from dataset of size (57, 5389)
# Lasso predicts 0.6017 for case with 0.86 and selected CV 2
# Prior to SMOGN sampling, mean is 8.526364544520428e-16 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.18it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.20it/s]
# Label distribution of: 0.511117486910743 0.2096206305439049 0.09353222638230646
# Resampled to size (59,)
# LassoCV score for 2 is [0.99960492] from dataset of size (59, 6389)
# LassoCV score for 3 is [0.99406585] from dataset of size (59, 4389)
# LassoCV score for 4 is [0.9998599] from dataset of size (59, 5389)
# Lasso predicts 0.4599 for case with 0.48 and selected CV 4
# Prior to SMOGN sampling, mean is 1.765081031216374e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
# Label distribution of: 0.5091755872881395 0.203818773909349 0.09359465718968593
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.99801258] from dataset of size (57, 1389)
# LassoCV score for 4 is [0.99996839] from dataset of size (57, 2389)
# Lasso predicts 0.643 for case with 0.66 and selected CV 2
# Prior to SMOGN sampling, mean is 1.978981567833256e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.18it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.23it/s]
# Label distribution of: 0.5175499439778679 0.20613197652777637 0.034855035937015826
# Resampled to size (59,)
# LassoCV score for 2 is [0.99597455] from dataset of size (59, 3389)
# LassoCV score for 3 is [0.99849967] from dataset of size (59, 6389)
# LassoCV score for 4 is [1.] from dataset of size (59, 389)
# Lasso predicts 0.4959 for case with 0.33 and selected CV 4
# Prior to SMOGN sampling, mean is 2.5642114588890346e-15 standard deviation is 0.9428828224673806
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.18it/s]
# r_index: 100%|##########| 4/4 [00:03<00:00,  1.21it/s]
# Label distribution of: 0.5106635417764249 0.20967048913814232 0.09987528809079363
# Resampled to size (59,)
# LassoCV score for 2 is [0.99969929] from dataset of size (59, 389)
# LassoCV score for 3 is [0.99884175] from dataset of size (59, 5389)
# LassoCV score for 4 is [0.99996249] from dataset of size (59, 2389)
# Lasso predicts 0.2795 for case with 0.49 and selected CV 4
# Prior to SMOGN sampling, mean is -4.758082127344334e-16 standard deviation is 0.9391403841472946
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.11it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.21it/s]
# Label distribution of: 0.5065630450034659 0.20122871477032386 0.09661198306706088
# Resampled to size (57,)
# LassoCV score for 2 is [0.99997978] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.99446718] from dataset of size (57, 6389)
# LassoCV score for 4 is [0.99977565] from dataset of size (57, 389)
# Lasso predicts 0.6427 for case with 0.78 and selected CV 2
# Prior to SMOGN sampling, mean is 1.253993440547729e-15 standard deviation is 0.9428828224673804
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.09it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.18it/s]
# Label distribution of: 0.5060409063234326 0.2004849929578169 0.08960897099831758
# Resampled to size (57,)
# LassoCV score for 2 is [0.99791053] from dataset of size (57, 3389)
# LassoCV score for 3 is [0.98880263] from dataset of size (57, 6389)
# LassoCV score for 4 is [0.99105236] from dataset of size (57, 2389)
# Lasso predicts 0.5902 for case with 0.81 and selected CV 2
# Prior to SMOGN sampling, mean is -1.61383073842662e-16 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.09it/s]
# r_index: 100%|##########| 2/2 [00:01<00:00,  1.20it/s]
# Label distribution of: 0.5076968318515386 0.20257029175819752 0.1015165509162801
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 2389)
# LassoCV score for 3 is [0.99985429] from dataset of size (57, 5389)
# LassoCV score for 4 is [0.9997916] from dataset of size (57, 3389)
# Lasso predicts 0.7279 for case with 0.71 and selected CV 2
# Prior to SMOGN sampling, mean is 1.432429243479432e-15 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 14/14 [00:11<00:00,  1.18it/s]
# r_index: 100%|##########| 4/4 [00:04<00:00,  1.20s/it]
# Label distribution of: 0.5181743458699848 0.20554460149926662 0.03410790635662482
# Resampled to size (59,)
# LassoCV score for 2 is [0.99955006] from dataset of size (59, 1389)
# LassoCV score for 3 is [0.99938736] from dataset of size (59, 2389)
# LassoCV score for 4 is [1.] from dataset of size (59, 3389)
# Lasso predicts 0.6306 for case with 0.32 and selected CV 4
# Prior to SMOGN sampling, mean is 2.0463274906849027e-16 standard deviation is 0.9428828224673805
# dist_matrix: 100%|##########| 15/15 [00:13<00:00,  1.10it/s]
# r_index: 100%|##########| 2/2 [00:02<00:00,  1.22s/it]
# Label distribution of: 0.5055709815114026 0.1997467705618937 0.08019791074874033
# Resampled to size (57,)
# LassoCV score for 2 is [1.] from dataset of size (57, 6389)
# LassoCV score for 3 is [0.99913685] from dataset of size (57, 2389)
# LassoCV score for 4 is [0.99362807] from dataset of size (57, 6389)
# Lasso predicts 0.6177 for case with 0.83 and selected CV 2

# %% [markdown]
# Define probability of an unsucessful procedure as $P = 1-u$ where $u$ is the UPDRS percent improvement prediction between $0$ and $1$.

# %%
# Wild bootstrap LASSO
if retrain == 1:
  aug = False
  results_ls_wbs = np.zeros_like(per_change)
  K_nz_wbs = []
  #R_nz_wbs = []
  c = 0
  for j in np.arange(c,len(subsc)):
      test_id = subsc[j]
      test_index = subsc == test_id
      train_index = subsc != test_id
      X_train = X_all_c[train_index,:,:]
      X_test = X_all_c[test_index,:,:]
      y_train = per_change[train_index]
      y_test = per_change[test_index]

      y_cat = y_train <= 0.3
      idy = np.where(y_cat==1)
      # Cross validation
                                            
      X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                  X_train,train_index,X_test,
                                                  test_index,pre_updrs_off,age,dd,sex,ledd,None,None,None,None,None,False,False,False)
      X0_ss00 = X0_ss0
      y_train_0 = y_train
      cvn = 5

      cv_scores = np.zeros((cvn,1))
      rs = 1
      rcfs = 1000
      (mu, sigma) = stats.norm.fit(y_train)
      kappa = stats.skew(y_train)
      print('Label distribution of:',mu,sigma,kappa)
      for jj in np.arange(2,cvn):
        # Resample to avoid stratification errors
        while np.sum(y_cat) < cvn:
          np.random.seed(rs)
          idyr = np.random.choice(np.asarray(idy).ravel())
          X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
          y_train = np.append(y_train,y_train[idyr])
          y_cat = y_train <= 0.3
          rs = rs+1
          print('Resampled to size',y_train.shape)
          ls0 = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
          est0 = ls0.fit(X0_ss0,y_train)
          eps = y_train-ls0.predict(X0_ss0)
          eps_v = eps*np.random.normal(0,1,1)
          y_train_0 = y_train
        if aug == True:
          y_train_n = y_train+(1.96*sigma)*np.random.normal(0,1,1)
          y_train = np.hstack((y_train,y_train_n))
          y_cat = y_train <= 0.3
          X0_ss0 = np.vstack((X0_ss0,X0_ss0))
        else: # Control for different training sample sizes
          while len(eps_v) < len(y_train):
            eps_v = np.hstack((eps_v,eps*np.random.normal(0,1,1)))
          y_train_n = y_train+eps_v
          y_train = np.hstack((y_train,y_train_n))
          y_cat = y_train <= 0.3
          X0_ss0 = np.vstack((X0_ss0,X0_ss0))

      for jj in np.arange(2,cvn):
        skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
        skf_gen = skf_g.split(X0_ss0,y_cat)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
        with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
          # Feature selection
          warnings.filterwarnings("ignore", category=ConvergenceWarning)
          sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
          X0_sst = sel.fit_transform(X0_ss0,y_train)
          X0_ss = X0_sst
          est_ls = lasso.fit(X0_ss,y_train)
          cv_scores[jj] = est_ls.score(X0_ss,y_train)
          print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
          
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
        best_cv = np.argmax(cv_scores)
        # Break any ties
        if np.sum(cv_scores == best_cv) > 1:
          cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
          for jjj in (cv_scores == cv_scores(best_cv)):
            if jjj > 0:
              skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
              skf_gen = skf_g.split(X0_ss0,y_cat) 
              X0_sst = sel.fit_transform(X0_ss0,y_train)
              X0_ss = X0_sst
              lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
              est_ls = lasso.fit(X0_ss,y_train)
              cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
          best_cv = np.argmax(cv_scores_tb)
        
        # Fit whole dataset with optimal cv
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
        sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
        X0_ss = sel.fit_transform(X0_ss0,y_train)
        X_test_ss = sel.transform(X_test_ss0)
        K_ss = sel.transform(K_all_c.reshape(1,-1))
        #R_ss = sel.transform(R_all_c.reshape(1,-1))
        
      # LASSO
      with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
        est_ls = lasso.fit(X0_ss,y_train)
        results_ls_wbs[c] = est_ls.predict(X_test_ss)
        if results_ls_wbs[c] < 0:
            dx, y_n = cKDTree(X0_ss00.reshape(X0_ss00.shape[0],-1)).query(X_test_ss0.reshape(1,-1),k=15)
            results_ls_wbs[c] = np.mean((y_train_0[y_n]))
            print('Using nearest neighbor')
        print('Lasso predicts',str(np.round(results_ls_wbs[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
        K_nz_wbs.append(np.squeeze(K_ss)[abs(est_ls.coef_)>0])
        #R_nz_wbs.append(np.squeeze(R_ss)[est_ls.coef_>0])
        c=c+1

  np.save('results_ls_wbs_d_cvs.npy',results_ls_wbs)
  np.save('results_K_nz_wbs_cvs.npy',K_nz_wbs)
  np.save('beta_nz_wbs_cvs.npy',est_ls.coef_[abs(est_ls.coef_)>0])
else:
  results_ls_wbs = np.load('results_ls_wbs_d.npy')
  K_nz_wbs = np.load('results_K_nz_wbs.npy',allow_pickle=True)
# Out:
# Label distribution of: 0.5669595264848581 0.20858808082526412 -0.24474920851943865
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99543504] from dataset of size (304, 389)
# LassoCV score for 3 is [0.99543584] from dataset of size (304, 6389)
# LassoCV score for 4 is [0.99543497] from dataset of size (304, 3389)
# Lasso predicts 0.7057 for case with 0.72 and selected CV 3
# Label distribution of: 0.5738548357091768 0.20932917254901903 -0.3279210191356042
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99787181] from dataset of size (304, 4389)
# LassoCV score for 3 is [0.99787181] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.99787181] from dataset of size (304, 4389)
# Lasso predicts 0.4936 for case with 0.47 and selected CV 2
# Label distribution of: 0.5677185809199048 0.20908232478622193 -0.24926099868801613
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99412336] from dataset of size (304, 3389)
# LassoCV score for 3 is [0.99412336] from dataset of size (304, 389)
# LassoCV score for 4 is [0.99412336] from dataset of size (304, 6389)
# Lasso predicts 0.8456 for case with 0.69 and selected CV 2
# Label distribution of: 0.5752269235227969 0.2084721065940771 -0.34398027688109245
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.95802192] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.95802192] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.95802192] from dataset of size (304, 6389)
# Lasso predicts 0.6741 for case with 0.42 and selected CV 2
# Label distribution of: 0.5827907017222488 0.19744836811095323 -0.25025976222641483
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# LassoCV score for 2 is [0.9072834] from dataset of size (312, 3389)
# LassoCV score for 3 is [0.90702549] from dataset of size (312, 5389)
# LassoCV score for 4 is [0.90728331] from dataset of size (312, 5389)
# Lasso predicts 0.4704 for case with 0.15 and selected CV 2
# Label distribution of: 0.5746924331750638 0.20884605172212908 -0.33822865445502964
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99950241] from dataset of size (304, 2389)
# LassoCV score for 3 is [0.99950241] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.99947361] from dataset of size (304, 4389)
# Lasso predicts 0.4883 for case with 0.44 and selected CV 3
# Label distribution of: 0.5624312245980657 0.20344924934212058 -0.28703446866429055
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [1.] from dataset of size (304, 2389)
# LassoCV score for 3 is [1.] from dataset of size (304, 1389)
# LassoCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.7559 for case with 0.88 and selected CV 2
# Label distribution of: 0.5758937568978073 0.20793336707043802 -0.35000008336051325
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99727256] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.99727256] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.99725625] from dataset of size (304, 5389)
# Lasso predicts 0.4128 for case with 0.4 and selected CV 2
# Label distribution of: 0.5702986081106105 0.20999601422390549 -0.27751686488556404
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99905366] from dataset of size (304, 3389)
# LassoCV score for 3 is [0.99905366] from dataset of size (304, 2389)
# LassoCV score for 4 is [0.99905352] from dataset of size (304, 389)
# Lasso predicts 0.5718 for case with 0.6 and selected CV 3
# Label distribution of: 0.5643062245980658 0.2060398064467874 -0.25159784666703033
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99972635] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.99972639] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.99972639] from dataset of size (304, 1389)
# Lasso predicts 0.4967 for case with 0.81 and selected CV 3
# Label distribution of: 0.5691451725886095 0.20973322323580731 -0.2629533781637346
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99909905] from dataset of size (304, 3389)
# LassoCV score for 3 is [0.99909905] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.99909905] from dataset of size (304, 1389)
# Lasso predicts 0.7957 for case with 0.64 and selected CV 2
# Label distribution of: 0.5669751715300725 0.2085993111100245 -0.24481874200363993
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.95867314] from dataset of size (304, 389)
# LassoCV score for 3 is [0.95887005] from dataset of size (304, 5389)
# LassoCV score for 4 is [0.95884444] from dataset of size (304, 389)
# Lasso predicts 0.5824 for case with 0.72 and selected CV 3
# Label distribution of: 0.5783286604955017 0.20527469945818264 -0.35630765675696446
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [1.] from dataset of size (304, 2389)
# LassoCV score for 3 is [1.] from dataset of size (304, 389)
# LassoCV score for 4 is [1.] from dataset of size (304, 389)
# Lasso predicts 0.6238 for case with 0.31 and selected CV 2
# Label distribution of: 0.5679867801536214 0.20923231991769523 -0.25136542100761594
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.9999973] from dataset of size (304, 6389)
# LassoCV score for 3 is [1.] from dataset of size (304, 1389)
# LassoCV score for 4 is [1.] from dataset of size (304, 1389)
# Lasso predicts 0.5114 for case with 0.68 and selected CV 3
# Label distribution of: 0.5774859976810078 0.2063190239320207 -0.3574795129443696
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99751739] from dataset of size (304, 389)
# LassoCV score for 3 is [0.99751739] from dataset of size (304, 2389)
# LassoCV score for 4 is [0.99751738] from dataset of size (304, 6389)
# Lasso predicts 0.3679 for case with 0.34 and selected CV 2
# Label distribution of: 0.5705357997614644 0.21002096073970725 -0.2807677568009367
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99949974] from dataset of size (304, 3389)
# LassoCV score for 3 is [0.99949974] from dataset of size (304, 389)
# LassoCV score for 4 is [0.99949974] from dataset of size (304, 389)
# Lasso predicts 0.446 for case with 0.59 and selected CV 2
# Label distribution of: 0.5607985715368413 0.2006390097129064 -0.34802680409786524
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99993411] from dataset of size (304, 389)
# LassoCV score for 3 is [0.99993411] from dataset of size (304, 5389)
# LassoCV score for 4 is [0.99993411] from dataset of size (304, 3389)
# Lasso predicts 0.661 for case with 0.94 and selected CV 3
# Label distribution of: 0.5636330386570226 0.20518643494540414 -0.26076044933979126
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.96542349] from dataset of size (304, 6389)
# LassoCV score for 3 is [0.96535208] from dataset of size (304, 389)
# LassoCV score for 4 is [0.96542349] from dataset of size (304, 6389)
# Lasso predicts 0.6839 for case with 0.84 and selected CV 2
# Label distribution of: 0.5841874969994993 0.19415564179220104 -0.16306203646880674
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# LassoCV score for 2 is [0.99911565] from dataset of size (312, 4389)
# LassoCV score for 3 is [0.99911182] from dataset of size (312, 1389)
# LassoCV score for 4 is [0.99911914] from dataset of size (312, 5389)
# Lasso predicts 0.2537 for case with 0.1 and selected CV 4
# Label distribution of: 0.5753580538663584 0.20837251231034953 -0.34527291849868297
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.97826474] from dataset of size (304, 2389)
# LassoCV score for 3 is [0.97826474] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.97822674] from dataset of size (304, 2389)
# Lasso predicts 0.4292 for case with 0.41 and selected CV 2
# Label distribution of: 0.5710026531694943 0.21004110516915736 -0.28733840263675836
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.96806617] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.96797756] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.96805602] from dataset of size (304, 1389)
# Lasso predicts 0.6322 for case with 0.57 and selected CV 2
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.93693063] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.93693076] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.93692832] from dataset of size (304, 6389)
# Lasso predicts 0.7396 for case with 0.66 and selected CV 3
# Label distribution of: 0.5694255265923677 0.20981871046638942 -0.2662656536773807
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.96702535] from dataset of size (304, 2389)
# LassoCV score for 3 is [0.96702384] from dataset of size (304, 2389)
# LassoCV score for 4 is [0.96702435] from dataset of size (304, 5389)
# Lasso predicts 0.5887 for case with 0.63 and selected CV 2
# Label distribution of: 0.5738037736176735 0.20935457901382964 -0.3272511581002607
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.95100933] from dataset of size (304, 2389)
# LassoCV score for 3 is [0.95097704] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.95100933] from dataset of size (304, 6389)
# Lasso predicts 0.6128 for case with 0.47 and selected CV 4
# Label distribution of: 0.5790052986721398 0.2043392189714069 -0.3521164038418525
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# LassoCV score for 2 is [0.99875982] from dataset of size (312, 1389)
# LassoCV score for 3 is [0.99875992] from dataset of size (312, 1389)
# LassoCV score for 4 is [0.99875502] from dataset of size (312, 3389)
# Lasso predicts 0.3827 for case with 0.28 and selected CV 3
# Label distribution of: 0.5703496493519336 0.21000221972805436 -0.27821061318927803
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.95475234] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.94889621] from dataset of size (304, 389)
# LassoCV score for 4 is [0.95475234] from dataset of size (304, 3389)
# Lasso predicts 0.6458 for case with 0.59 and selected CV 4
# Label distribution of: 0.572169786689569 0.20992345901172824 -0.3042853268818935
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.98509457] from dataset of size (304, 5389)
# LassoCV score for 3 is [0.98521623] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.98521623] from dataset of size (304, 1389)
# Lasso predicts 0.6238 for case with 0.53 and selected CV 4
# Label distribution of: 0.5629738602569804 0.2042678402570905 -0.27346537727473835
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.93874543] from dataset of size (304, 4389)
# LassoCV score for 3 is [0.93850186] from dataset of size (304, 2389)
# LassoCV score for 4 is [0.93660829] from dataset of size (304, 5389)
# Lasso predicts 0.628 for case with 0.86 and selected CV 2
# Label distribution of: 0.5735011834458024 0.20949562291124812 -0.3232022231648087
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.94752889] from dataset of size (304, 389)
# LassoCV score for 3 is [0.94752943] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.94752229] from dataset of size (304, 1389)
# Lasso predicts 0.4501 for case with 0.48 and selected CV 3
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.96084442] from dataset of size (304, 4389)
# LassoCV score for 3 is [0.96124151] from dataset of size (304, 2389)
# LassoCV score for 4 is [0.96107932] from dataset of size (304, 6389)
# Lasso predicts 0.6484 for case with 0.66 and selected CV 3
# Label distribution of: 0.5776164097832509 0.206166083456723 -0.3575627941827524
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.98072468] from dataset of size (304, 2389)
# LassoCV score for 3 is [0.98072468] from dataset of size (304, 3389)
# LassoCV score for 4 is [0.98072403] from dataset of size (304, 5389)
# Lasso predicts 0.5306 for case with 0.33 and selected CV 2
# Label distribution of: 0.5731361230448997 0.20964415222225632 -0.31816132090731236
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.92151023] from dataset of size (304, 6389)
# LassoCV score for 3 is [0.92138004] from dataset of size (304, 389)
# LassoCV score for 4 is [0.92151023] from dataset of size (304, 4389)
# Lasso predicts 0.4222 for case with 0.49 and selected CV 2
# Label distribution of: 0.5652707307709053 0.20711530756483246 -0.2442832622694056
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.92618533] from dataset of size (304, 3389)
# LassoCV score for 3 is [0.91972482] from dataset of size (304, 1389)
# LassoCV score for 4 is [0.89499138] from dataset of size (304, 3389)
# Lasso predicts 0.7319 for case with 0.78 and selected CV 2
# Label distribution of: 0.5644585150464088 0.20622109204736833 -0.2500116622013785
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.93854106] from dataset of size (304, 4389)
# LassoCV score for 3 is [0.93854106] from dataset of size (304, 5389)
# LassoCV score for 4 is [0.93854106] from dataset of size (304, 1389)
# Lasso predicts 0.5947 for case with 0.81 and selected CV 2
# Label distribution of: 0.5670343992012403 0.20864142707871972 -0.24509142715462312
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.97037871] from dataset of size (304, 3389)
# LassoCV score for 3 is [0.9703787] from dataset of size (304, 6389)
# LassoCV score for 4 is [0.9703787] from dataset of size (304, 6389)
# Lasso predicts 0.7109 for case with 0.71 and selected CV 2
# Label distribution of: 0.5781196303951672 0.20554616966278674 -0.356990224910928
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.97195099] from dataset of size (304, 1389)
# LassoCV score for 3 is [0.97195101] from dataset of size (304, 6389)
# LassoCV score for 4 is [0.97195101] from dataset of size (304, 6389)
# Lasso predicts 0.4483 for case with 0.32 and selected CV 3
# Label distribution of: 0.5637275208943621 0.2053113472299323 -0.2592529006209024
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.97038683] from dataset of size (304, 6389)
# LassoCV score for 3 is [0.97038819] from dataset of size (304, 5389)
# LassoCV score for 4 is [0.97036797] from dataset of size (304, 389)
# Lasso predicts 0.7305 for case with 0.83 and selected CV 3

# %%
def bland_altman_plot(data1, data2, *args, **kwargs):
    data1     = np.asarray(data1)
    data2     = np.asarray(data2)
    mean      = np.mean([data1, data2], axis=0)
    diff      = data1-data2                   # Difference between datasets
    md        = np.mean(diff)                 # Mean of the difference
    sd        = np.std(diff, axis=0)          # Standard deviation of the difference

    plt.scatter(mean, diff, *args, **kwargs)
    plt.axhline(md,           color='gray', linestyle='--')
    plt.text(0.1, 2*md, r'$\mu$ = '+str(np.round(md,2)), horizontalalignment='center',verticalalignment='center')
    plt.text(0.5, 0.4, r'$\mu + 1.96 \sigma$ = '+str(np.round(md + 1.96*sd,2)), horizontalalignment='center',verticalalignment='center')
    plt.text(0.5, -0.5, r'$\mu - 1.96 \sigma$ = '+str(np.round(md - 1.96*sd,2)), horizontalalignment='center',verticalalignment='center')
    plt.axhline(md + 1.96*sd, color='gray', linestyle='--')
    plt.axhline(md - 1.96*sd, color='gray', linestyle='--')
    plt.ylim([-4*1.96*sd,4*1.96*sd])
    diff_in = np.logical_and(diff < md + 1.96*sd,diff > md - 1.96*sd)
    plt.scatter(mean[diff_in], diff[diff_in], *args, **kwargs)
    plt.xlabel(r'$\frac{y_{true}+y_{predicted}}{2}$',fontsize=16)
    plt.ylabel(r'$y_{predicted}-y_{true}$',fontsize=12)
    return diff,diff_in

# %%
d,din = bland_altman_plot(results_ls_aug,per_change)

# %%
ylim = 1.25
fs = 32
ofx = 0.25
ofy = 0.75
pre_imp = np.repeat((np.asarray(pre_updrs_iii_off,dtype=float)-np.asarray(pre_updrs_iii_on,dtype=float))/np.asarray(pre_updrs_iii_off,dtype=float),r)
per_change = np.repeat(per_change,r)
plt.rcParams['figure.figsize'] = [40, 10]
fig,ax = plt.subplots(1,5,sharex=True,sharey=True)
#ax[0].scatter(pre_imp,per_change)
col = np.where(per_change <= 0.3,'orange','blue')
ax[0].scatter(pre_imp,per_change, c=col,linewidth=0)
lr = stats.linregress(pre_imp,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(ofx,ofy,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=fs)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=fs)
ax[0].set_xlabel('Prediction',fontsize=fs)
ax[0].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax[0].set_ylabel('True UPDRS-III improvement',fontsize=fs)
ax[0].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
col = np.where(per_change <= 0.3,'orange','blue')

ax[1].scatter(results_ls,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls),per_change)
y_model = results_ls*lr.slope+lr.intercept
ax[1].plot(results_ls,y_model,color='r')
ax[1].text(ofx,ofy,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=fs) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Lasso',fontsize=fs)
ax[1].set_xlabel('Prediction',fontsize=fs)
ax[1].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[1].set_ylabel('True Improvement',fontsize=fs)
ax[1].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
col = np.where(per_change <= 0.3,'orange','blue')


ax[2].scatter(results_ls_smogn,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_smogn),per_change)
y_model = results_ls_smogn*lr.slope+lr.intercept
ax[2].plot(results_ls_smogn,y_model,color='r')
ax[2].text(ofx,ofy,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[2].transAxes,fontsize=fs) 
ax[2].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].set_xlabel('Prediction',fontsize=fs)
ax[2].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[2].set_ylabel('True Improvement',fontsize=fs)
ax[2].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax[2].set_title('SMOGN Lasso',fontsize=fs)

ax[3].scatter(results_ls_wbs,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_wbs),per_change)
y_model = results_ls_wbs*lr.slope+lr.intercept
ax[3].plot(results_ls_wbs,y_model,color='r')
ax[3].text(ofx,ofy,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[3].transAxes,fontsize=fs) 
ax[3].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[3].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[3].set_xlabel('Prediction',fontsize=fs)
ax[3].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[3].set_ylabel('True Improvement',fontsize=fs)
ax[3].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax[3].set_title('Wild Boostrap Lasso',fontsize=fs)

ax[4].scatter(results_ls_aug,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[4].plot(results_ls_aug,y_model,color='r')
ax[4].text(ofx,ofy,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[4].transAxes,fontsize=fs) 
ax[4].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[4].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[4].set_xlabel('Prediction',fontsize=fs)
ax[4].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[4].set_ylabel('True Improvement',fontsize=fs)
ax[4].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax[4].set_title('Noise Compensated Lasso',fontsize=fs)
plt.ylim([0,ylim])
plt.xlim([0,ylim])

plt.savefig('plots_auto.png')
plt.style.use('default')

# %%
from collections import Counter

plt.rcParams["figure.figsize"] = (30,15)
fig, axes = plt.subplots(1,4,sharey=True)
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.2)

R = [item for sublist in K_nz_vl for item in sublist]
letter_counts = Counter(R)
lc = { x: count for x, count in letter_counts.items() if count > 35 } #30
df = pd.DataFrame.from_dict(lc, orient='index')
df.sort_values(0, ascending=False, inplace=True)
df.plot(ax=axes[0], y=0, kind='bar', legend=False, fontsize=fs,stacked=True, width=1, edgecolor='black',color='tab:orange')
axes[0].set_title('Lasso',fontsize=fs)
R = [item for sublist in K_nz_smogn for item in sublist]
letter_counts = Counter(R)
lc = { x: count for x, count in letter_counts.items() if count > 35 } #23
df = pd.DataFrame.from_dict(lc, orient='index')
df.sort_values(0, ascending=False, inplace=True)
df.plot(ax=axes[1], y=0, kind='bar', legend=False, fontsize=fs,stacked=True, width=1, edgecolor='black',color='tab:red')
axes[1].set_title('SMOGN Lasso',fontsize=fs)
R = [item for sublist in K_nz_wbs for item in sublist]
letter_counts = Counter(R)
lc = { x: count for x, count in letter_counts.items() if count > 35 } #28
df = pd.DataFrame.from_dict(lc, orient='index')
df.sort_values(0, ascending=False, inplace=True)
df.plot(ax=axes[2], y=0, kind='bar', legend=False, fontsize=fs,stacked=True, width=1, edgecolor='black',color='tab:purple')
axes[2].set_title('Wild Bootstrap Lasso',fontsize=fs)
R = [item for sublist in K_nz_nc for item in sublist]
letter_counts = Counter(R)
lc = { x: count for x, count in letter_counts.items() if count > 35 } #25
df = pd.DataFrame.from_dict(lc, orient='index')
df.sort_values(0, ascending=False, inplace=True)
df.plot(ax=axes[3], y=0, kind='bar', legend=False, fontsize=fs,stacked=True, width=1, edgecolor='black',color='tab:green')
axes[3].set_title('Noise Compensated Lasso',fontsize=fs)
plt.suptitle('Predictive radiomic features',fontsize=fs)
plt.ylabel('Frequency',fontsize=16)

plt.style.use('default')
plt.savefig('feats_auto.png')

# %%
from sklearn.metrics import precision_recall_curve, recall_score, accuracy_score, precision_score

# %%
plt.rcParams["figure.figsize"] = (10,10)
fig,ax = plt.subplots(1,1,sharex=True,sharey=True)
t = 0.3
y_bin = per_change<t

y_predicted_ls = results_ls < 0.3
y_predicted_ls_aug = results_ls_aug < 0.3
y_predicted_lct = pre_imp < 0.3
y_predicted_aug = 1-results_lgrp_aug
y_predicted_lr = 1-results_lgrp
y_predicted_smogn = results_ls_smogn < 0.3
y_predicted_wbs = results_ls_wbs < 0.3

estimators = np.vstack((lct_change < 0.3,results_lgr,results_lgr_aug,results_ls < 0.3,results_ls_aug < 0.3,results_ls_smogn < 0.3,results_ls_wbs < 0.3))


fprlsa, tprlsa, _ = roc_curve(y_bin,  y_predicted_ls_aug)
fprls, tprls, _ = roc_curve(y_bin,  y_predicted_ls)
fprl, tprl, _ = roc_curve(y_bin,  y_predicted_lct)
fpra, tpra, ts_aug = roc_curve(y_bin, y_predicted_aug)
fprlr, tprlr, ts = roc_curve(y_bin, y_predicted_lr)
pra,rca,ta = precision_recall_curve(y_bin,y_predicted_aug)
prlr,rclr,tlr = precision_recall_curve(y_bin,y_predicted_lr)

# fprl = np.zeros_like(fprlr)
# tprl = np.zeros_like(tprlr)
scores = np.zeros((7,4))

for j in np.arange(estimators.shape[0]):
    spf = recall_score(y_bin,estimators[j,:],pos_label=0)
    scores[j,0] = spf
    sns = recall_score(y_bin,estimators[j,:])
    scores[j,1] = sns
    acc = accuracy_score(y_bin,estimators[j,:])
    scores[j,2] = acc
    prec = precision_score(y_bin,estimators[j,:])
    scores[j,3] = prec

fprlss, tprlss, _ = roc_curve(y_bin, y_predicted_smogn)
fprlwb, tprlwb, _ = roc_curve(y_bin, y_predicted_wbs)
roc_auc_lr = auc(fprlr, tprlr)
roc_auc_lr_aug = auc(fpra, tpra)
roc_auc_ls = auc(fprls, tprls)
roc_auc_lct = auc(fprl, tprl)
roc_auc_ls_aug = auc(fprlsa, tprlsa)
roc_auc_ls_smogn = auc(fprlss, tprlss)
roc_auc_ls_wbs = auc(fprlwb, tprlwb)

ax.plot(fprlr, tprlr, label = 'LR AUC = %0.2f' % roc_auc_lr, linewidth=5)
ax.plot(fpra, tpra, label = 'LR + noise AUC = %0.2f' % roc_auc_lr_aug, linewidth=5)
# ax.plot(fprl, tprl, label = 'LCT AUC = %0.2f' % roc_auc_lct, linewidth=5)
# ax.plot(fprlsa, tprlsa, label = 'Lasso + noise AUC = %0.2f' % roc_auc_ls_aug, linewidth=5)
# ax.plot(fprlss, tprlss, label = 'Lasso + SMOGN AUC = %0.2f' % roc_auc_ls_smogn, linewidth=5)
# ax.plot(fprlwb, tprlwb, label = 'Lasso + wild bootstrap AUC = %0.2f' % roc_auc_ls_wbs, linewidth=5)
ax.plot(np.linspace(0,1,len(fpra)),np.linspace(0,1,len(fpra)),linewidth=5,color='black',linestyle='dashed')
ax.set_title('Receiver Operating Characteristic',fontsize=fs)
ax.set_xlabel('False positive rate \n $(1-specificity$)',fontsize=fs)
ax.set_ylabel('True positive rate \n $(sensitivity$)',fontsize=fs)
ax.xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax.yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax.legend(bbox_to_anchor=(0.4,0.15),fontsize=fs//1.5)

# ax[1].plot(rclr, prlr, label='LR', linewidth=5)
# ax[1].plot(rca, pra, label='LR + noise', linewidth=5)
# ax[1].plot(np.linspace(0,1,len(fpra)),1-np.linspace(0,1,len(fpra)),linewidth=5,color='black',linestyle='dashed')
# ax[1].set_title('Precision Recall',fontsize=fs)
# ax[1].set_xlabel('Recall \n $(sensitivity$)',fontsize=fs)
# ax[1].set_ylabel('Precision \n $(sensitivity$)',fontsize=fs)
# ax[1].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[1].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[1].legend(fontsize=fs//3)
plt.style.use('default')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (10,5)
fig,ax = plt.subplots(1,1,sharex=True,sharey=True)
t = 0.3
y_bin = per_change<t

# y_predicted_ls = 1-results_ls
# y_predicted_ls_aug = 1-results_ls_aug
# y_predicted_lct = 1-pre_imp
# y_predicted_aug = 1-results_lgrp_aug
# y_predicted_lr = 1-results_lgrp
# y_predicted_smogn = 1-results_ls_smogn
# y_predicted_wbs = 1-results_ls_wbs

estimators = np.vstack((lct_change < 0.3,results_lgr,results_lgr_aug,results_ls < 0.3,results_ls_aug < 0.3,results_ls_smogn < 0.3,results_ls_wbs < 0.3))


# # fprlsa, tprlsa, _ = roc_curve(y_bin,  y_predicted_ls_aug)
# # fprls, tprls, _ = roc_curve(y_bin,  y_predicted_ls)
# # fprl, tprl, _ = roc_curve(y_bin,  y_predicted_lct)
# fpra, tpra, ts_aug = roc_curve(y_bin, y_predicted_aug)
# pra,rca,ta = precision_recall_curve(y_bin,y_predicted_aug)
# fprlr, tprlr, ts = roc_curve(y_bin, y_predicted_lr)
# prlr,rclr,tlr = precision_recall_curve(y_bin,y_predicted_lr)
# fprl = np.zeros_like(fprlr)
# tprl = np.zeros_like(tprlr)
scores = np.zeros((7,4))

for j in np.arange(estimators.shape[0]):
    spf = recall_score(y_bin,estimators[j,:],pos_label=0)
    scores[j,0] = spf
    sns = recall_score(y_bin,estimators[j,:])
    scores[j,1] = sns
    acc = accuracy_score(y_bin,estimators[j,:])
    scores[j,2] = acc
    prec = precision_score(y_bin,estimators[j,:])
    scores[j,3] = prec

# fprlss, tprlss, _ = roc_curve(y_bin, y_predicted_smogn)
# fprlwb, tprlwb, _ = roc_curve(y_bin, y_predicted_wbs)
# print(fprl)
# print(tprl)
# # roc_auc_lct = auc(fprl, tprl)
# roc_auc_lr = auc(fprlr, tprlr)
# roc_auc_lr_aug = auc(fpra, tpra)
# roc_auc_ls = auc(fprls, tprls)
# roc_auc_ls_aug = auc(fprlsa, tprlsa)
# roc_auc_ls_smogn = auc(fprlss, tprlss)
# roc_auc_ls_wbs = auc(fprlwb, tprlwb)

# plt.rcParams['legend.loc']='lower right'
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[0,:]), '-o', label = 'LCT',color='tab:blue')
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[3,:]), '-o', label = 'Lasso',color='tab:orange',zorder=7)
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[5,:]), '-o', label = 'SMOGN Lasso',color='tab:red')
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[6,:]), '-o', label = 'Wild Bootstrap Lasso',color='tab:purple',zorder=6)
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[4,:]), '-o', label = 'Noise Compensated Lasso',color='tab:green')
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[1,:]), '-o', label = 'Logistic Regression',color='tab:gray')
ax.plot(np.asarray((0,1,2,3)),np.squeeze(scores[2,:]), '-o', label = 'Noise Compensated Logistic regression',color='tab:pink')
ax.set_xticks((0,1,2,3))
ax.set_xticklabels(['Specificity','Sensitivity','Accuracy','Precision'])
ax.set_ylim((-0.15,1.15))
# ax[0].plot(fprlr, tprlr, label = 'LR AUC = %0.2f' % roc_auc_lr, linewidth=5)
# ax[0].plot(fpra, tpra, label = 'LR + noise AUC = %0.2f' % roc_auc_lr_aug, linewidth=5)
# ax[0].plot(np.linspace(0,1,len(fpra)),np.linspace(0,1,len(fpra)),linewidth=5,color='black',linestyle='dashed')
# ax[0].set_title('Receiver Operating Characteristic',fontsize=fs)
# ax[0].set_xlabel('False positive rate \n $(1-specificity$)',fontsize=fs)
# ax[0].set_ylabel('True positive rate \n $(sensitivity$)',fontsize=fs)
# ax[0].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[0].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
ax.legend(bbox_to_anchor=(1,0.25),fontsize=fs//3)

plt.rcParams['legend.loc']='lower left'
plt.title('Classification performance')
plt.savefig('classifier_auto.png')
# ax[1].plot(rclr, prlr, linewidth=5)
# ax[1].plot(rca, pra, linewidth=5)
# # ax[1].plot(fprlsa, tprlsa, label = 'Lasso + noise AUC = %0.2f' % roc_auc_ls_aug, linewidth=5)
# # ax[1].plot(fprlss, tprlss, label = 'Lasso + SMOGN AUC = %0.2f' % roc_auc_ls_smogn, linewidth=5)
# # ax[1].plot(fprlwb, tprlwb, label = 'Lasso + wild bootstrap AUC = %0.2f' % roc_auc_ls_wbs, linewidth=5)
# ax[1].set_title('Precision Recall',fontsize=fs)
# ax[1].set_xlabel('Recall \n $(sensitivity$)',fontsize=fs)
# ax[1].set_ylabel('Precision \n $(sensitivity$)',fontsize=fs)
# ax[1].xaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[1].yaxis.set_tick_params(labelleft=True,labelsize=fs//1.5)
# ax[1].legend(fontsize=fs//1.5)
# plt.style.use('default')
# plt.show()

# %%
def rec(res,pc):
    epsilon = np.sort(abs(res-pc))
    print('Maximum error is',np.amax(epsilon))
    epsilon_prev = 0
    x = []
    y = []
    c = 0
    m = len(epsilon)
    for j in np.arange(m):
        if epsilon[j] > epsilon_prev:
            x.append(epsilon_prev)
            y.append(c/m)
            epsilon_prev = epsilon[j]
            c = c+1
    acc = c/m
    eta = np.amax(y)
    x.append(1)
    y.append(1)

    return np.asarray(x),np.asarray(y),acc,eta

# %%
x_lct,y_lct,a,eta = rec(pre_imp,per_change)
plt.plot(x_lct,y_lct,label='LCT %0.2f' % eta)
# x_ls,y_ls,a,eta = rec(results_ls,per_change)
# plt.plot(x_ls,y_ls,label='Lasso %0.2f' % eta)
x_smogn,y_smogn,a,eta = rec(results_ls_smogn,per_change)
plt.plot(x_smogn,y_smogn,label='Lasso + SMOGN %0.2f' % eta)
x_lsa,y_lsa,a,eta = rec(results_ls_aug,per_change)
plt.plot(x_lsa,y_lsa,label='Lasso + noise %0.2f' % eta)
x_wbs,y_wbs,a,eta = rec(results_ls_wbs,per_change)
plt.plot(x_wbs,y_wbs,label='Wild bootstrapped Lasso %0.2f' % eta)
x_n,y_n,a,eta = rec(np.mean(per_change)*np.ones_like(per_change),per_change)

plt.plot(x_n,y_n,linestyle='dashed',color='k',label='Mean %0.2f' % eta)
plt.xlabel('Absolute deviation')
plt.ylabel('Accuracy')
plt.xlim([0,1])
plt.title('REC')
plt.legend()
# Out:
# Maximum error is 0.8064516129032258
# Maximum error is 0.35414431148817305
# Maximum error is 0.3649122503964056
# Maximum error is 0.3232977642926328
# Maximum error is 0.4742399709254066
