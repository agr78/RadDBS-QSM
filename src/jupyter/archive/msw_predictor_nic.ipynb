# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
from sklearn.linear_model import QuantileRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RANSACRegressor
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
import warnings
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
from sklearn.exceptions import ConvergenceWarning
from sklearn import preprocessing as skp
from sklearn import model_selection as sms
from sklearn import feature_selection as skf
from sklearn import linear_model as slm
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util as util
import nibabel as nib
import os
import pickle
from torch import nn
from scipy.spatial import cKDTree
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (15,5)
def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0]//2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()
    

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index-1) % volume.shape[0] 
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index+1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2
visualize = 1
# Load data
nrows = 256
ncols = 256
nslices = 160
segs = []
qsms = []
laros = []
voxel_sizes = []
trackers = []
q_directory = '/home/ali/RadDBS-QSM/data/nii/chh/orig/qsm/'
q_directory = os.listdir(q_directory)
q_directory = sorted(q_directory)
qu_directory = '/home/ali/RadDBS-QSM/data/nii/chh/lr_roi_ft'
qu_directory = os.listdir(qu_directory)
qu_directory = sorted(qu_directory)
s_directory = '/home/ali/RadDBS-QSM/data/nii/chh/orig/seg/'
s_directory = os.listdir(s_directory)
s_directory = sorted(s_directory)
m_directory = '/home/ali/RadDBS-QSM/data/nii/chh/masks'
m_directory = os.listdir(m_directory)
m_directory = sorted(m_directory)
case_list = []
d_count = 0
if visualize == 1:
    for filename in q_directory:
    
        seg_filename = s_directory[d_count]
        laro_filename = qu_directory[d_count]
        mask_filename = m_directory[d_count]
        seg = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/orig/seg/'+seg_filename)
        mask = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/masks/'+mask_filename)
        voxel_size = seg.header['pixdim'][0:3]
        voxel_sizes.append(voxel_size)
        segs.append(seg.get_fdata()[:nrows,:ncols,:nslices])
        qsm = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/orig/qsm/'+filename)
        qsms.append(qsm.get_fdata()[:nrows,:ncols,:nslices])

        laro = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/lr_roi_ft/'+laro_filename)
        laros.append(1000*laro.get_fdata()[:nrows,:ncols,:nslices])
        print('Appending arrays with segmentation',seg_filename,'QSM,',filename,
              'LARO,',laro_filename,'and mask',mask_filename)
        case_list.append(filename)
        n_cases = len(segs)
        d_count = d_count+1
# Out:
# Appending arrays with segmentation 01_roi_combined.nii QSM, 00001_qsm.nii.gz LARO, QSM_lrr_01.nii and mask mask01.nii
# Appending arrays with segmentation 02_roi_combined.nii QSM, 00002_qsm.nii.gz LARO, QSM_lrr_02.nii and mask mask02.nii
# Appending arrays with segmentation 03_roi_combined.nii QSM, 00003_qsm.nii.gz LARO, QSM_lrr_03.nii and mask mask03.nii
# Appending arrays with segmentation 04_roi_combined.nii QSM, 00004_qsm.nii.gz LARO, QSM_lrr_04.nii and mask mask04.nii
# Appending arrays with segmentation 05_roi_combined.nii QSM, 00005_qsm.nii.gz LARO, QSM_lrr_05.nii and mask mask05.nii
# Appending arrays with segmentation 06_roi_combined.nii QSM, 00006_qsm.nii.gz LARO, QSM_lrr_06.nii and mask mask06.nii
# Appending arrays with segmentation 07_roi_combined.nii QSM, 00007_qsm.nii.gz LARO, QSM_lrr_07.nii and mask mask07.nii
# Appending arrays with segmentation 08_roi_combined.nii QSM, 00008_qsm.nii.gz LARO, QSM_lrr_08.nii and mask mask08.nii
# Appending arrays with segmentation 09_roi_combined.nii QSM, 00009_qsm.nii.gz LARO, QSM_lrr_09.nii and mask mask09.nii
# Appending arrays with segmentation 10_roi_combined.nii QSM, 00010_qsm.nii.gz LARO, QSM_lrr_10.nii and mask mask10.nii
# Appending arrays with segmentation 11_roi_combined.nii QSM, 00011_qsm.nii.gz LARO, QSM_lrr_11.nii and mask mask11.nii
# Appending arrays with segmentation 13_roi_combined.nii QSM, 00013_qsm.nii.gz LARO, QSM_lrr_13.nii and mask mask13.nii
# Appending arrays with segmentation 14_roi_combined.nii QSM, 00014_qsm.nii.gz LARO, QSM_lrr_14.nii and mask mask14.nii
# Appending arrays with segmentation 16_roi_combined.nii QSM, 00016_qsm.nii.gz LARO, QSM_lrr_16.nii and mask mask16.nii
# Appending arrays with segmentation 18_roi_combined.nii QSM, 00018_qsm.nii.gz LARO, QSM_lrr_18.nii and mask mask18.nii
# Appending arrays with segmentation 19_roi_combined.nii QSM, 00019_qsm.nii.gz LARO, QSM_lrr_19.nii and mask mask19.nii
# Appending arrays with segmentation 20_roi_combined.nii QSM, 00020_qsm.nii.gz LARO, QSM_lrr_20.nii and mask mask20.nii
# Appending arrays with segmentation 21_roi_combined.nii QSM, 00021_qsm.nii.gz LARO, QSM_lrr_21.nii and mask mask21.nii
# Appending arrays with segmentation 22_roi_combined.nii QSM, 00022_qsm.nii.gz LARO, QSM_lrr_22.nii and mask mask22.nii
# Appending arrays with segmentation 23_roi_combined.nii QSM, 00023_qsm.nii.gz LARO, QSM_lrr_23.nii and mask mask23.nii
# Appending arrays with segmentation 24_roi_combined.nii QSM, 00024_qsm.nii.gz LARO, QSM_lrr_24.nii and mask mask24.nii
# Appending arrays with segmentation 25_roi_combined.nii QSM, 00025_qsm.nii.gz LARO, QSM_lrr_25.nii and mask mask25.nii
# Appending arrays with segmentation 26_roi_combined.nii QSM, 00026_qsm.nii.gz LARO, QSM_lrr_26.nii and mask mask26.nii
# Appending arrays with segmentation 27_roi_combined.nii QSM, 00027_qsm.nii.gz LARO, QSM_lrr_27.nii and mask mask27.nii
# Appending arrays with segmentation 28_roi_combined.nii QSM, 00028_qsm.nii.gz LARO, QSM_lrr_28.nii and mask mask28.nii
# Appending arrays with segmentation 29_roi_combined.nii QSM, 00029_qsm.nii.gz LARO, QSM_lrr_29.nii and mask mask29.nii
# Appending arrays with segmentation 30_roi_combined.nii QSM, 00030_qsm.nii.gz LARO, QSM_lrr_30.nii and mask mask30.nii
# Appending arrays with segmentation 31_roi_combined.nii QSM, 00031_qsm.nii.gz LARO, QSM_lrr_31.nii and mask mask31.nii
# Appending arrays with segmentation 32_roi_combined.nii QSM, 00032_qsm.nii.gz LARO, QSM_lrr_32.nii and mask mask32.nii
# Appending arrays with segmentation 33_roi_combined.nii QSM, 00033_qsm.nii.gz LARO, QSM_lrr_33.nii and mask mask33.nii
# Appending arrays with segmentation 34_roi_combined.nii QSM, 00034_qsm.nii.gz LARO, QSM_lrr_34.nii and mask mask34.nii
# Appending arrays with segmentation 35_roi_combined.nii QSM, 00035_qsm.nii.gz LARO, QSM_lrr_35.nii and mask mask35.nii
# Appending arrays with segmentation 36_roi_combined.nii QSM, 00036_qsm.nii.gz LARO, QSM_lrr_36.nii and mask mask36.nii
# Appending arrays with segmentation 37_roi_combined.nii QSM, 00037_qsm.nii.gz LARO, QSM_lrr_37.nii and mask mask37.nii
# Appending arrays with segmentation 38_roi_combined.nii QSM, 00038_qsm.nii.gz LARO, QSM_lrr_38.nii and mask mask38.nii
# Appending arrays with segmentation 39_roi_combined.nii QSM, 00039_qsm.nii.gz LARO, QSM_lrr_39.nii and mask mask39.nii
# Appending arrays with segmentation 40_roi_combined.nii QSM, 00040_qsm.nii.gz LARO, QSM_lrr_40.nii and mask mask40.nii

# %%
df = pd.read_csv('/home/ali/RadDBS-QSM/data/xlxs/updrs_iii_chh.csv')
df
# Out:
#     subjects    LCT   Unnamed: 2                     UPDRSⅢ  \
# 0        NaN     NaN         NaN  Preoperative Off-Medicine
# 1        1.0  62.26%         NaN                         53
# 2        2.0  75.00%         NaN                         32
# 3        3.0  51.72%         NaN                         58
# 4        4.0  22.58%         NaN                         62
# 5        5.0  55.88%         NaN                         34
# 6        6.0  75.44%         NaN                         57
# 7        7.0  84.00%         NaN                        100
# 8        8.0  41.86%         NaN                         43
# 9        9.0  72.58%         NaN                         62
# 10      10.0  81.25%         NaN                         64
# 11      11.0  70.21%         NaN                         94
# 12      12.0  63.95%         NaN                         86
# 13      13.0  89.55%         NaN                         67
# 14      14.0  88.46%         NaN                         26
# 15      15.0  62.50%         NaN                         72
# 16      16.0  48.00%         NaN                         25
# 17      17.0  14.29%         NaN                         98
# 18      18.0  36.62%         NaN                         71
# 19      19.0  54.90%         NaN                         51
# 20      20.0  81.63%         NaN                         49
# 21      21.0  71.43%         NaN                         49
# 22      22.0  90.32%         NaN                         31
# 23      23.0  65.85%         NaN                         41
# 24      24.0  74.29%         NaN                         35
# 25      25.0  83.61%         NaN                         61
# 26      26.0  58.97%         NaN                         78
# 27      27.0   5.88%         NaN                         51
# 28      28.0  76.67%         NaN                         60
# 29      29.0  81.01%         NaN                         79
# 30      30.0  62.35%         NaN                         85
# 31      31.0  27.91%         NaN                         43
# 32      32.0  31.48%         NaN                         54
# 33      33.0  80.33%         NaN                         61
# 34      34.0  40.74%         NaN                         54
# 35      35.0  16.13%         NaN                         93
# 36      36.0  59.26%         NaN                         54
# 37      37.0  61.40%         NaN                         57
# 38      38.0  95.92%         NaN                         49
# 39      39.0  79.35%         NaN                         92
# 40      40.0  50.00%         NaN                         54
#
#                   Unnamed: 4                                       Unnamed: 5  \
# 0   Preoperative On-Medicine  Postoperative  Off-Medicine &Off-Stimulation\n
# 1                         20                                               40
# 2                          8                                               26
# 3                         28                                               52
# 4                         48                                               61
# 5                         15                                               44
# 6                         14                                               55
# 7                         16                                               68
# 8                         25                                               48
# 9                         17                                               56
# 10                        12                                               33
# 11                        28                                               31
# 12                        31                                               28
# 13                         7                                               64
# 14                         3                                               31
# 15                        27                                               72
# 16                        13                                               17
# 17                        84                                               86
# 18                        45                                               49
# 19                        23                                               37
# 20                         9                                               20
# 21                        14                                               42
# 22                         3                                               46
# 23                        14                                               43
# 24                         9                                               21
# 25                        10                                               60
# 26                        32                                               64
# 27                        48                                               45
# 28                        14                                               68
# 29                        15                                               79
# 30                        32                                               92
# 31                        31                                               31
# 32                        37                                               64
# 33                        12                                               53
# 34                        32                                               64
# 35                        78                                               69
# 36                        22                                               57
# 37                        22                                               56
# 38                         2                                               58
# 39                        19                                              NaN
# 40                        27                                               34
#
#                                      Unnamed: 6  \
# 0   Postoperative  Off-Medicine &On-Stimulation
# 1                                            15
# 2                                            17
# 3                                            18
# 4                                            36
# 5                                            29
# 6                                            32
# 7                                            12
# 8                                            26
# 9                                            25
# 10                                           12
# 11                                           34
# 12                                           27
# 13                                           19
# 14                                           18
# 15                                           44
# 16                                            8
# 17                                           43
# 18                                           47
# 19                                           21
# 20                                            3
# 21                                            8
# 22                                           28
# 23                                           24
# 24                                           15
# 25                                           21
# 26                                           29
# 27                                           27
# 28                                           43
# 29                                           32
# 30                                           40
# 31                                            6
# 32                                           28
# 33                                           21
# 34                                           36
# 35                                           47
# 36                                           12
# 37                                           11
# 38                                           14
# 39                                           63
# 40                                            9
#
#                                     Unnamed: 7  Unnamed: 8
# 0   Postoperative  On-Medicine &On-Stimulation         NaN
# 1                                            7         NaN
# 2                                           10         NaN
# 3                                           20         NaN
# 4                                           28         NaN
# 5                                           22         NaN
# 6                                           16         NaN
# 7                                          NaN         NaN
# 8                                           26         NaN
# 9                                           11         NaN
# 10                                         NaN         NaN
# 11                                          43         NaN
# 12                                          18         NaN
# 13                                         NaN         NaN
# 14                                          17         NaN
# 15                                          38         NaN
# 16                                           8         NaN
# 17                                          34         NaN
# 18                                          46         NaN
# 19                                          18         NaN
# 20                                         NaN         NaN
# 21                                         NaN         NaN
# 22                                         NaN         NaN
# 23                                          24         NaN
# 24                                         NaN         NaN
# 25                                          17         NaN
# 26                                          21         NaN
# 27                                          20         NaN
# 28                                         NaN         NaN
# 29                                          28         NaN
# 30                                         NaN         NaN
# 31                                         NaN         NaN
# 32                                          25         NaN
# 33                                          15         NaN
# 34                                          29         NaN
# 35                                          44         NaN
# 36                                         NaN         NaN
# 37                                         NaN         NaN
# 38                                          12         NaN
# 39                                         NaN         NaN
# 40                                           8         NaN

# %%
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]

# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][:2])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
for i in np.arange(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 01_roi_combined.nii for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 02_roi_combined.nii for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 03_roi_combined.nii for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 04_roi_combined.nii for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 05_roi_combined.nii for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 06_roi_combined.nii for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 07_roi_combined.nii for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 08_roi_combined.nii for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 09_roi_combined.nii for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 10_roi_combined.nii for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 11_roi_combined.nii for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 13_roi_combined.nii for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 14_roi_combined.nii for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 16_roi_combined.nii for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 18_roi_combined.nii for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 19_roi_combined.nii for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 20_roi_combined.nii for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 21_roi_combined.nii for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 22_roi_combined.nii for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 23_roi_combined.nii for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 24_roi_combined.nii for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 25_roi_combined.nii for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 26_roi_combined.nii for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 27_roi_combined.nii for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 28_roi_combined.nii for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 29_roi_combined.nii for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 30_roi_combined.nii for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 31_roi_combined.nii for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 32_roi_combined.nii for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 33_roi_combined.nii for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 34_roi_combined.nii for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 35_roi_combined.nii for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 36_roi_combined.nii for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 37_roi_combined.nii for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 38_roi_combined.nii for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 39_roi_combined.nii for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 40_roi_combined.nii for case 40.0

# %%
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])                                
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])
post_updrs_iii_off =  np.asarray(df[df.columns[6]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])

per_change = (np.asarray(pre_updrs_iii_off).astype(float)-np.asarray(post_updrs_iii_off).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))
lct_change = (np.asarray(pre_updrs_iii_off).astype(float)-(np.asarray(pre_updrs_iii_on)).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))

# %%
cv_names = {'CORNELL ID',
            ' OFF (pre-dbs updrs)',
            ' ON (pre-dbs updrs)',
            ' OFF meds ON stim 6mo',
            'Age',
            'Sex',
            'Ethnicity',
            'Race',
            'Disease Duration (year)',
            'Physician',
            ' pre op levadopa equivalent dose (mg)',
            ' Location',
            ' Target',
            ' Test medication status'}


# Load scores
file_dir = '/home/ali/RadDBS-QSM/data/docs/dbs_03292024.csv'
motor_df = util.filter_data(file_dir,cv_names,True)
# Find cases with all required scores
cv_dict = util.filter_cases(motor_df,cv_names)
subs = cv_dict['CORNELL ID']
# Load extracted features
npy_dir = '/home/ali/RadDBS-QSM/data/npy/new/'
phi_dir = '/home/ali/RadDBS-QSM/data/phi/new/phi/'
roi_path = '/home/ali/RadDBS-QSM/data/xlxs/new_segs.csv'
n_rois = 6
all_rois = False
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595,all_rois)
print(np.unique(R_all))
ids = np.asarray(ID_all).astype(int)

# Use cases from only 1 rater
phys = cv_dict['Physician']
# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(ids).astype(int),np.asarray(cv_dict['CORNELL ID'])[phys==1].astype(int))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
# Exclude GPi
c_cases_idx[ids == 36] = 0
# c_cases_idx[ids == 42] = 0
# c_cases_idx[ids == 52] = 0
c_cases_idx[ids == 53] = 0
# c_cases_idx[ids == 98] = 0
# c_cases_idx[ids == 108] = 0
print(np.sum(c_cases_idx))
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
print(len(s_cases_idx))
        
X_all_c = X_all[c_cases_idx,2:6,:]
#X_all_c = (np.load('X2h_sr.npy').T).reshape((31,6381))
# print('Applying combat')
K_all_c = K_all[c_cases_idx,2:6,:]
R_all_c = R_all[c_cases_idx,2:6,:]
# Re-index the scored subjects with respect to complete cases

per_change = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' OFF meds ON stim 6mo'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_updrs = cv_dict[' OFF (pre-dbs updrs)'][s_cases_idx]
dd = cv_dict['Disease Duration (year)'][s_cases_idx]
ledd = cv_dict[' pre op levadopa equivalent dose (mg)'][s_cases_idx]
tmed = cv_dict[' Test medication status'][s_cases_idx]

age = cv_dict['Age'][s_cases_idx]
loc = cv_dict[' Location'][s_cases_idx]
sex = cv_dict['Sex'][s_cases_idx]
rce = cv_dict['Race'][s_cases_idx]
eth = cv_dict['Ethnicity'][s_cases_idx]
tgt = cv_dict[' Target'][s_cases_idx]
subsc = subs[s_cases_idx]
# Reshape keys and ROIs
if all_rois == True:
    K_all_cu = np.empty((K_all_c.shape[0],K_all_c.shape[1],K_all_c.shape[2]+1),dtype=object)
    K_all_cu[:,:,:-1] = K_all_c
    K_all_cu[:,:,-1] = 'pre_updrs'
    K_all_cu[:,:,-1] = 'disease_duration'
    K_all_cu[:,:,-1] = 'pre op levadopa equivalent dose (mg)'
    K_all_cu[:,:,-1] = ' Test medication status'
    K_all_cu[:,:,-1] = 'Physician'
    K_all_cu[:,:,-1] = 'Age'
    K_all_cu[:,:,-1] = 'Location'
    K_all_cu[:,:,-1] = 'Sex'
    K_all_cu[:,:,-1] = 'Race'
    K_all_cu[:,:,-1] = 'Ethnicity'
    
    K = K_all_cu.reshape((K_all_cu.shape[0],K_all_cu.shape[1]*K_all_cu.shape[2]))[0]
    R = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))
else:
    K_all_c = K_all_c.reshape((K_all_c.shape[0],K_all_c.shape[1]*K_all_c.shape[2]))[0]
    R_all_c = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))

print(np.unique(R_all_c))
# Out:
# Keeping CORNELL ID
# Keeping Age
# Keeping Sex
# Keeping Ethnicity
# Keeping Race
# Keeping Disease Duration (year)
# Keeping Physician
# Keeping  OFF (pre-dbs updrs)
# Keeping  ON (pre-dbs updrs)
# Keeping  pre op levadopa equivalent dose (mg)
# Keeping  Location
# Keeping  Target
# Keeping  Test medication status
# Keeping  OFF meds ON stim 6mo
# {'CORNELL ID', ' OFF (pre-dbs updrs)', ' ON (pre-dbs updrs)', ' OFF meds ON stim 6mo', 'Ethnicity', 'Sex', ' Test medication status', ' pre op levadopa equivalent dose (mg)', 'Race', 'Physician', ' Location', ' Target', 'Disease Duration (year)', 'Age'}
# ['X_115_01.npy', 'X_115_02.npy', 'X_115_03.npy', 'X_115_04.npy', 'X_115_05.npy', 'X_115_06.npy', 'X_115_07.npy', 'X_115_08.npy', 'X_115_09.npy', 'X_115_10.npy', 'X_115_100.npy', 'X_115_101.npy', 'X_115_102.npy', 'X_115_104.npy', 'X_115_105.npy', 'X_115_106.npy', 'X_115_107.npy', 'X_115_108.npy', 'X_115_109.npy', 'X_115_11.npy', 'X_115_110.npy', 'X_115_111.npy', 'X_115_112.npy', 'X_115_113.npy', 'X_115_114.npy', 'X_115_115.npy', 'X_115_116.npy', 'X_115_12.npy', 'X_115_13.npy', 'X_115_14.npy', 'X_115_15.npy', 'X_115_16.npy', 'X_115_17.npy', 'X_115_18.npy', 'X_115_19.npy', 'X_115_20.npy', 'X_115_22.npy', 'X_115_23.npy', 'X_115_24.npy', 'X_115_25.npy', 'X_115_26.npy', 'X_115_27.npy', 'X_115_29.npy', 'X_115_30.npy', 'X_115_31.npy', 'X_115_32.npy', 'X_115_33.npy', 'X_115_34.npy', 'X_115_36.npy', 'X_115_37.npy', 'X_115_39.npy', 'X_115_40.npy', 'X_115_41.npy', 'X_115_42.npy', 'X_115_44.npy', 'X_115_45.npy', 'X_115_46.npy', 'X_115_48.npy', 'X_115_49.npy', 'X_115_50.npy', 'X_115_51.npy', 'X_115_52.npy', 'X_115_53.npy', 'X_115_55.npy', 'X_115_56.npy', 'X_115_57.npy', 'X_115_58.npy', 'X_115_59.npy', 'X_115_60.npy', 'X_115_61.npy', 'X_115_62.npy', 'X_115_63.npy', 'X_115_64.npy', 'X_115_66.npy', 'X_115_67.npy', 'X_115_68.npy', 'X_115_69.npy', 'X_115_70.npy', 'X_115_71.npy', 'X_115_72.npy', 'X_115_73.npy', 'X_115_74.npy', 'X_115_75.npy', 'X_115_76.npy', 'X_115_77.npy', 'X_115_78.npy', 'X_115_79.npy', 'X_115_80.npy', 'X_115_81.npy', 'X_115_82.npy', 'X_115_83.npy', 'X_115_84.npy', 'X_115_85.npy', 'X_115_86.npy', 'X_115_87.npy', 'X_115_88.npy', 'X_115_89.npy', 'X_115_90.npy', 'X_115_92.npy', 'X_115_93.npy', 'X_115_94.npy', 'X_115_95.npy', 'X_115_97.npy', 'X_115_98.npy', 'X_115_99.npy']
# Allocated arrays
# Created feature matrix
# Created ROI matrix
# Created feature label matrix
# ['0.0' 'Left red nucleus' 'Left substantia nigra'
#  'Left subthalamic nucleus' 'Right Substantia nigra' 'Right red nucleus'
#  'Right subthalamic nucleus']
# 31
# 69
# ['0.0' 'Left substantia nigra' 'Left subthalamic nucleus'
#  'Right Substantia nigra' 'Right subthalamic nucleus']

# %%
n_cases = len(per_change)
results_ls_aug = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
r = 1

# %%
Js = []
aug = True
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs,age,dd,loc,ledd,None,None,None,None,None,False,False,False)
    # 10
    cvn = 5
    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    print(np.sum(X0_ss0))
    (mu, sigma) = stats.norm.fit(y_train)
    kappa = stats.skew(y_train)
    print('Label distribution of:',mu,sigma,kappa)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
      if aug == True:
        y_train_n = y_train+(2.326*sigma)*np.random.normal(0,1,1)
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
    
    for jj in np.arange(2,cvn):
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)

      # Break any ties
      if np.sum(cv_scores == best_cv) > 1:
        cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
        for jjj in (cv_scores == cv_scores(best_cv)):
          if jjj > 0:
            skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
            skf_gen = skf_g.split(X0_ss0,y_cat) 
            X0_sst = sel.fit_transform(X0_ss0,y_train)
            X0_ss = X0_sst
            lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
            est_ls = lasso.fit(X0_ss,y_train)
            cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
        best_cv = np.argmax(cv_scores_tb)
      
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
      results_ls_aug[c] = est_ls.predict(X_test_ss)
      if results_ls_aug[c] < 0:
          dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)
          results_ls_aug[c] = y_train[y_n]
          print('Using nearest neighbor')
      print('Lasso predicts',str(np.round(results_ls_aug[c],4)),
            'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
      try:
        K_nz.append(np.squeeze(K_ss)[est_ls.coef_>0])
      except:
        print('No features appended')
      c=c+1
# Out:
# 1.7706724975141697e-11
# Label distribution of: 0.6493797332610988 0.2356459981054766 -0.822647341233261
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41621382] from dataset of size (256, 2385)
# LassoCV score for 3 is [0.41447841] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.41621382] from dataset of size (256, 385)
# Lasso predicts 0.6125 for case with 0.67 and selected CV 2
# No features appended
# -1.0766143532237038e-10
# Label distribution of: 0.6393268232081887 0.228141573224618 -0.865250864641114
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41736815] from dataset of size (256, 385)
# LassoCV score for 3 is [0.41461615] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41736815] from dataset of size (256, 3385)
# Using nearest neighbor
# Lasso predicts 0.5949 for case with 0.97 and selected CV 2
# No features appended
# 2.2652102416031994e-11
# Label distribution of: 0.6455149989615818 0.23437661211565589 -0.792722688406113
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41594877] from dataset of size (256, 2385)
# LassoCV score for 3 is [0.41250732] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41594877] from dataset of size (256, 5385)
# Lasso predicts 0.7812 for case with 0.78 and selected CV 2
# No features appended
# 1.830358087318018e-11
# Label distribution of: 0.655601955483321 0.23354649467427782 -0.9122499366873172
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41844856] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.41634209] from dataset of size (256, 385)
# LassoCV score for 4 is [0.41844856] from dataset of size (256, 2385)
# Lasso predicts 0.4468 for case with 0.48 and selected CV 2
# No features appended
# 5.002220859751105e-12
# Label distribution of: 0.6477924316737972 0.23536365894771702 -0.8060648356167894
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41600299] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.40871231] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.41600299] from dataset of size (256, 1385)
# Lasso predicts 0.7911 for case with 0.71 and selected CV 2
# No features appended
# 1.0373923942097463e-11
# Label distribution of: 0.6445186221499877 0.23372724825476596 -0.7919883452696557
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41601842] from dataset of size (256, 4385)
# LassoCV score for 3 is [0.41314542] from dataset of size (256, 385)
# LassoCV score for 4 is [0.41601842] from dataset of size (256, 2385)
# Lasso predicts 0.7292 for case with 0.81 and selected CV 2
# No features appended
# 7.332801033044234e-12
# Label distribution of: 0.6442210031023686 0.23350736984372764 -0.7924899044159993
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41605048] from dataset of size (256, 4385)
# LassoCV score for 3 is [0.41196926] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.41605048] from dataset of size (256, 2385)
# Lasso predicts 0.6815 for case with 0.82 and selected CV 2
# No features appended
# 4.376943252282217e-12
# Label distribution of: 0.6421147759961415 0.23160675947033096 -0.8072206349697161
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41642961] from dataset of size (256, 3385)
# LassoCV score for 3 is [0.40673179] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.41642961] from dataset of size (256, 4385)
# Lasso predicts 0.6468 for case with 0.88 and selected CV 2
# No features appended
# 1.4921397450962104e-11
# Label distribution of: 0.6653519554833209 0.21948300513415092 -0.9261431205793806
# Resampled to size (31,)
# Resampled to size (32,)
# Resampled to size (33,)
# LassoCV score for 2 is [0.47246876] from dataset of size (264, 2385)
# LassoCV score for 3 is [0.47245687] from dataset of size (264, 5385)
# LassoCV score for 4 is [0.47246876] from dataset of size (264, 5385)
# Lasso predicts 0.0041 for case with 0.19 and selected CV 2
# No features appended
# 1.1453948900452815e-11
# Label distribution of: 0.6433191272004927 0.23276777808776417 -0.796262196143525
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41617976] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.3541048] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.41617976] from dataset of size (256, 3385)
# Lasso predicts 0.6948 for case with 0.85 and selected CV 2
# No features appended
# 8.469669410260394e-12
# Label distribution of: 0.6454481093294748 0.23433718721541313 -0.7925639277879651
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41595165] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.41306836] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.41595165] from dataset of size (256, 6385)
# Lasso predicts 0.6603 for case with 0.78 and selected CV 2
# No features appended
# 9.86233317235019e-12
# Label distribution of: 0.6419723258536914 0.23145620209129852 -0.8090132356692766
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41646515] from dataset of size (256, 385)
# LassoCV score for 3 is [0.40452124] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41646515] from dataset of size (256, 4385)
# Lasso predicts 0.6337 for case with 0.89 and selected CV 2
# No features appended
# 1.5660361896152608e-11
# Label distribution of: 0.6543605761729762 0.23437613091582502 -0.8938686657370641
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41781507] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.41535924] from dataset of size (256, 385)
# LassoCV score for 4 is [0.41781507] from dataset of size (256, 1385)
# Lasso predicts 0.5623 for case with 0.52 and selected CV 2
# No features appended
# 1.6086687537608668e-11
# Label distribution of: 0.6468156306969962 0.2350246204163482 -0.7985921892416697
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41594347] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.41462742] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.31227417] from dataset of size (256, 4385)
# Lasso predicts 0.3938 for case with 0.74 and selected CV 2
# No features appended
# 1.3159251466277055e-11
# Label distribution of: 0.6538600199994501 0.23465224314525635 -0.886272054317513
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41758728] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.41558972] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41758728] from dataset of size (256, 1385)
# Lasso predicts 0.6391 for case with 0.53 and selected CV 2
# No features appended
# 1.0658141036401503e-11
# Label distribution of: 0.6412097986205758 0.23060222765200317 -0.820573924542346
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41667748] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.41429785] from dataset of size (256, 1385)
# LassoCV score for 4 is [0.41667748] from dataset of size (256, 2385)
# Lasso predicts 0.5736 for case with 0.91 and selected CV 2
# No features appended
# 7.219114195322618e-12
# Label distribution of: 0.6449352888166543 0.2340150189920344 -0.7918591260968485
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41598228] from dataset of size (256, 385)
# LassoCV score for 3 is [0.41291376] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.41598228] from dataset of size (256, 2385)
# Lasso predicts 0.7567 for case with 0.8 and selected CV 2
# No features appended
# 1.0231815394945443e-11
# Label distribution of: 0.6445186221499877 0.23372724825476596 -0.7919883452696557
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.18200009] from dataset of size (256, 1)
# LassoCV score for 3 is [0.41601842] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.41601842] from dataset of size (256, 1385)
# Lasso predicts 0.5389 for case with 0.81 and selected CV 3
# No features appended
# 1.27613475342514e-11
# Label distribution of: 0.6393438909671919 0.228166159851381 -0.8647299368655631
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41736078] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.40511797] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41736078] from dataset of size (256, 2385)
# Lasso predicts 0.7127 for case with 0.97 and selected CV 2
# No features appended
# 1.2107648217352107e-11
# Label distribution of: 0.6436257650071304 0.2330316433885754 -0.7945832072870734
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41509104] from dataset of size (256, 385)
# LassoCV score for 3 is [0.41242413] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.41477061] from dataset of size (256, 5385)
# Using nearest neighbor
# Lasso predicts 0.4939 for case with 0.84 and selected CV 2
# No features appended
# 1.5717205315013416e-11
# Label distribution of: 0.6666999946990072 0.21639808153172727 -0.8859502176709874
# Resampled to size (31,)
# Resampled to size (32,)
# Resampled to size (33,)
# LassoCV score for 2 is [0.46704191] from dataset of size (264, 385)
# LassoCV score for 3 is [0.46703976] from dataset of size (264, 1385)
# LassoCV score for 4 is [0.46704191] from dataset of size (264, 385)
# Lasso predicts 0.2352 for case with 0.15 and selected CV 4
# No features appended
# 7.958078640513122e-12
# Label distribution of: 0.6687448126261781 0.21112405555642186 -0.7854539364677489
# Resampled to size (31,)
# Resampled to size (32,)
# Resampled to size (33,)
# LassoCV score for 2 is [0.46438982] from dataset of size (264, 6385)
# LassoCV score for 3 is [0.46438982] from dataset of size (264, 1385)
# LassoCV score for 4 is [0.46438982] from dataset of size (264, 2385)
# Lasso predicts 0.2945 for case with 0.09 and selected CV 3
# No features appended
# 6.565414878423326e-12
# Label distribution of: 0.6615244361034759 0.22666410774677231 -0.9655965095034017
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.42298948] from dataset of size (256, 3385)
# LassoCV score for 3 is [0.31874503] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.31874503] from dataset of size (256, 4385)
# Lasso predicts 0.4714 for case with 0.3 and selected CV 2
# No features appended
# 4.405364961712621e-12
# Label distribution of: 0.6563972771207478 0.23290563856073992 -0.9233948396561067
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41890752] from dataset of size (256, 3385)
# LassoCV score for 3 is [0.41364712] from dataset of size (256, 1385)
# LassoCV score for 4 is [0.41890752] from dataset of size (256, 385)
# Lasso predicts 0.5415 for case with 0.46 and selected CV 4
# No features appended
# 5.314859663485549e-12
# Label distribution of: 0.6484381136754113 0.23551856598199494 -0.8122168503525554
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41607165] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.41418567] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.41607165] from dataset of size (256, 1385)
# Lasso predicts 0.5959 for case with 0.69 and selected CV 2
# No features appended
# 7.105427357601002e-12
# Label distribution of: 0.6510345795967961 0.2355872595275298 -0.8442366615141563
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41658527] from dataset of size (256, 4385)
# LassoCV score for 3 is [0.41434981] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41658527] from dataset of size (256, 2385)
# Lasso predicts 0.6631 for case with 0.62 and selected CV 4
# No features appended
# 6.338041202980094e-12
# Label distribution of: 0.6514870129545852 0.235508457962084 -0.8506731109941843
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.4167141] from dataset of size (256, 2385)
# LassoCV score for 3 is [0.41334274] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.4167141] from dataset of size (256, 2385)
# Lasso predicts 0.6587 for case with 0.6 and selected CV 2
# No features appended
# 3.097966327914037e-12
# Label distribution of: 0.6513833762483482 0.23552888987780995 -0.8491831307728512
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41668355] from dataset of size (256, 4385)
# LassoCV score for 3 is [0.41510538] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.41668355] from dataset of size (256, 1385)
# Lasso predicts 0.5671 for case with 0.61 and selected CV 2
# No features appended
# 2.8990143619012088e-12
# Label distribution of: 0.6514265168868296 0.2355205566995504 -0.8498022994263561
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41669619] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.40307393] from dataset of size (256, 6385)
# LassoCV score for 4 is [0.41669619] from dataset of size (256, 4385)
# Lasso predicts 0.5955 for case with 0.61 and selected CV 2
# No features appended
# 1.5063505998114124e-12
# Label distribution of: 0.6566019554833209 0.23272679532807528 -0.9261496299585259
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41903256] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.41759646] from dataset of size (256, 385)
# LassoCV score for 4 is [0.41903256] from dataset of size (256, 385)
# Lasso predicts 0.4448 for case with 0.45 and selected CV 2
# No features appended
# 7.332801033044234e-12
# Label distribution of: 0.6510891349705002 0.23557918704721473 -0.8450030003554975
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.41660018] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.41337794] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.41660018] from dataset of size (256, 4385)
# Lasso predicts 0.5944 for case with 0.62 and selected CV 2
# No features appended

# %%
util.eval_prediction(np.vstack((pre_imp,
                               results_ls_aug,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
# Fix nearest neighbor problem
# Fix differing noise problem

# %%
# Do wild bootstrap
# Repeat CHH with wild bootstrap and higher zscore
Js = []
aug = False
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(c,len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs,age,dd,loc,ledd,None,None,None,None,None,False,False,False)
    X0_ss00 = X0_ss0
    y_train_0 = y_train
    cvn = 5

    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    (mu, sigma) = stats.norm.fit(y_train)
    kappa = stats.skew(y_train)
    print('Label distribution of:',mu,sigma,kappa)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
        ls0 = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
        est0 = ls0.fit(X0_ss0,y_train)
        eps = y_train-ls0.predict(X0_ss0)
        eps_v = eps*np.random.normal(0,1,1)
        y_train_0 = y_train
      if aug == True:
        y_train_n = y_train+(1.96*sigma)*np.random.normal(0,1,1)
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
      else: # Control for different training sample sizes
        while len(eps_v) < len(y_train):
          eps_v = np.hstack((eps_v,eps*np.random.normal(0,1,1)))
        y_train_n = y_train+eps_v
        cc = cc+1
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))

    for jj in np.arange(2,cvn):
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)
      # Break any ties
      if np.sum(cv_scores == best_cv) > 1:
        cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
        for jjj in (cv_scores == cv_scores(best_cv)):
          if jjj > 0:
            skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
            skf_gen = skf_g.split(X0_ss0,y_cat) 
            X0_sst = sel.fit_transform(X0_ss0,y_train)
            X0_ss = X0_sst
            lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
            est_ls = lasso.fit(X0_ss,y_train)
            cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
        best_cv = np.argmax(cv_scores_tb)
      
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
      results_ls[c] = est_ls.predict(X_test_ss)
      if results_ls[c] < 0:
          dx, y_n = cKDTree(X0_ss00.reshape(X0_ss00.shape[0],-1)).query(X_test_ss0.reshape(1,-1),k=15)
          results_ls[c] = np.mean((y_train_0[y_n]))
          print('Using nearest neighbor')
      print('Lasso predicts',str(np.round(results_ls[c],4)),
            'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
      try:
        K_nz.append(np.squeeze(K_ss)[est_ls.coef_>0])
      except:
        print('No features appended')
      c=c+1
# Out:
# Label distribution of: 0.6493797332610988 0.2356459981054766 -0.822647341233261
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.99917335] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.99917335] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.99917335] from dataset of size (256, 385)
# Lasso predicts 0.6804 for case with 0.67 and selected CV 2
# No features appended
# Label distribution of: 0.6393268232081887 0.228141573224618 -0.865250864641114
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.97822664] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.97822664] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.97822664] from dataset of size (256, 6385)
# Using nearest neighbor
# Lasso predicts 0.6408 for case with 0.97 and selected CV 2
# No features appended
# Label distribution of: 0.6455149989615818 0.23437661211565589 -0.792722688406113
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.91215412] from dataset of size (256, 385)
# LassoCV score for 3 is [0.91206156] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.91215412] from dataset of size (256, 5385)
# Lasso predicts 0.8538 for case with 0.78 and selected CV 2
# No features appended
# Label distribution of: 0.655601955483321 0.23354649467427782 -0.9122499366873172
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90832544] from dataset of size (256, 3385)
# LassoCV score for 3 is [0.90826415] from dataset of size (256, 1385)
# LassoCV score for 4 is [0.90832467] from dataset of size (256, 6385)
# Lasso predicts 0.4512 for case with 0.48 and selected CV 2
# No features appended
# Label distribution of: 0.6477924316737972 0.23536365894771702 -0.8060648356167894
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.91296121] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.91284626] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.91295775] from dataset of size (256, 6385)
# Lasso predicts 0.8512 for case with 0.71 and selected CV 2
# No features appended
# Label distribution of: 0.6445186221499877 0.23372724825476596 -0.7919883452696557
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90662025] from dataset of size (256, 385)
# LassoCV score for 3 is [0.90654208] from dataset of size (256, 1385)
# LassoCV score for 4 is [0.90662025] from dataset of size (256, 6385)
# Lasso predicts 0.8051 for case with 0.81 and selected CV 2
# No features appended
# Label distribution of: 0.6442210031023686 0.23350736984372764 -0.7924899044159993
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.9072039] from dataset of size (256, 385)
# LassoCV score for 3 is [0.90077151] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.90720222] from dataset of size (256, 2385)
# Lasso predicts 0.7519 for case with 0.82 and selected CV 2
# No features appended
# Label distribution of: 0.6421147759961415 0.23160675947033096 -0.8072206349697161
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.87650482] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.87645095] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.87650482] from dataset of size (256, 2385)
# Lasso predicts 0.7163 for case with 0.88 and selected CV 2
# No features appended
# Label distribution of: 0.6653519554833209 0.21948300513415092 -0.9261431205793806
# Resampled to size (31,)
# Resampled to size (32,)
# Resampled to size (33,)
# LassoCV score for 2 is [0.99413268] from dataset of size (264, 1385)
# LassoCV score for 3 is [0.99526186] from dataset of size (264, 385)
# LassoCV score for 4 is [0.98896694] from dataset of size (264, 4385)
# Lasso predicts 0.497 for case with 0.19 and selected CV 3
# No features appended
# Label distribution of: 0.6433191272004927 0.23276777808776417 -0.796262196143525
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90111594] from dataset of size (256, 3385)
# LassoCV score for 3 is [0.89895026] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.90111594] from dataset of size (256, 1385)
# Lasso predicts 0.8581 for case with 0.85 and selected CV 2
# No features appended
# Label distribution of: 0.6454481093294748 0.23433718721541313 -0.7925639277879651
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.91518164] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.91479255] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.9151709] from dataset of size (256, 1385)
# Lasso predicts 0.7357 for case with 0.78 and selected CV 2
# No features appended
# Label distribution of: 0.6419723258536914 0.23145620209129852 -0.8090132356692766
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90882476] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.90880597] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.90882476] from dataset of size (256, 5385)
# Lasso predicts 0.7049 for case with 0.89 and selected CV 2
# No features appended
# Label distribution of: 0.6543605761729762 0.23437613091582502 -0.8938686657370641
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.8983775] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.89830844] from dataset of size (256, 385)
# LassoCV score for 4 is [0.8983775] from dataset of size (256, 2385)
# Lasso predicts 0.6291 for case with 0.52 and selected CV 2
# No features appended
# Label distribution of: 0.6468156306969962 0.2350246204163482 -0.7985921892416697
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90327048] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.9032119] from dataset of size (256, 385)
# LassoCV score for 4 is [0.90327048] from dataset of size (256, 6385)
# Lasso predicts 0.3639 for case with 0.74 and selected CV 2
# No features appended
# Label distribution of: 0.6538600199994501 0.23465224314525635 -0.886272054317513
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.99551944] from dataset of size (256, 3385)
# LassoCV score for 3 is [0.99551944] from dataset of size (256, 1385)
# LassoCV score for 4 is [0.99551934] from dataset of size (256, 385)
# Lasso predicts 0.7037 for case with 0.53 and selected CV 2
# No features appended
# Label distribution of: 0.6412097986205758 0.23060222765200317 -0.820573924542346
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90706732] from dataset of size (256, 385)
# LassoCV score for 3 is [0.90690901] from dataset of size (256, 385)
# LassoCV score for 4 is [0.90706732] from dataset of size (256, 3385)
# Lasso predicts 0.644 for case with 0.91 and selected CV 2
# No features appended
# Label distribution of: 0.6449352888166543 0.2340150189920344 -0.7918591260968485
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90085737] from dataset of size (256, 385)
# LassoCV score for 3 is [0.89956592] from dataset of size (256, 4385)
# LassoCV score for 4 is [0.90510205] from dataset of size (256, 1385)
# Lasso predicts 0.8424 for case with 0.8 and selected CV 4
# No features appended
# Label distribution of: 0.6445186221499877 0.23372724825476596 -0.7919883452696557
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.98128189] from dataset of size (256, 385)
# LassoCV score for 3 is [0.98128189] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.98128148] from dataset of size (256, 2385)
# Lasso predicts 0.5253 for case with 0.81 and selected CV 3
# No features appended
# Label distribution of: 0.6393438909671919 0.228166159851381 -0.8647299368655631
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.88223221] from dataset of size (256, 2385)
# LassoCV score for 3 is [0.88215565] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.88223221] from dataset of size (256, 4385)
# Lasso predicts 0.7646 for case with 0.97 and selected CV 2
# No features appended
# Label distribution of: 0.6436257650071304 0.2330316433885754 -0.7945832072870734
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90607113] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.90687675] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.90794954] from dataset of size (256, 6385)
# Using nearest neighbor
# Lasso predicts 0.626 for case with 0.84 and selected CV 4
# No features appended
# Label distribution of: 0.6666999946990072 0.21639808153172727 -0.8859502176709874
# Resampled to size (31,)
# Resampled to size (32,)
# Resampled to size (33,)
# LassoCV score for 2 is [0.98994181] from dataset of size (264, 385)
# LassoCV score for 3 is [0.99989979] from dataset of size (264, 2385)
# LassoCV score for 4 is [0.99991523] from dataset of size (264, 1385)
# Lasso predicts 0.5178 for case with 0.15 and selected CV 4
# No features appended
# Label distribution of: 0.6687448126261781 0.21112405555642186 -0.7854539364677489
# Resampled to size (31,)
# Resampled to size (32,)
# Resampled to size (33,)
# LassoCV score for 2 is [0.96241692] from dataset of size (264, 4385)
# LassoCV score for 3 is [0.96238322] from dataset of size (264, 1385)
# LassoCV score for 4 is [0.9624181] from dataset of size (264, 385)
# Lasso predicts 0.5612 for case with 0.09 and selected CV 4
# No features appended
# Label distribution of: 0.6615244361034759 0.22666410774677231 -0.9655965095034017
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90163786] from dataset of size (256, 1385)
# LassoCV score for 3 is [0.9016078] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.66771004] from dataset of size (256, 4385)
# Lasso predicts 0.5332 for case with 0.3 and selected CV 2
# No features appended
# Label distribution of: 0.6563972771207478 0.23290563856073992 -0.9233948396561067
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90247802] from dataset of size (256, 2385)
# LassoCV score for 3 is [0.90240606] from dataset of size (256, 3385)
# LassoCV score for 4 is [0.90247636] from dataset of size (256, 4385)
# Lasso predicts 0.6247 for case with 0.46 and selected CV 2
# No features appended
# Label distribution of: 0.6484381136754113 0.23551856598199494 -0.8122168503525554
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.89827015] from dataset of size (256, 4385)
# LassoCV score for 3 is [0.89815636] from dataset of size (256, 385)
# LassoCV score for 4 is [0.89827015] from dataset of size (256, 6385)
# Lasso predicts 0.6685 for case with 0.69 and selected CV 2
# No features appended
# Label distribution of: 0.6510345795967961 0.2355872595275298 -0.8442366615141563
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.88864643] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.88857531] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.88829469] from dataset of size (256, 385)
# Lasso predicts 0.7312 for case with 0.62 and selected CV 2
# No features appended
# Label distribution of: 0.6514870129545852 0.235508457962084 -0.8506731109941843
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.89509902] from dataset of size (256, 6385)
# LassoCV score for 3 is [0.90466026] from dataset of size (256, 385)
# LassoCV score for 4 is [0.78186742] from dataset of size (256, 4385)
# Lasso predicts 0.6174 for case with 0.6 and selected CV 3
# No features appended
# Label distribution of: 0.6513833762483482 0.23552888987780995 -0.8491831307728512
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.89000773] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.88998422] from dataset of size (256, 385)
# LassoCV score for 4 is [0.89000773] from dataset of size (256, 4385)
# Lasso predicts 0.6399 for case with 0.61 and selected CV 2
# No features appended
# Label distribution of: 0.6514265168868296 0.2355205566995504 -0.8498022994263561
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90373126] from dataset of size (256, 2385)
# LassoCV score for 3 is [0.90359043] from dataset of size (256, 2385)
# LassoCV score for 4 is [0.90372968] from dataset of size (256, 4385)
# Lasso predicts 0.6366 for case with 0.61 and selected CV 2
# No features appended
# Label distribution of: 0.6566019554833209 0.23272679532807528 -0.9261496299585259
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90413196] from dataset of size (256, 385)
# LassoCV score for 3 is [0.90406764] from dataset of size (256, 385)
# LassoCV score for 4 is [0.90414625] from dataset of size (256, 6385)
# Lasso predicts 0.5078 for case with 0.45 and selected CV 4
# No features appended
# Label distribution of: 0.6510891349705002 0.23557918704721473 -0.8450030003554975
# Resampled to size (31,)
# Resampled to size (32,)
# LassoCV score for 2 is [0.90322619] from dataset of size (256, 5385)
# LassoCV score for 3 is [0.9031352] from dataset of size (256, 385)
# LassoCV score for 4 is [0.90322218] from dataset of size (256, 3385)
# Lasso predicts 0.666 for case with 0.62 and selected CV 2
# No features appended

# %%
# pre_imp = (np.asarray(pre_updrs_off,dtype=float)-np.asarray(pre_updrs_off,dtype=float))/np.asarray(pre_updrs_off,dtype=float)
results_ls[results_ls>1] = 1
util.eval_prediction(np.vstack((pre_imp,
                               results_ls,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')

# %%
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
plt.rcParams['figure.figsize'] = [20, 5]
fig,ax = plt.subplots(1,3,sharex=True,sharey=True)
#ax[0].scatter(pre_imp,per_change)
col = np.where(per_change <= 0.3,'orange','blue')
ax[0].scatter(pre_imp,per_change, c=col,linewidth=0)
lr = stats.linregress(pre_imp.T,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(0.50,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=16)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=16)
ax[0].set_ylabel('True improvement',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[1].scatter(results_ls,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls),per_change)
y_model = results_ls*lr.slope+lr.intercept
ax[1].plot(results_ls,y_model,color='r')
ax[1].text(0.50,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Wild Bootstrap Lasso',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[2].scatter(results_ls_aug,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[2].plot(results_ls_aug,y_model,color='r')
ax[2].text(1.75,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[2].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].set_title('Noise Compensated Lasso',fontsize=16)
plt.ylim([0,1.5])
plt.xlim([0,1.5])
plt.style.use('default')
