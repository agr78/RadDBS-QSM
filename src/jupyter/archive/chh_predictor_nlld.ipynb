# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
from sklearn.linear_model import QuantileRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RANSACRegressor
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
import warnings
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
from sklearn.exceptions import ConvergenceWarning
from sklearn import preprocessing as skp
from sklearn import model_selection as sms
from sklearn import feature_selection as skf
from sklearn import linear_model as slm
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util as util
import nibabel as nib
import os
import pickle
from torch import nn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (15,5)
def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0]//2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()
    

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index-1) % volume.shape[0] 
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index+1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2
visualize = 1
# Load data
nrows = 256
ncols = 256
nslices = 160
segs = []
qsms = []
laros = []
voxel_sizes = []
trackers = []
q_directory = '/home/ali/RadDBS-QSM/data/nii/chh/orig/qsm/'
q_directory = os.listdir(q_directory)
q_directory = sorted(q_directory)
qu_directory = '/home/ali/RadDBS-QSM/data/nii/chh/lr_roi_ft'
qu_directory = os.listdir(qu_directory)
qu_directory = sorted(qu_directory)
s_directory = '/home/ali/RadDBS-QSM/data/nii/chh/orig/seg/'
s_directory = os.listdir(s_directory)
s_directory = sorted(s_directory)
m_directory = '/home/ali/RadDBS-QSM/data/nii/chh/masks'
m_directory = os.listdir(m_directory)
m_directory = sorted(m_directory)
case_list = []
d_count = 0
if visualize == 1:
    for filename in q_directory:
    
        seg_filename = s_directory[d_count]
        laro_filename = qu_directory[d_count]
        mask_filename = m_directory[d_count]
        seg = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/orig/seg/'+seg_filename)
        mask = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/masks/'+mask_filename)
        voxel_size = seg.header['pixdim'][0:3]
        voxel_sizes.append(voxel_size)
        segs.append(seg.get_fdata()[:nrows,:ncols,:nslices])
        qsm = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/orig/qsm/'+filename)
        qsms.append(qsm.get_fdata()[:nrows,:ncols,:nslices])

        laro = nib.load('/home/ali/RadDBS-QSM/data/nii/chh/lr_roi_ft/'+laro_filename)
        laros.append(1000*laro.get_fdata()[:nrows,:ncols,:nslices])
        print('Appending arrays with segmentation',seg_filename,'QSM,',filename,
              'LARO,',laro_filename,'and mask',mask_filename)
        case_list.append(filename)
        n_cases = len(segs)
        d_count = d_count+1
# Out:
# Appending arrays with segmentation 01_roi_combined.nii QSM, 00001_qsm.nii.gz LARO, QSM_lrr_01.nii and mask mask01.nii
# Appending arrays with segmentation 02_roi_combined.nii QSM, 00002_qsm.nii.gz LARO, QSM_lrr_02.nii and mask mask02.nii
# Appending arrays with segmentation 03_roi_combined.nii QSM, 00003_qsm.nii.gz LARO, QSM_lrr_03.nii and mask mask03.nii
# Appending arrays with segmentation 04_roi_combined.nii QSM, 00004_qsm.nii.gz LARO, QSM_lrr_04.nii and mask mask04.nii
# Appending arrays with segmentation 05_roi_combined.nii QSM, 00005_qsm.nii.gz LARO, QSM_lrr_05.nii and mask mask05.nii
# Appending arrays with segmentation 06_roi_combined.nii QSM, 00006_qsm.nii.gz LARO, QSM_lrr_06.nii and mask mask06.nii
# Appending arrays with segmentation 07_roi_combined.nii QSM, 00007_qsm.nii.gz LARO, QSM_lrr_07.nii and mask mask07.nii
# Appending arrays with segmentation 08_roi_combined.nii QSM, 00008_qsm.nii.gz LARO, QSM_lrr_08.nii and mask mask08.nii
# Appending arrays with segmentation 09_roi_combined.nii QSM, 00009_qsm.nii.gz LARO, QSM_lrr_09.nii and mask mask09.nii
# Appending arrays with segmentation 10_roi_combined.nii QSM, 00010_qsm.nii.gz LARO, QSM_lrr_10.nii and mask mask10.nii
# Appending arrays with segmentation 11_roi_combined.nii QSM, 00011_qsm.nii.gz LARO, QSM_lrr_11.nii and mask mask11.nii
# Appending arrays with segmentation 13_roi_combined.nii QSM, 00013_qsm.nii.gz LARO, QSM_lrr_13.nii and mask mask13.nii
# Appending arrays with segmentation 14_roi_combined.nii QSM, 00014_qsm.nii.gz LARO, QSM_lrr_14.nii and mask mask14.nii
# Appending arrays with segmentation 16_roi_combined.nii QSM, 00016_qsm.nii.gz LARO, QSM_lrr_16.nii and mask mask16.nii
# Appending arrays with segmentation 18_roi_combined.nii QSM, 00018_qsm.nii.gz LARO, QSM_lrr_18.nii and mask mask18.nii
# Appending arrays with segmentation 19_roi_combined.nii QSM, 00019_qsm.nii.gz LARO, QSM_lrr_19.nii and mask mask19.nii
# Appending arrays with segmentation 20_roi_combined.nii QSM, 00020_qsm.nii.gz LARO, QSM_lrr_20.nii and mask mask20.nii
# Appending arrays with segmentation 21_roi_combined.nii QSM, 00021_qsm.nii.gz LARO, QSM_lrr_21.nii and mask mask21.nii
# Appending arrays with segmentation 22_roi_combined.nii QSM, 00022_qsm.nii.gz LARO, QSM_lrr_22.nii and mask mask22.nii
# Appending arrays with segmentation 23_roi_combined.nii QSM, 00023_qsm.nii.gz LARO, QSM_lrr_23.nii and mask mask23.nii
# Appending arrays with segmentation 24_roi_combined.nii QSM, 00024_qsm.nii.gz LARO, QSM_lrr_24.nii and mask mask24.nii
# Appending arrays with segmentation 25_roi_combined.nii QSM, 00025_qsm.nii.gz LARO, QSM_lrr_25.nii and mask mask25.nii
# Appending arrays with segmentation 26_roi_combined.nii QSM, 00026_qsm.nii.gz LARO, QSM_lrr_26.nii and mask mask26.nii
# Appending arrays with segmentation 27_roi_combined.nii QSM, 00027_qsm.nii.gz LARO, QSM_lrr_27.nii and mask mask27.nii
# Appending arrays with segmentation 28_roi_combined.nii QSM, 00028_qsm.nii.gz LARO, QSM_lrr_28.nii and mask mask28.nii
# Appending arrays with segmentation 29_roi_combined.nii QSM, 00029_qsm.nii.gz LARO, QSM_lrr_29.nii and mask mask29.nii
# Appending arrays with segmentation 30_roi_combined.nii QSM, 00030_qsm.nii.gz LARO, QSM_lrr_30.nii and mask mask30.nii
# Appending arrays with segmentation 31_roi_combined.nii QSM, 00031_qsm.nii.gz LARO, QSM_lrr_31.nii and mask mask31.nii
# Appending arrays with segmentation 32_roi_combined.nii QSM, 00032_qsm.nii.gz LARO, QSM_lrr_32.nii and mask mask32.nii
# Appending arrays with segmentation 33_roi_combined.nii QSM, 00033_qsm.nii.gz LARO, QSM_lrr_33.nii and mask mask33.nii
# Appending arrays with segmentation 34_roi_combined.nii QSM, 00034_qsm.nii.gz LARO, QSM_lrr_34.nii and mask mask34.nii
# Appending arrays with segmentation 35_roi_combined.nii QSM, 00035_qsm.nii.gz LARO, QSM_lrr_35.nii and mask mask35.nii
# Appending arrays with segmentation 36_roi_combined.nii QSM, 00036_qsm.nii.gz LARO, QSM_lrr_36.nii and mask mask36.nii
# Appending arrays with segmentation 37_roi_combined.nii QSM, 00037_qsm.nii.gz LARO, QSM_lrr_37.nii and mask mask37.nii
# Appending arrays with segmentation 38_roi_combined.nii QSM, 00038_qsm.nii.gz LARO, QSM_lrr_38.nii and mask mask38.nii
# Appending arrays with segmentation 39_roi_combined.nii QSM, 00039_qsm.nii.gz LARO, QSM_lrr_39.nii and mask mask39.nii
# Appending arrays with segmentation 40_roi_combined.nii QSM, 00040_qsm.nii.gz LARO, QSM_lrr_40.nii and mask mask40.nii

# %%
df = pd.read_csv('/home/ali/RadDBS-QSM/data/xlxs/updrs_iii_chh.csv')
df
# Out:
#     subjects    LCT   Unnamed: 2                     UPDRSⅢ  \
# 0        NaN     NaN         NaN  Preoperative Off-Medicine
# 1        1.0  62.26%         NaN                         53
# 2        2.0  75.00%         NaN                         32
# 3        3.0  51.72%         NaN                         58
# 4        4.0  22.58%         NaN                         62
# 5        5.0  55.88%         NaN                         34
# 6        6.0  75.44%         NaN                         57
# 7        7.0  84.00%         NaN                        100
# 8        8.0  41.86%         NaN                         43
# 9        9.0  72.58%         NaN                         62
# 10      10.0  81.25%         NaN                         64
# 11      11.0  70.21%         NaN                         94
# 12      12.0  63.95%         NaN                         86
# 13      13.0  89.55%         NaN                         67
# 14      14.0  88.46%         NaN                         26
# 15      15.0  62.50%         NaN                         72
# 16      16.0  48.00%         NaN                         25
# 17      17.0  14.29%         NaN                         98
# 18      18.0  36.62%         NaN                         71
# 19      19.0  54.90%         NaN                         51
# 20      20.0  81.63%         NaN                         49
# 21      21.0  71.43%         NaN                         49
# 22      22.0  90.32%         NaN                         31
# 23      23.0  65.85%         NaN                         41
# 24      24.0  74.29%         NaN                         35
# 25      25.0  83.61%         NaN                         61
# 26      26.0  58.97%         NaN                         78
# 27      27.0   5.88%         NaN                         51
# 28      28.0  76.67%         NaN                         60
# 29      29.0  81.01%         NaN                         79
# 30      30.0  62.35%         NaN                         85
# 31      31.0  27.91%         NaN                         43
# 32      32.0  31.48%         NaN                         54
# 33      33.0  80.33%         NaN                         61
# 34      34.0  40.74%         NaN                         54
# 35      35.0  16.13%         NaN                         93
# 36      36.0  59.26%         NaN                         54
# 37      37.0  61.40%         NaN                         57
# 38      38.0  95.92%         NaN                         49
# 39      39.0  79.35%         NaN                         92
# 40      40.0  50.00%         NaN                         54
#
#                   Unnamed: 4                                       Unnamed: 5  \
# 0   Preoperative On-Medicine  Postoperative  Off-Medicine &Off-Stimulation\n
# 1                         20                                               40
# 2                          8                                               26
# 3                         28                                               52
# 4                         48                                               61
# 5                         15                                               44
# 6                         14                                               55
# 7                         16                                               68
# 8                         25                                               48
# 9                         17                                               56
# 10                        12                                               33
# 11                        28                                               31
# 12                        31                                               28
# 13                         7                                               64
# 14                         3                                               31
# 15                        27                                               72
# 16                        13                                               17
# 17                        84                                               86
# 18                        45                                               49
# 19                        23                                               37
# 20                         9                                               20
# 21                        14                                               42
# 22                         3                                               46
# 23                        14                                               43
# 24                         9                                               21
# 25                        10                                               60
# 26                        32                                               64
# 27                        48                                               45
# 28                        14                                               68
# 29                        15                                               79
# 30                        32                                               92
# 31                        31                                               31
# 32                        37                                               64
# 33                        12                                               53
# 34                        32                                               64
# 35                        78                                               69
# 36                        22                                               57
# 37                        22                                               56
# 38                         2                                               58
# 39                        19                                              NaN
# 40                        27                                               34
#
#                                      Unnamed: 6  \
# 0   Postoperative  Off-Medicine &On-Stimulation
# 1                                            15
# 2                                            17
# 3                                            18
# 4                                            36
# 5                                            29
# 6                                            32
# 7                                            12
# 8                                            26
# 9                                            25
# 10                                           12
# 11                                           34
# 12                                           27
# 13                                           19
# 14                                           18
# 15                                           44
# 16                                            8
# 17                                           43
# 18                                           47
# 19                                           21
# 20                                            3
# 21                                            8
# 22                                           28
# 23                                           24
# 24                                           15
# 25                                           21
# 26                                           29
# 27                                           27
# 28                                           43
# 29                                           32
# 30                                           40
# 31                                            6
# 32                                           28
# 33                                           21
# 34                                           36
# 35                                           47
# 36                                           12
# 37                                           11
# 38                                           14
# 39                                           63
# 40                                            9
#
#                                     Unnamed: 7  Unnamed: 8
# 0   Postoperative  On-Medicine &On-Stimulation         NaN
# 1                                            7         NaN
# 2                                           10         NaN
# 3                                           20         NaN
# 4                                           28         NaN
# 5                                           22         NaN
# 6                                           16         NaN
# 7                                          NaN         NaN
# 8                                           26         NaN
# 9                                           11         NaN
# 10                                         NaN         NaN
# 11                                          43         NaN
# 12                                          18         NaN
# 13                                         NaN         NaN
# 14                                          17         NaN
# 15                                          38         NaN
# 16                                           8         NaN
# 17                                          34         NaN
# 18                                          46         NaN
# 19                                          18         NaN
# 20                                         NaN         NaN
# 21                                         NaN         NaN
# 22                                         NaN         NaN
# 23                                          24         NaN
# 24                                         NaN         NaN
# 25                                          17         NaN
# 26                                          21         NaN
# 27                                          20         NaN
# 28                                         NaN         NaN
# 29                                          28         NaN
# 30                                         NaN         NaN
# 31                                         NaN         NaN
# 32                                          25         NaN
# 33                                          15         NaN
# 34                                          29         NaN
# 35                                          44         NaN
# 36                                         NaN         NaN
# 37                                         NaN         NaN
# 38                                          12         NaN
# 39                                         NaN         NaN
# 40                                           8         NaN

# %%
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]

# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][:2])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
for i in np.arange(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 01_roi_combined.nii for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 02_roi_combined.nii for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 03_roi_combined.nii for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 04_roi_combined.nii for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 05_roi_combined.nii for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 06_roi_combined.nii for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 07_roi_combined.nii for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 08_roi_combined.nii for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 09_roi_combined.nii for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 10_roi_combined.nii for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 11_roi_combined.nii for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 13_roi_combined.nii for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 14_roi_combined.nii for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 16_roi_combined.nii for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 18_roi_combined.nii for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 19_roi_combined.nii for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 20_roi_combined.nii for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 21_roi_combined.nii for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 22_roi_combined.nii for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 23_roi_combined.nii for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 24_roi_combined.nii for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 25_roi_combined.nii for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 26_roi_combined.nii for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 27_roi_combined.nii for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 28_roi_combined.nii for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 29_roi_combined.nii for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 30_roi_combined.nii for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 31_roi_combined.nii for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 32_roi_combined.nii for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 33_roi_combined.nii for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 34_roi_combined.nii for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 35_roi_combined.nii for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 36_roi_combined.nii for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 37_roi_combined.nii for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 38_roi_combined.nii for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 39_roi_combined.nii for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 40_roi_combined.nii for case 40.0

# %%
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])                                
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])
post_updrs_iii_off =  np.asarray(df[df.columns[6]][np.hstack((False,np.in1d(subject_id,subject_id_corr)))])

per_change = (np.asarray(pre_updrs_iii_off).astype(float)-np.asarray(post_updrs_iii_off).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))
lct_change = (np.asarray(pre_updrs_iii_off).astype(float)-(np.asarray(pre_updrs_iii_on)).astype(float))/(np.asarray(pre_updrs_iii_off).astype(float))

# %%
logger = logging.getLogger("radiomics")
logger.setLevel(logging.ERROR)

reextract = 0

# Assume all voxel sizes are identical
voxel_size = (0.9,0.9,0.9)
if reextract == 1:
    # Generate feature structure Phi from all ROIs and all cases
    extractor = featureextractor.RadiomicsFeatureExtractor()
    extractor.enableAllFeatures()
    extractor.enableAllImageTypes()
    extractor.enableFeatureClassByName('shape2D',enabled = False)

    seg_labels_all = np.unique(np.asarray(segs))
    Phi_gt = []
    Phi_vd = []
    Phi_lr = []
    seg_labels = []
    reextract = 0
    x_row_gt = []
    x_row_lr = []

    keylib = []
    roilib = []
    loop_count = 1
    n_rois = seg_labels_all[seg_labels_all>0].__len__()
    roi_names = np.asarray(['Background','Right substantia nigra','Right subthalamic nucleus',
                            'Left subthalamic nucleus', 'Left substantia nigra', 'Right dentate nucleus', 'Left dentate nucleus'])
    for i in np.arange(subject_id_corr.__len__()):
        seg_sitk = sitk.GetImageFromArray(segs[i])
        seg_sitk.SetSpacing(voxel_size)
        qsm_sitk_gt = sitk.GetImageFromArray(qsms[i])
        qsm_sitk_gt.SetSpacing(voxel_size)
        qsm_sitk_lr = sitk.GetImageFromArray(laros[i])
        qsm_sitk_lr.SetSpacing(voxel_size)
        # Index back since subject 12 is missing ROIs
        for j in seg_labels_all:
            if j>0:
                fv_count = 0
                featureVector_gt = extractor.execute(qsm_sitk_gt,seg_sitk,label=int(j));
                featureVector_lr = extractor.execute(qsm_sitk_lr,seg_sitk,label=int(j));
                Phi_gt.append(featureVector_gt)
                Phi_lr.append(featureVector_lr)
                for key, value in six.iteritems(featureVector_gt):
                    if 'diagnostic' in key:
                        next
                    else:
                        x_row_gt.append(featureVector_gt[key])
                        x_row_lr.append(featureVector_lr[key])
                        fv_count = fv_count+1
                        keylib.append(key)
                        roilib.append(roi_names[int(j)])
                x_row_gt.append(pre_updrs_iii_off[i])
                x_row_lr.append(pre_updrs_iii_off[i])
                fv_count = fv_count+1
        print('Extracting features for subject',subject_id_corr[i],'and appending feature matrix with vector of length',fv_count,'with UPDRS score',pre_updrs_iii_off[i])
                
    X0_gt = np.array(x_row_gt)
    X0_lr = np.array(x_row_lr)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/X0_gt_chh_rois_rp.npy',X0_gt)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/X0_lr_chh_rois_rp.npy',X0_lr)

    K = np.asarray(keylib)
    R = np.asarray(roi_names)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/K_chh_rp.npy',K)
    np.save('/home/ali/RadDBS-QSM/data/npy/rp/R_chh_rp.npy',R)

    print('Saving ground truth feature vector')
    with open('/home/ali/RadDBS-QSM/data/npy/rp/Phi_mcl_gt_roi_chh_rp', 'wb') as fp:  
        pickle.dump(Phi_gt, fp)
    
    print('Saving undersampled feature vector')
    with open('/home/ali/RadDBS-QSM/data/npy/rp/Phi_mcl_lr_roi_chh_rp', 'wb') as fp:  
        pickle.dump(Phi_lr, fp)

else:
    X0_gt = np.load('/home/ali/RadDBS-QSM/data/npy/rp/X0_gt_chh_rois_rp.npy')
    X0_lr = np.load('/home/ali/RadDBS-QSM/data/npy/rp/X0_lr_chh_rois_rp.npy')
    K = np.load('/home/ali/RadDBS-QSM/data/npy/rp/K_chh_rp.npy')
    R = np.load('/home/ali/RadDBS-QSM/data/npy/rp/R_chh_rp.npy')
    n_rois = R.shape[0]-1
    with open('/home/ali/RadDBS-QSM/data/npy/rp/Phi_mcl_gt_roi_chh_rp', "rb") as fp:  
        Phi_gt = pickle.load(fp)
    
    with open('/home/ali/RadDBS-QSM/data/npy/rp/Phi_mcl_lr_roi_chh_rp', "rb") as fp:  
        Phi_lr = pickle.load(fp)

# %%
X0_gt0 = np.load('/home/ali/RadDBS-QSM/data/npy/old/X0_gt_chh_rois.npy')
np.mean((X0_gt.astype(float)-X0_gt0.astype(float))**2)
# Out:
# 2.1903674007309297e-31

# %%
n_features = 1596
n_rois = 6
X_all_c = X0_gt.reshape(n_cases,n_rois,n_features)[:,0:4,:]
K_all_c = K.reshape(n_cases,n_rois,n_features-1)[:,0:4,:]

# %%
n_cases = len(per_change)
n_roisc = Phi_gt.__len__()/n_cases
L = int(len(X0_gt)/n_cases)
n_features = int(L/n_rois)
subsc = subject_id_corr
pre_updrs_off = pre_updrs_iii_off
results_ls_aug = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
r = 1

# %%
Kg = np.asarray([('gradient' or 'wavelet' or 'lbp' or 'glcm' or 'exponential') in feature for feature in K]).reshape((n_cases,n_rois,n_features-1))
gmask = np.append(Kg[0,0,:],[1],axis=-1)

# %%
Js = []
aug = True
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs_off,None,None,None,None,None,None,None,None,None,False,False,False)
    # 10
    cvn = 5
    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    (mu, sigma) = stats.norm.fit(y_train)
    kappa = stats.skew(y_train)
    print('Label distribution of:',mu,sigma,kappa)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
      if aug == True:
        y_train_n = y_train+(sigma/mu)*np.random.normal(0,4*sigma,1)
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
      
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)

      # Break any ties
      if np.sum(cv_scores == best_cv) > 1:
        cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
        for jjj in (cv_scores == cv_scores(best_cv)):
          if jjj > 0:
            skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
            skf_gen = skf_g.split(X0_ss0,y_cat) 
            X0_sst = sel.fit_transform(X0_ss0,y_train)
            X0_ss = X0_sst
            lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
            est_ls = lasso.fit(X0_ss,y_train)
            cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
        best_cv = np.argmax(cv_scores_tb)
      
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
    results_ls_aug[c] = est_ls.predict(X_test_ss)
    print('Lasso predicts',str(np.round(results_ls_aug[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
  
    c=c+1
# Out:
# Label distribution of: 0.5669595264848581 0.20858808082526412 -0.24474920851943865
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976546] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.81999127] from dataset of size (152, 2385)
# LassoCV score for 4 is [0.63884729] from dataset of size (304, 1385)
# Lasso predicts 0.653 for case with 0.72 and selected CV 2
# Label distribution of: 0.5738548357091768 0.20932917254901903 -0.3279210191356042
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977049] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.82950529] from dataset of size (152, 385)
# LassoCV score for 4 is [0.64383699] from dataset of size (304, 6385)
# Lasso predicts 0.4546 for case with 0.47 and selected CV 2
# Label distribution of: 0.5677185809199048 0.20908232478622193 -0.24926099868801613
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976492] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.82551726] from dataset of size (152, 1385)
# LassoCV score for 4 is [0.63831268] from dataset of size (304, 1385)
# Lasso predicts 0.7937 for case with 0.69 and selected CV 2
# Label distribution of: 0.5752269235227969 0.2084721065940771 -0.34398027688109245
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977409] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.83068069] from dataset of size (152, 2385)
# LassoCV score for 4 is [0.64745461] from dataset of size (304, 385)
# Lasso predicts 0.6348 for case with 0.42 and selected CV 2
# Label distribution of: 0.5827907017222488 0.19744836811095323 -0.25025976222641483
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# LassoCV score for 2 is [0.98784908] from dataset of size (78, 6385)
# LassoCV score for 3 is [0.70712602] from dataset of size (156, 385)
# LassoCV score for 4 is [0.70329727] from dataset of size (312, 1385)
# Lasso predicts 0.2719 for case with 0.15 and selected CV 2
# Label distribution of: 0.5746924331750638 0.20884605172212908 -0.33822865445502964
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977259] from dataset of size (76, 3385)
# LassoCV score for 3 is [0.83020684] from dataset of size (152, 385)
# LassoCV score for 4 is [0.64594054] from dataset of size (304, 5385)
# Lasso predicts 0.4316 for case with 0.44 and selected CV 2
# Label distribution of: 0.5624312245980657 0.20344924934212058 -0.28703446866429055
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977457] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.83021579] from dataset of size (152, 2385)
# LassoCV score for 4 is [0.64794143] from dataset of size (304, 1385)
# Lasso predicts 0.7195 for case with 0.88 and selected CV 2
# Label distribution of: 0.5758937568978073 0.20793336707043802 -0.35000008336051325
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977614] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.83216845] from dataset of size (152, 385)
# LassoCV score for 4 is [0.6495328] from dataset of size (304, 4385)
# Lasso predicts 0.3804 for case with 0.4 and selected CV 2
# Label distribution of: 0.5702986081106105 0.20999601422390549 -0.27751686488556404
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976513] from dataset of size (76, 385)
# LassoCV score for 3 is [0.82537199] from dataset of size (152, 385)
# LassoCV score for 4 is [0.63851738] from dataset of size (304, 3385)
# Lasso predicts 0.5368 for case with 0.6 and selected CV 2
# Label distribution of: 0.5643062245980658 0.2060398064467874 -0.25159784666703033
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976957] from dataset of size (76, 2385)
# LassoCV score for 3 is [0.82927291] from dataset of size (152, 5385)
# LassoCV score for 4 is [0.64291392] from dataset of size (304, 1385)
# Lasso predicts 0.4603 for case with 0.81 and selected CV 2
# Label distribution of: 0.5691451725886095 0.20973322323580731 -0.2629533781637346
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976464] from dataset of size (76, 3385)
# LassoCV score for 3 is [0.82590462] from dataset of size (152, 385)
# LassoCV score for 4 is [0.63804304] from dataset of size (304, 1385)
# Lasso predicts 0.7562 for case with 0.64 and selected CV 2
# Label distribution of: 0.5669751715300725 0.2085993111100245 -0.24481874200363993
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976545] from dataset of size (76, 4385)
# LassoCV score for 3 is [0.82506347] from dataset of size (152, 5385)
# LassoCV score for 4 is [0.6388335] from dataset of size (304, 2385)
# Lasso predicts 0.5563 for case with 0.72 and selected CV 2
# Label distribution of: 0.5783286604955017 0.20527469945818264 -0.35630765675696446
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99978526] from dataset of size (76, 2385)
# LassoCV score for 3 is [0.83605069] from dataset of size (152, 4385)
# LassoCV score for 4 is [0.65894324] from dataset of size (304, 385)
# Lasso predicts 0.5877 for case with 0.31 and selected CV 2
# Label distribution of: 0.5679867801536214 0.20923231991769523 -0.25136542100761594
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976431] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.82961034] from dataset of size (152, 6385)
# LassoCV score for 4 is [0.63818909] from dataset of size (304, 2385)
# Lasso predicts 0.4709 for case with 0.68 and selected CV 2
# Label distribution of: 0.5774859976810078 0.2063190239320207 -0.3574795129443696
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99978181] from dataset of size (76, 5385)
# LassoCV score for 3 is [0.83652507] from dataset of size (152, 385)
# LassoCV score for 4 is [0.65535799] from dataset of size (304, 1385)
# Lasso predicts 0.3432 for case with 0.34 and selected CV 2
# Label distribution of: 0.5705357997614644 0.21002096073970725 -0.2807677568009367
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.9997653] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.826799] from dataset of size (152, 4385)
# LassoCV score for 4 is [0.63869106] from dataset of size (304, 385)
# Lasso predicts 0.4113 for case with 0.59 and selected CV 2
# Label distribution of: 0.5607985715368413 0.2006390097129064 -0.34802680409786524
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99978038] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.83373353] from dataset of size (152, 385)
# LassoCV score for 4 is [0.65386964] from dataset of size (304, 1385)
# Lasso predicts 0.626 for case with 0.94 and selected CV 2
# Label distribution of: 0.5636330386570226 0.20518643494540414 -0.26076044933979126
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977116] from dataset of size (76, 4385)
# LassoCV score for 3 is [0.83113163] from dataset of size (152, 1385)
# LassoCV score for 4 is [0.6445071] from dataset of size (304, 1385)
# Lasso predicts 0.6454 for case with 0.84 and selected CV 2
# Label distribution of: 0.5841874969994993 0.19415564179220104 -0.16306203646880674
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# LassoCV score for 2 is [0.98778336] from dataset of size (78, 4385)
# LassoCV score for 3 is [0.71837472] from dataset of size (156, 6385)
# LassoCV score for 4 is [0.70352872] from dataset of size (312, 6385)
# Lasso predicts 0.1574 for case with 0.1 and selected CV 2
# Label distribution of: 0.5753580538663584 0.20837251231034953 -0.34527291849868297
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976845] from dataset of size (76, 5385)
# LassoCV score for 3 is [0.83210047] from dataset of size (152, 385)
# LassoCV score for 4 is [0.64784663] from dataset of size (304, 1385)
# Lasso predicts 0.413 for case with 0.41 and selected CV 2
# Label distribution of: 0.5710026531694943 0.21004110516915736 -0.28733840263675836
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976573] from dataset of size (76, 385)
# LassoCV score for 3 is [0.82757704] from dataset of size (152, 5385)
# LassoCV score for 4 is [0.63910856] from dataset of size (304, 2385)
# Lasso predicts 0.5999 for case with 0.57 and selected CV 2
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99975408] from dataset of size (76, 3385)
# LassoCV score for 3 is [0.82444296] from dataset of size (152, 5385)
# LassoCV score for 4 is [0.63625405] from dataset of size (304, 385)
# Lasso predicts 0.7058 for case with 0.66 and selected CV 2
# Label distribution of: 0.5694255265923677 0.20981871046638942 -0.2662656536773807
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.9997647] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.82393503] from dataset of size (152, 2385)
# LassoCV score for 4 is [0.63810169] from dataset of size (304, 5385)
# Lasso predicts 0.5637 for case with 0.63 and selected CV 2
# Label distribution of: 0.5738037736176735 0.20935457901382964 -0.3272511581002607
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977038] from dataset of size (76, 6385)
# LassoCV score for 3 is [0.82755323] from dataset of size (152, 3385)
# LassoCV score for 4 is [0.64371924] from dataset of size (304, 1385)
# Lasso predicts 0.5568 for case with 0.47 and selected CV 2
# Label distribution of: 0.5790052986721398 0.2043392189714069 -0.3521164038418525
# Resampled to size (37,)
# Resampled to size (38,)
# Resampled to size (39,)
# LassoCV score for 2 is [0.98683926] from dataset of size (78, 1385)
# LassoCV score for 3 is [0.68912089] from dataset of size (156, 1385)
# LassoCV score for 4 is [0.68340153] from dataset of size (312, 385)
# Lasso predicts 0.2632 for case with 0.28 and selected CV 2
# Label distribution of: 0.5703496493519336 0.21000221972805436 -0.27821061318927803
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976516] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.82623658] from dataset of size (152, 385)
# LassoCV score for 4 is [0.63855257] from dataset of size (304, 1385)
# Lasso predicts 0.6375 for case with 0.59 and selected CV 2
# Label distribution of: 0.572169786689569 0.20992345901172824 -0.3042853268818935
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976723] from dataset of size (76, 2385)
# LassoCV score for 3 is [0.82255425] from dataset of size (152, 5385)
# LassoCV score for 4 is [0.6403016] from dataset of size (304, 385)
# Lasso predicts 0.6007 for case with 0.53 and selected CV 2
# Label distribution of: 0.5629738602569804 0.2042678402570905 -0.27346537727473835
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976973] from dataset of size (76, 3385)
# LassoCV score for 3 is [0.83066309] from dataset of size (152, 2385)
# LassoCV score for 4 is [0.64629574] from dataset of size (304, 385)
# Lasso predicts 0.6204 for case with 0.86 and selected CV 2
# Label distribution of: 0.5735011834458024 0.20949562291124812 -0.3232022231648087
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.9997697] from dataset of size (76, 5385)
# LassoCV score for 3 is [0.82813547] from dataset of size (152, 6385)
# LassoCV score for 4 is [0.64304684] from dataset of size (304, 385)
# Lasso predicts 0.417 for case with 0.48 and selected CV 2
# Label distribution of: 0.568660732794787 0.20955271665824066 -0.2576598769765803
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976463] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.82112504] from dataset of size (152, 3385)
# LassoCV score for 4 is [0.63802102] from dataset of size (304, 385)
# Lasso predicts 0.6097 for case with 0.66 and selected CV 2
# Label distribution of: 0.5776164097832509 0.206166083456723 -0.3575627941827524
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99978233] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.83733049] from dataset of size (152, 1385)
# LassoCV score for 4 is [0.65586056] from dataset of size (304, 385)
# Lasso predicts 0.5012 for case with 0.33 and selected CV 2
# Label distribution of: 0.5731361230448997 0.20964415222225632 -0.31816132090731236
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976894] from dataset of size (76, 2385)
# LassoCV score for 3 is [0.83100401] from dataset of size (152, 6385)
# LassoCV score for 4 is [0.64229197] from dataset of size (304, 2385)
# Lasso predicts 0.4368 for case with 0.49 and selected CV 2
# Label distribution of: 0.5652707307709053 0.20711530756483246 -0.2442832622694056
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.97661295] from dataset of size (76, 2385)
# LassoCV score for 3 is [0.827099] from dataset of size (152, 4385)
# LassoCV score for 4 is [0.64093962] from dataset of size (304, 2385)
# Lasso predicts 0.7196 for case with 0.78 and selected CV 2
# Label distribution of: 0.5644585150464088 0.20622109204736833 -0.2500116622013785
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976924] from dataset of size (76, 5385)
# LassoCV score for 3 is [0.82643073] from dataset of size (152, 2385)
# LassoCV score for 4 is [0.64258573] from dataset of size (304, 2385)
# Lasso predicts 0.5565 for case with 0.81 and selected CV 2
# Label distribution of: 0.5670343992012403 0.20864142707871972 -0.24509142715462312
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99976539] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.82856771] from dataset of size (152, 6385)
# LassoCV score for 4 is [0.6374775] from dataset of size (304, 385)
# Lasso predicts 0.6548 for case with 0.71 and selected CV 2
# Label distribution of: 0.5781196303951672 0.20554616966278674 -0.356990224910928
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99978438] from dataset of size (76, 4385)
# LassoCV score for 3 is [0.84169831] from dataset of size (152, 6385)
# LassoCV score for 4 is [0.65802092] from dataset of size (304, 3385)
# Lasso predicts 0.4164 for case with 0.32 and selected CV 2
# Label distribution of: 0.5637275208943621 0.2053113472299323 -0.2592529006209024
# Resampled to size (37,)
# Resampled to size (38,)
# LassoCV score for 2 is [0.99977093] from dataset of size (76, 1385)
# LassoCV score for 3 is [0.82883975] from dataset of size (152, 5385)
# LassoCV score for 4 is [0.64426936] from dataset of size (304, 5385)
# Lasso predicts 0.6923 for case with 0.83 and selected CV 2

# %%
results_ls_aug
# Out:
# array([0.65302438, 0.45462166, 0.79374439, 0.63484516, 0.27185643,
#        0.43156333, 0.71945184, 0.38038123, 0.53677549, 0.46032967,
#        0.75618492, 0.55625034, 0.58768754, 0.47092442, 0.34319201,
#        0.41132769, 0.62595218, 0.64537432, 0.1573904 , 0.4130357 ,
#        0.59994176, 0.70581068, 0.56374732, 0.55682312, 0.26324368,
#        0.63753498, 0.6007117 , 0.62041401, 0.41699648, 0.60971878,
#        0.50120079, 0.43682759, 0.71955733, 0.55647412, 0.65481671,
#        0.41636583, 0.69230797])

# %%
pre_imp = (np.asarray(pre_updrs_iii_off,dtype=float)-np.asarray(pre_updrs_iii_on,dtype=float))/np.asarray(pre_updrs_iii_off,dtype=float)
util.eval_prediction(np.vstack((pre_imp,
                               results_ls_aug,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')

# %%
Js = []
aug = False
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs_off,None,None,None,None,None,None,None,None,None,False,False,False)
    # 10
    cvn = 5
    cv_scores = np.zeros((cvn,1))
    rs = 1
    # Add Gaussian noise to labels
    (mu, sigma) = stats.norm.fit(per_change)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        
      if aug == True:
        y_train_n = y_train+(sigma/mu)*np.random.normal(0,4*sigma,1)
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
      
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=1000,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj])
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)

      # Break any ties
      if np.sum(cv_scores == best_cv) > 1:
        cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
        for jjj in (cv_scores == cv_scores[best_cv]):
          if jjj > 0:
            skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
            skf_gen = skf_g.split(X0_ss0,y_cat) 
            X0_sst = sel.fit_transform(X0_ss0,y_train)
            X0_ss = X0_sst
            lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
            est_ls = lasso.fit(X0_ss,y_train)
            cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
        best_cv = np.argmax(cv_scores_tb)
      
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=1000,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
    results_ls[c] = est_ls.predict(X_test_ss)
    print('Lasso predicts',str(np.round(results_ls[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
  
    c=c+1
# Out:
# LassoCV score for 2 is [0.99702873]
# LassoCV score for 3 is [0.99742976]
# LassoCV score for 4 is [0.99987129]
# Lasso predicts 0.6643 for case with 0.72 and selected CV 4
# LassoCV score for 2 is [0.8155521]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99999993]
# Lasso predicts 0.5023 for case with 0.47 and selected CV 3
# LassoCV score for 2 is [0.98168324]
# LassoCV score for 3 is [0.99938249]
# LassoCV score for 4 is [0.99938716]
# Lasso predicts 0.8044 for case with 0.69 and selected CV 4
# LassoCV score for 2 is [0.8718873]
# LassoCV score for 3 is [0.99624032]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.6353 for case with 0.42 and selected CV 4
# LassoCV score for 2 is [0.75219306]
# LassoCV score for 3 is [0.99999698]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.4336 for case with 0.15 and selected CV 4
# LassoCV score for 2 is [0.99388453]
# LassoCV score for 3 is [0.99999152]
# LassoCV score for 4 is [0.99919632]
# Lasso predicts 0.4732 for case with 0.44 and selected CV 3
# LassoCV score for 2 is [0.99352115]
# LassoCV score for 3 is [0.99312885]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.7559 for case with 0.88 and selected CV 4
# LassoCV score for 2 is [0.99999999]
# LassoCV score for 3 is [0.99956821]
# LassoCV score for 4 is [0.99876877]
# Lasso predicts 0.4107 for case with 0.4 and selected CV 2
# LassoCV score for 2 is [0.99990881]
# LassoCV score for 3 is [0.99880823]
# LassoCV score for 4 is [0.99719985]
# Lasso predicts 0.5932 for case with 0.6 and selected CV 2
# LassoCV score for 2 is [0.99999086]
# LassoCV score for 3 is [0.99901713]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.5086 for case with 0.81 and selected CV 4
# LassoCV score for 2 is [1.]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99999987]
# Lasso predicts 0.7578 for case with 0.64 and selected CV 2
# LassoCV score for 2 is [0.95703269]
# LassoCV score for 3 is [0.99872784]
# LassoCV score for 4 is [0.97820812]
# Lasso predicts 0.6867 for case with 0.72 and selected CV 3
# LassoCV score for 2 is [0.99938019]
# LassoCV score for 3 is [0.99177029]
# LassoCV score for 4 is [0.99462627]
# Lasso predicts 0.6285 for case with 0.31 and selected CV 2
# LassoCV score for 2 is [0.99986164]
# LassoCV score for 3 is [0.98142824]
# LassoCV score for 4 is [0.99984475]
# Lasso predicts 0.4832 for case with 0.68 and selected CV 2
# LassoCV score for 2 is [0.9357638]
# LassoCV score for 3 is [0.96130739]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.3796 for case with 0.34 and selected CV 4
# LassoCV score for 2 is [0.99072019]
# LassoCV score for 3 is [0.99970357]
# LassoCV score for 4 is [0.99034932]
# Lasso predicts 0.46 for case with 0.59 and selected CV 3
# LassoCV score for 2 is [1.]
# LassoCV score for 3 is [0.99999995]
# LassoCV score for 4 is [0.99882296]
# Lasso predicts 0.6534 for case with 0.94 and selected CV 2
# LassoCV score for 2 is [0.9923711]
# LassoCV score for 3 is [0.99943427]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.6824 for case with 0.84 and selected CV 4
# LassoCV score for 2 is [0.99982875]
# LassoCV score for 3 is [0.99999846]
# LassoCV score for 4 is [0.99999992]
# Lasso predicts 0.3429 for case with 0.1 and selected CV 4
# LassoCV score for 2 is [0.99709122]
# LassoCV score for 3 is [0.97571612]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.4571 for case with 0.41 and selected CV 4
# LassoCV score for 2 is [0.86121437]
# LassoCV score for 3 is [0.98569315]
# LassoCV score for 4 is [0.9995206]
# Lasso predicts 0.6457 for case with 0.57 and selected CV 4
# LassoCV score for 2 is [0.69308727]
# LassoCV score for 3 is [0.99999893]
# LassoCV score for 4 is [0.99973825]
# Lasso predicts 0.7104 for case with 0.66 and selected CV 3
# LassoCV score for 2 is [0.81638698]
# LassoCV score for 3 is [0.99987863]
# LassoCV score for 4 is [0.99999185]
# Lasso predicts 0.5938 for case with 0.63 and selected CV 4
# LassoCV score for 2 is [0.99899478]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.9999995]
# Lasso predicts 0.6249 for case with 0.47 and selected CV 3
# LassoCV score for 2 is [0.99999424]
# LassoCV score for 3 is [0.99500117]
# LassoCV score for 4 is [0.9880121]
# Lasso predicts 0.3487 for case with 0.28 and selected CV 2
# LassoCV score for 2 is [0.7576277]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99409327]
# Lasso predicts 0.6461 for case with 0.59 and selected CV 3
# LassoCV score for 2 is [0.74044058]
# LassoCV score for 3 is [0.9820095]
# LassoCV score for 4 is [0.99971626]
# Lasso predicts 0.6167 for case with 0.53 and selected CV 4
# LassoCV score for 2 is [0.6132676]
# LassoCV score for 3 is [0.97893266]
# LassoCV score for 4 is [1.]
# Lasso predicts 0.6405 for case with 0.86 and selected CV 4
# LassoCV score for 2 is [0.73632789]
# LassoCV score for 3 is [0.9862068]
# LassoCV score for 4 is [0.98834637]
# Lasso predicts 0.4637 for case with 0.48 and selected CV 4
# LassoCV score for 2 is [0.83897877]
# LassoCV score for 3 is [0.92915134]
# LassoCV score for 4 is [0.99890832]
# Lasso predicts 0.6364 for case with 0.66 and selected CV 4
# LassoCV score for 2 is [0.757927]
# LassoCV score for 3 is [0.97761523]
# LassoCV score for 4 is [0.99999563]
# Lasso predicts 0.5292 for case with 0.33 and selected CV 4
# LassoCV score for 2 is [0.58544153]
# LassoCV score for 3 is [0.99004234]
# LassoCV score for 4 is [0.99473586]
# Lasso predicts 0.4326 for case with 0.49 and selected CV 4
# LassoCV score for 2 is [0.79305998]
# LassoCV score for 3 is [0.99993647]
# LassoCV score for 4 is [0.99825756]
# Lasso predicts 0.748 for case with 0.78 and selected CV 3
# LassoCV score for 2 is [0.65948213]
# LassoCV score for 3 is [0.99702513]
# LassoCV score for 4 is [0.99989644]
# Lasso predicts 0.6155 for case with 0.81 and selected CV 4
# LassoCV score for 2 is [0.77032961]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99112193]
# Lasso predicts 0.7 for case with 0.71 and selected CV 3
# LassoCV score for 2 is [0.85451852]
# LassoCV score for 3 is [0.97289662]
# LassoCV score for 4 is [0.99996734]
# Lasso predicts 0.5041 for case with 0.32 and selected CV 4
# LassoCV score for 2 is [0.84581161]
# LassoCV score for 3 is [0.97128718]
# LassoCV score for 4 is [0.99997882]
# Lasso predicts 0.7221 for case with 0.83 and selected CV 4

# %%
pre_imp = (np.asarray(pre_updrs_iii_off,dtype=float)-np.asarray(pre_updrs_iii_on,dtype=float))/np.asarray(pre_updrs_iii_off,dtype=float)
util.eval_prediction(np.vstack((pre_imp,
                               results_ls,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')

# %%
pre_imp = np.repeat((np.asarray(pre_updrs_iii_off,dtype=float)-np.asarray(pre_updrs_iii_on,dtype=float))/np.asarray(pre_updrs_iii_off,dtype=float),r)
per_change = np.repeat(per_change,r)
plt.rcParams['figure.figsize'] = [20, 5]
fig,ax = plt.subplots(1,3,sharex=True,sharey=True)
#ax[0].scatter(pre_imp,per_change)
col = np.where(per_change <= 0.3,'orange','blue')
ax[0].scatter(pre_imp,per_change, c=col,linewidth=0)
lr = stats.linregress(pre_imp,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(0.6,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=16)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=16)
ax[0].set_ylabel('True improvement',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[1].scatter(results_ls,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls),per_change)
y_model = results_ls*lr.slope+lr.intercept
ax[1].plot(results_ls,y_model,color='r')
ax[1].text(0.55,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Lasso',fontsize=16)
ax[1].set_xlabel('Prediction',fontsize=16)
col = np.where(per_change <= 0.3,'orange','blue')
ax[2].scatter(results_ls_aug,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[2].plot(results_ls_aug,y_model,color='r')
ax[2].text(0.55,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[2].transAxes,fontsize=16) 
ax[2].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].set_title('Noise Compensated Lasso',fontsize=16)
plt.ylim([0,1.25])
plt.xlim([0,1.25])
plt.style.use('default')

# %%
np.save('results_ls_aug_d.npy',results_ls_aug)
