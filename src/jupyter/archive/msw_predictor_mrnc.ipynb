# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
from sklearn.linear_model import QuantileRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RANSACRegressor
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
import warnings
#from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
from sklearn.exceptions import ConvergenceWarning
from sklearn import preprocessing as skp
from sklearn import model_selection as sms
from sklearn import feature_selection as skf
from sklearn import linear_model as slm
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util as util
import nibabel as nib
import os
import pickle
from scipy.spatial import cKDTree
# Out:
# Skipping torch import

# %%
if not sys.warnoptions:
    warnings.simplefilter("ignore",category=ConvergenceWarning)
    os.environ["PYTHONWARNINGS"] = "ignore::UserWarning"

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (15,5)
def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0]//2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()
    

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index-1) % volume.shape[0] 
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index+1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

# %%
cv_names = {'CORNELL ID',
            ' OFF (pre-dbs updrs)',
            ' ON (pre-dbs updrs)',
            ' OFF meds ON stim 6mo',
            'Age',
            'Sex',
            'Ethnicity',
            'Race',
            'Disease Duration (year)',
            'Physician',
            ' pre op levadopa equivalent dose (mg)',
            ' Location',
            ' Target',
            ' Test medication status'}


# Load scores
file_dir = '/data/Ali/RadDBS-QSM/data/docs/dbs_03292024.csv'
motor_df = util.filter_data(file_dir,cv_names,True)
# Find cases with all required scores
cv_dict = util.filter_cases(motor_df,cv_names)
subs = cv_dict['CORNELL ID']
# Load extracted features
npy_dir = '/data/Ali/RadDBS-QSM/data/npy/new/'
phi_dir = '/data/Ali/RadDBS-QSM/data/phi/new/phi/'
roi_path = '/data/Ali/RadDBS-QSM/data/xlxs/new_segs.csv'
n_rois = 6
all_rois = False
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595,all_rois)
print(np.unique(R_all))
ids = np.asarray(ID_all).astype(int)

# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(ids).astype(int),np.asarray(cv_dict['CORNELL ID']))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
# Exclude GPi
c_cases_idx[ids == 36] = 0
# c_cases_idx[ids == 42] = 0
# c_cases_idx[ids == 52] = 0
c_cases_idx[ids == 53] = 0
# c_cases_idx[ids == 98] = 0
# c_cases_idx[ids == 108] = 0
print(np.sum(c_cases_idx))
subs[subs <= 90]
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
print(len(s_cases_idx))
        
X_all_c = X_all[c_cases_idx,2:6,:]
#X_all_c = (np.load('X2h_sr.npy').T).reshape((31,6381))
# print('Applying combat')
K_all_c = K_all[c_cases_idx,2:6,:]
R_all_c = R_all[c_cases_idx,2:6,:]
# Re-index the scored subjects with respect to complete cases

per_change = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' OFF meds ON stim 6mo'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_updrs = cv_dict[' OFF (pre-dbs updrs)'][s_cases_idx]
dd = cv_dict['Disease Duration (year)'][s_cases_idx]
ledd = cv_dict[' pre op levadopa equivalent dose (mg)'][s_cases_idx]
tmed = cv_dict[' Test medication status'][s_cases_idx]
phys = cv_dict['Physician'][s_cases_idx]
age = cv_dict['Age'][s_cases_idx]
loc = cv_dict[' Location'][s_cases_idx]
sex = cv_dict['Sex'][s_cases_idx]
rce = cv_dict['Race'][s_cases_idx]
eth = cv_dict['Ethnicity'][s_cases_idx]
tgt = cv_dict[' Target'][s_cases_idx]
subsc = subs[s_cases_idx]

# Reshape keys and ROIs
if all_rois == True:
    K_all_cu = np.empty((K_all_c.shape[0],K_all_c.shape[1],K_all_c.shape[2]+1),dtype=object)
    K_all_cu[:,:,:-1] = K_all_c
    K_all_cu[:,:,-1] = 'pre_updrs'
    K_all_cu[:,:,-1] = 'disease_duration'
    K_all_cu[:,:,-1] = 'pre op levadopa equivalent dose (mg)'
    K_all_cu[:,:,-1] = ' Test medication status'
    K_all_cu[:,:,-1] = 'Physician'
    K_all_cu[:,:,-1] = 'Age'
    K_all_cu[:,:,-1] = 'Location'
    K_all_cu[:,:,-1] = 'Sex'
    K_all_cu[:,:,-1] = 'Race'
    K_all_cu[:,:,-1] = 'Ethnicity'
    
    K = K_all_cu.reshape((K_all_cu.shape[0],K_all_cu.shape[1]*K_all_cu.shape[2]))[0]
    R = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))
else:
    K_all_c = K_all_c.reshape((K_all_c.shape[0],K_all_c.shape[1]*K_all_c.shape[2]))[0]
    R_all_c = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))

print(np.unique(R_all_c))
# Out:
# Keeping CORNELL ID
# Keeping Age
# Keeping Sex
# Keeping Ethnicity
# Keeping Race
# Keeping Disease Duration (year)
# Keeping Physician
# Keeping  OFF (pre-dbs updrs)
# Keeping  ON (pre-dbs updrs)
# Keeping  pre op levadopa equivalent dose (mg)
# Keeping  Location
# Keeping  Target
# Keeping  Test medication status
# Keeping  OFF meds ON stim 6mo
# {' ON (pre-dbs updrs)', 'Race', 'Disease Duration (year)', 'Sex', ' OFF (pre-dbs updrs)', ' pre op levadopa equivalent dose (mg)', ' Target', 'CORNELL ID', 'Ethnicity', ' Test medication status', ' Location', 'Physician', ' OFF meds ON stim 6mo', 'Age'}
# ['X_115_01.npy', 'X_115_02.npy', 'X_115_03.npy', 'X_115_04.npy', 'X_115_05.npy', 'X_115_06.npy', 'X_115_07.npy', 'X_115_08.npy', 'X_115_09.npy', 'X_115_10.npy', 'X_115_100.npy', 'X_115_101.npy', 'X_115_102.npy', 'X_115_104.npy', 'X_115_105.npy', 'X_115_106.npy', 'X_115_107.npy', 'X_115_108.npy', 'X_115_109.npy', 'X_115_11.npy', 'X_115_110.npy', 'X_115_111.npy', 'X_115_112.npy', 'X_115_113.npy', 'X_115_114.npy', 'X_115_115.npy', 'X_115_116.npy', 'X_115_12.npy', 'X_115_13.npy', 'X_115_14.npy', 'X_115_15.npy', 'X_115_16.npy', 'X_115_17.npy', 'X_115_18.npy', 'X_115_19.npy', 'X_115_20.npy', 'X_115_22.npy', 'X_115_23.npy', 'X_115_24.npy', 'X_115_25.npy', 'X_115_26.npy', 'X_115_27.npy', 'X_115_29.npy', 'X_115_30.npy', 'X_115_31.npy', 'X_115_32.npy', 'X_115_33.npy', 'X_115_34.npy', 'X_115_36.npy', 'X_115_37.npy', 'X_115_39.npy', 'X_115_40.npy', 'X_115_41.npy', 'X_115_42.npy', 'X_115_44.npy', 'X_115_45.npy', 'X_115_46.npy', 'X_115_48.npy', 'X_115_49.npy', 'X_115_50.npy', 'X_115_51.npy', 'X_115_52.npy', 'X_115_53.npy', 'X_115_55.npy', 'X_115_56.npy', 'X_115_57.npy', 'X_115_58.npy', 'X_115_59.npy', 'X_115_60.npy', 'X_115_61.npy', 'X_115_62.npy', 'X_115_63.npy', 'X_115_64.npy', 'X_115_66.npy', 'X_115_67.npy', 'X_115_68.npy', 'X_115_69.npy', 'X_115_70.npy', 'X_115_71.npy', 'X_115_72.npy', 'X_115_73.npy', 'X_115_74.npy', 'X_115_75.npy', 'X_115_76.npy', 'X_115_77.npy', 'X_115_78.npy', 'X_115_79.npy', 'X_115_80.npy', 'X_115_81.npy', 'X_115_82.npy', 'X_115_83.npy', 'X_115_84.npy', 'X_115_85.npy', 'X_115_86.npy', 'X_115_87.npy', 'X_115_88.npy', 'X_115_89.npy', 'X_115_90.npy', 'X_115_92.npy', 'X_115_93.npy', 'X_115_94.npy', 'X_115_95.npy', 'X_115_97.npy', 'X_115_98.npy', 'X_115_99.npy']
# Allocated arrays
# Created feature matrix
# Created ROI matrix
# Created feature label matrix
# ['0.0' 'Left red nucleus' 'Left substantia nigra'
#  'Left subthalamic nucleus' 'Right Substantia nigra' 'Right red nucleus'
#  'Right subthalamic nucleus']
# 63
# 69
# ['0.0' 'Left substantia nigra' 'Left subthalamic nucleus'
#  'Right Substantia nigra' 'Right subthalamic nucleus']

# %%
n_cases = len(per_change)
results_ls_aug = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
r = 1

# %%
Js = []
aug = True
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs,age,dd,loc,ledd,phys,None,None,None,None,False,False,False)
    cvn = 5
    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    mu = np.zeros_like(y_train)
    sigma = np.zeros_like(y_train)
    
    for i in np.unique(phys):
      (mux, sigmax) = stats.norm.fit(y_train[np.where(phys[train_index] == i)[0]])
      mu[phys[train_index] == i] = mux
      sigma[phys[train_index] == i] = sigmax
    np.random.seed(rs)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        sigma = np.append(sigma,sigma[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
      if aug == True:
        y_train_n = y_train+(sigma)*np.random.normal(0,1,1)
        y_train = np.hstack((y_train,y_train_n))
        sigma = np.hstack((sigma,sigma))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
    
    for jj in np.arange(2,cvn):
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.amax((2,np.argmax(cv_scores)))
      
      # Fit whole dataset with optimal cv
      with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
        sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X_test_sst = sel.transform(X_test_ss0)
        X0_ss = X0_sst
        X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
      est_ls = lasso.fit(X0_ss,y_train)
      results_ls_aug[c] = est_ls.predict(X_test_ss)
      if results_ls_aug[c] < 0:
          dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)
          results_ls_aug[c] = y_train[y_n]
          print('Using nearest neighbor')
      print('Lasso predicts',str(np.round(results_ls_aug[c],4)),
            'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
      try:
        K_nz.append(np.squeeze(K_ss)[est_ls.coef_>0])
      except:
        print('No features appended')
      c=c+1
# Out:
# LassoCV score for 2 is [0.5612489] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.55757898] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.56134004] from dataset of size (496, 1386)
# Lasso predicts 0.6237 for case with 0.71 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55581625] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.55619505] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.55908908] from dataset of size (496, 3386)
# Lasso predicts 0.6106 for case with 0.5 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.3371581] from dataset of size (496, 386)
# LassoCV score for 3 is [0.54256094] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.56130666] from dataset of size (496, 2386)
# Lasso predicts 0.6988 for case with 0.67 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.46099713] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.46099713] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.56118587] from dataset of size (496, 1386)
# Lasso predicts 0.7505 for case with 0.77 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55950705] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.56001201] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.56104954] from dataset of size (496, 1386)
# Lasso predicts 0.8346 for case with 0.97 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56306233] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.55793247] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.56336205] from dataset of size (496, 1386)
# Lasso predicts 0.9989 for case with 0.74 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56115095] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.56139606] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.56236257] from dataset of size (496, 2386)
# Lasso predicts 0.6776 for case with 0.71 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56123981] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.55986483] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.56133538] from dataset of size (496, 3386)
# Lasso predicts 0.7729 for case with 0.78 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56518889] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.56489366] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.56502768] from dataset of size (496, 2386)
# Lasso predicts 0.8149 for case with 0.85 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56133838] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.54112349] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.41476781] from dataset of size (496, 386)
# Lasso predicts 0.7547 for case with 0.57 and selected CV 2
# No features appended
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:366: RuntimeWarning: Mean of empty slice.
#   loc = data.mean()
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:371: RuntimeWarning: Mean of empty slice.
#   scale = np.sqrt(((data - loc)**2).mean())
# LassoCV score for 2 is [0.54491072] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.33227614] from dataset of size (496, 386)
# LassoCV score for 4 is [0.55540625] from dataset of size (496, 1386)
# Lasso predicts 0.8265 for case with 0.74 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56008266] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.56112067] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.55615281] from dataset of size (496, 2386)
# Lasso predicts 0.6325 for case with 0.48 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.56027889] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.55521052] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.56139034] from dataset of size (496, 1386)
# Lasso predicts 0.4775 for case with 0.71 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56091561] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.2471252] from dataset of size (496, 386)
# LassoCV score for 4 is [0.55613548] from dataset of size (496, 6386)
# Lasso predicts 0.6917 for case with 0.81 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.43044096] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.56030928] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.56035748] from dataset of size (496, 6386)
# Lasso predicts 0.7901 for case with 0.82 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55480731] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.56072817] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.55236675] from dataset of size (496, 5386)
# Lasso predicts 0.4764 for case with 0.67 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.55967619] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.55967619] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.55967619] from dataset of size (496, 5386)
# Lasso predicts 0.8663 for case with 0.88 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.43147062] from dataset of size (504, 5386)
# LassoCV score for 3 is [0.45956735] from dataset of size (504, 2386)
# LassoCV score for 4 is [0.47063542] from dataset of size (504, 4386)
# Lasso predicts 0.5691 for case with 0.19 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55986428] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.54878999] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.56076647] from dataset of size (496, 1386)
# Lasso predicts 0.9219 for case with 0.85 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55349139] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.55915669] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.53445179] from dataset of size (496, 6386)
# Lasso predicts 0.8307 for case with 0.78 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.5571416] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.55342335] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.5571416] from dataset of size (496, 4386)
# Lasso predicts 0.8048 for case with 0.3 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56124449] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.56119257] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.56091658] from dataset of size (496, 3386)
# Lasso predicts 0.7962 for case with 0.89 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.46464247] from dataset of size (504, 4386)
# LassoCV score for 3 is [0.48879882] from dataset of size (504, 6386)
# LassoCV score for 4 is [0.49050213] from dataset of size (504, 1386)
# Lasso predicts 0.6987 for case with 0.08 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55973117] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.39652912] from dataset of size (496, 386)
# LassoCV score for 4 is [0.56144611] from dataset of size (496, 2386)
# Lasso predicts 0.7 for case with 0.52 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55886001] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.34032093] from dataset of size (496, 386)
# LassoCV score for 4 is [0.27982044] from dataset of size (496, 386)
# Lasso predicts 0.6842 for case with 0.74 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56002617] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.5559482] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.5602278] from dataset of size (496, 1386)
# Lasso predicts 0.6696 for case with 0.81 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55302176] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.5489263] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.56134499] from dataset of size (496, 2386)
# Lasso predicts 0.9437 for case with 0.53 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56107319] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.56004711] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.56122694] from dataset of size (496, 3386)
# Lasso predicts 0.7144 for case with 0.91 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.4968317] from dataset of size (496, 386)
# LassoCV score for 3 is [0.55502565] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.55856564] from dataset of size (496, 2386)
# Lasso predicts 0.436 for case with 0.66 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.5587148] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.55648055] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.55707358] from dataset of size (496, 3386)
# Lasso predicts 0.5488 for case with 0.53 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.32262624] from dataset of size (496, 386)
# LassoCV score for 3 is [0.56085444] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.56132407] from dataset of size (496, 1386)
# Lasso predicts 0.5987 for case with 0.8 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55969504] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.55492343] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.55488744] from dataset of size (496, 4386)
# Lasso predicts 0.6822 for case with 0.89 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.5588385] from dataset of size (496, 386)
# LassoCV score for 3 is [0.5554116] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.44529481] from dataset of size (496, 2386)
# Lasso predicts 0.8728 for case with 0.48 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.55494879] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.56181887] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.56346832] from dataset of size (496, 6386)
# Lasso predicts 0.6949 for case with 0.76 and selected CV 4
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.3714544] from dataset of size (504, 386)
# LassoCV score for 3 is [0.39004365] from dataset of size (504, 386)
# LassoCV score for 4 is [0.4879261] from dataset of size (504, 4386)
# Lasso predicts 0.661 for case with 0.26 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55842469] from dataset of size (496, 386)
# LassoCV score for 3 is [0.55568865] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.55669264] from dataset of size (496, 4386)
# Lasso predicts 0.7895 for case with 0.81 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56110429] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.56129395] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.56145562] from dataset of size (496, 4386)
# Lasso predicts 0.6866 for case with 0.97 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55845738] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.51277316] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.55220934] from dataset of size (496, 386)
# Lasso predicts 0.5907 for case with 0.56 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56136194] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.54355877] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.54355877] from dataset of size (496, 3386)
# Lasso predicts 0.9879 for case with 0.65 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56097105] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.55968985] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.5591563] from dataset of size (496, 5386)
# Lasso predicts 0.5492 for case with 0.66 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.55930904] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.55808065] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.55821576] from dataset of size (496, 4386)
# Lasso predicts 0.6463 for case with 0.52 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.52616383] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.29500399] from dataset of size (496, 386)
# LassoCV score for 4 is [0.54214995] from dataset of size (496, 3386)
# Lasso predicts 0.6522 for case with 0.84 and selected CV 4
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.44606567] from dataset of size (504, 386)
# LassoCV score for 3 is [0.48348104] from dataset of size (504, 4386)
# LassoCV score for 4 is [0.49390206] from dataset of size (504, 5386)
# Lasso predicts 0.5304 for case with 0.15 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.53418857] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.55456384] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.56296575] from dataset of size (496, 5386)
# Lasso predicts 0.5485 for case with 0.5 and selected CV 4
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.49391298] from dataset of size (504, 1386)
# LassoCV score for 3 is [0.49408369] from dataset of size (504, 2386)
# LassoCV score for 4 is [0.49048484] from dataset of size (504, 6386)
# Lasso predicts 0.7375 for case with 0.09 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.56254511] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.56182433] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.56265833] from dataset of size (496, 4386)
# Lasso predicts 0.6905 for case with 0.3 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56126955] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.55142214] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.46533625] from dataset of size (496, 386)
# Lasso predicts 0.5812 for case with 0.46 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56147447] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.56145683] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.56147447] from dataset of size (496, 6386)
# Lasso predicts 0.4303 for case with 0.64 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.55869941] from dataset of size (496, 386)
# LassoCV score for 3 is [0.55406482] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.55853746] from dataset of size (496, 2386)
# Lasso predicts 0.5777 for case with 0.96 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.55394041] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.41690873] from dataset of size (496, 386)
# LassoCV score for 4 is [0.55865561] from dataset of size (496, 5386)
# Lasso predicts 0.8102 for case with 0.82 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.53208144] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.39580638] from dataset of size (496, 386)
# LassoCV score for 4 is [0.38625328] from dataset of size (496, 386)
# Lasso predicts 0.6846 for case with 0.67 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56083794] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.5566373] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.56092264] from dataset of size (496, 2386)
# Lasso predicts 0.5345 for case with 0.71 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.54614223] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.55675863] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.55770765] from dataset of size (496, 2386)
# Lasso predicts 0.4093 for case with 0.78 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.53899016] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.3508197] from dataset of size (496, 386)
# LassoCV score for 4 is [0.53602127] from dataset of size (496, 3386)
# Lasso predicts 0.5715 for case with 0.69 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.5610521] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.55744433] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.56107501] from dataset of size (496, 5386)
# Lasso predicts 0.669 for case with 0.62 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.55975053] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.54236976] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.54236976] from dataset of size (496, 6386)
# Lasso predicts 0.7078 for case with 0.56 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.56080277] from dataset of size (496, 386)
# LassoCV score for 3 is [0.56153788] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.56153039] from dataset of size (496, 2386)
# Lasso predicts 0.7978 for case with 0.6 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.56128473] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.54500623] from dataset of size (496, 386)
# LassoCV score for 4 is [0.5611064] from dataset of size (496, 6386)
# Lasso predicts 0.7061 for case with 0.61 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.55995582] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.56127965] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.55739457] from dataset of size (496, 2386)
# Lasso predicts 0.7385 for case with 0.63 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.55880208] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.54811379] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.54811379] from dataset of size (496, 3386)
# Lasso predicts 0.5992 for case with 0.94 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.55280788] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.56112967] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.56136219] from dataset of size (496, 2386)
# Lasso predicts 0.766 for case with 0.61 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.56136307] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.56205265] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.56201774] from dataset of size (496, 1386)
# Lasso predicts 0.6437 for case with 0.45 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.53029399] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.52027333] from dataset of size (496, 386)
# LassoCV score for 4 is [0.45563973] from dataset of size (496, 3386)
# Lasso predicts 0.6279 for case with 0.62 and selected CV 2
# No features appended

# %%
util.eval_prediction(np.vstack((pre_imp,
                               results_ls_aug,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
# Fix nearest neighbor problem
# Fix differing noise problem

# %%
Js = []
aug = True
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs,age,dd,loc,ledd,phys,None,None,None,None,False,False,False)
    cvn = 5
    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    mu = np.zeros_like(y_train)
    sigma = np.zeros_like(y_train)
    
    for i in np.unique(phys):
      (mux, sigmax) = stats.norm.fit(y_train[np.where(phys[train_index] == i)[0]])
      mu[phys[train_index] == i] = mux
      sigma[phys[train_index] == i] = sigmax
    np.random.seed(rs)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        sigma = np.append(sigma,sigma[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
      if aug == True:
        y_train_n = y_train#+(sigma)*np.random.normal(0,1,1)
        y_train = np.hstack((y_train,y_train_n))
        sigma = np.hstack((sigma,sigma))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
    
    for jj in np.arange(2,cvn):
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.amax((2,np.argmax(cv_scores)))
      
      # Fit whole dataset with optimal cv
      with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
        sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X_test_sst = sel.transform(X_test_ss0)
        X0_ss = X0_sst
        X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
      est_ls = lasso.fit(X0_ss,y_train)
      results_ls_aug[c] = est_ls.predict(X_test_ss)
      if results_ls_aug[c] < 0:
          dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)
          results_ls_aug[c] = y_train[y_n]
          print('Using nearest neighbor')
      print('Lasso predicts',str(np.round(results_ls_aug[c],4)),
            'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
      try:
        K_nz.append(np.squeeze(K_ss)[est_ls.coef_>0])
      except:
        print('No features appended')
      c=c+1
# Out:
# LassoCV score for 2 is [0.91612585] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.49926246] from dataset of size (496, 386)
# LassoCV score for 4 is [0.93560011] from dataset of size (496, 2386)
# Lasso predicts 0.5791 for case with 0.71 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99859177] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.66520415] from dataset of size (496, 386)
# LassoCV score for 4 is [0.55244522] from dataset of size (496, 386)
# Lasso predicts 0.5881 for case with 0.5 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.98979153] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99871043] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.98213417] from dataset of size (496, 1386)
# Lasso predicts 0.83 for case with 0.67 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99700672] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99978551] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.99973887] from dataset of size (496, 1386)
# Lasso predicts 0.6888 for case with 0.77 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.73968076] from dataset of size (496, 386)
# LassoCV score for 3 is [0.49998371] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99765128] from dataset of size (496, 6386)
# Lasso predicts 0.2853 for case with 0.97 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.61946188] from dataset of size (496, 386)
# LassoCV score for 3 is [0.98694013] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99338173] from dataset of size (496, 2386)
# Lasso predicts 1.0384 for case with 0.74 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.79013311] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99991773] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.65078559] from dataset of size (496, 386)
# Lasso predicts 0.6712 for case with 0.71 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99073789] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.78376454] from dataset of size (496, 386)
# LassoCV score for 4 is [0.54423542] from dataset of size (496, 386)
# Lasso predicts 0.6635 for case with 0.78 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99650242] from dataset of size (496, 1386)
# LassoCV score for 3 is [-7.97248255] from dataset of size (496, 386)
# LassoCV score for 4 is [0.94452586] from dataset of size (496, 2386)
# Lasso predicts 0.7957 for case with 0.85 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.70366944] from dataset of size (496, 386)
# LassoCV score for 3 is [0.97224749] from dataset of size (496, 386)
# LassoCV score for 4 is [0.69084306] from dataset of size (496, 386)
# Lasso predicts 0.659 for case with 0.57 and selected CV 3
# No features appended
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:366: RuntimeWarning: Mean of empty slice.
#   loc = data.mean()
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:371: RuntimeWarning: Mean of empty slice.
#   scale = np.sqrt(((data - loc)**2).mean())
# LassoCV score for 2 is [0.89061091] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.74906577] from dataset of size (496, 386)
# LassoCV score for 4 is [0.74906577] from dataset of size (496, 386)
# Lasso predicts 0.7475 for case with 0.74 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.96337439] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.56978652] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99886735] from dataset of size (496, 4386)
# Lasso predicts 0.6142 for case with 0.48 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99435337] from dataset of size (496, 386)
# LassoCV score for 3 is [0.37765045] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99257679] from dataset of size (496, 2386)
# Lasso predicts 0.3631 for case with 0.71 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99848632] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99833851] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.99974848] from dataset of size (496, 2386)
# Lasso predicts 0.6729 for case with 0.81 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99717493] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.99310417] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.99999828] from dataset of size (496, 1386)
# Lasso predicts 0.7006 for case with 0.82 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.9993998] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99494028] from dataset of size (496, 386)
# LassoCV score for 4 is [0.91038044] from dataset of size (496, 386)
# Lasso predicts 0.3739 for case with 0.67 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99963492] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.95761324] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.89424836] from dataset of size (496, 386)
# Lasso predicts 0.7013 for case with 0.88 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.79641973] from dataset of size (504, 386)
# LassoCV score for 3 is [0.98053249] from dataset of size (504, 4386)
# LassoCV score for 4 is [0.93461756] from dataset of size (504, 5386)
# Lasso predicts 0.659 for case with 0.19 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99961787] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99996988] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.97004855] from dataset of size (496, 386)
# Lasso predicts 0.7662 for case with 0.85 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99859438] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99933786] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.99673727] from dataset of size (496, 1386)
# Lasso predicts 0.8656 for case with 0.78 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99979151] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.90313028] from dataset of size (496, 386)
# LassoCV score for 4 is [0.7613891] from dataset of size (496, 386)
# Lasso predicts 0.6964 for case with 0.3 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.9845273] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.45441968] from dataset of size (496, 386)
# LassoCV score for 4 is [0.90055177] from dataset of size (496, 386)
# Lasso predicts 0.7399 for case with 0.89 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.76997579] from dataset of size (504, 386)
# LassoCV score for 3 is [0.99765914] from dataset of size (504, 2386)
# LassoCV score for 4 is [0.89305197] from dataset of size (504, 3386)
# Lasso predicts 0.824 for case with 0.08 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.97350452] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.98652991] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.98408835] from dataset of size (496, 2386)
# Lasso predicts 0.647 for case with 0.52 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.82454189] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.99260928] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.99704186] from dataset of size (496, 2386)
# Lasso predicts 0.6543 for case with 0.74 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.89386613] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99966537] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.99951508] from dataset of size (496, 2386)
# Lasso predicts 0.6352 for case with 0.81 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.86718725] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99973846] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.96543779] from dataset of size (496, 386)
# Lasso predicts 0.9175 for case with 0.53 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.88674874] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.54335826] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99805396] from dataset of size (496, 2386)
# Lasso predicts 0.5955 for case with 0.91 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.93562677] from dataset of size (496, 386)
# LassoCV score for 3 is [0.95815811] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99943515] from dataset of size (496, 1386)
# Lasso predicts 0.425 for case with 0.66 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99758367] from dataset of size (496, 1386)
# LassoCV score for 3 is [1.] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.70909466] from dataset of size (496, 386)
# Lasso predicts 0.6673 for case with 0.53 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.92159804] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.99966111] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.75546531] from dataset of size (496, 386)
# Lasso predicts 0.5708 for case with 0.8 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.95422377] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.99912988] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.99902762] from dataset of size (496, 1386)
# Lasso predicts 0.6015 for case with 0.89 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.84024764] from dataset of size (496, 386)
# LassoCV score for 3 is [0.93721746] from dataset of size (496, 386)
# LassoCV score for 4 is [0.79916564] from dataset of size (496, 386)
# Lasso predicts 0.8805 for case with 0.48 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99994637] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99852324] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.97373788] from dataset of size (496, 1386)
# Lasso predicts 0.6729 for case with 0.76 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.82509768] from dataset of size (504, 3386)
# LassoCV score for 3 is [0.99720989] from dataset of size (504, 4386)
# LassoCV score for 4 is [0.82015042] from dataset of size (504, 386)
# Lasso predicts 0.5945 for case with 0.26 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.94213292] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.99907458] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.99973815] from dataset of size (496, 1386)
# Lasso predicts 0.6388 for case with 0.81 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99998264] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.99982447] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.99839317] from dataset of size (496, 386)
# Lasso predicts 0.6387 for case with 0.97 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99950107] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.9958268] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.99974293] from dataset of size (496, 2386)
# Lasso predicts 0.5573 for case with 0.56 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99967856] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99567142] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.99726475] from dataset of size (496, 1386)
# Lasso predicts 0.801 for case with 0.65 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.84193963] from dataset of size (496, 386)
# LassoCV score for 3 is [0.98530078] from dataset of size (496, 386)
# LassoCV score for 4 is [0.80595332] from dataset of size (496, 2386)
# Lasso predicts 0.5501 for case with 0.66 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99938519] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.87454073] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99685057] from dataset of size (496, 1386)
# Lasso predicts 0.7597 for case with 0.52 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99409758] from dataset of size (496, 6386)
# LassoCV score for 3 is [0.94375774] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.58073993] from dataset of size (496, 386)
# Lasso predicts 0.6354 for case with 0.84 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.99990509] from dataset of size (504, 1386)
# LassoCV score for 3 is [0.78287792] from dataset of size (504, 386)
# LassoCV score for 4 is [0.78287792] from dataset of size (504, 386)
# Lasso predicts 0.6885 for case with 0.15 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.9491915] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.99934735] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.99986455] from dataset of size (496, 1386)
# Lasso predicts 0.5128 for case with 0.5 and selected CV 4
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.58800329] from dataset of size (504, 386)
# LassoCV score for 3 is [0.90200241] from dataset of size (504, 386)
# LassoCV score for 4 is [0.99811909] from dataset of size (504, 1386)
# Lasso predicts 0.8264 for case with 0.09 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99973409] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.99973902] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.99850043] from dataset of size (496, 1386)
# Lasso predicts 0.6537 for case with 0.3 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99968706] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99608551] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.99994899] from dataset of size (496, 4386)
# Lasso predicts 0.4961 for case with 0.46 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.99989806] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.99765352] from dataset of size (496, 3386)
# LassoCV score for 4 is [0.77956518] from dataset of size (496, 386)
# Lasso predicts 0.3833 for case with 0.64 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99516073] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.38293365] from dataset of size (496, 386)
# LassoCV score for 4 is [0.94767524] from dataset of size (496, 5386)
# Lasso predicts 0.7549 for case with 0.96 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99875509] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.51874776] from dataset of size (496, 386)
# LassoCV score for 4 is [0.52753957] from dataset of size (496, 386)
# Lasso predicts 0.7417 for case with 0.82 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99742056] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.9992915] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.58120775] from dataset of size (496, 386)
# Lasso predicts 0.6192 for case with 0.67 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99843672] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.999912] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.87231942] from dataset of size (496, 386)
# Lasso predicts 0.5489 for case with 0.71 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99858167] from dataset of size (496, 2386)
# LassoCV score for 3 is [0.97792783] from dataset of size (496, 386)
# LassoCV score for 4 is [0.99994269] from dataset of size (496, 1386)
# Lasso predicts 0.3599 for case with 0.78 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.72808521] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99744003] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.99921004] from dataset of size (496, 2386)
# Lasso predicts 0.4506 for case with 0.69 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.96758189] from dataset of size (496, 1386)
# LassoCV score for 3 is [1.] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.99988749] from dataset of size (496, 2386)
# Lasso predicts 0.6255 for case with 0.62 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.98500205] from dataset of size (496, 5386)
# LassoCV score for 3 is [0.58816204] from dataset of size (496, 386)
# LassoCV score for 4 is [0.80431329] from dataset of size (496, 1386)
# Lasso predicts 0.678 for case with 0.56 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.99307973] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.98797721] from dataset of size (496, 386)
# LassoCV score for 4 is [0.9892157] from dataset of size (496, 2386)
# Lasso predicts 0.8068 for case with 0.6 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.62270295] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99580013] from dataset of size (496, 4386)
# LassoCV score for 4 is [0.98497773] from dataset of size (496, 2386)
# Lasso predicts 0.7418 for case with 0.61 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99984755] from dataset of size (496, 4386)
# LassoCV score for 3 is [0.99638818] from dataset of size (496, 5386)
# LassoCV score for 4 is [0.65572584] from dataset of size (496, 386)
# Lasso predicts 0.6752 for case with 0.63 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.92626847] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99344748] from dataset of size (496, 1386)
# LassoCV score for 4 is [0.93524765] from dataset of size (496, 386)
# Lasso predicts 0.5588 for case with 0.94 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.95170748] from dataset of size (496, 3386)
# LassoCV score for 3 is [0.99960005] from dataset of size (496, 2386)
# LassoCV score for 4 is [0.53747853] from dataset of size (496, 386)
# Lasso predicts 0.7087 for case with 0.61 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.70731973] from dataset of size (496, 386)
# LassoCV score for 3 is [0.99511749] from dataset of size (496, 386)
# LassoCV score for 4 is [0.9408851] from dataset of size (496, 386)
# Lasso predicts 0.5192 for case with 0.45 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.99974192] from dataset of size (496, 1386)
# LassoCV score for 3 is [0.91463015] from dataset of size (496, 6386)
# LassoCV score for 4 is [0.59694126] from dataset of size (496, 386)
# Lasso predicts 0.6873 for case with 0.62 and selected CV 2
# No features appended

# %%
# pre_imp = (np.asarray(pre_updrs_off,dtype=float)-np.asarray(pre_updrs_off,dtype=float))/np.asarray(pre_updrs_off,dtype=float)
# results_ls[results_ls>1] = 1
util.eval_prediction(np.vstack((pre_imp,
                               results_ls_aug,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')

# %%
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
plt.rcParams['figure.figsize'] = [20, 5]
fig,ax = plt.subplots(1,3,sharex=True,sharey=True)
#ax[0].scatter(pre_imp,per_change)
col = np.where(per_change <= 0.3,'orange','blue')
ax[0].scatter(pre_imp,per_change, c=col,linewidth=0)
lr = stats.linregress(pre_imp.T,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(0.50,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=16)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=16)
ax[0].set_ylabel('True improvement',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[1].scatter(results_ls,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls),per_change)
y_model = results_ls*lr.slope+lr.intercept
ax[1].plot(results_ls,y_model,color='r')
ax[1].text(0.50,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Wild Bootstrap Lasso',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[2].scatter(results_ls_aug,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[2].plot(results_ls_aug,y_model,color='r')
ax[2].text(1.75,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[2].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].set_title('Noise Compensated Lasso',fontsize=16)
plt.ylim([0,1.5])
plt.xlim([0,1.5])
plt.style.use('default')
# Out:
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   slope = ssxym / ssxm
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:187: RuntimeWarning: divide by zero encountered in double_scalars
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:194: RuntimeWarning: invalid value encountered in double_scalars
#   intercept_stderr = slope_stderr * np.sqrt(ssxm + xmean**2)

# %%
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
plt.rcParams['figure.figsize'] = [15, 5]
fig,ax = plt.subplots(1,2,sharex=True,sharey=True)
ax[0].scatter(pre_imp,per_change)
lr = stats.linregress(pre_imp.T,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(0.6,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=16)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=16)
ax[0].set_ylabel('True UPDRS-III improvement',fontsize=16)

ax[1].scatter(results_ls_aug,per_change)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[1].plot(results_ls_aug,y_model,color='r')
ax[1].text(0.6,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Noise Compensated Lasso',fontsize=16)
ax[1].set_ylabel('True UPDRS-III improvement',fontsize=16)
ax[1].yaxis.set_tick_params(labelleft=True)
plt.ylim([0,1.5])
plt.xlim([0,1.5])
plt.style.use('default')
