# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
from sklearn.linear_model import QuantileRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RANSACRegressor
import os
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
from pylab import rcParams
import pandas as pd
import warnings
#from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
from sklearn.exceptions import ConvergenceWarning
from sklearn import preprocessing as skp
from sklearn import model_selection as sms
from sklearn import feature_selection as skf
from sklearn import linear_model as slm
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util as util
import nibabel as nib
import os
import pickle
from scipy.spatial import cKDTree
# Out:
# Skipping torch import

# %%
if not sys.warnoptions:
    warnings.simplefilter("ignore",category=ConvergenceWarning)
    os.environ["PYTHONWARNINGS"] = "ignore::UserWarning"

# %%
plt.style.use('dark_background')
plt.rcParams["figure.figsize"] = (15,5)
def remove_keymap_conflicts(new_keys_set):
    for prop in plt.rcParams:
        if prop.startswith('keymap.'):
            keys = plt.rcParams[prop]
            remove_list = set(keys) & new_keys_set
            for key in remove_list:
                keys.remove(key)

def multi_slice_viewer(volume):
    remove_keymap_conflicts({'j', 'k'})
    fig, ax = plt.subplots()
    ax.volume = volume
    ax.index = volume.shape[0]//2
    ax.imshow(volume[ax.index])
    fig.canvas.mpl_connect('key_press_event', process_key)

def process_key(event):
    fig = event.canvas.figure
    ax = fig.axes[0]
    if event.key == 'j':
        previous_slice(ax)
    elif event.key == 'k':
        next_slice(ax)
    fig.canvas.draw()
    

def previous_slice(ax):
    volume = ax.volume
    ax.index = (ax.index-1) % volume.shape[0] 
    ax.images[0].set_array(volume[ax.index])

def next_slice(ax):
    volume = ax.volume
    ax.index = (ax.index+1) % volume.shape[0]
    ax.images[0].set_array(volume[ax.index])

# %%
cv_names = {'CORNELL ID',
            ' OFF (pre-dbs updrs)',
            ' ON (pre-dbs updrs)',
            ' OFF meds ON stim 6mo',
            'Age',
            'Sex',
            'Ethnicity',
            'Race',
            'Disease Duration (year)',
            'Physician',
            ' pre op levadopa equivalent dose (mg)',
            ' Location',
            ' Target',
            ' Test medication status'}


# Load scores
file_dir = '/data/Ali/RadDBS-QSM/data/docs/dbs_03292024.csv'
motor_df = util.filter_data(file_dir,cv_names,True)
# Find cases with all required scores
cv_dict = util.filter_cases(motor_df,cv_names)
subs = cv_dict['CORNELL ID']
# Load extracted features
npy_dir = '/data/Ali/RadDBS-QSM/data/npy/new/'
phi_dir = '/data/Ali/RadDBS-QSM/data/phi/new/phi/'
roi_path = '/data/Ali/RadDBS-QSM/data/xlxs/new_segs.csv'
n_rois = 6
all_rois = False
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595,all_rois)
print(np.unique(R_all))
ids = np.asarray(ID_all).astype(int)

# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(ids).astype(int),np.asarray(cv_dict['CORNELL ID']))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
# Exclude GPi
c_cases_idx[ids == 36] = 0
# c_cases_idx[ids == 42] = 0
# c_cases_idx[ids == 52] = 0
c_cases_idx[ids == 53] = 0
# c_cases_idx[ids == 98] = 0
# c_cases_idx[ids == 108] = 0
print(np.sum(c_cases_idx))
subs[subs <= 90]
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
print(len(s_cases_idx))
        
X_all_c = X_all[c_cases_idx,2:6,:]
#X_all_c = (np.load('X2h_sr.npy').T).reshape((31,6381))
# print('Applying combat')
K_all_c = K_all[c_cases_idx,2:6,:]
R_all_c = R_all[c_cases_idx,2:6,:]
# Re-index the scored subjects with respect to complete cases

per_change = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' OFF meds ON stim 6mo'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_updrs = cv_dict[' OFF (pre-dbs updrs)'][s_cases_idx]
dd = cv_dict['Disease Duration (year)'][s_cases_idx]
ledd = cv_dict[' pre op levadopa equivalent dose (mg)'][s_cases_idx]
tmed = cv_dict[' Test medication status'][s_cases_idx]
phys = cv_dict['Physician'][s_cases_idx]
age = cv_dict['Age'][s_cases_idx]
loc = cv_dict[' Location'][s_cases_idx]
sex = cv_dict['Sex'][s_cases_idx]
rce = cv_dict['Race'][s_cases_idx]
eth = cv_dict['Ethnicity'][s_cases_idx]
tgt = cv_dict[' Target'][s_cases_idx]
subsc = subs[s_cases_idx]

# Reshape keys and ROIs
if all_rois == True:
    K_all_cu = np.empty((K_all_c.shape[0],K_all_c.shape[1],K_all_c.shape[2]+1),dtype=object)
    K_all_cu[:,:,:-1] = K_all_c
    K_all_cu[:,:,-1] = 'pre_updrs'
    K_all_cu[:,:,-1] = 'disease_duration'
    K_all_cu[:,:,-1] = 'pre op levadopa equivalent dose (mg)'
    K_all_cu[:,:,-1] = ' Test medication status'
    K_all_cu[:,:,-1] = 'Physician'
    K_all_cu[:,:,-1] = 'Age'
    K_all_cu[:,:,-1] = 'Location'
    K_all_cu[:,:,-1] = 'Sex'
    K_all_cu[:,:,-1] = 'Race'
    K_all_cu[:,:,-1] = 'Ethnicity'
    
    K = K_all_cu.reshape((K_all_cu.shape[0],K_all_cu.shape[1]*K_all_cu.shape[2]))[0]
    R = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))
else:
    K_all_c = K_all_c.reshape((K_all_c.shape[0],K_all_c.shape[1]*K_all_c.shape[2]))[0]
    R_all_c = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))

print(np.unique(R_all_c))
# Out:
# Keeping CORNELL ID
# Keeping Age
# Keeping Sex
# Keeping Ethnicity
# Keeping Race
# Keeping Disease Duration (year)
# Keeping Physician
# Keeping  OFF (pre-dbs updrs)
# Keeping  ON (pre-dbs updrs)
# Keeping  pre op levadopa equivalent dose (mg)
# Keeping  Location
# Keeping  Target
# Keeping  Test medication status
# Keeping  OFF meds ON stim 6mo
# {' ON (pre-dbs updrs)', 'Race', 'Disease Duration (year)', 'Sex', ' OFF (pre-dbs updrs)', ' pre op levadopa equivalent dose (mg)', ' Target', 'CORNELL ID', 'Ethnicity', ' Test medication status', ' Location', 'Physician', ' OFF meds ON stim 6mo', 'Age'}
# ['X_115_01.npy', 'X_115_02.npy', 'X_115_03.npy', 'X_115_04.npy', 'X_115_05.npy', 'X_115_06.npy', 'X_115_07.npy', 'X_115_08.npy', 'X_115_09.npy', 'X_115_10.npy', 'X_115_100.npy', 'X_115_101.npy', 'X_115_102.npy', 'X_115_104.npy', 'X_115_105.npy', 'X_115_106.npy', 'X_115_107.npy', 'X_115_108.npy', 'X_115_109.npy', 'X_115_11.npy', 'X_115_110.npy', 'X_115_111.npy', 'X_115_112.npy', 'X_115_113.npy', 'X_115_114.npy', 'X_115_115.npy', 'X_115_116.npy', 'X_115_12.npy', 'X_115_13.npy', 'X_115_14.npy', 'X_115_15.npy', 'X_115_16.npy', 'X_115_17.npy', 'X_115_18.npy', 'X_115_19.npy', 'X_115_20.npy', 'X_115_22.npy', 'X_115_23.npy', 'X_115_24.npy', 'X_115_25.npy', 'X_115_26.npy', 'X_115_27.npy', 'X_115_29.npy', 'X_115_30.npy', 'X_115_31.npy', 'X_115_32.npy', 'X_115_33.npy', 'X_115_34.npy', 'X_115_36.npy', 'X_115_37.npy', 'X_115_39.npy', 'X_115_40.npy', 'X_115_41.npy', 'X_115_42.npy', 'X_115_44.npy', 'X_115_45.npy', 'X_115_46.npy', 'X_115_48.npy', 'X_115_49.npy', 'X_115_50.npy', 'X_115_51.npy', 'X_115_52.npy', 'X_115_53.npy', 'X_115_55.npy', 'X_115_56.npy', 'X_115_57.npy', 'X_115_58.npy', 'X_115_59.npy', 'X_115_60.npy', 'X_115_61.npy', 'X_115_62.npy', 'X_115_63.npy', 'X_115_64.npy', 'X_115_66.npy', 'X_115_67.npy', 'X_115_68.npy', 'X_115_69.npy', 'X_115_70.npy', 'X_115_71.npy', 'X_115_72.npy', 'X_115_73.npy', 'X_115_74.npy', 'X_115_75.npy', 'X_115_76.npy', 'X_115_77.npy', 'X_115_78.npy', 'X_115_79.npy', 'X_115_80.npy', 'X_115_81.npy', 'X_115_82.npy', 'X_115_83.npy', 'X_115_84.npy', 'X_115_85.npy', 'X_115_86.npy', 'X_115_87.npy', 'X_115_88.npy', 'X_115_89.npy', 'X_115_90.npy', 'X_115_92.npy', 'X_115_93.npy', 'X_115_94.npy', 'X_115_95.npy', 'X_115_97.npy', 'X_115_98.npy', 'X_115_99.npy']
# Allocated arrays
# Created feature matrix
# Created ROI matrix
# Created feature label matrix
# ['0.0' 'Left red nucleus' 'Left substantia nigra'
#  'Left subthalamic nucleus' 'Right Substantia nigra' 'Right red nucleus'
#  'Right subthalamic nucleus']
# 63
# 69
# ['0.0' 'Left substantia nigra' 'Left subthalamic nucleus'
#  'Right Substantia nigra' 'Right subthalamic nucleus']

# %%
n_cases = len(per_change)
results_ls_aug = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
r = 1

# %%
Js = []
aug = False
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs,age,dd,loc,ledd,phys,None,None,None,None,False,False,False)
    cvn = 5
    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    mu = np.zeros_like(y_train)
    sigma = np.zeros_like(y_train)
    
    for i in np.unique(phys):
      (mux, sigmax) = stats.norm.fit(y_train[np.where(phys[train_index] == i)[0]])
      mu[phys[train_index] == i] = mux
      sigma[phys[train_index] == i] = sigmax
    np.random.seed(rs)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        sigma = np.append(sigma,sigma[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
      if aug == True:
        y_train_n = y_train+(sigma)*np.random.normal(0,1,1)
        y_train = np.hstack((y_train,y_train_n))
        sigma = np.hstack((sigma,sigma))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
    
    for jj in np.arange(2,cvn):
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.amax((2,np.argmax(cv_scores)))
      
      # Fit whole dataset with optimal cv
      with warnings.catch_warnings():
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
        sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X_test_sst = sel.transform(X_test_ss0)
        X0_ss = X0_sst
        X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
      est_ls = lasso.fit(X0_ss,y_train)
      results_ls_aug[c] = est_ls.predict(X_test_ss)
      if results_ls_aug[c] < 0:
          dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)
          results_ls_aug[c] = y_train[y_n]
          print('Using nearest neighbor')
      print('Lasso predicts',str(np.round(results_ls_aug[c],4)),
            'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
      try:
        K_nz.append(np.squeeze(K_ss)[est_ls.coef_>0])
      except:
        print('No features appended')
      c=c+1
# Out:
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6461 for case with 0.71 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6495 for case with 0.5 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6468 for case with 0.67 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.645 for case with 0.77 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 1386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6419 for case with 0.97 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 2386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6456 for case with 0.74 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6461 for case with 0.71 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6449 for case with 0.78 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6438 for case with 0.85 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 4386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6484 for case with 0.57 and selected CV 2
# No features appended
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:366: RuntimeWarning: Mean of empty slice.
#   loc = data.mean()
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:371: RuntimeWarning: Mean of empty slice.
#   scale = np.sqrt(((data - loc)**2).mean())
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 1386)
# Lasso predicts 0.6456 for case with 0.74 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.11411924] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 2386)
# Lasso predicts 0.638 for case with 0.48 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.16686952] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 2386)
# Lasso predicts 0.644 for case with 0.71 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 2386)
# Lasso predicts 0.6444 for case with 0.81 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 2386)
# Lasso predicts 0.6443 for case with 0.82 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.16655727] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 4386)
# Lasso predicts 0.5968 for case with 0.67 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 4386)
# LassoCV score for 4 is [0.] from dataset of size (62, 4386)
# Lasso predicts 0.6433 for case with 0.88 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.] from dataset of size (63, 3386)
# LassoCV score for 3 is [0.24775336] from dataset of size (63, 1386)
# LassoCV score for 4 is [0.17959894] from dataset of size (63, 1)
# Lasso predicts 0.6523 for case with 0.19 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 4386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6438 for case with 0.85 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14558189] from dataset of size (62, 1)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 4386)
# Lasso predicts 0.6449 for case with 0.78 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.17084673] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 4386)
# LassoCV score for 4 is [0.] from dataset of size (62, 3386)
# Lasso predicts 0.6571 for case with 0.3 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14671412] from dataset of size (62, 1)
# LassoCV score for 3 is [0.] from dataset of size (62, 4386)
# LassoCV score for 4 is [0.] from dataset of size (62, 2386)
# Lasso predicts 0.6432 for case with 0.89 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.14082233] from dataset of size (63, 386)
# LassoCV score for 3 is [0.2539644] from dataset of size (63, 1386)
# LassoCV score for 4 is [0.19773036] from dataset of size (63, 1)
# Lasso predicts 0.653 for case with 0.08 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 2386)
# LassoCV score for 3 is [0.06474738] from dataset of size (62, 4386)
# LassoCV score for 4 is [0.] from dataset of size (62, 2386)
# Lasso predicts 0.6492 for case with 0.52 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.14763956] from dataset of size (62, 1)
# LassoCV score for 3 is [0.05714347] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 4386)
# Lasso predicts 0.6118 for case with 0.74 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14223421] from dataset of size (62, 1)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 1386)
# Lasso predicts 0.6444 for case with 0.81 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.15508817] from dataset of size (62, 1)
# LassoCV score for 3 is [0.07477397] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 1386)
# Lasso predicts 0.6489 for case with 0.53 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 3386)
# LassoCV score for 3 is [0.20914663] from dataset of size (62, 1386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.638 for case with 0.91 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.14865405] from dataset of size (62, 1)
# LassoCV score for 3 is [0.05276293] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6468 for case with 0.66 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.08537462] from dataset of size (62, 386)
# LassoCV score for 3 is [0.02723399] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.649 for case with 0.53 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14135976] from dataset of size (62, 1)
# LassoCV score for 3 is [0.1955741] from dataset of size (62, 1)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6378 for case with 0.8 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6432 for case with 0.89 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 5386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6498 for case with 0.48 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.0403128] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6523 for case with 0.76 and selected CV 3
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.22859564] from dataset of size (63, 1)
# LassoCV score for 3 is [0.22859564] from dataset of size (63, 1)
# LassoCV score for 4 is [0.41656038] from dataset of size (63, 3386)
# Lasso predicts 0.6061 for case with 0.26 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 6386)
# LassoCV score for 3 is [0.05468804] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6092 for case with 0.81 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 6386)
# LassoCV score for 3 is [0.06221345] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6417 for case with 0.97 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.04053379] from dataset of size (62, 386)
# LassoCV score for 3 is [0.10807627] from dataset of size (62, 2386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6472 for case with 0.56 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.01971953] from dataset of size (62, 1386)
# LassoCV score for 3 is [0.10526459] from dataset of size (62, 3386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6721 for case with 0.65 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.00417323] from dataset of size (62, 1386)
# LassoCV score for 3 is [0.04825936] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6555 for case with 0.66 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.08827968] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6738 for case with 0.52 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 6386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.644 for case with 0.84 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.46549522] from dataset of size (63, 386)
# LassoCV score for 3 is [0.38876295] from dataset of size (63, 5386)
# LassoCV score for 4 is [0.70884534] from dataset of size (63, 3386)
# Lasso predicts 0.6882 for case with 0.15 and selected CV 4
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 5386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 386)
# Lasso predicts 0.6495 for case with 0.5 and selected CV 2
# No features appended
# Resampled to size (63,)
# LassoCV score for 2 is [0.97401269] from dataset of size (63, 386)
# LassoCV score for 3 is [0.47416886] from dataset of size (63, 3386)
# LassoCV score for 4 is [0.7003069] from dataset of size (63, 6386)
# Lasso predicts 0.9428 for case with 0.09 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.01479187] from dataset of size (62, 6386)
# LassoCV score for 3 is [0.08902143] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6461 for case with 0.3 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 6386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6502 for case with 0.46 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14773162] from dataset of size (62, 1)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6473 for case with 0.64 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 1386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.642 for case with 0.96 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.06308806] from dataset of size (62, 386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6442 for case with 0.82 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 3386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6468 for case with 0.67 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 3386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6461 for case with 0.71 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 5386)
# LassoCV score for 3 is [0.1144524] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 4386)
# Lasso predicts 0.6247 for case with 0.78 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 5386)
# LassoCV score for 3 is [0.2443501] from dataset of size (62, 2386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6147 for case with 0.69 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 3386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6476 for case with 0.62 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 6386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 5386)
# Lasso predicts 0.6484 for case with 0.56 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14678463] from dataset of size (62, 1)
# LassoCV score for 3 is [0.13854614] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6478 for case with 0.6 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14793656] from dataset of size (62, 1)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 4386)
# Lasso predicts 0.6477 for case with 0.61 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.14758016] from dataset of size (62, 1)
# LassoCV score for 3 is [0.20602607] from dataset of size (62, 2386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6474 for case with 0.63 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 3386)
# LassoCV score for 3 is [0.07565235] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6188 for case with 0.94 and selected CV 3
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6478 for case with 0.61 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 5386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6503 for case with 0.45 and selected CV 2
# No features appended
# LassoCV score for 2 is [0.] from dataset of size (62, 4386)
# LassoCV score for 3 is [0.] from dataset of size (62, 6386)
# LassoCV score for 4 is [0.] from dataset of size (62, 6386)
# Lasso predicts 0.6476 for case with 0.62 and selected CV 2
# No features appended

# %%
util.eval_prediction(np.vstack((pre_imp,
                               results_ls_aug,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
# Fix nearest neighbor problem
# Fix differing noise problem

# %%
# Do wild bootstrap
# Repeat CHH with wild bootstrap and higher zscore
Js = []
aug = False
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(c,len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
                                          
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs,age,dd,loc,ledd,phys,None,None,None,None,False,False,False)
    X0_ss00 = X0_ss0
    y_train_0 = y_train
    cvn = 5

    cv_scores = np.zeros((cvn,1))
    rs = 1
    rcfs = 1000
    (mu, sigma) = stats.norm.fit(y_train)
    kappa = stats.skew(y_train)
    print('Label distribution of:',mu,sigma,kappa)
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        print('Resampled to size',y_train.shape)
        ls0 = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
        est0 = ls0.fit(X0_ss0,y_train)
        eps = y_train-ls0.predict(X0_ss0)
        eps_v = eps*np.random.normal(0,1,1)
        y_train_0 = y_train
      if aug == True:
        y_train_n = y_train+(1.96*sigma)*np.random.normal(0,1,1)
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))
      else: # Control for different training sample sizes
        while len(eps_v) < len(y_train):
          eps_v = np.hstack((eps_v,eps*np.random.normal(0,1,1)))
        y_train_n = y_train+eps_v
        cc = cc+1
        y_train = np.hstack((y_train,y_train_n))
        y_cat = y_train <= 0.3
        X0_ss0 = np.vstack((X0_ss0,X0_ss0))

    for jj in np.arange(2,cvn):
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rcfs,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj],'from dataset of size',X0_ss.shape)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)
      # Break any ties
      if np.sum(cv_scores == best_cv) > 1:
        cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
        for jjj in (cv_scores == cv_scores(best_cv)):
          if jjj > 0:
            skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
            skf_gen = skf_g.split(X0_ss0,y_cat) 
            X0_sst = sel.fit_transform(X0_ss0,y_train)
            X0_ss = X0_sst
            lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
            est_ls = lasso.fit(X0_ss,y_train)
            cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
        best_cv = np.argmax(cv_scores_tb)
      
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=rcfs,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
      results_ls[c] = est_ls.predict(X_test_ss)
      if results_ls[c] < 0:
          dx, y_n = cKDTree(X0_ss00.reshape(X0_ss00.shape[0],-1)).query(X_test_ss0.reshape(1,-1),k=15)
          results_ls[c] = np.mean((y_train_0[y_n]))
          print('Using nearest neighbor')
      print('Lasso predicts',str(np.round(results_ls[c],4)),
            'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
      try:
        K_nz.append(np.squeeze(K_ss)[est_ls.coef_>0])
      except:
        print('No features appended')
      c=c+1
# Out:
# Label distribution of: 0.64610526934279 0.2124176811796581 -0.8558213740991051
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31649/1256414643.py in <module>
#      54         X0_ss0 = np.vstack((X0_ss0,X0_ss0))
#      55       else: # Control for different training sample sizes
# ---> 56         while len(eps_v) < len(y_train):
#      57           eps_v = np.hstack((eps_v,eps*np.random.normal(0,1,1)))
#      58         y_train_n = y_train+eps_v
#
# NameError: name 'eps_v' is not defined

# %%
# pre_imp = (np.asarray(pre_updrs_off,dtype=float)-np.asarray(pre_updrs_off,dtype=float))/np.asarray(pre_updrs_off,dtype=float)
results_ls[results_ls>1] = 1
util.eval_prediction(np.vstack((pre_imp,
                               results_ls,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')

# %%
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
plt.rcParams['figure.figsize'] = [20, 5]
fig,ax = plt.subplots(1,3,sharex=True,sharey=True)
#ax[0].scatter(pre_imp,per_change)
col = np.where(per_change <= 0.3,'orange','blue')
ax[0].scatter(pre_imp,per_change, c=col,linewidth=0)
lr = stats.linregress(pre_imp.T,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(0.50,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=16)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=16)
ax[0].set_ylabel('True improvement',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[1].scatter(results_ls,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls),per_change)
y_model = results_ls*lr.slope+lr.intercept
ax[1].plot(results_ls,y_model,color='r')
ax[1].text(0.50,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Wild Bootstrap Lasso',fontsize=16)

col = np.where(per_change <= 0.3,'orange','blue')
ax[2].scatter(results_ls_aug,per_change, c=col,linewidth=0)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[2].plot(results_ls_aug,y_model,color='r')
ax[2].text(1.75,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[2].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[2].set_title('Noise Compensated Lasso',fontsize=16)
plt.ylim([0,1.5])
plt.xlim([0,1.5])
plt.style.use('default')

# %%
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
plt.rcParams['figure.figsize'] = [15, 5]
fig,ax = plt.subplots(1,2,sharex=True,sharey=True)
ax[0].scatter(pre_imp,per_change)
lr = stats.linregress(pre_imp.T,per_change)
y_model = pre_imp*lr.slope+lr.intercept
ax[0].plot(pre_imp,y_model,color='r')
ax[0].text(0.6,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.3f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[0].transAxes,fontsize=16)  
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].set_title('LCT',fontsize=16)
ax[0].set_ylabel('True UPDRS-III improvement',fontsize=16)

ax[1].scatter(results_ls_aug,per_change)
lr = stats.linregress(np.squeeze(results_ls_aug),per_change)
y_model = results_ls_aug*lr.slope+lr.intercept
ax[1].plot(results_ls_aug,y_model,color='r')
ax[1].text(0.6,0.75,'$y$ = '+str(np.round(lr.slope,2))+'$x$ + '+str(np.round(lr.intercept,2))+'\n'+'$r$ = '+str(np.round(lr.rvalue,2))+'\n'+'$p$ = '+str(('{:.7f}'.format(lr.pvalue))),
                    ha='left', va='bottom', transform=ax[1].transAxes,fontsize=16) 
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].set_title('Noise Compensated Lasso',fontsize=16)
ax[1].set_ylabel('True UPDRS-III improvement',fontsize=16)
ax[1].yaxis.set_tick_params(labelleft=True)
plt.ylim([0,1.5])
plt.xlim([0,1.5])
plt.style.use('default')
