# %%
# Import libraries

import matplotlib.pyplot as plt
import pandas as pd
import warnings
from econml.sklearn_extensions.linear_model import WeightedLassoCV
import sklearn.model_selection as sms
import sklearn.linear_model as slm
import sklearn.preprocessing as skp
import sklearn.metrics as sme
import sklearn.feature_selection as skf
import sklearn.ensemble as ske
import sklearn.utils as sku
import sklearn.decomposition as skd
import sklearn.neighbors as skn
from sklearn.exceptions import ConvergenceWarning
from celer import GroupLassoCV
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util
from scipy.spatial import cKDTree
import nibabel as nib
import os
import pickle
from torch import nn
from rvae import VAE
from rvae import train_model
from adapt.feature_based import CORAL
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
HTML('''
<style>
.jupyter-matplotlib {
    background-color: #000;
}

.widget-label, .jupyter-matplotlib-header{
    color: #fff;
}

.jupyter-button {
    background-color: #333;
    color: #fff;
}
</style>
''')
# Out:
# <style>
# .jupyter-matplotlib {
#     background-color: #000;
# }
#
# .widget-label, .jupyter-matplotlib-header{
#     color: #fff;
# }
#
# .jupyter-button {
#     background-color: #333;
#     color: #fff;
# }
# </style>

# %%
# Maybe y should also be scaled? 
# Perhaps a transform would be more effective, or scaling implemented with consistent cross-validation
# Different scaling methods? 
#     This seems most important for noise-sensitive models like LARS. All other use StandardScaler()
# Transformers?
# Model-specific scaling methods?
#     Yes, see above
# Common cross-validation function ✓
#     Use built-in functions wherever possible and `utils.gridsearch_pickparams()` elsewhere
# Quantile loss
# RANSAC
# Data augmentation? (Mixup)
# Data generation? (SMOGN)
# Combine CHH dataset ✓
# Implement CV and test ✓
# Print selected features ✓
# Make magnitude templates
# Sample weights ✓
# Look at segmentations by error ✓ (Appears to have most difference in red nucleus, which includes surrounding (white?) matter for underperforming cases)
# Extract features from current (1:6) eroded ROIs
# Extract features from all ROIs
# Plot segmentation variance against error for each case across all ROIs ✓
# Why does excluding the subthalamic nucleus increase the correlation (r=0.5 -> r=0.6)?
# Best performance with all ROIs: cvn=6, k=1800
# Best performance with ROIs 0:4, excluding STN: cvn=6, k=1800
# Should the pre-operative UPDRS be appended once or to each ROI? ✓
# Plot histogram of features for successful and unsuccessful predictions

# %%
# Augment with CHH data
X0_gt = np.load('/home/ali/RadDBS-QSM/data/npy/old/X0_gt_chh_rois.npy')
df = pd.read_csv('/home/ali/RadDBS-QSM/data/xlxs/updrs_iii_chh.csv')
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]
n_rois = 6
# Data
s_directory = open('/home/ali/RadDBS-QSM/data/roi/roi_list','r').read().splitlines()
# Load
with open('/home/ali/RadDBS-QSM/data/pickles/segs_chh', "rb") as fp:  
    segs = pickle.load(fp)
    n_cases = len(segs)
with open('/home/ali/RadDBS-QSM/data/pickles/qsms_chh', "rb") as fp:  
    qsms = pickle.load(fp)
with open('/home/ali/RadDBS-QSM/data/phi/chh/Phi_mcl_gt_roi_chh', "rb") as fp:  
    Phi_gt = pickle.load(fp)
L = int(len(X0_gt)/n_cases)
n_features = int(L/n_rois)
# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][-2:])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
for i in range(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float)                             
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float) 
post_updrs_iii_off =  np.asarray(df[df.columns[6]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float) 

per_change = (pre_updrs_iii_off-post_updrs_iii_off)/pre_updrs_iii_off
pre_updrs_off = pre_updrs_iii_off
X_all_c = X0_gt.reshape(n_cases,n_rois,n_features)
X_all_c = X_all_c[:,0:4,:]
lct_change = (pre_updrs_iii_off-pre_updrs_iii_on)/pre_updrs_iii_off
pre_imp = lct_change
subsc = subject_id_corr
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000001 for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000002 for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000003 for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000004 for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000005 for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000006 for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000007 for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000008 for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000009 for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000010 for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000011 for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000013 for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000014 for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000016 for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000018 for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000019 for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000020 for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000021 for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000022 for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000023 for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000024 for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000025 for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000026 for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000027 for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000028 for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000029 for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000030 for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000031 for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000032 for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000033 for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000034 for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000035 for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000036 for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000037 for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000038 for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000039 for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000040 for case 40.0

# %%
df
# Out:
#     subjects    LCT   Unnamed: 2                     UPDRSⅢ  \
# 0        NaN     NaN         NaN  Preoperative Off-Medicine
# 1        1.0  62.26%         NaN                         53
# 2        2.0  75.00%         NaN                         32
# 3        3.0  51.72%         NaN                         58
# 4        4.0  22.58%         NaN                         62
# 5        5.0  55.88%         NaN                         34
# 6        6.0  75.44%         NaN                         57
# 7        7.0  84.00%         NaN                        100
# 8        8.0  41.86%         NaN                         43
# 9        9.0  72.58%         NaN                         62
# 10      10.0  81.25%         NaN                         64
# 11      11.0  70.21%         NaN                         94
# 12      12.0  63.95%         NaN                         86
# 13      13.0  89.55%         NaN                         67
# 14      14.0  88.46%         NaN                         26
# 15      15.0  62.50%         NaN                         72
# 16      16.0  48.00%         NaN                         25
# 17      17.0  14.29%         NaN                         98
# 18      18.0  36.62%         NaN                         71
# 19      19.0  54.90%         NaN                         51
# 20      20.0  81.63%         NaN                         49
# 21      21.0  71.43%         NaN                         49
# 22      22.0  90.32%         NaN                         31
# 23      23.0  65.85%         NaN                         41
# 24      24.0  74.29%         NaN                         35
# 25      25.0  83.61%         NaN                         61
# 26      26.0  58.97%         NaN                         78
# 27      27.0   5.88%         NaN                         51
# 28      28.0  76.67%         NaN                         60
# 29      29.0  81.01%         NaN                         79
# 30      30.0  62.35%         NaN                         85
# 31      31.0  27.91%         NaN                         43
# 32      32.0  31.48%         NaN                         54
# 33      33.0  80.33%         NaN                         61
# 34      34.0  40.74%         NaN                         54
# 35      35.0  16.13%         NaN                         93
# 36      36.0  59.26%         NaN                         54
# 37      37.0  61.40%         NaN                         57
# 38      38.0  95.92%         NaN                         49
# 39      39.0  79.35%         NaN                         92
# 40      40.0  50.00%         NaN                         54
#
#                   Unnamed: 4                                       Unnamed: 5  \
# 0   Preoperative On-Medicine  Postoperative  Off-Medicine &Off-Stimulation\n
# 1                         20                                               40
# 2                          8                                               26
# 3                         28                                               52
# 4                         48                                               61
# 5                         15                                               44
# 6                         14                                               55
# 7                         16                                               68
# 8                         25                                               48
# 9                         17                                               56
# 10                        12                                               33
# 11                        28                                               31
# 12                        31                                               28
# 13                         7                                               64
# 14                         3                                               31
# 15                        27                                               72
# 16                        13                                               17
# 17                        84                                               86
# 18                        45                                               49
# 19                        23                                               37
# 20                         9                                               20
# 21                        14                                               42
# 22                         3                                               46
# 23                        14                                               43
# 24                         9                                               21
# 25                        10                                               60
# 26                        32                                               64
# 27                        48                                               45
# 28                        14                                               68
# 29                        15                                               79
# 30                        32                                               92
# 31                        31                                               31
# 32                        37                                               64
# 33                        12                                               53
# 34                        32                                               64
# 35                        78                                               69
# 36                        22                                               57
# 37                        22                                               56
# 38                         2                                               58
# 39                        19                                              NaN
# 40                        27                                               34
#
#                                      Unnamed: 6  \
# 0   Postoperative  Off-Medicine &On-Stimulation
# 1                                            15
# 2                                            17
# 3                                            18
# 4                                            36
# 5                                            29
# 6                                            32
# 7                                            12
# 8                                            26
# 9                                            25
# 10                                           12
# 11                                           34
# 12                                           27
# 13                                           19
# 14                                           18
# 15                                           44
# 16                                            8
# 17                                           43
# 18                                           47
# 19                                           21
# 20                                            3
# 21                                            8
# 22                                           28
# 23                                           24
# 24                                           15
# 25                                           21
# 26                                           29
# 27                                           27
# 28                                           43
# 29                                           32
# 30                                           40
# 31                                            6
# 32                                           28
# 33                                           21
# 34                                           36
# 35                                           47
# 36                                           12
# 37                                           11
# 38                                           14
# 39                                           63
# 40                                            9
#
#                                     Unnamed: 7  Unnamed: 8
# 0   Postoperative  On-Medicine &On-Stimulation         NaN
# 1                                            7         NaN
# 2                                           10         NaN
# 3                                           20         NaN
# 4                                           28         NaN
# 5                                           22         NaN
# 6                                           16         NaN
# 7                                          NaN         NaN
# 8                                           26         NaN
# 9                                           11         NaN
# 10                                         NaN         NaN
# 11                                          43         NaN
# 12                                          18         NaN
# 13                                         NaN         NaN
# 14                                          17         NaN
# 15                                          38         NaN
# 16                                           8         NaN
# 17                                          34         NaN
# 18                                          46         NaN
# 19                                          18         NaN
# 20                                         NaN         NaN
# 21                                         NaN         NaN
# 22                                         NaN         NaN
# 23                                          24         NaN
# 24                                         NaN         NaN
# 25                                          17         NaN
# 26                                          21         NaN
# 27                                          20         NaN
# 28                                         NaN         NaN
# 29                                          28         NaN
# 30                                         NaN         NaN
# 31                                         NaN         NaN
# 32                                          25         NaN
# 33                                          15         NaN
# 34                                          29         NaN
# 35                                          44         NaN
# 36                                         NaN         NaN
# 37                                         NaN         NaN
# 38                                          12         NaN
# 39                                         NaN         NaN
# 40                                           8         NaN

# %%
scoring = 'r2'
results_bls = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
results_gls = np.zeros_like(per_change)
gerror = np.zeros_like(per_change)
alphas = np.logspace(-5,-3,100)
Ks = []
Kstg = []
w = []
wg = []
pcases = []

# %%
Js = []
err_var = np.zeros_like(per_change)
r = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    idy = y_train[y_train<=0.3]
    
    # Cross validation
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,test_index,pre_updrs_off,np.zeros_like(pre_updrs_off),False,False,False)
    cvn = len(X0_ss0-1)
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
      # Feature selection
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      sel = skf.SelectKBest(skf.r_regression,k=4100)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      kappa.append(np.linalg.cond(X0_ss0))
      X_test_ss = X_test_sst
      dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=cvn,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
    # Reconstruct nearest neighbor
    r[j] = est_ls.predict(X0_ss[y_n,:])
    err_var[j] = np.mean(abs(est_ls.predict(X0_ss)-y_train))
    rerror[j] = np.abs(r[j]-y_train[y_n])
    #s.append(est_ls.score(X0_ss,y_train))
    results_ls[j] = est_ls.predict(X_test_ss)
    # # If reconstruction error is too high, use nearest neighbor
    if rerror[j] > 0.1 and dx > 36:
        print('Using nearest neighbor')
        results_ls[j] = y_train[y_n]
    print('Lasso predicts',str(np.round(results_ls[j],4)),
              'for case with',str(np.round(per_change[j],2)),
             # 'with regularization',str(est_ls.alpha_),
              'with reconstruction error',str(np.round(rerror[j],9)),
              'maximum error',str(np.round(err_var[j],9)),
              'and neighbor',str(np.round(y_train[y_n],2).item()),
              'and distance',str((dx)))
    gerror[j] = (abs(results_ls[j]-y_test))
# Out:
# Lasso predicts 0.9679 for case with 0.72 with reconstruction error 0.000765647 maximum error 0.000382717 and neighbor 0.81 and distance [52.79807487]
# Lasso predicts 0.5143 for case with 0.47 with reconstruction error 0.032309767 maximum error 0.017652156 and neighbor 0.81 and distance [56.54839221]
# Lasso predicts 0.87 for case with 0.69 with reconstruction error 0.005078627 maximum error 0.005500813 and neighbor 0.48 and distance [66.8513502]
# Lasso predicts 0.7602 for case with 0.42 with reconstruction error 0.002868754 maximum error 0.011404095 and neighbor 0.49 and distance [214.22757535]
# Lasso predicts 0.4358 for case with 0.15 with reconstruction error 0.022675374 maximum error 0.031892775 and neighbor 0.47 and distance [66.19523652]
# Lasso predicts 0.6152 for case with 0.44 with reconstruction error 0.048825242 maximum error 0.019791107 and neighbor 0.81 and distance [54.90576372]
# Lasso predicts 0.7439 for case with 0.88 with reconstruction error 0.001106298 maximum error 0.001289712 and neighbor 0.44 and distance [70.1889731]
# Lasso predicts 0.4356 for case with 0.4 with reconstruction error 0.074481233 maximum error 0.028968005 and neighbor 0.81 and distance [53.59488752]
# Lasso predicts 0.5478 for case with 0.6 with reconstruction error 1.6169e-05 maximum error 6.534e-06 and neighbor 0.81 and distance [56.6700254]
# Lasso predicts 0.5747 for case with 0.81 with reconstruction error 0.008155436 maximum error 0.002317205 and neighbor 0.1 and distance [51.77760574]
# Lasso predicts 0.7761 for case with 0.64 with reconstruction error 0.000292781 maximum error 0.007235398 and neighbor 0.72 and distance [60.21661435]
# Lasso predicts 0.5327 for case with 0.72 with reconstruction error 1.16e-07 maximum error 1.83e-07 and neighbor 0.71 and distance [54.53556035]
# Lasso predicts 0.491 for case with 0.31 with reconstruction error 0.03714375 maximum error 0.015653832 and neighbor 0.81 and distance [56.34169688]
# Lasso predicts 0.5834 for case with 0.68 with reconstruction error 0.002127092 maximum error 0.001979818 and neighbor 0.44 and distance [56.04228281]
# Lasso predicts 0.3625 for case with 0.34 with reconstruction error 0.001247024 maximum error 0.002994704 and neighbor 0.47 and distance [73.5614262]
# Lasso predicts 0.4743 for case with 0.59 with reconstruction error 1.2074e-05 maximum error 3.1821e-05 and neighbor 0.4 and distance [62.77740984]
# Using nearest neighbor
# Lasso predicts 0.8125 for case with 0.94 with reconstruction error 0.106014821 maximum error 0.051032785 and neighbor 0.81 and distance [62.16100625]
# Lasso predicts 0.5601 for case with 0.84 with reconstruction error 0.018649442 maximum error 0.009223575 and neighbor 0.94 and distance [67.25815385]
# Lasso predicts 0.4 for case with 0.1 with reconstruction error 0.054173057 maximum error 0.023447747 and neighbor 0.81 and distance [54.18833684]
# Lasso predicts 0.6592 for case with 0.41 with reconstruction error 0.049601443 maximum error 0.024202705 and neighbor 0.81 and distance [64.06860042]
# Lasso predicts 0.7332 for case with 0.57 with reconstruction error 0.000682928 maximum error 0.009865177 and neighbor 0.28 and distance [97.13523648]
# Lasso predicts 0.9004 for case with 0.66 with reconstruction error 0.00026056 maximum error 0.000304056 and neighbor 0.59 and distance [80.19743204]
# Lasso predicts 0.5826 for case with 0.63 with reconstruction error 0.006457212 maximum error 0.008670979 and neighbor 0.48 and distance [71.93016604]
# Lasso predicts 0.5712 for case with 0.47 with reconstruction error 0.002741536 maximum error 0.017263932 and neighbor 0.47 and distance [60.89158702]
# Lasso predicts 0.2963 for case with 0.28 with reconstruction error 8.945e-06 maximum error 1.1655e-05 and neighbor 0.64 and distance [83.41530342]
# Lasso predicts 0.7364 for case with 0.59 with reconstruction error 0.035883469 maximum error 0.022785919 and neighbor 0.33 and distance [69.02195159]
# Lasso predicts 0.5299 for case with 0.53 with reconstruction error 1.1707e-05 maximum error 1.2538e-05 and neighbor 0.6 and distance [62.23339129]
# Lasso predicts 0.4934 for case with 0.86 with reconstruction error 0.0572204 maximum error 0.019666657 and neighbor 0.81 and distance [65.66116547]
# Lasso predicts 0.4559 for case with 0.48 with reconstruction error 0.004359243 maximum error 0.002271781 and neighbor 0.81 and distance [58.8678159]
# Lasso predicts 0.7892 for case with 0.66 with reconstruction error 0.00298853 maximum error 0.00753185 and neighbor 0.64 and distance [73.33142833]
# Lasso predicts 0.5027 for case with 0.33 with reconstruction error 0.000129085 maximum error 0.000229255 and neighbor 0.48 and distance [68.49149372]
# Lasso predicts 0.4865 for case with 0.49 with reconstruction error 5.373e-06 maximum error 5.277e-06 and neighbor 0.86 and distance [76.90008186]
# Lasso predicts 0.7321 for case with 0.78 with reconstruction error 0.001323042 maximum error 0.034442089 and neighbor 0.66 and distance [2660814.96675177]
# Lasso predicts 0.5935 for case with 0.81 with reconstruction error 0.000332672 maximum error 0.000343796 and neighbor 0.47 and distance [55.11330113]
# Lasso predicts 0.7482 for case with 0.71 with reconstruction error 0.020167946 maximum error 0.015576216 and neighbor 0.72 and distance [54.74711489]
# Lasso predicts 0.3944 for case with 0.32 with reconstruction error 0.028264735 maximum error 0.023625522 and neighbor 0.41 and distance [77.70904259]
# Lasso predicts 0.6128 for case with 0.83 with reconstruction error 0.018995085 maximum error 0.008127711 and neighbor 0.81 and distance [56.64720358]

# %%
util.eval_prediction(np.vstack((pre_imp,
                               results_ls,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
