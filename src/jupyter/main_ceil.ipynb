# %%
# Import libraries
import warnings
import IPython
import matplotlib.pyplot as plt
import os
import numpy as np
from pathlib import Path
import scipy.stats as stats
from pylab import rcParams
import pandas as pd
import sys
sys.path.append('../')

# Import RadDBS-QSM modules
import util
import loader
import extract
import train
import memorize
import label_permute

# %%
os.environ["PYTHONWARNINGS"] = ('ignore::UserWarning')
# Find the repository path
raddbs_path = loader.get_raddbs_path(
    "/".join(IPython.extract_module_locals()[1]["__vsc_ipynb_file__"].split("/")))
nii_dir = '/data/nii/chh/orig/'

# %%
raddbs_path
# Out:
# 'c:\\Users\\agr78\\RadDBS-QSM\\'

# %%
segs = []
qsms = []
# Assuming `nii_dir` input contains subdirectories `qsm`, `seg`, and `masks`
try:
    segs,qsms,n_cases = loader.s1data(raddbs_path,nii_dir,False)
except:
    print('Using demo data')
# Add your QSM, or use default radiomic feature

# %%
# Load clinical variables
df = pd.read_csv(Path(raddbs_path+'/data/xlxs/updrs_iii_chh_cvs.csv'))
age,sex,dd,ledd,subsc,pre_updrs_off,pre_updrs_on,post_updrs_off,per_change,lct_change = loader.s1cvdata(df,segs,raddbs_path,nii_dir,False)

# %%
# Obtain the feature value matrix X, feature labels K, and ROIs R
X_all_c,K_all_c,R_all_c = extract.feature_matrix(raddbs_path,segs,qsms,subsc,reextract=0)

# %%
# Train permuter
n_perms = 10
for j in range(n_perms):
    results_max = label_permute.train_estimator(subsc,X_all_c,K_all_c,per_change,pre_updrs_on,age,sex,dd,None,'nc_iid_q',True,False,j,True)
    util.eval_prediction(np.vstack((lct_change,results_max)),per_change,['LCT','Label Permutation'],[20,5])
# Out:
# Label permutation successful
# Estimator predicts 0.45 for case with 0.72 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.0617 for case with 0.47 and selected CV 4 and 182 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7648 for case with 0.69 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6871 for case with 0.42 and selected CV 2 and 179 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7226 for case with 0.15 and selected CV 5 and 81 minority cases using random state 0 and sample size (429, 5388)
# Label permutation successful
# Estimator predicts 0.5382 for case with 0.44 and selected CV 2 and 180 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4366 for case with 0.88 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.58 for case with 0.4 and selected CV 2 and 179 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3748 for case with 0.6 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.1195 for case with 0.81 and selected CV 3 and 182 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.1009 for case with 0.64 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.506 for case with 0.72 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.2343 for case with 0.31 and selected CV 2 and 179 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.441 for case with 0.68 and selected CV 2 and 183 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4851 for case with 0.34 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.1087 for case with 0.59 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts -0.0499 for case with 0.94 and selected CV 2 and 180 minority cases using random state 0 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.7534 for case with 0.84 and selected CV 4 and 182 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6113 for case with 0.1 and selected CV 2 and 79 minority cases using random state 0 and sample size (429, 1388)
# Label permutation successful
# Estimator predicts 0.2978 for case with 0.41 and selected CV 2 and 179 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.596 for case with 0.57 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.7009 for case with 0.66 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4714 for case with 0.63 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4259 for case with 0.47 and selected CV 2 and 182 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6042 for case with 0.28 and selected CV 4 and 85 minority cases using random state 0 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.3296 for case with 0.59 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.292 for case with 0.53 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.4299 for case with 0.86 and selected CV 2 and 184 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5989 for case with 0.48 and selected CV 2 and 180 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.867 for case with 0.66 and selected CV 2 and 183 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4105 for case with 0.33 and selected CV 2 and 179 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6562 for case with 0.49 and selected CV 4 and 180 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6232 for case with 0.78 and selected CV 2 and 184 minority cases using random state 0 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4299 for case with 0.81 and selected CV 2 and 184 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6022 for case with 0.71 and selected CV 4 and 181 minority cases using random state 0 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.3573 for case with 0.32 and selected CV 2 and 181 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.35 for case with 0.83 and selected CV 2 and 182 minority cases using random state 0 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6915 for case with 0.72 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3049 for case with 0.47 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9749 for case with 0.69 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9292 for case with 0.42 and selected CV 2 and 82 minority cases using random state 1 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.4725 for case with 0.15 and selected CV 4 and 163 minority cases using random state 1 and sample size (429, 1388)
# Label permutation successful
# Estimator predicts 0.7833 for case with 0.44 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6285 for case with 0.88 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.8187 for case with 0.4 and selected CV 5 and 81 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6302 for case with 0.6 and selected CV 2 and 84 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3861 for case with 0.81 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3567 for case with 0.64 and selected CV 5 and 84 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.7357 for case with 0.72 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4674 for case with 0.31 and selected CV 4 and 80 minority cases using random state 1 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.6805 for case with 0.68 and selected CV 4 and 86 minority cases using random state 1 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.7334 for case with 0.34 and selected CV 4 and 82 minority cases using random state 1 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.3564 for case with 0.59 and selected CV 4 and 84 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.4197 for case with 0.94 and selected CV 4 and 82 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9298 for case with 0.84 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.3553 for case with 0.1 and selected CV 3 and 161 minority cases using random state 1 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.5219 for case with 0.41 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.841 for case with 0.57 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.9618 for case with 0.66 and selected CV 2 and 84 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.892 for case with 0.63 and selected CV 4 and 84 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6691 for case with 0.47 and selected CV 2 and 83 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3435 for case with 0.28 and selected CV 3 and 169 minority cases using random state 1 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.5793 for case with 0.59 and selected CV 5 and 84 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5357 for case with 0.53 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.6344 for case with 0.86 and selected CV 5 and 84 minority cases using random state 1 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.8362 for case with 0.48 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 1.2224 for case with 0.66 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6513 for case with 0.33 and selected CV 5 and 81 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.9675 for case with 0.49 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8304 for case with 0.78 and selected CV 4 and 86 minority cases using random state 1 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.6708 for case with 0.81 and selected CV 5 and 86 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.8374 for case with 0.71 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5975 for case with 0.32 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5997 for case with 0.83 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.427 for case with 0.72 and selected CV 3 and 167 minority cases using random state 2 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.023 for case with 0.47 and selected CV 3 and 162 minority cases using random state 2 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.7065 for case with 0.69 and selected CV 3 and 166 minority cases using random state 2 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.6527 for case with 0.42 and selected CV 3 and 163 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6721 for case with 0.15 and selected CV 3 and 111 minority cases using random state 2 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.5112 for case with 0.44 and selected CV 3 and 161 minority cases using random state 2 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.4618 for case with 0.88 and selected CV 5 and 167 minority cases using random state 2 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.5534 for case with 0.4 and selected CV 3 and 163 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.2444 for case with 0.6 and selected CV 5 and 164 minority cases using random state 2 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.0918 for case with 0.81 and selected CV 3 and 168 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.0857 for case with 0.64 and selected CV 3 and 164 minority cases using random state 2 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.4717 for case with 0.72 and selected CV 3 and 167 minority cases using random state 2 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.1989 for case with 0.31 and selected CV 3 and 160 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4174 for case with 0.68 and selected CV 3 and 164 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5577 for case with 0.34 and selected CV 3 and 159 minority cases using random state 2 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.0582 for case with 0.59 and selected CV 5 and 164 minority cases using random state 2 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.107 for case with 0.94 and selected CV 3 and 164 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6564 for case with 0.84 and selected CV 3 and 166 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5422 for case with 0.1 and selected CV 2 and 101 minority cases using random state 2 and sample size (429, 3388)
# Label permutation successful
# Estimator predicts 0.3602 for case with 0.41 and selected CV 2 and 163 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6541 for case with 0.57 and selected CV 3 and 166 minority cases using random state 2 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.7106 for case with 0.66 and selected CV 3 and 164 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4126 for case with 0.63 and selected CV 2 and 164 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.393 for case with 0.47 and selected CV 3 and 162 minority cases using random state 2 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.5435 for case with 0.28 and selected CV 4 and 118 minority cases using random state 2 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.2772 for case with 0.59 and selected CV 3 and 164 minority cases using random state 2 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.2424 for case with 0.53 and selected CV 4 and 164 minority cases using random state 2 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3648 for case with 0.86 and selected CV 3 and 165 minority cases using random state 2 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.5713 for case with 0.48 and selected CV 5 and 164 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7914 for case with 0.66 and selected CV 2 and 164 minority cases using random state 2 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3868 for case with 0.33 and selected CV 3 and 161 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.2869 for case with 0.49 and selected CV 4 and 164 minority cases using random state 2 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.5879 for case with 0.78 and selected CV 3 and 166 minority cases using random state 2 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.4061 for case with 0.81 and selected CV 2 and 166 minority cases using random state 2 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4718 for case with 0.71 and selected CV 5 and 165 minority cases using random state 2 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.2841 for case with 0.32 and selected CV 3 and 158 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3415 for case with 0.83 and selected CV 3 and 168 minority cases using random state 2 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6295 for case with 0.72 and selected CV 4 and 113 minority cases using random state 3 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.2358 for case with 0.47 and selected CV 4 and 106 minority cases using random state 3 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.9202 for case with 0.69 and selected CV 2 and 112 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.8691 for case with 0.42 and selected CV 4 and 112 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5677 for case with 0.15 and selected CV 2 and 118 minority cases using random state 3 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.7302 for case with 0.44 and selected CV 4 and 112 minority cases using random state 3 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.665 for case with 0.88 and selected CV 2 and 114 minority cases using random state 3 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.7647 for case with 0.4 and selected CV 2 and 112 minority cases using random state 3 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.5625 for case with 0.6 and selected CV 5 and 113 minority cases using random state 3 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.309 for case with 0.81 and selected CV 2 and 114 minority cases using random state 3 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.293 for case with 0.64 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6774 for case with 0.72 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4033 for case with 0.31 and selected CV 4 and 112 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6305 for case with 0.68 and selected CV 2 and 106 minority cases using random state 3 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.7083 for case with 0.34 and selected CV 2 and 106 minority cases using random state 3 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.297 for case with 0.59 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2693 for case with 0.94 and selected CV 3 and 111 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.8797 for case with 0.84 and selected CV 2 and 114 minority cases using random state 3 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4564 for case with 0.1 and selected CV 2 and 112 minority cases using random state 3 and sample size (429, 4388)
# Label permutation successful
# Estimator predicts 0.4647 for case with 0.41 and selected CV 2 and 112 minority cases using random state 3 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6 for case with 0.57 and selected CV 4 and 113 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9153 for case with 0.66 and selected CV 4 and 113 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5764 for case with 0.63 and selected CV 3 and 113 minority cases using random state 3 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.5677 for case with 0.47 and selected CV 4 and 107 minority cases using random state 3 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4409 for case with 0.28 and selected CV 2 and 120 minority cases using random state 3 and sample size (429, 3388)
# Label permutation successful
# Estimator predicts 0.5537 for case with 0.59 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4805 for case with 0.53 and selected CV 4 and 113 minority cases using random state 3 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.5646 for case with 0.86 and selected CV 5 and 108 minority cases using random state 3 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.7312 for case with 0.48 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 1.1967 for case with 0.66 and selected CV 4 and 107 minority cases using random state 3 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.5913 for case with 0.33 and selected CV 3 and 112 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7605 for case with 0.49 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7972 for case with 0.78 and selected CV 3 and 108 minority cases using random state 3 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.611 for case with 0.81 and selected CV 4 and 108 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7587 for case with 0.71 and selected CV 2 and 113 minority cases using random state 3 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.5488 for case with 0.32 and selected CV 4 and 106 minority cases using random state 3 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5362 for case with 0.83 and selected CV 2 and 114 minority cases using random state 3 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.6857 for case with 0.72 and selected CV 4 and 82 minority cases using random state 4 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.2926 for case with 0.47 and selected CV 5 and 78 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.9736 for case with 0.69 and selected CV 5 and 82 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9237 for case with 0.42 and selected CV 5 and 80 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7391 for case with 0.15 and selected CV 3 and 89 minority cases using random state 4 and sample size (429, 2388)
# Label permutation successful
# Estimator predicts 0.7651 for case with 0.44 and selected CV 5 and 81 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.8773 for case with 0.88 and selected CV 4 and 81 minority cases using random state 4 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.8153 for case with 0.4 and selected CV 5 and 80 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5988 for case with 0.6 and selected CV 4 and 81 minority cases using random state 4 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.3732 for case with 0.81 and selected CV 4 and 81 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3347 for case with 0.64 and selected CV 5 and 82 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7265 for case with 0.72 and selected CV 5 and 82 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4559 for case with 0.31 and selected CV 5 and 78 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.6844 for case with 0.68 and selected CV 4 and 78 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7564 for case with 0.34 and selected CV 5 and 75 minority cases using random state 4 and sample size (418, 3388)
# Label permutation successful
# Skipping split 5 feature elimination failed
# Estimator predicts 0.3722 for case with 0.59 and selected CV 2 and 81 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3024 for case with 0.94 and selected CV 4 and 81 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.9301 for case with 0.84 and selected CV 5 and 81 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6189 for case with 0.1 and selected CV 3 and 89 minority cases using random state 4 and sample size (429, 4388)
# Label permutation successful
# Estimator predicts 0.58 for case with 0.41 and selected CV 4 and 80 minority cases using random state 4 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.8403 for case with 0.57 and selected CV 5 and 81 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.9615 for case with 0.66 and selected CV 5 and 82 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.6184 for case with 0.63 and selected CV 2 and 82 minority cases using random state 4 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.6151 for case with 0.47 and selected CV 5 and 78 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.6952 for case with 0.28 and selected CV 2 and 91 minority cases using random state 4 and sample size (429, 2388)
# Label permutation successful
# Estimator predicts 0.5574 for case with 0.59 and selected CV 5 and 79 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5173 for case with 0.53 and selected CV 4 and 82 minority cases using random state 4 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.6205 for case with 0.86 and selected CV 2 and 77 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7861 for case with 0.48 and selected CV 4 and 82 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 1.2439 for case with 0.66 and selected CV 5 and 78 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Skipping split 5 feature elimination failed
# Estimator predicts 0.6613 for case with 0.33 and selected CV 4 and 79 minority cases using random state 4 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 1.1702 for case with 0.49 and selected CV 5 and 82 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.8563 for case with 0.78 and selected CV 5 and 77 minority cases using random state 4 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.6636 for case with 0.81 and selected CV 5 and 77 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.71 for case with 0.71 and selected CV 4 and 82 minority cases using random state 4 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5522 for case with 0.32 and selected CV 5 and 75 minority cases using random state 4 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.5884 for case with 0.83 and selected CV 5 and 81 minority cases using random state 4 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7272 for case with 0.72 and selected CV 4 and 91 minority cases using random state 5 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.3274 for case with 0.47 and selected CV 3 and 87 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9384 for case with 0.69 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8976 for case with 0.42 and selected CV 2 and 87 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4914 for case with 0.15 and selected CV 3 and 166 minority cases using random state 5 and sample size (429, 5388)
# Label permutation successful
# Estimator predicts 0.7931 for case with 0.44 and selected CV 3 and 87 minority cases using random state 5 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.7902 for case with 0.88 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.8484 for case with 0.4 and selected CV 3 and 87 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6699 for case with 0.6 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3928 for case with 0.81 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3789 for case with 0.64 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.7573 for case with 0.72 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4977 for case with 0.31 and selected CV 3 and 85 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7209 for case with 0.68 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7226 for case with 0.34 and selected CV 3 and 86 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3843 for case with 0.59 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.486 for case with 0.94 and selected CV 4 and 91 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9599 for case with 0.84 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4944 for case with 0.1 and selected CV 4 and 162 minority cases using random state 5 and sample size (429, 3388)
# Label permutation successful
# Estimator predicts 0.6159 for case with 0.41 and selected CV 3 and 87 minority cases using random state 5 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.8822 for case with 0.57 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.9396 for case with 0.66 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.784 for case with 0.63 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6736 for case with 0.47 and selected CV 3 and 87 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3454 for case with 0.28 and selected CV 3 and 170 minority cases using random state 5 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.5869 for case with 0.59 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5287 for case with 0.53 and selected CV 3 and 88 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6417 for case with 0.86 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8056 for case with 0.48 and selected CV 5 and 87 minority cases using random state 5 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 1.257 for case with 0.66 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.6903 for case with 0.33 and selected CV 2 and 86 minority cases using random state 5 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.8482 for case with 0.49 and selected CV 3 and 88 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.869 for case with 0.78 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.695 for case with 0.81 and selected CV 3 and 91 minority cases using random state 5 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.7416 for case with 0.71 and selected CV 4 and 91 minority cases using random state 5 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6496 for case with 0.32 and selected CV 3 and 85 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6055 for case with 0.83 and selected CV 2 and 91 minority cases using random state 5 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8549 for case with 0.72 and selected CV 4 and 63 minority cases using random state 6 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.4465 for case with 0.47 and selected CV 4 and 61 minority cases using random state 6 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 1.0884 for case with 0.69 and selected CV 2 and 63 minority cases using random state 6 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 1.0539 for case with 0.42 and selected CV 2 and 61 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7703 for case with 0.15 and selected CV 4 and 106 minority cases using random state 6 and sample size (429, 1388)
# Label permutation successful
# Estimator predicts 0.9284 for case with 0.44 and selected CV 4 and 61 minority cases using random state 6 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.834 for case with 0.88 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9782 for case with 0.4 and selected CV 2 and 59 minority cases using random state 6 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.8004 for case with 0.6 and selected CV 3 and 63 minority cases using random state 6 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.512 for case with 0.81 and selected CV 4 and 62 minority cases using random state 6 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5101 for case with 0.64 and selected CV 4 and 62 minority cases using random state 6 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.8944 for case with 0.72 and selected CV 2 and 63 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6194 for case with 0.31 and selected CV 4 and 58 minority cases using random state 6 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.8451 for case with 0.68 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 1.0284 for case with 0.34 and selected CV 3 and 57 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5128 for case with 0.59 and selected CV 4 and 63 minority cases using random state 6 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.442 for case with 0.94 and selected CV 4 and 60 minority cases using random state 6 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 1.1002 for case with 0.84 and selected CV 3 and 61 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6142 for case with 0.1 and selected CV 2 and 104 minority cases using random state 6 and sample size (429, 3388)
# Label permutation successful
# Estimator predicts 0.6736 for case with 0.41 and selected CV 2 and 60 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 1.0261 for case with 0.57 and selected CV 2 and 64 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 1.0944 for case with 0.66 and selected CV 4 and 62 minority cases using random state 6 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.78 for case with 0.63 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.8034 for case with 0.47 and selected CV 4 and 61 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.617 for case with 0.28 and selected CV 3 and 108 minority cases using random state 6 and sample size (429, 6388)
# Label permutation successful
# Estimator predicts 0.7521 for case with 0.59 and selected CV 2 and 63 minority cases using random state 6 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.6592 for case with 0.53 and selected CV 3 and 64 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7694 for case with 0.86 and selected CV 4 and 61 minority cases using random state 6 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9173 for case with 0.48 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 1.403 for case with 0.66 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.815 for case with 0.33 and selected CV 2 and 58 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 1.045 for case with 0.49 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.9856 for case with 0.78 and selected CV 2 and 61 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8223 for case with 0.81 and selected CV 2 and 61 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.899 for case with 0.71 and selected CV 3 and 62 minority cases using random state 6 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.7664 for case with 0.32 and selected CV 2 and 57 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7445 for case with 0.83 and selected CV 2 and 62 minority cases using random state 6 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5965 for case with 0.72 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2358 for case with 0.47 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.8655 for case with 0.69 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8344 for case with 0.42 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4479 for case with 0.15 and selected CV 3 and 186 minority cases using random state 7 and sample size (429, 388)
# Label permutation successful
# Estimator predicts 0.688 for case with 0.44 and selected CV 4 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5512 for case with 0.88 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7198 for case with 0.4 and selected CV 2 and 133 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4868 for case with 0.6 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2772 for case with 0.81 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.2457 for case with 0.64 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6165 for case with 0.72 and selected CV 3 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3746 for case with 0.31 and selected CV 2 and 131 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5864 for case with 0.68 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7174 for case with 0.34 and selected CV 5 and 132 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2988 for case with 0.59 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2947 for case with 0.94 and selected CV 2 and 131 minority cases using random state 7 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.8013 for case with 0.84 and selected CV 3 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3518 for case with 0.1 and selected CV 3 and 183 minority cases using random state 7 and sample size (429, 1388)
# Label permutation successful
# Estimator predicts 0.4442 for case with 0.41 and selected CV 4 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7517 for case with 0.57 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8795 for case with 0.66 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.6037 for case with 0.63 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5493 for case with 0.47 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2542 for case with 0.28 and selected CV 2 and 192 minority cases using random state 7 and sample size (429, 388)
# Label permutation successful
# Estimator predicts 0.5185 for case with 0.59 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4323 for case with 0.53 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5323 for case with 0.86 and selected CV 4 and 134 minority cases using random state 7 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.7249 for case with 0.48 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.9874 for case with 0.66 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.5569 for case with 0.33 and selected CV 4 and 132 minority cases using random state 7 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.9099 for case with 0.49 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7069 for case with 0.78 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5631 for case with 0.81 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7165 for case with 0.71 and selected CV 2 and 130 minority cases using random state 7 and sample size (418, 5388)
# Label permutation successful
# Estimator predicts 0.4981 for case with 0.32 and selected CV 2 and 132 minority cases using random state 7 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4926 for case with 0.83 and selected CV 2 and 134 minority cases using random state 7 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.323 for case with 0.72 and selected CV 3 and 189 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts -0.0678 for case with 0.47 and selected CV 2 and 185 minority cases using random state 8 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.6164 for case with 0.69 and selected CV 2 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5756 for case with 0.42 and selected CV 2 and 186 minority cases using random state 8 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.5657 for case with 0.15 and selected CV 4 and 136 minority cases using random state 8 and sample size (429, 388)
# Label permutation successful
# Estimator predicts 0.4214 for case with 0.44 and selected CV 5 and 185 minority cases using random state 8 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3649 for case with 0.88 and selected CV 3 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4692 for case with 0.4 and selected CV 3 and 186 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.1817 for case with 0.6 and selected CV 3 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.0015 for case with 0.81 and selected CV 3 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts -0.0044 for case with 0.64 and selected CV 3 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3766 for case with 0.72 and selected CV 3 and 189 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.119 for case with 0.31 and selected CV 2 and 185 minority cases using random state 8 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.3327 for case with 0.68 and selected CV 3 and 187 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5072 for case with 0.34 and selected CV 2 and 184 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.0013 for case with 0.59 and selected CV 3 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts -0.0111 for case with 0.94 and selected CV 3 and 185 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6006 for case with 0.84 and selected CV 2 and 186 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5742 for case with 0.1 and selected CV 2 and 136 minority cases using random state 8 and sample size (429, 1388)
# Label permutation successful
# Estimator predicts 0.1549 for case with 0.41 and selected CV 3 and 186 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4714 for case with 0.57 and selected CV 3 and 189 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6216 for case with 0.66 and selected CV 3 and 186 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2221 for case with 0.63 and selected CV 3 and 187 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3089 for case with 0.47 and selected CV 2 and 186 minority cases using random state 8 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4046 for case with 0.28 and selected CV 2 and 141 minority cases using random state 8 and sample size (429, 388)
# Label permutation successful
# Estimator predicts 0.2229 for case with 0.59 and selected CV 5 and 187 minority cases using random state 8 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.1686 for case with 0.53 and selected CV 2 and 189 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2691 for case with 0.86 and selected CV 2 and 187 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Best CV fit failed, using max
# Estimator predicts 0.5381 for case with 0.48 and selected CV 4 and 187 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7035 for case with 0.66 and selected CV 4 and 187 minority cases using random state 8 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.3021 for case with 0.33 and selected CV 3 and 185 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3613 for case with 0.49 and selected CV 4 and 188 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4995 for case with 0.78 and selected CV 3 and 187 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3144 for case with 0.81 and selected CV 3 and 186 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4419 for case with 0.71 and selected CV 5 and 186 minority cases using random state 8 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.2483 for case with 0.32 and selected CV 3 and 183 minority cases using random state 8 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.2534 for case with 0.83 and selected CV 3 and 188 minority cases using random state 8 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.4939 for case with 0.72 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.0929 for case with 0.47 and selected CV 5 and 138 minority cases using random state 9 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.8367 for case with 0.69 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7406 for case with 0.42 and selected CV 2 and 135 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7893 for case with 0.15 and selected CV 3 and 49 minority cases using random state 9 and sample size (429, 5388)
# Label permutation successful
# Estimator predicts 0.583 for case with 0.44 and selected CV 2 and 136 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5193 for case with 0.88 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.6318 for case with 0.4 and selected CV 2 and 135 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4063 for case with 0.6 and selected CV 5 and 141 minority cases using random state 9 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.1727 for case with 0.81 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.1632 for case with 0.64 and selected CV 2 and 141 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.5503 for case with 0.72 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.2772 for case with 0.31 and selected CV 2 and 132 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Skipping split 3 feature elimination failed
# Estimator predicts 0.4947 for case with 0.68 and selected CV 2 and 140 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6563 for case with 0.34 and selected CV 5 and 133 minority cases using random state 9 and sample size (418, 3388)
# Label permutation successful
# Estimator predicts 0.1849 for case with 0.59 and selected CV 5 and 141 minority cases using random state 9 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.1427 for case with 0.94 and selected CV 2 and 137 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.8296 for case with 0.84 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6876 for case with 0.1 and selected CV 3 and 49 minority cases using random state 9 and sample size (429, 3388)
# Label permutation successful
# Estimator predicts 0.3548 for case with 0.41 and selected CV 2 and 135 minority cases using random state 9 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.6331 for case with 0.57 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7888 for case with 0.66 and selected CV 2 and 141 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.593 for case with 0.63 and selected CV 3 and 141 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4783 for case with 0.47 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7031 for case with 0.28 and selected CV 5 and 55 minority cases using random state 9 and sample size (429, 388)
# Label permutation successful
# Estimator predicts 0.34 for case with 0.59 and selected CV 3 and 141 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.3497 for case with 0.53 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4502 for case with 0.86 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6568 for case with 0.48 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 1.0657 for case with 0.66 and selected CV 2 and 140 minority cases using random state 9 and sample size (418, 6388)
# Label permutation successful
# Estimator predicts 0.4651 for case with 0.33 and selected CV 2 and 133 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.7269 for case with 0.49 and selected CV 2 and 139 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.6394 for case with 0.78 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 4388)
# Label permutation successful
# Estimator predicts 0.4882 for case with 0.81 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 1388)
# Label permutation successful
# Estimator predicts 0.6405 for case with 0.71 and selected CV 5 and 139 minority cases using random state 9 and sample size (418, 2388)
# Label permutation successful
# Estimator predicts 0.3823 for case with 0.32 and selected CV 2 and 132 minority cases using random state 9 and sample size (418, 388)
# Label permutation successful
# Estimator predicts 0.4182 for case with 0.83 and selected CV 2 and 138 minority cases using random state 9 and sample size (418, 388)

# %%
# Train memorizer
results_max = memorize.train_memorizer(subsc,X_all_c,K_all_c,per_change,pre_updrs_on,age,sex,dd,None,'nc_iid_q',True,False,1,True)
util.eval_prediction(np.vstack((lct_change,results_max)),per_change,['LCT','Theoretical Ceiling'],[20,5])
# Out:
# Estimator predicts 0.8061 for case with 0.72 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5693 for case with 0.47 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.7829 for case with 0.69 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5208 for case with 0.42 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.2465 for case with 0.15 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5355 for case with 0.44 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.9607 for case with 0.88 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.4921 for case with 0.4 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.6859 for case with 0.6 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.8819 for case with 0.81 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.7381 for case with 0.64 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.8003 for case with 0.72 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.4132 for case with 0.31 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.7629 for case with 0.68 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.4344 for case with 0.34 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.6698 for case with 0.59 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 1.0147 for case with 0.94 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.9262 for case with 0.84 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.1935 for case with 0.1 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5128 for case with 0.41 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.6717 for case with 0.57 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.7503 for case with 0.66 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.7172 for case with 0.63 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5735 for case with 0.47 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.3854 for case with 0.28 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.6932 for case with 0.59 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.6273 for case with 0.53 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.9382 for case with 0.86 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5726 for case with 0.48 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.7482 for case with 0.66 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.4388 for case with 0.33 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.5886 for case with 0.49 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.8676 for case with 0.78 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.8853 for case with 0.81 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.8038 for case with 0.71 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.4223 for case with 0.32 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)
# Estimator predicts 0.9095 for case with 0.83 and selected CV 5 and 86 minority cases using random state 1 and sample size (429, 388)

# %%
# Train estimator
results_ls_aug = train.train_estimator(subsc,X_all_c,K_all_c,per_change,pre_updrs_on,age,sex,dd,None,'nc_iid_q',True,True,1,True)
util.eval_prediction(np.vstack((lct_change,results_ls_aug)),per_change,['LCT','Noise compensated Lasso'],[20,5])
# Out:
# Estimator predicts 0.7741 for case with 0.72 and selected CV 4 and 86 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.591 for case with 0.47 and selected CV 4 and 83 minority cases using random state 1 and sample size (418, 2388)
# Estimator predicts 0.8701 for case with 0.69 and selected CV 2 and 86 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.7329 for case with 0.42 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.2717 for case with 0.15 and selected CV 3 and 163 minority cases using random state 1 and sample size (429, 6388)
# Estimator predicts 0.577 for case with 0.44 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.8324 for case with 0.88 and selected CV 5 and 84 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.509 for case with 0.4 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.6765 for case with 0.6 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 1388)
# Estimator predicts 0.6006 for case with 0.81 and selected CV 4 and 86 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.8379 for case with 0.64 and selected CV 2 and 85 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.6838 for case with 0.72 and selected CV 5 and 86 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.7092 for case with 0.31 and selected CV 5 and 81 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.5932 for case with 0.68 and selected CV 5 and 86 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.4701 for case with 0.34 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.5578 for case with 0.59 and selected CV 5 and 85 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.7552 for case with 0.94 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.7711 for case with 0.84 and selected CV 4 and 86 minority cases using random state 1 and sample size (418, 1388)
# Estimator predicts 0.1116 for case with 0.1 and selected CV 3 and 163 minority cases using random state 1 and sample size (429, 6388)
# Estimator predicts 0.5413 for case with 0.41 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.7158 for case with 0.57 and selected CV 5 and 84 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.8314 for case with 0.66 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.6896 for case with 0.63 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.6854 for case with 0.47 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.2105 for case with 0.28 and selected CV 3 and 169 minority cases using random state 1 and sample size (429, 6388)
# Estimator predicts 0.7496 for case with 0.59 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.7419 for case with 0.53 and selected CV 5 and 84 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.7113 for case with 0.86 and selected CV 4 and 84 minority cases using random state 1 and sample size (418, 5388)
# Estimator predicts 0.562 for case with 0.48 and selected CV 5 and 83 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.7217 for case with 0.66 and selected CV 4 and 85 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.6233 for case with 0.33 and selected CV 5 and 82 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.5251 for case with 0.49 and selected CV 2 and 84 minority cases using random state 1 and sample size (418, 1388)
# Estimator predicts 0.8203 for case with 0.78 and selected CV 5 and 86 minority cases using random state 1 and sample size (418, 6388)
# Estimator predicts 0.6905 for case with 0.81 and selected CV 5 and 86 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.7937 for case with 0.71 and selected CV 5 and 86 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.5566 for case with 0.32 and selected CV 4 and 82 minority cases using random state 1 and sample size (418, 388)
# Estimator predicts 0.8209 for case with 0.83 and selected CV 4 and 86 minority cases using random state 1 and sample size (418, 3388)
