# %%
import sys
sys.path.append('../')
import torchio as tio
from torchvision.utils import make_grid
from torch.optim import Adam
from torch.autograd import Variable
import torch.cuda as cuda
import torch.nn as nn
import torch
from torch.distributions import Normal
from mlp.datasets import QSM_slices
import os
import numpy as np
import util
import sklearn.preprocessing as skp
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
# Get case IDs
case_list = open('/home/ali/RadDBS-QSM/data/docs/cases_90','r')
lines = case_list.read()
lists = np.loadtxt(case_list.name,comments="#", delimiter=",",unpack=False,dtype=str)
case_id = []
for lines in lists:     
    case_id.append(lines[-9:-7])

# Load scores
file_dir = '/home/ali/RadDBS-QSM/data/docs/QSM anonymus- 6.22.2023-1528_wldd.csv'
motor_df = util.filter_scores(file_dir,'pre-dbs updrs','stim','pre op levadopa equivalent dose (mg)','CORNELL ID')
# Find cases with all required scores
subs,pre_imp,post_imp,pre_updrs_off,ledd = util.get_full_cases(motor_df,
                                                          'CORNELL ID',
                                                          'OFF (pre-dbs updrs)',
                                                          'ON (pre-dbs updrs)',
                                                          'OFF meds ON stim 6mo',
                                                          'pre op levadopa equivalent dose (mg)')
print(ledd)
# Load extracted features
npy_dir = '/home/ali/RadDBS-QSM/data/npy/'
phi_dir = '/home/ali/RadDBS-QSM/data/phi/phi/'
roi_path = '/data/Ali/atlas/mcgill_pd_atlas/PD25-subcortical-labels.csv'
n_rois = 6
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595,False)
ids = np.asarray(ID_all).astype(int)

# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(case_id).astype(int),np.asarray(subs).astype(int))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
X_all_c = X_all[c_cases_idx,0:4,:]
K_all_c = K_all[c_cases_idx,0:4,:]
R_all_c = R_all[c_cases_idx,0:4,:]
# Re-index the scored subjects with respect to complete cases
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
subs_init = subs[s_cases_idx]
pre_imp_init = pre_imp[s_cases_idx]
post_imp_init = post_imp[s_cases_idx]
pre_updrs_off_init = pre_updrs_off[s_cases_idx]
ledd_init = ledd[s_cases_idx]
per_change_init = post_imp_init
subs = np.asarray(ID_all,dtype=float)[np.in1d(np.asarray(ID_all,dtype=float),subs_init)]
subs0 = subs_init
pre_imp = np.zeros((1,len(subs))).T
post_imp = np.zeros((1,len(subs))).T
pre_updrs_off = np.zeros((1,len(subs))).T
ledd = np.zeros((1,len(subs))).T
per_change = np.zeros((1,len(subs))).T
for j in np.arange(len(subs)):
    pre_imp[j] = pre_imp_init[subs_init == subs[j]]
    post_imp[j] = post_imp_init[subs_init == subs[j]]
    pre_updrs_off[j] = pre_updrs_off_init[subs_init == subs[j]]
    ledd[j] = ledd_init[subs_init == subs[j]]
    per_change[j] = per_change_init[subs_init == subs[j]]

subsc = subs
X_all_c = X_all_c.reshape(X_all_c.shape[0],-1)
X_all_c = np.append(X_all_c,pre_updrs_off,axis=1)
X_all_c = np.append(X_all_c,ledd,axis=1)
print(np.unique(R_all_c))
# Out:
#        Unnamed: 0                PRE-OP           Unnamed: 2  \
# 0      CORNELL ID  Apathy Off (pre-dbs)  Apathy ON (pre-dbs)
# 1              67                    na                   13
# 2   only Ct data                     na                   na
# 3              74                    na                   na
# 4              84                    na                   22
# ..            ...                   ...                  ...
# 87             52                   NaN                  NaN
# 88             53                   NaN                  NaN
# 89             54                   NaN                  NaN
# 90             55                   NaN                  NaN
# 91             56                   NaN                  NaN
#
#              Unnamed: 3          Unnamed: 4    Unnamed: 5  \
# 0   OFF (pre-dbs updrs)  ON (pre-dbs updrs)  mri (pre-op)
# 1                    60                  41      3/9/2020
# 2                    43                  12            na
# 3                    34                  11     2/10/2020
# 4                    53                  13      6/1/2020
# ..                  ...                 ...           ...
# 87                   58                  27           NaN
# 88                   77                  47           NaN
# 89                   63                  36           NaN
# 90                   40                  29           NaN
# 91                   81                  20           NaN
#
#                               Unnamed: 6                  POST-OP (6 MONTHS)  \
# 0   pre op levadopa equivalent dose (mg)  6 mo levadopa equivalent dose (mg)
# 1                                    500                                 500
# 2                                   2304                                 819
# 3                                   1200                                 600
# 4                                    350                                 150
# ..                                   ...                                 ...
# 87                                  1804                                1804
# 88                                   575                                 250
# 89                                  1400                                 400
# 90                                   400                                 450
# 91                                  2162                                1050
#
#               Unnamed: 8           Unnamed: 9          Unnamed: 10  \
# 0   OFF meds ON stim 6mo  ON meds ON stim 6mo  off stim on med 6mo
# 1                     31                   29                  NaN
# 2                     na                   20                   18
# 3                     na                   17                   na
# 4                     na                   34                   na
# ..                   ...                  ...                  ...
# 87                    19                   12                  NaN
# 88                   NaN                   19                   26
# 89                     8                  NaN                  NaN
# 90                   NaN                   13                  NaN
# 91                   NaN                    7                  NaN
#
#              Unnamed: 11     Unnamed: 12     Unnamed: 13 Unnamed: 14
# 0   off stim off med 6mo  apathy off 6mo  apathy on 6 mo        ledd
# 1                    NaN              na              na         NaN
# 2                    NaN              na              na         NaN
# 3                    NaN              na              na     1021.00
# 4                    NaN              na              na         NaN
# ..                   ...             ...             ...         ...
# 87                   NaN             NaN             NaN      500.00
# 88                   NaN             NaN             NaN      100.00
# 89                   NaN             NaN             NaN      550.00
# 90                    37             NaN             NaN      400.00
# 91                   NaN             NaN             NaN         NaN
#
# [92 rows x 15 columns]
#        CORNELL ID OFF (pre-dbs updrs) ON (pre-dbs updrs)  \
# 1              67                  60                 41
# 2   only Ct data                   43                 12
# 3              74                  34                 11
# 4              84                  53                 13
# 5              75                  62                  8
# ..            ...                 ...                ...
# 87             52                  58                 27
# 88             53                  77                 47
# 89             54                  63                 36
# 90             55                  40                 29
# 91             56                  81                 20
#
#    pre op levadopa equivalent dose (mg) OFF meds ON stim 6mo  \
# 1                                   500                   31
# 2                                  2304                  NaN
# 3                                  1200                  NaN
# 4                                   350                  NaN
# 5                                     0                    2
# ..                                  ...                  ...
# 87                                 1804                   19
# 88                                  575                  NaN
# 89                                 1400                    8
# 90                                  400                  NaN
# 91                                 2162                  NaN
#
#    ON meds ON stim 6mo  off stim on med 6mo  off stim off med 6mo
# 1                   29                  NaN                   NaN
# 2                   20                   18                   NaN
# 3                   17                  NaN                   NaN
# 4                   34                  NaN                   NaN
# 5                  NaN                  NaN                   NaN
# ..                 ...                  ...                   ...
# 87                  12                  NaN                   NaN
# 88                  19                   26                   NaN
# 89                 NaN                  NaN                   NaN
# 90                  13                  NaN                    37
# 91                   7                  NaN                   NaN
#
# [91 rows x 8 columns]
# [ 500.     0.   900.   700.   988.   902.   450.  1401.   900.   712.
#  1950.  1300.  1400.   875.   949.  1100.  1427.   325.  1924.  1000.
#   800.  1700.  1866.   875.  1506.  1404.   181.8 1200.   750.   200.
#  1153.  2088.   369.5  798.  1719.     0.   450.  2269.   600.  1032.
#  1625.   400.  1230.   849.   360.  1064.   456.   600.   100.   711.
#  1804.  1400. ]
# Allocated arrays
# Created feature matrix
# Created ROI matrix
# Created feature label matrix
# ['Left red nucleus' 'Left substantia nigra' 'Right Substantia nigra'
#  'Right red nucleus']

# %%
data_dir = os.listdir('../mlp/tensor_slices_0')
scaler = skp.StandardScaler()
X = scaler.fit_transform(X_all_c)
train_dataset = QSM_slices(data_dir=data_dir,aug_state=1, factor=0, X=X,subsc=subsc,targets=per_change,prefix='../mlp/')
data_loader = DataLoader(train_dataset, batch_size=X.shape[0], shuffle=True)
img_size = 64 # Image size
batch_size = X.shape[0]//2  # Batch size

# Model
device = 'cuda' if torch.cuda.is_available() else 'cpu'
z_size = 512
generator_layer_size = [512, 1024, 2048]
discriminator_layer_size = [2048, 1024, 512]
N = len(np.unique(np.round(per_change,1)))
# Training
epochs = 1000
learning_rate = 1e-4

# %%
class Generator(nn.Module):
    
    def __init__(self, generator_layer_size, z_size, img_size):
        super().__init__()
        
        self.z_size = z_size
        self.img_size = img_size
        
        self.model = nn.Sequential(
            nn.Linear(self.z_size, generator_layer_size[0]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(generator_layer_size[0], generator_layer_size[1]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(generator_layer_size[1], generator_layer_size[2]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(generator_layer_size[2], self.img_size * self.img_size),
            nn.Tanh()
        )
    
    def forward(self, z):
        
        # Reshape z
        z = z.view(-1, self.z_size)
        x = z
  
        # Generator out
        out = self.model(x)
        
        return out.view(-1, self.img_size, self.img_size)

# %%
class Discriminator(nn.Module):
    
    def __init__(self, discriminator_layer_size, img_size):
        super().__init__()
        
        self.img_size = img_size
        
        self.model = nn.Sequential(
            nn.Linear(self.img_size * self.img_size, discriminator_layer_size[0]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Linear(discriminator_layer_size[0], discriminator_layer_size[1]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Linear(discriminator_layer_size[1], discriminator_layer_size[2]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout(0.3),
            nn.Linear(discriminator_layer_size[2], 1),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        
        # Reshape fake image
        x = x.view(-1, self.img_size * self.img_size)
        # Discriminator out
        out = self.model(x)
        
        return out.squeeze()

# %%
# Define generator
generator = Generator(generator_layer_size, z_size, img_size).to(device)
# Define discriminator
discriminator = Discriminator(discriminator_layer_size, img_size).to(device)
# Loss function
criterion = nn.BCELoss()

# %%
# Optimizer
g_optimizer = torch.optim.Adam(generator.parameters(), lr=learning_rate)
d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=learning_rate)

# %%
def generator_train_step(batch_size, discriminator, generator, g_optimizer, criterion):
    
    # Init gradient
    g_optimizer.zero_grad()
    
    # Building z
    z = Variable(torch.randn(batch_size, z_size)).to(device)
    
    # Generating fake images
    fake_images = generator(z)
    
    # Disciminating fake images
    validity = discriminator(fake_images)
    
    # Calculating discrimination loss (fake images)
    g_loss = criterion(validity, Variable(torch.ones(batch_size)).to(device))
    
    # Backword propagation
    g_loss.backward()
    
    #  Optimizing generator
    g_optimizer.step()
    
    return g_loss.data

# %%
def discriminator_train_step(batch_size, discriminator, generator, d_optimizer, criterion, real_images):
    
    # Init gradient 
    d_optimizer.zero_grad()

    # Disciminating real images
    real_validity = discriminator(real_images)
    
    # Calculating discrimination loss (real images)
    real_loss = criterion(real_validity, Variable(torch.ones(batch_size)).to(device))
    
    # Building z
    z = Variable(torch.randn(batch_size, z_size)).to(device)
    
    # Generating fake images
    fake_images = generator(z)
    
    # Disciminating fake images
    fake_validity = discriminator(fake_images)
    
    # Calculating discrimination loss (fake images)
    fake_loss = criterion(fake_validity, Variable(torch.zeros(batch_size)).to(device))
    
    # Sum two losses
    d_loss = real_loss + fake_loss
    
    # Backword propagation
    d_loss.backward()
    
    # Optimizing discriminator
    d_optimizer.step()
    
    return d_loss.data

# %%
snr = 1.0
for epoch in range(epochs):
    
    print('Starting epoch {}...'.format(epoch+1))
    
    for i, (images, X, labels) in enumerate(data_loader):
        
        # Train data with noise

        real_images = ((Variable(images).to(device))/torch.amax(images))+(0.99)**(epoch//2)*(1/snr)*(torch.randn(images.shape).to(device))
        labels = Variable(labels).to(device)
        
        # Set generator train
        generator.train()
        
        # Train discriminator
        d_loss = discriminator_train_step(len(real_images), discriminator,
                                          generator, d_optimizer, criterion,
                                          real_images)
        
        # Train generator
        g_loss = generator_train_step(batch_size, discriminator, generator, g_optimizer, criterion)
    
    # Set generator eval
    generator.eval()
    
    print('g_loss: {:.5}, d_loss: {:.5}, generated image SNR {:.5}'.format(g_loss, d_loss, snr))
    
    # Building z 
    z = Variable(torch.randn(len(data_loader.dataset), z_size)).to(device)

    # Generating images
    sample_images = generator(z).unsqueeze(1).data.cpu()
    snr = torch.mean(sample_images)/torch.var(sample_images)

sample_images = sample_images/torch.amax(sample_images)
real_images_out = real_images/torch.amax(real_images)
# Out:
# Starting epoch 1...
# g_loss: 2.2513, d_loss: 12.525, generated image SNR 1.0
# Starting epoch 2...
# g_loss: 1.021, d_loss: 3.5264, generated image SNR 1.7039
# Starting epoch 3...
# g_loss: 0.54084, d_loss: 2.2111, generated image SNR 1.6994
# Starting epoch 4...
# g_loss: 0.62821, d_loss: 2.2483, generated image SNR 1.7982
# Starting epoch 5...
# g_loss: 0.51512, d_loss: 2.1305, generated image SNR 1.7554
# Starting epoch 6...
# g_loss: 0.94647, d_loss: 2.1612, generated image SNR 1.7364
# Starting epoch 7...
# g_loss: 1.8797, d_loss: 1.3207, generated image SNR 1.649
# Starting epoch 8...
# g_loss: 1.9035, d_loss: 1.068, generated image SNR 1.6858
# Starting epoch 9...
# g_loss: 2.28, d_loss: 1.1734, generated image SNR 1.7107
# Starting epoch 10...
# g_loss: 2.8363, d_loss: 1.1306, generated image SNR 1.6687
# Starting epoch 11...
# g_loss: 4.4639, d_loss: 0.34561, generated image SNR 1.6876
# Starting epoch 555...
# g_loss: 4.3691, d_loss: 0.30854, generated image SNR 1.6236
# Starting epoch 556...
# g_loss: 4.8648, d_loss: 0.66089, generated image SNR 1.6696
# Starting epoch 557...
# g_loss: 5.1572, d_loss: 0.34979, generated image SNR 1.6761
# Starting epoch 558...
# g_loss: 3.6897, d_loss: 0.23576, generated image SNR 1.554
# Starting epoch 559...
# g_loss: 3.5185, d_loss: 0.48168, generated image SNR 1.7925
# Starting epoch 560...
# g_loss: 3.4958, d_loss: 0.37379, generated image SNR 1.5428
# Starting epoch 561...
# g_loss: 3.0336, d_loss: 0.40544, generated image SNR 1.613
# Starting epoch 562...
# g_loss: 3.1157, d_loss: 0.35479, generated image SNR 1.546
# Starting epoch 563...
# g_loss: 3.5523, d_loss: 0.32033, generated image SNR 1.646
# Starting epoch 564...
# g_loss: 3.9277, d_loss: 0.42774, generated image SNR 1.7372
# Starting epoch 565...
# g_loss: 3.8759, d_loss: 0.59131, generated image SNR 1.5928
# Starting epoch 566...
# g_loss: 3.5893, d_loss: 0.51735, generated image SNR 1.6725
# Starting epoch 567...
# g_loss: 3.492, d_loss: 0.53068, generated image SNR 1.6216
# Starting epoch 568...
# g_loss: 3.4974, d_loss: 0.60781, generated image SNR 1.7633
# Starting epoch 569...
# g_loss: 2.9468, d_loss: 0.39333, generated image SNR 1.6816
# Starting epoch 570...
# g_loss: 3.7313, d_loss: 0.3859, generated image SNR 1.72
# Starting epoch 571...
# g_loss: 3.8571, d_loss: 0.29395, generated image SNR 1.632
# Starting epoch 572...
# g_loss: 3.9943, d_loss: 0.38164, generated image SNR 1.5823
# Starting epoch 573...
# g_loss: 3.2505, d_loss: 0.37566, generated image SNR 1.7429
# Starting epoch 574...
# g_loss: 3.0355, d_loss: 0.53063, generated image SNR 1.4766
# Starting epoch 575...
# g_loss: 3.3473, d_loss: 1.017, generated image SNR 1.7181
# Starting epoch 576...
# g_loss: 2.0577, d_loss: 0.74655, generated image SNR 1.6573
# Starting epoch 577...
# g_loss: 2.2266, d_loss: 0.73286, generated image SNR 1.6429
# Starting epoch 578...
# g_loss: 2.2764, d_loss: 0.69011, generated image SNR 1.6726
# Starting epoch 579...
# g_loss: 3.0951, d_loss: 0.91456, generated image SNR 1.8031
# Starting epoch 580...
# g_loss: 2.8224, d_loss: 0.65031, generated image SNR 1.8121
# Starting epoch 581...
# g_loss: 4.3148, d_loss: 0.72168, generated image SNR 1.5471
# Starting epoch 582...
# g_loss: 4.3938, d_loss: 0.6402, generated image SNR 1.6904
# Starting epoch 583...
# g_loss: 2.8833, d_loss: 0.92333, generated image SNR 1.7512
# Starting epoch 584...
# g_loss: 3.1225, d_loss: 0.81844, generated image SNR 1.6877
# Starting epoch 585...
# g_loss: 2.7155, d_loss: 0.62638, generated image SNR 1.6103
# Starting epoch 586...
# g_loss: 2.4042, d_loss: 0.78378, generated image SNR 1.773
# Starting epoch 587...
# g_loss: 2.5496, d_loss: 0.62765, generated image SNR 1.7939
# Starting epoch 588...
# g_loss: 2.528, d_loss: 0.51943, generated image SNR 1.8035
# Starting epoch 589...
# g_loss: 3.8845, d_loss: 0.48244, generated image SNR 1.7384
# Starting epoch 590...
# ...
# Starting epoch 806...
# g_loss: 3.2278, d_loss: 0.5327, generated image SNR 1.4259
# Starting epoch 807...
# g_loss: 3.7294, d_loss: 0.45094, generated image SNR 1.4017
# Starting epoch 808...
# g_loss: 4.2175, d_loss: 0.50104, generated image SNR 1.3899
# Starting epoch 809...
# g_loss: 4.5898, d_loss: 0.3468, generated image SNR 1.5092
# Starting epoch 810...
# g_loss: 4.794, d_loss: 0.50752, generated image SNR 1.4761
# Starting epoch 811...
# g_loss: 4.9326, d_loss: 0.57617, generated image SNR 1.4509
# Starting epoch 812...
# g_loss: 5.1612, d_loss: 0.40506, generated image SNR 1.4537
# Starting epoch 813...
# g_loss: 3.9326, d_loss: 0.34896, generated image SNR 1.3786
# Starting epoch 814...
# g_loss: 3.3484, d_loss: 0.45735, generated image SNR 1.4073
# Starting epoch 815...
# g_loss: 4.1555, d_loss: 0.39077, generated image SNR 1.4504
# Starting epoch 816...
# g_loss: 3.8691, d_loss: 0.46744, generated image SNR 1.3887
# Starting epoch 817...
# g_loss: 5.0345, d_loss: 0.23964, generated image SNR 1.5048
# Starting epoch 818...
# g_loss: 4.1442, d_loss: 0.3158, generated image SNR 1.4248
# Starting epoch 819...
# g_loss: 4.8037, d_loss: 0.52075, generated image SNR 1.4421
# Starting epoch 820...
# g_loss: 5.6301, d_loss: 0.31029, generated image SNR 1.4771
# Starting epoch 821...
# g_loss: 5.6799, d_loss: 0.22767, generated image SNR 1.439
# Starting epoch 822...
# g_loss: 5.0537, d_loss: 0.19773, generated image SNR 1.5114
# Starting epoch 823...
# g_loss: 4.9245, d_loss: 0.33357, generated image SNR 1.5053
# Starting epoch 824...
# g_loss: 5.1057, d_loss: 0.20001, generated image SNR 1.4759
# Starting epoch 825...
# g_loss: 5.1625, d_loss: 0.40572, generated image SNR 1.4551
# Starting epoch 826...
# g_loss: 4.663, d_loss: 0.23803, generated image SNR 1.5656
# Starting epoch 827...
# g_loss: 5.1298, d_loss: 0.20837, generated image SNR 1.5053
# Starting epoch 828...
# g_loss: 5.6075, d_loss: 0.18031, generated image SNR 1.4096
# Starting epoch 829...
# g_loss: 5.4062, d_loss: 0.19555, generated image SNR 1.5165
# Starting epoch 830...
# g_loss: 5.7761, d_loss: 0.15493, generated image SNR 1.4943
# Starting epoch 831...
# g_loss: 6.2598, d_loss: 0.15927, generated image SNR 1.5075
# Starting epoch 832...
# g_loss: 5.9935, d_loss: 0.24897, generated image SNR 1.5582
# Starting epoch 833...
# g_loss: 4.5063, d_loss: 0.23895, generated image SNR 1.5941
# Starting epoch 834...
# g_loss: 4.7706, d_loss: 0.34778, generated image SNR 1.4944
# Starting epoch 835...
# g_loss: 5.1818, d_loss: 0.20744, generated image SNR 1.5054
# Starting epoch 836...
# g_loss: 4.1694, d_loss: 0.24013, generated image SNR 1.316
# Starting epoch 837...
# g_loss: 3.7667, d_loss: 0.12871, generated image SNR 1.5506
# g_loss: 4.6477, d_loss: 0.27583, generated image SNR 1.8204
# Starting epoch 906...
# g_loss: 4.2818, d_loss: 0.42951, generated image SNR 1.9474
# Starting epoch 907...
# g_loss: 3.9275, d_loss: 0.19887, generated image SNR 1.7304
# Starting epoch 908...
# g_loss: 3.9002, d_loss: 0.13393, generated image SNR 1.7788
# Starting epoch 909...
# g_loss: 4.597, d_loss: 0.094164, generated image SNR 1.9485
# Starting epoch 910...
# g_loss: 5.3181, d_loss: 0.1237, generated image SNR 1.7178
# Starting epoch 911...
# g_loss: 5.3703, d_loss: 0.058848, generated image SNR 1.8145
# Starting epoch 912...
# g_loss: 5.2576, d_loss: 0.093262, generated image SNR 1.7597
# Starting epoch 913...
# g_loss: 6.6724, d_loss: 0.079213, generated image SNR 1.7485
# Starting epoch 914...
# g_loss: 6.7485, d_loss: 0.10432, generated image SNR 1.8157
# Starting epoch 915...
# g_loss: 6.4698, d_loss: 0.16773, generated image SNR 1.7915
# Starting epoch 916...
# g_loss: 5.7012, d_loss: 0.28789, generated image SNR 1.8013
# Starting epoch 917...
# g_loss: 5.7005, d_loss: 0.27019, generated image SNR 1.8489
# Starting epoch 918...
# g_loss: 4.0499, d_loss: 0.21122, generated image SNR 1.7564
# Starting epoch 919...
# g_loss: 4.3672, d_loss: 0.11615, generated image SNR 1.7401
# Starting epoch 920...
# g_loss: 3.5947, d_loss: 0.16751, generated image SNR 1.7316
# Starting epoch 921...
# g_loss: 4.0485, d_loss: 0.20599, generated image SNR 1.589
# Starting epoch 922...
# g_loss: 4.2725, d_loss: 0.28926, generated image SNR 1.7036
# Starting epoch 923...
# g_loss: 5.7935, d_loss: 0.3239, generated image SNR 1.7073
# Starting epoch 924...
# g_loss: 5.8402, d_loss: 0.098758, generated image SNR 1.675
# Starting epoch 925...
# g_loss: 4.953, d_loss: 0.6183, generated image SNR 1.817
# Starting epoch 926...
# g_loss: 5.4935, d_loss: 0.43107, generated image SNR 1.8278
# Starting epoch 927...
# g_loss: 5.8476, d_loss: 0.27599, generated image SNR 1.7666
# Starting epoch 928...
# g_loss: 3.6069, d_loss: 0.19643, generated image SNR 1.7915
# Starting epoch 929...
# g_loss: 3.5107, d_loss: 0.28885, generated image SNR 1.6229
# Starting epoch 930...
# g_loss: 3.3529, d_loss: 0.33037, generated image SNR 1.7363
# Starting epoch 931...
# g_loss: 3.3709, d_loss: 0.45696, generated image SNR 1.677
# Starting epoch 932...
# g_loss: 4.8044, d_loss: 0.38251, generated image SNR 1.68
# Starting epoch 933...
# g_loss: 5.0635, d_loss: 0.30924, generated image SNR 1.6098
# Starting epoch 934...
# g_loss: 5.0979, d_loss: 0.49293, generated image SNR 1.7322
# Starting epoch 935...
# g_loss: 3.9791, d_loss: 0.44626, generated image SNR 1.6276
# Starting epoch 936...
# g_loss: 3.4077, d_loss: 0.38638, generated image SNR 1.8212
# Starting epoch 937...
# g_loss: 2.9577, d_loss: 0.3325, generated image SNR 1.6084
# Starting epoch 938...
# g_loss: 3.1235, d_loss: 0.58972, generated image SNR 1.5971
# Starting epoch 939...
# g_loss: 3.3715, d_loss: 0.47866, generated image SNR 1.7417
# Starting epoch 940...
# g_loss: 4.5301, d_loss: 0.34305, generated image SNR 1.5014
# Starting epoch 941...
# g_loss: 4.18, d_loss: 0.60213, generated image SNR 1.7545
# Starting epoch 942...
# g_loss: 4.0019, d_loss: 0.45385, generated image SNR 1.4763
# Starting epoch 943...
# g_loss: 3.4348, d_loss: 0.23865, generated image SNR 1.5656
# Starting epoch 944...
# g_loss: 3.9865, d_loss: 0.404, generated image SNR 1.5461
# Starting epoch 945...
# g_loss: 3.5465, d_loss: 0.46776, generated image SNR 1.6035
# Starting epoch 946...
# g_loss: 2.5665, d_loss: 0.40118, generated image SNR 1.585
# Starting epoch 947...
# g_loss: 3.0259, d_loss: 0.33734, generated image SNR 1.6645
# Starting epoch 948...
# g_loss: 3.4981, d_loss: 0.38418, generated image SNR 1.5864
# Starting epoch 949...
# g_loss: 4.006, d_loss: 0.23075, generated image SNR 1.655
# Starting epoch 950...
# g_loss: 4.0406, d_loss: 0.26966, generated image SNR 1.6547
# Starting epoch 951...
# g_loss: 4.536, d_loss: 0.12764, generated image SNR 1.5899
# Starting epoch 952...
# g_loss: 4.5325, d_loss: 0.14645, generated image SNR 1.6496
# Starting epoch 953...
# g_loss: 6.675, d_loss: 0.3028, generated image SNR 1.4081
# Starting epoch 954...
# g_loss: 5.0025, d_loss: 0.14333, generated image SNR 1.4968
# Starting epoch 955...
# g_loss: 4.8175, d_loss: 0.17816, generated image SNR 1.5457
# Starting epoch 956...
# g_loss: 4.267, d_loss: 0.12488, generated image SNR 1.7483
# Starting epoch 957...
# g_loss: 3.628, d_loss: 0.14694, generated image SNR 1.6008
# Starting epoch 958...
# g_loss: 3.9966, d_loss: 0.16807, generated image SNR 1.5256
# Starting epoch 959...
# g_loss: 4.2984, d_loss: 0.12972, generated image SNR 1.5457
# Starting epoch 960...
# g_loss: 3.9691, d_loss: 0.14798, generated image SNR 1.4867
# Starting epoch 961...
# g_loss: 4.1141, d_loss: 0.15544, generated image SNR 1.6389
# Starting epoch 962...
# g_loss: 3.639, d_loss: 0.14814, generated image SNR 1.6088
# Starting epoch 963...
# g_loss: 4.2744, d_loss: 0.073962, generated image SNR 1.5819
# Starting epoch 964...
# g_loss: 5.4012, d_loss: 0.12785, generated image SNR 1.6921
# Starting epoch 965...
# g_loss: 4.4706, d_loss: 0.12856, generated image SNR 1.5407
# Starting epoch 966...
# g_loss: 4.4048, d_loss: 0.17264, generated image SNR 1.6644
# Starting epoch 967...
# g_loss: 4.9353, d_loss: 0.17472, generated image SNR 1.7334
# Starting epoch 968...
# g_loss: 4.1974, d_loss: 0.28643, generated image SNR 1.6328
# Starting epoch 969...
# g_loss: 3.9644, d_loss: 0.16315, generated image SNR 1.5334
# Starting epoch 970...
# g_loss: 3.7218, d_loss: 0.17637, generated image SNR 1.5675
# Starting epoch 971...
# g_loss: 3.5149, d_loss: 0.2481, generated image SNR 1.643
# Starting epoch 972...
# g_loss: 3.7355, d_loss: 0.23344, generated image SNR 1.5993
# Starting epoch 973...
# g_loss: 3.5376, d_loss: 0.19438, generated image SNR 1.6808
# Starting epoch 974...
# g_loss: 4.2558, d_loss: 0.19101, generated image SNR 1.7313
# Starting epoch 975...
# g_loss: 4.8399, d_loss: 0.1027, generated image SNR 1.7662
# Starting epoch 976...
# g_loss: 5.0402, d_loss: 0.20805, generated image SNR 1.8183
# Starting epoch 977...
# g_loss: 4.1266, d_loss: 0.17788, generated image SNR 1.7504
# Starting epoch 978...
# g_loss: 4.9731, d_loss: 0.14876, generated image SNR 1.7577
# Starting epoch 979...
# g_loss: 4.6332, d_loss: 0.21012, generated image SNR 1.9265
# Starting epoch 980...
# g_loss: 4.7142, d_loss: 0.17842, generated image SNR 1.7156
# Starting epoch 981...
# g_loss: 4.3223, d_loss: 0.12833, generated image SNR 1.7851
# Starting epoch 982...
# g_loss: 3.4684, d_loss: 0.16743, generated image SNR 1.7693
# Starting epoch 983...
# g_loss: 3.6419, d_loss: 0.15271, generated image SNR 1.7711
# Starting epoch 984...
# g_loss: 3.5659, d_loss: 0.26171, generated image SNR 1.8072
# Starting epoch 985...
# g_loss: 3.813, d_loss: 0.26179, generated image SNR 1.6309
# Starting epoch 986...
# g_loss: 3.8054, d_loss: 0.26631, generated image SNR 1.743
# Starting epoch 987...
# g_loss: 3.8959, d_loss: 0.18949, generated image SNR 1.839
# Starting epoch 988...
# g_loss: 4.6326, d_loss: 0.19612, generated image SNR 1.7903
# Starting epoch 989...
# g_loss: 4.2063, d_loss: 0.29582, generated image SNR 1.9663
# Starting epoch 990...
# g_loss: 4.0825, d_loss: 0.20571, generated image SNR 1.9917
# Starting epoch 991...
# g_loss: 4.3337, d_loss: 0.27408, generated image SNR 1.8447
# Starting epoch 992...
# g_loss: 3.2977, d_loss: 0.35519, generated image SNR 2.0199
# Starting epoch 993...
# g_loss: 3.224, d_loss: 0.35853, generated image SNR 1.9641
# Starting epoch 994...
# g_loss: 2.9519, d_loss: 0.1426, generated image SNR 1.9495
# Starting epoch 995...
# g_loss: 4.7596, d_loss: 0.33256, generated image SNR 1.9637
# Starting epoch 996...
# g_loss: 5.0874, d_loss: 0.17779, generated image SNR 2.0152
# Starting epoch 997...
# g_loss: 4.0259, d_loss: 0.10302, generated image SNR 1.9873
# Starting epoch 998...
# g_loss: 4.3518, d_loss: 0.12026, generated image SNR 1.8957
# Starting epoch 999...
# g_loss: 4.3735, d_loss: 0.11968, generated image SNR 1.9921
# Starting epoch 1000...
# g_loss: 4.3218, d_loss: 0.26869, generated image SNR 1.9866

# %%
# Show images
print('Generated images range from',torch.amin(sample_images),'to',torch.amax(sample_images),'and real images range from',torch.amin(real_images),'to',torch.max(real_images))
fig, ax = plt.subplots(figsize=(20, 20))
grid = make_grid(torch.vstack((sample_images,real_images.cpu()+(1/7*snr)*(torch.randn(images.shape).cpu()))), nrow=9, normalize=True).permute(1,2,0).numpy()
#+)),
ax.imshow(np.rot90(grid))
fig.show()
# Out:
# Generated images range from tensor(-0.7117) to tensor(1.) and real images range from tensor(-1.0068, device='cuda:0') to tensor(1.0115, device='cuda:0')
