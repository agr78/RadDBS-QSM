# %%
# Import libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import nibabel as nib
import sklearn.model_selection as sms
import sklearn.linear_model as slm
import sklearn.preprocessing as skp
import sklearn.neural_network as snn
import sklearn.metrics as sme
import sklearn.cross_decomposition as skd
from radiomics import featureextractor 
import numpy as np
import pandas as pd
from scipy.stats import linregress
from IPython.display import HTML
import util
from multiprocessing import Pool

# %%
HTML('''
<style>
.jupyter-matplotlib {
    background-color: #000;
}

.widget-label, .jupyter-matplotlib-header{
    color: #fff;
}

.jupyter-button {
    background-color: #333;
    color: #fff;
}
</style>
''')
# Out:
# <style>
# .jupyter-matplotlib {
#     background-color: #000;
# }
#
# .widget-label, .jupyter-matplotlib-header{
#     color: #fff;
# }
#
# .jupyter-button {
#     background-color: #333;
#     color: #fff;
# }
# </style>

# %%
# Get case IDs
case_list = open('/home/ali/RadDBS-QSM/data/docs/cases_90','r')
lines = case_list.read()
lists = np.loadtxt(case_list.name,comments="#", delimiter=",",unpack=False,dtype=str)
case_id = []
for lines in lists:     
    case_id.append(lines[-9:-7])

# Load scores
file_dir = '/home/ali/RadDBS-QSM/data/docs/QSM anonymus- 6.22.2023-1528.csv'
motor_df = util.filter_scores(file_dir,'pre-dbs updrs','stim','CORNELL ID')
# Find cases with all required scores
subs,pre_imp,post_imp,pre_updrs_off = util.get_full_cases(motor_df,
                                                          'CORNELL ID',
                                                          'OFF (pre-dbs updrs)',
                                                          'ON (pre-dbs updrs)',
                                                          'OFF meds ON stim 6mo')
# Load extracted features
npy_dir = '/home/ali/RadDBS-QSM/data/npy/'
phi_dir = '/home/ali/RadDBS-QSM/data/phi/'
roi_path = '/data/Ali/atlas/mcgill_pd_atlas/PD25-subcortical-labels.csv'
n_rois = 6
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595)
ids = np.asarray(ID_all).astype(int)
# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(case_id).astype(int),np.asarray(subs).astype(int))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
X_all_c = X_all[c_cases_idx,:,:]
K_all_c = K_all[c_cases_idx,:,:]
R_all_c = R_all[c_cases_idx,:,:]
# Re-index the scored subjects with respect to complete cases
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
pre_imp = pre_imp[s_cases_idx]
post_imp = post_imp[s_cases_idx]
pre_updrs_off = pre_updrs_off[s_cases_idx]
per_change = post_imp

# %%
X_train,X_test,y_train,y_test,train_index,test_index = util.set_split(X_all_c,per_change,1,0.1)
X0_tt,scaler = util.make_feature_matrix(X_train,pre_updrs_off[train_index])
entropy_train = util.calc_entropy(X0_tt.ravel())
entropy_test = util.calc_entropy(X_test.ravel())
print('Split datasets into training ( entropy of',str(entropy_train),') and testing ( entropy of',str(entropy_test),')')
# Out:
# Split datasets into training ( entropy of 16.65874892433296 ) and testing ( entropy of 14.098697229259342 )

# %%
est = snn.MLPRegressor()
cvn = 5

param_grid = {'hidden_layer_sizes': [(X_train.shape[1],X_train.shape[2])],
          'activation': ['relu'],
          'alpha': [1e-3,1e-2,1e-1,1e0,1e1],
          'epsilon': [1e0],
          'solver': ['adam'],
          'max_iter':[5000]}

gsc = sms.GridSearchCV(
    est,
    param_grid,
    cv=cvn, 
    scoring='r2',
    verbose=10,
    n_jobs=-1,
    return_train_score=True,
    refit=False)

grid_result = gsc.fit(X0_tt,y_train)
best_params = grid_result.best_params_

best_mlp = snn.MLPRegressor(hidden_layer_sizes=best_params["hidden_layer_sizes"], 
                        activation=best_params["activation"],
                        solver=best_params["solver"],
                        alpha=best_params['alpha'],
                        epsilon=best_params["epsilon"],
                        max_iter=5000, 
                        n_iter_no_change=500, 
                        verbose=True,
                        early_stopping=True,
                        random_state=1,
                        batch_size=len(X0_tt)//cvn)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
best_params
# Out:
# {'activation': 'relu',
#  'alpha': 0.01,
#  'epsilon': 1.0,
#  'hidden_layer_sizes': (6, 1595),
#  'max_iter': 5000,
#  'solver': 'adam'}

# %%
X_test_in = util.scale_feature_matrix(X_test,pre_updrs_off[test_index],scaler)
estcv = best_mlp.fit(X0_tt,y_train)
pls = skd.PLSRegression(n_components=1000)
pls.fit(X0_tt, y_train)
# Out:
# Iteration 1, loss = 0.22862904
# Validation score: -3.614708
# Iteration 2, loss = 0.22736239
# Validation score: -3.577769
# Iteration 3, loss = 0.22548619
# Validation score: -3.533329
# Iteration 4, loss = 0.22340120
# Validation score: -3.482749
# Iteration 5, loss = 0.22104605
# Validation score: -3.426756
# Iteration 6, loss = 0.21854781
# Validation score: -3.370471
# Iteration 7, loss = 0.21605387
# Validation score: -3.313413
# Iteration 8, loss = 0.21336229
# Validation score: -3.253658
# Iteration 9, loss = 0.21063496
# Validation score: -3.192060
# Iteration 10, loss = 0.20791760
# Validation score: -3.124875
# Iteration 11, loss = 0.20481341
# Validation score: -3.053967
# Iteration 12, loss = 0.20175694
# Validation score: -2.978946
# Iteration 13, loss = 0.19819876
# Validation score: -2.903813
# Iteration 14, loss = 0.19472269
# Validation score: -2.812498
# Iteration 15, loss = 0.19056500
# Validation score: -2.717195
# Iteration 16, loss = 0.18645535
# Validation score: -2.621754
# Iteration 17, loss = 0.18229358
# Validation score: -2.529455
# Iteration 18, loss = 0.17822972
# Validation score: -2.437665
# Iteration 19, loss = 0.17382956
# Validation score: -2.344880
# Iteration 20, loss = 0.16957877
# Validation score: -2.247497
# Iteration 21, loss = 0.16531515
# Validation score: -2.149977
# Iteration 22, loss = 0.16072203
# Validation score: -2.050947
# Iteration 23, loss = 0.15618500
# Validation score: -1.946201
# Iteration 24, loss = 0.15140346
# Validation score: -1.837450
# Iteration 25, loss = 0.14622864
# Validation score: -1.721557
# Iteration 26, loss = 0.14071300
# Validation score: -1.600548
# Iteration 27, loss = 0.13478127
# Validation score: -1.475438
# Iteration 28, loss = 0.12855731
# Validation score: -1.341801
# Iteration 29, loss = 0.12204378
# Validation score: -1.203398
# Iteration 30, loss = 0.11523285
# Validation score: -1.062586
# Iteration 31, loss = 0.10824191
# Validation score: -0.921223
# Iteration 32, loss = 0.10136306
# Validation score: -0.780469
# Iteration 33, loss = 0.09356267
# Validation score: -0.651172
# Iteration 34, loss = 0.08681210
# Validation score: -0.522831
# Iteration 35, loss = 0.07988704
# Validation score: -0.405639
# Iteration 36, loss = 0.07359409
# Validation score: -0.299768
# Iteration 37, loss = 0.06761165
# Validation score: -0.209527
# Iteration 38, loss = 0.06206091
# Validation score: -0.137947
# Iteration 39, loss = 0.05694263
# Validation score: -0.085810
# Iteration 40, loss = 0.05313759
# Validation score: -0.049129
# Iteration 41, loss = 0.04948717
# Validation score: -0.029175
# Iteration 42, loss = 0.04676409
# Validation score: -0.022298
# Iteration 43, loss = 0.04512659
# Validation score: -0.026586
# Iteration 44, loss = 0.04354599
# Validation score: -0.038382
# Iteration 45, loss = 0.04260117
# Validation score: -0.054645
# Iteration 46, loss = 0.04200963
# Validation score: -0.072755
# Iteration 47, loss = 0.04165457
# Validation score: -0.090298
# Iteration 48, loss = 0.04145666
# Validation score: -0.104587
# Iteration 49, loss = 0.04124299
# Validation score: -0.112815
# Iteration 50, loss = 0.04118114
# Validation score: -0.123184
# Iteration 51, loss = 0.04116744
# Validation score: -0.131101
# Iteration 52, loss = 0.04117653
# Validation score: -0.138251
# Iteration 53, loss = 0.04122366
# Validation score: -0.144153
# Iteration 54, loss = 0.04118172
# Validation score: -0.144704
# Iteration 55, loss = 0.04117461
# Validation score: -0.143906
# Iteration 56, loss = 0.04116615
# Validation score: -0.142828
# Iteration 57, loss = 0.04116443
# Validation score: -0.136065
# Iteration 58, loss = 0.04114136
# Validation score: -0.132861
# Iteration 59, loss = 0.04114408
# Validation score: -0.130430
# Iteration 60, loss = 0.04114119
# Validation score: -0.131124
# Iteration 61, loss = 0.04111820
# Validation score: -0.133583
# Iteration 62, loss = 0.04111095
# Validation score: -0.132591
# Iteration 63, loss = 0.04110740
# Validation score: -0.133561
# Iteration 64, loss = 0.04108158
# Validation score: -0.133599
# Iteration 65, loss = 0.04107130
# Validation score: -0.133589
# Iteration 66, loss = 0.04109431
# Validation score: -0.137699
# Iteration 67, loss = 0.04104866
# Validation score: -0.136569
# Iteration 68, loss = 0.04105850
# Validation score: -0.135805
# Iteration 69, loss = 0.04104158
# Validation score: -0.137368
# Iteration 70, loss = 0.04102703
# Validation score: -0.136054
# Iteration 71, loss = 0.04105702
# Validation score: -0.139387
# Iteration 72, loss = 0.04100853
# Validation score: -0.141535
# Iteration 73, loss = 0.04101066
# Validation score: -0.140294
# Iteration 74, loss = 0.04099237
# Validation score: -0.140663
# Iteration 75, loss = 0.04098804
# Validation score: -0.139453
# Iteration 76, loss = 0.04096786
# Validation score: -0.139707
# Iteration 77, loss = 0.04097594
# Validation score: -0.141564
# Iteration 78, loss = 0.04096548
# Validation score: -0.137343
# Iteration 79, loss = 0.04095776
# Validation score: -0.136872
# Iteration 80, loss = 0.04091916
# Validation score: -0.133330
# Iteration 81, loss = 0.04094374
# Validation score: -0.125983
# Iteration 82, loss = 0.04092087
# Validation score: -0.126038
# Iteration 83, loss = 0.04090409
# Validation score: -0.123870
# Iteration 84, loss = 0.04091589
# Validation score: -0.123488
# Iteration 85, loss = 0.04092837
# Validation score: -0.126008
# Iteration 86, loss = 0.04087663
# Validation score: -0.126562
# Iteration 87, loss = 0.04086643
# Validation score: -0.127049
# Iteration 88, loss = 0.04086098
# Validation score: -0.128721
# Iteration 89, loss = 0.04085370
# Validation score: -0.128271
# Iteration 90, loss = 0.04083008
# Validation score: -0.131728
# Iteration 91, loss = 0.04080611
# Validation score: -0.135949
# Iteration 92, loss = 0.04080299
# Validation score: -0.139603
# Iteration 93, loss = 0.04087880
# Validation score: -0.147529
# Iteration 94, loss = 0.04080116
# Validation score: -0.146738
# Iteration 95, loss = 0.04077017
# Validation score: -0.141624
# Iteration 96, loss = 0.04082085
# Validation score: -0.133214
# Iteration 97, loss = 0.04077289
# Validation score: -0.130563
# Iteration 98, loss = 0.04088136
# Validation score: -0.138541
# Iteration 99, loss = 0.04073127
# Validation score: -0.135141
# Iteration 100, loss = 0.04071610
# Validation score: -0.131603
# Iteration 101, loss = 0.04071711
# Validation score: -0.128417
# Iteration 102, loss = 0.04074629
# Validation score: -0.124364
# Iteration 103, loss = 0.04075917
# Validation score: -0.128372
# Iteration 104, loss = 0.04072603
# Validation score: -0.132782
# Iteration 105, loss = 0.04070421
# Validation score: -0.130493
# Iteration 106, loss = 0.04066478
# Validation score: -0.134116
# Iteration 107, loss = 0.04069097
# Validation score: -0.135554
# Iteration 108, loss = 0.04065600
# Validation score: -0.142245
# Iteration 109, loss = 0.04063850
# Validation score: -0.145262
# Iteration 110, loss = 0.04063254
# Validation score: -0.146938
# Iteration 111, loss = 0.04064567
# Validation score: -0.142982
# Iteration 112, loss = 0.04060864
# Validation score: -0.144633
# Iteration 113, loss = 0.04059455
# Validation score: -0.147008
# Iteration 114, loss = 0.04061218
# Validation score: -0.148663
# Iteration 115, loss = 0.04057926
# Validation score: -0.145844
# Iteration 116, loss = 0.04059243
# Validation score: -0.135530
# Iteration 117, loss = 0.04056449
# Validation score: -0.136112
# Iteration 118, loss = 0.04054241
# Validation score: -0.132785
# Iteration 119, loss = 0.04060371
# Validation score: -0.125778
# Iteration 120, loss = 0.04053593
# Validation score: -0.126532
# Iteration 121, loss = 0.04054187
# Validation score: -0.127810
# Iteration 122, loss = 0.04053367
# Validation score: -0.123186
# Iteration 123, loss = 0.04053757
# Validation score: -0.125700
# Iteration 124, loss = 0.04048454
# Validation score: -0.125552
# Iteration 125, loss = 0.04049424
# Validation score: -0.126095
# Iteration 126, loss = 0.04050022
# Validation score: -0.130520
# Iteration 127, loss = 0.04045107
# Validation score: -0.128719
# Iteration 128, loss = 0.04044065
# Validation score: -0.129250
# Iteration 129, loss = 0.04044027
# Validation score: -0.134853
# Iteration 130, loss = 0.04041973
# Validation score: -0.136968
# Iteration 131, loss = 0.04040363
# Validation score: -0.137395
# Iteration 132, loss = 0.04042885
# Validation score: -0.134265
# Iteration 133, loss = 0.04038502
# Validation score: -0.138923
# Iteration 134, loss = 0.04035607
# Validation score: -0.140741
# Iteration 135, loss = 0.04035554
# Validation score: -0.141510
# Iteration 136, loss = 0.04035529
# Validation score: -0.145416
# Iteration 137, loss = 0.04033651
# Validation score: -0.145245
# Iteration 138, loss = 0.04032252
# Validation score: -0.141914
# Iteration 139, loss = 0.04031443
# Validation score: -0.139543
# Iteration 140, loss = 0.04031305
# Validation score: -0.140043
# Iteration 141, loss = 0.04030544
# Validation score: -0.135395
# Iteration 142, loss = 0.04027219
# Validation score: -0.136833
# Iteration 143, loss = 0.04026798
# Validation score: -0.136586
# Iteration 144, loss = 0.04026645
# Validation score: -0.141889
# Iteration 145, loss = 0.04025619
# Validation score: -0.140800
# Iteration 146, loss = 0.04023249
# Validation score: -0.140974
# Iteration 147, loss = 0.04023053
# Validation score: -0.140106
# Iteration 148, loss = 0.04044727
# Validation score: -0.152161
# Iteration 149, loss = 0.04023975
# Validation score: -0.142266
# Iteration 150, loss = 0.04021349
# Validation score: -0.137171
# Iteration 151, loss = 0.04018064
# Validation score: -0.140279
# Iteration 152, loss = 0.04017092
# Validation score: -0.139683
# Iteration 153, loss = 0.04018129
# Validation score: -0.134076
# Iteration 154, loss = 0.04013537
# Validation score: -0.133298
# Iteration 155, loss = 0.04013694
# Validation score: -0.135544
# Iteration 156, loss = 0.04013803
# Validation score: -0.139983
# Iteration 157, loss = 0.04012497
# Validation score: -0.139910
# Iteration 158, loss = 0.04009571
# Validation score: -0.136713
# Iteration 159, loss = 0.04012058
# Validation score: -0.130721
# Iteration 160, loss = 0.04009367
# Validation score: -0.135767
# Iteration 161, loss = 0.04005803
# Validation score: -0.137742
# Iteration 162, loss = 0.04012809
# Validation score: -0.145384
# Iteration 163, loss = 0.04004885
# Validation score: -0.142232
# Iteration 164, loss = 0.04003869
# Validation score: -0.140328
# Iteration 165, loss = 0.04001239
# Validation score: -0.142844
# Iteration 166, loss = 0.04001677
# Validation score: -0.143126
# Iteration 167, loss = 0.04004756
# Validation score: -0.148117
# Iteration 168, loss = 0.03997215
# Validation score: -0.144243
# Iteration 169, loss = 0.03995585
# Validation score: -0.141043
# Iteration 170, loss = 0.03996128
# Validation score: -0.140226
# Iteration 171, loss = 0.03995871
# Validation score: -0.137753
# Iteration 172, loss = 0.03993631
# Validation score: -0.138805
# Iteration 173, loss = 0.03993415
# Validation score: -0.135858
# Iteration 174, loss = 0.03997391
# Validation score: -0.133526
# Iteration 175, loss = 0.03995622
# Validation score: -0.143598
# Iteration 176, loss = 0.03987446
# Validation score: -0.145834
# Iteration 177, loss = 0.03988019
# Validation score: -0.147173
# Iteration 178, loss = 0.03996485
# Validation score: -0.154181
# Iteration 179, loss = 0.03984362
# Validation score: -0.146290
# Iteration 180, loss = 0.03988296
# Validation score: -0.138381
# Iteration 181, loss = 0.03986759
# Validation score: -0.138623
# Iteration 182, loss = 0.03981910
# Validation score: -0.141351
# Iteration 183, loss = 0.03985468
# Validation score: -0.142286
# Iteration 184, loss = 0.03981925
# Validation score: -0.144226
# Iteration 185, loss = 0.03980545
# Validation score: -0.135546
# Iteration 186, loss = 0.03976859
# Validation score: -0.136218
# Iteration 187, loss = 0.03976512
# Validation score: -0.133707
# Iteration 188, loss = 0.03975218
# Validation score: -0.131627
# Iteration 189, loss = 0.03973794
# Validation score: -0.133377
# Iteration 190, loss = 0.03972162
# Validation score: -0.134739
# Iteration 191, loss = 0.03971530
# Validation score: -0.136234
# Iteration 192, loss = 0.03969443
# Validation score: -0.139449
# Iteration 193, loss = 0.03970415
# Validation score: -0.137152
# Iteration 194, loss = 0.03967077
# Validation score: -0.139925
# Iteration 195, loss = 0.03964266
# Validation score: -0.144440
# Iteration 196, loss = 0.03969060
# Validation score: -0.152480
# Iteration 197, loss = 0.03973417
# Validation score: -0.147300
# Iteration 198, loss = 0.03964735
# Validation score: -0.151967
# Iteration 199, loss = 0.03964543
# Validation score: -0.145279
# Iteration 200, loss = 0.03961702
# Validation score: -0.147305
# Iteration 201, loss = 0.03958264
# Validation score: -0.145511
# Iteration 202, loss = 0.03957711
# Validation score: -0.143419
# Iteration 203, loss = 0.03961704
# Validation score: -0.148414
# Iteration 204, loss = 0.03956724
# Validation score: -0.146098
# Iteration 205, loss = 0.03962549
# Validation score: -0.140181
# Iteration 206, loss = 0.03951328
# Validation score: -0.143965
# Iteration 207, loss = 0.03950405
# Validation score: -0.146069
# Iteration 208, loss = 0.03951857
# Validation score: -0.149372
# Iteration 209, loss = 0.03949851
# Validation score: -0.144355
# Iteration 210, loss = 0.03949184
# Validation score: -0.147085
# Iteration 211, loss = 0.03947106
# Validation score: -0.141393
# Iteration 212, loss = 0.03945995
# Validation score: -0.138134
# Iteration 213, loss = 0.03946805
# Validation score: -0.134905
# Iteration 214, loss = 0.03959604
# Validation score: -0.146225
# Iteration 215, loss = 0.03940969
# Validation score: -0.143004
# Iteration 216, loss = 0.03940821
# Validation score: -0.138905
# Iteration 217, loss = 0.03938972
# Validation score: -0.141716
# Iteration 218, loss = 0.03937576
# Validation score: -0.142745
# Iteration 219, loss = 0.03936816
# Validation score: -0.140002
# Iteration 220, loss = 0.03933993
# Validation score: -0.140971
# Iteration 221, loss = 0.03936070
# Validation score: -0.146151
# Iteration 222, loss = 0.03932037
# Validation score: -0.141577
# Iteration 223, loss = 0.03931105
# Validation score: -0.142171
# Iteration 224, loss = 0.03930621
# Validation score: -0.143394
# Iteration 225, loss = 0.03931412
# Validation score: -0.138087
# Iteration 226, loss = 0.03928105
# Validation score: -0.138102
# Iteration 227, loss = 0.03938998
# Validation score: -0.128329
# Iteration 228, loss = 0.03924798
# Validation score: -0.132046
# Iteration 229, loss = 0.03925019
# Validation score: -0.133163
# Iteration 230, loss = 0.03933213
# Validation score: -0.146490
# Iteration 231, loss = 0.03923431
# Validation score: -0.142376
# Iteration 232, loss = 0.03926933
# Validation score: -0.147040
# Iteration 233, loss = 0.03926165
# Validation score: -0.138909
# Iteration 234, loss = 0.03915452
# Validation score: -0.140821
# Iteration 235, loss = 0.03917210
# Validation score: -0.145524
# Iteration 236, loss = 0.03916205
# Validation score: -0.145528
# Iteration 237, loss = 0.03917114
# Validation score: -0.135645
# Iteration 238, loss = 0.03916695
# Validation score: -0.140327
# Iteration 239, loss = 0.03909761
# Validation score: -0.133804
# Iteration 240, loss = 0.03908729
# Validation score: -0.132125
# Iteration 241, loss = 0.03908082
# Validation score: -0.132132
# Iteration 242, loss = 0.03907191
# Validation score: -0.132134
# Iteration 243, loss = 0.03904279
# Validation score: -0.135823
# Iteration 244, loss = 0.03903604
# Validation score: -0.138906
# Iteration 245, loss = 0.03906272
# Validation score: -0.137996
# Iteration 246, loss = 0.03897375
# Validation score: -0.145376
# Iteration 247, loss = 0.03900115
# Validation score: -0.153638
# Iteration 248, loss = 0.03898604
# Validation score: -0.153893
# Iteration 249, loss = 0.03905430
# Validation score: -0.159097
# Iteration 250, loss = 0.03895668
# Validation score: -0.147672
# Iteration 251, loss = 0.03900834
# Validation score: -0.137638
# Iteration 252, loss = 0.03891457
# Validation score: -0.130700
# Iteration 253, loss = 0.03897718
# Validation score: -0.122720
# Iteration 254, loss = 0.03897173
# Validation score: -0.129990
# Iteration 255, loss = 0.03890564
# Validation score: -0.129466
# Iteration 256, loss = 0.03888140
# Validation score: -0.130894
# Iteration 257, loss = 0.03886533
# Validation score: -0.132339
# Iteration 258, loss = 0.03886682
# Validation score: -0.138047
# Iteration 259, loss = 0.03888001
# Validation score: -0.142741
# Iteration 260, loss = 0.03880843
# Validation score: -0.143101
# Iteration 261, loss = 0.03880499
# Validation score: -0.144003
# Iteration 262, loss = 0.03878661
# Validation score: -0.147098
# Iteration 263, loss = 0.03886353
# Validation score: -0.151848
# Iteration 264, loss = 0.03877596
# Validation score: -0.149382
# Iteration 265, loss = 0.03875320
# Validation score: -0.144210
# Iteration 266, loss = 0.03875819
# Validation score: -0.140598
# Iteration 267, loss = 0.03872110
# Validation score: -0.145716
# Iteration 268, loss = 0.03871862
# Validation score: -0.150520
# Iteration 269, loss = 0.03870743
# Validation score: -0.151212
# Iteration 270, loss = 0.03869623
# Validation score: -0.151671
# Iteration 271, loss = 0.03867947
# Validation score: -0.153095
# Iteration 272, loss = 0.03866226
# Validation score: -0.154367
# Iteration 273, loss = 0.03865717
# Validation score: -0.155251
# Iteration 274, loss = 0.03865657
# Validation score: -0.150992
# Iteration 275, loss = 0.03863229
# Validation score: -0.149538
# Iteration 276, loss = 0.03869386
# Validation score: -0.157194
# Iteration 277, loss = 0.03860975
# Validation score: -0.149905
# Iteration 278, loss = 0.03858957
# Validation score: -0.147969
# Iteration 279, loss = 0.03855020
# Validation score: -0.145050
# Iteration 280, loss = 0.03854618
# Validation score: -0.142848
# Iteration 281, loss = 0.03852131
# Validation score: -0.134471
# Iteration 282, loss = 0.03855263
# Validation score: -0.135131
# Iteration 283, loss = 0.03851385
# Validation score: -0.128206
# Iteration 284, loss = 0.03852937
# Validation score: -0.125941
# Iteration 285, loss = 0.03849645
# Validation score: -0.128515
# Iteration 286, loss = 0.03848041
# Validation score: -0.133017
# Iteration 287, loss = 0.03849366
# Validation score: -0.138190
# Iteration 288, loss = 0.03842787
# Validation score: -0.139631
# Iteration 289, loss = 0.03844649
# Validation score: -0.140978
# Iteration 290, loss = 0.03840058
# Validation score: -0.142837
# Iteration 291, loss = 0.03838872
# Validation score: -0.144641
# Iteration 292, loss = 0.03837427
# Validation score: -0.144225
# Iteration 293, loss = 0.03835925
# Validation score: -0.144180
# Iteration 294, loss = 0.03835987
# Validation score: -0.145233
# Iteration 295, loss = 0.03835938
# Validation score: -0.138887
# Iteration 296, loss = 0.03835518
# Validation score: -0.136784
# Iteration 297, loss = 0.03833572
# Validation score: -0.129004
# Iteration 298, loss = 0.03831813
# Validation score: -0.128909
# Iteration 299, loss = 0.03830471
# Validation score: -0.131064
# Iteration 300, loss = 0.03828799
# Validation score: -0.133445
# Iteration 301, loss = 0.03824715
# Validation score: -0.138880
# Iteration 302, loss = 0.03825525
# Validation score: -0.144717
# Iteration 303, loss = 0.03821510
# Validation score: -0.141849
# Iteration 304, loss = 0.03820031
# Validation score: -0.140143
# Iteration 305, loss = 0.03827865
# Validation score: -0.134146
# Iteration 306, loss = 0.03819736
# Validation score: -0.141991
# Iteration 307, loss = 0.03817544
# Validation score: -0.143993
# Iteration 308, loss = 0.03814553
# Validation score: -0.148264
# Iteration 309, loss = 0.03813198
# Validation score: -0.151383
# Iteration 310, loss = 0.03810510
# Validation score: -0.159865
# Iteration 311, loss = 0.03813889
# Validation score: -0.160738
# Iteration 312, loss = 0.03812123
# Validation score: -0.160791
# Iteration 313, loss = 0.03811400
# Validation score: -0.164521
# Iteration 314, loss = 0.03811289
# Validation score: -0.165411
# Iteration 315, loss = 0.03809253
# Validation score: -0.153106
# Iteration 316, loss = 0.03805177
# Validation score: -0.145640
# Iteration 317, loss = 0.03802307
# Validation score: -0.146429
# Iteration 318, loss = 0.03805342
# Validation score: -0.138736
# Iteration 319, loss = 0.03800690
# Validation score: -0.141914
# Iteration 320, loss = 0.03798387
# Validation score: -0.137590
# Iteration 321, loss = 0.03800189
# Validation score: -0.136053
# Iteration 322, loss = 0.03797189
# Validation score: -0.145306
# Iteration 323, loss = 0.03795758
# Validation score: -0.145705
# Iteration 324, loss = 0.03799216
# Validation score: -0.155392
# Iteration 325, loss = 0.03790760
# Validation score: -0.150256
# Iteration 326, loss = 0.03791446
# Validation score: -0.149454
# Iteration 327, loss = 0.03787758
# Validation score: -0.148024
# Iteration 328, loss = 0.03783033
# Validation score: -0.140226
# Iteration 329, loss = 0.03795355
# Validation score: -0.128309
# Iteration 330, loss = 0.03786062
# Validation score: -0.130117
# Iteration 331, loss = 0.03793804
# Validation score: -0.141525
# Iteration 332, loss = 0.03781320
# Validation score: -0.140656
# Iteration 333, loss = 0.03780703
# Validation score: -0.144078
# Iteration 334, loss = 0.03781663
# Validation score: -0.137609
# Iteration 335, loss = 0.03776022
# Validation score: -0.143403
# Iteration 336, loss = 0.03773881
# Validation score: -0.142611
# Iteration 337, loss = 0.03774738
# Validation score: -0.140670
# Iteration 338, loss = 0.03771182
# Validation score: -0.142328
# Iteration 339, loss = 0.03773593
# Validation score: -0.147080
# Iteration 340, loss = 0.03774010
# Validation score: -0.143207
# Iteration 341, loss = 0.03767454
# Validation score: -0.148161
# Iteration 342, loss = 0.03769897
# Validation score: -0.154162
# Iteration 343, loss = 0.03764509
# Validation score: -0.145989
# Iteration 344, loss = 0.03764622
# Validation score: -0.144705
# Iteration 345, loss = 0.03761503
# Validation score: -0.147338
# Iteration 346, loss = 0.03760660
# Validation score: -0.148436
# Iteration 347, loss = 0.03772459
# Validation score: -0.136239
# Iteration 348, loss = 0.03757488
# Validation score: -0.136030
# Iteration 349, loss = 0.03759388
# Validation score: -0.145985
# Iteration 350, loss = 0.03755200
# Validation score: -0.143991
# Iteration 351, loss = 0.03749970
# Validation score: -0.150609
# Iteration 352, loss = 0.03750133
# Validation score: -0.153952
# Iteration 353, loss = 0.03751026
# Validation score: -0.163996
# Iteration 354, loss = 0.03752095
# Validation score: -0.170119
# Iteration 355, loss = 0.03750300
# Validation score: -0.167786
# Iteration 356, loss = 0.03744803
# Validation score: -0.154961
# Iteration 357, loss = 0.03743418
# Validation score: -0.144137
# Iteration 358, loss = 0.03742979
# Validation score: -0.138927
# Iteration 359, loss = 0.03743181
# Validation score: -0.135717
# Iteration 360, loss = 0.03737920
# Validation score: -0.135934
# Iteration 361, loss = 0.03739636
# Validation score: -0.141408
# Iteration 362, loss = 0.03738974
# Validation score: -0.136126
# Iteration 363, loss = 0.03733700
# Validation score: -0.143946
# Iteration 364, loss = 0.03731742
# Validation score: -0.148164
# Iteration 365, loss = 0.03728498
# Validation score: -0.147406
# Iteration 366, loss = 0.03727247
# Validation score: -0.146823
# Iteration 367, loss = 0.03726648
# Validation score: -0.144791
# Iteration 368, loss = 0.03727135
# Validation score: -0.143929
# Iteration 369, loss = 0.03728311
# Validation score: -0.156391
# Iteration 370, loss = 0.03723072
# Validation score: -0.157999
# Iteration 371, loss = 0.03720974
# Validation score: -0.160568
# Iteration 372, loss = 0.03722290
# Validation score: -0.155805
# Iteration 373, loss = 0.03726489
# Validation score: -0.145582
# Iteration 374, loss = 0.03717390
# Validation score: -0.151581
# Iteration 375, loss = 0.03713603
# Validation score: -0.151024
# Iteration 376, loss = 0.03712333
# Validation score: -0.145824
# Iteration 377, loss = 0.03713722
# Validation score: -0.140943
# Iteration 378, loss = 0.03718272
# Validation score: -0.151285
# Iteration 379, loss = 0.03712154
# Validation score: -0.145637
# Iteration 380, loss = 0.03705468
# Validation score: -0.147224
# Iteration 381, loss = 0.03704829
# Validation score: -0.152515
# Iteration 382, loss = 0.03703498
# Validation score: -0.155357
# Iteration 383, loss = 0.03700306
# Validation score: -0.151983
# Iteration 384, loss = 0.03703059
# Validation score: -0.145252
# Iteration 385, loss = 0.03697400
# Validation score: -0.145958
# Iteration 386, loss = 0.03697238
# Validation score: -0.149295
# Iteration 387, loss = 0.03694979
# Validation score: -0.143026
# Iteration 388, loss = 0.03693998
# Validation score: -0.146099
# Iteration 389, loss = 0.03692502
# Validation score: -0.142000
# Iteration 390, loss = 0.03690977
# Validation score: -0.140952
# Iteration 391, loss = 0.03689652
# Validation score: -0.142935
# Iteration 392, loss = 0.03686955
# Validation score: -0.138661
# Iteration 393, loss = 0.03685597
# Validation score: -0.136767
# Iteration 394, loss = 0.03687591
# Validation score: -0.135170
# Iteration 395, loss = 0.03679943
# Validation score: -0.140938
# Iteration 396, loss = 0.03678219
# Validation score: -0.147043
# Iteration 397, loss = 0.03677379
# Validation score: -0.157059
# Iteration 398, loss = 0.03678383
# Validation score: -0.169001
# Iteration 399, loss = 0.03679447
# Validation score: -0.170667
# Iteration 400, loss = 0.03678442
# Validation score: -0.168731
# Iteration 401, loss = 0.03678395
# Validation score: -0.160468
# Iteration 402, loss = 0.03672647
# Validation score: -0.156948
# Iteration 403, loss = 0.03667910
# Validation score: -0.149791
# Iteration 404, loss = 0.03675305
# Validation score: -0.139636
# Iteration 405, loss = 0.03667022
# Validation score: -0.141549
# Iteration 406, loss = 0.03668901
# Validation score: -0.145798
# Iteration 407, loss = 0.03666142
# Validation score: -0.146178
# Iteration 408, loss = 0.03669891
# Validation score: -0.131338
# Iteration 409, loss = 0.03661859
# Validation score: -0.128099
# Iteration 410, loss = 0.03660116
# Validation score: -0.131926
# Iteration 411, loss = 0.03657199
# Validation score: -0.134849
# Iteration 412, loss = 0.03655121
# Validation score: -0.135138
# Iteration 413, loss = 0.03655056
# Validation score: -0.143780
# Iteration 414, loss = 0.03654928
# Validation score: -0.149476
# Iteration 415, loss = 0.03646842
# Validation score: -0.143453
# Iteration 416, loss = 0.03646207
# Validation score: -0.138210
# Iteration 417, loss = 0.03653823
# Validation score: -0.131091
# Iteration 418, loss = 0.03643595
# Validation score: -0.139298
# Iteration 419, loss = 0.03649425
# Validation score: -0.149839
# Iteration 420, loss = 0.03640221
# Validation score: -0.145748
# Iteration 421, loss = 0.03645087
# Validation score: -0.138010
# Iteration 422, loss = 0.03635855
# Validation score: -0.141057
# Iteration 423, loss = 0.03643737
# Validation score: -0.140996
# Iteration 424, loss = 0.03633124
# Validation score: -0.147845
# Iteration 425, loss = 0.03631210
# Validation score: -0.149020
# Iteration 426, loss = 0.03639919
# Validation score: -0.139561
# Iteration 427, loss = 0.03628798
# Validation score: -0.144929
# Iteration 428, loss = 0.03626685
# Validation score: -0.148738
# Iteration 429, loss = 0.03625718
# Validation score: -0.150668
# Iteration 430, loss = 0.03623319
# Validation score: -0.150616
# Iteration 431, loss = 0.03623674
# Validation score: -0.143368
# Iteration 432, loss = 0.03620208
# Validation score: -0.145422
# Iteration 433, loss = 0.03625801
# Validation score: -0.139132
# Iteration 434, loss = 0.03615187
# Validation score: -0.147371
# Iteration 435, loss = 0.03615704
# Validation score: -0.152303
# Iteration 436, loss = 0.03613655
# Validation score: -0.155434
# Iteration 437, loss = 0.03614292
# Validation score: -0.149408
# Iteration 438, loss = 0.03610597
# Validation score: -0.149523
# Iteration 439, loss = 0.03608378
# Validation score: -0.148901
# Iteration 440, loss = 0.03607344
# Validation score: -0.140780
# Iteration 441, loss = 0.03608513
# Validation score: -0.137934
# Iteration 442, loss = 0.03601956
# Validation score: -0.130162
# Iteration 443, loss = 0.03604375
# Validation score: -0.124186
# Iteration 444, loss = 0.03602898
# Validation score: -0.126457
# Iteration 445, loss = 0.03599539
# Validation score: -0.133540
# Iteration 446, loss = 0.03594741
# Validation score: -0.139155
# Iteration 447, loss = 0.03599418
# Validation score: -0.151568
# Iteration 448, loss = 0.03594567
# Validation score: -0.150154
# Iteration 449, loss = 0.03589900
# Validation score: -0.150230
# Iteration 450, loss = 0.03588191
# Validation score: -0.151051
# Iteration 451, loss = 0.03589465
# Validation score: -0.155541
# Iteration 452, loss = 0.03589593
# Validation score: -0.146073
# Iteration 453, loss = 0.03583690
# Validation score: -0.148241
# Iteration 454, loss = 0.03583477
# Validation score: -0.145957
# Iteration 455, loss = 0.03581226
# Validation score: -0.150342
# Iteration 456, loss = 0.03585118
# Validation score: -0.158863
# Iteration 457, loss = 0.03579912
# Validation score: -0.157321
# Iteration 458, loss = 0.03574269
# Validation score: -0.146525
# Iteration 459, loss = 0.03579238
# Validation score: -0.136760
# Iteration 460, loss = 0.03574238
# Validation score: -0.135431
# Iteration 461, loss = 0.03572842
# Validation score: -0.129980
# Iteration 462, loss = 0.03571132
# Validation score: -0.132555
# Iteration 463, loss = 0.03567373
# Validation score: -0.136323
# Iteration 464, loss = 0.03578254
# Validation score: -0.129308
# Iteration 465, loss = 0.03573650
# Validation score: -0.140757
# Iteration 466, loss = 0.03568457
# Validation score: -0.132959
# Iteration 467, loss = 0.03562470
# Validation score: -0.143672
# Iteration 468, loss = 0.03557925
# Validation score: -0.143790
# Iteration 469, loss = 0.03557650
# Validation score: -0.151573
# Iteration 470, loss = 0.03559068
# Validation score: -0.157107
# Iteration 471, loss = 0.03556926
# Validation score: -0.143131
# Iteration 472, loss = 0.03552283
# Validation score: -0.147024
# Iteration 473, loss = 0.03547513
# Validation score: -0.143345
# Iteration 474, loss = 0.03547598
# Validation score: -0.138069
# Iteration 475, loss = 0.03544433
# Validation score: -0.139110
# Iteration 476, loss = 0.03543706
# Validation score: -0.139719
# Iteration 477, loss = 0.03548080
# Validation score: -0.136303
# Iteration 478, loss = 0.03543927
# Validation score: -0.148133
# Iteration 479, loss = 0.03536284
# Validation score: -0.148353
# Iteration 480, loss = 0.03536474
# Validation score: -0.150162
# Iteration 481, loss = 0.03536708
# Validation score: -0.142275
# Iteration 482, loss = 0.03534664
# Validation score: -0.148123
# Iteration 483, loss = 0.03530483
# Validation score: -0.142173
# Iteration 484, loss = 0.03528055
# Validation score: -0.136411
# Iteration 485, loss = 0.03532819
# Validation score: -0.126088
# Iteration 486, loss = 0.03537915
# Validation score: -0.135415
# Iteration 487, loss = 0.03532888
# Validation score: -0.147686
# Iteration 488, loss = 0.03524393
# Validation score: -0.148600
# Iteration 489, loss = 0.03523739
# Validation score: -0.133382
# Iteration 490, loss = 0.03517147
# Validation score: -0.130134
# Iteration 491, loss = 0.03521897
# Validation score: -0.125882
# Iteration 492, loss = 0.03517017
# Validation score: -0.134245
# Iteration 493, loss = 0.03514201
# Validation score: -0.139757
# Iteration 494, loss = 0.03510752
# Validation score: -0.133412
# Iteration 495, loss = 0.03508589
# Validation score: -0.133481
# Iteration 496, loss = 0.03509587
# Validation score: -0.136475
# Iteration 497, loss = 0.03503525
# Validation score: -0.144709
# Iteration 498, loss = 0.03503538
# Validation score: -0.149392
# Iteration 499, loss = 0.03512077
# Validation score: -0.140651
# Iteration 500, loss = 0.03499098
# Validation score: -0.147637
# Iteration 501, loss = 0.03498761
# Validation score: -0.150748
# Iteration 502, loss = 0.03495802
# Validation score: -0.143255
# Iteration 503, loss = 0.03493613
# Validation score: -0.140342
# Iteration 504, loss = 0.03489943
# Validation score: -0.142231
# Iteration 505, loss = 0.03487726
# Validation score: -0.146978
# Iteration 506, loss = 0.03491514
# Validation score: -0.156645
# Iteration 507, loss = 0.03486755
# Validation score: -0.152367
# Iteration 508, loss = 0.03484555
# Validation score: -0.147444
# Iteration 509, loss = 0.03483336
# Validation score: -0.141195
# Iteration 510, loss = 0.03480031
# Validation score: -0.146088
# Iteration 511, loss = 0.03480855
# Validation score: -0.147787
# Iteration 512, loss = 0.03474462
# Validation score: -0.141540
# Iteration 513, loss = 0.03478109
# Validation score: -0.134785
# Iteration 514, loss = 0.03475901
# Validation score: -0.143400
# Iteration 515, loss = 0.03471057
# Validation score: -0.144565
# Iteration 516, loss = 0.03469084
# Validation score: -0.140878
# Iteration 517, loss = 0.03468462
# Validation score: -0.139786
# Iteration 518, loss = 0.03467664
# Validation score: -0.140998
# Iteration 519, loss = 0.03464599
# Validation score: -0.143850
# Iteration 520, loss = 0.03463279
# Validation score: -0.148923
# Iteration 521, loss = 0.03463182
# Validation score: -0.150133
# Iteration 522, loss = 0.03458287
# Validation score: -0.141469
# Iteration 523, loss = 0.03460900
# Validation score: -0.135377
# Iteration 524, loss = 0.03456065
# Validation score: -0.135651
# Iteration 525, loss = 0.03455334
# Validation score: -0.138165
# Iteration 526, loss = 0.03456637
# Validation score: -0.143301
# Iteration 527, loss = 0.03457550
# Validation score: -0.130864
# Iteration 528, loss = 0.03453680
# Validation score: -0.141410
# Iteration 529, loss = 0.03455360
# Validation score: -0.133644
# Iteration 530, loss = 0.03454507
# Validation score: -0.149295
# Iteration 531, loss = 0.03450324
# Validation score: -0.143221
# Iteration 532, loss = 0.03440229
# Validation score: -0.150026
# Iteration 533, loss = 0.03440664
# Validation score: -0.157741
# Iteration 534, loss = 0.03446993
# Validation score: -0.149154
# Iteration 535, loss = 0.03435670
# Validation score: -0.147030
# Iteration 536, loss = 0.03433920
# Validation score: -0.147648
# Iteration 537, loss = 0.03435246
# Validation score: -0.150892
# Iteration 538, loss = 0.03437059
# Validation score: -0.145202
# Iteration 539, loss = 0.03431385
# Validation score: -0.147847
# Iteration 540, loss = 0.03426597
# Validation score: -0.160747
# Iteration 541, loss = 0.03430326
# Validation score: -0.168495
# Iteration 542, loss = 0.03427498
# Validation score: -0.164623
# Iteration 543, loss = 0.03425788
# Validation score: -0.160349
# Validation score did not improve more than tol=0.000100 for 500 consecutive epochs. Stopping.
# /home/ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 42
#   warnings.warn(f"Y residual is constant at iteration {k}")
# PLSRegression(n_components=1000)

# %%
n = X_test.shape[0]
results = estcv.predict(X_test_in.reshape([X_test_in.shape[0],
                                           X_test_in.shape[1]*X_test_in.shape[2]]))
ut_l = results
plt.rcParams["figure.figsize"] = (15,5)
# Cross validation results
[fig,ax] = plt.subplots(1,2,sharex=True, sharey=True)
lr_prepost = linregress(pre_imp[test_index],y_test)
ax[0].scatter(pre_imp[test_index],y_test)
ax[0].plot(pre_imp[test_index],pre_imp[test_index]*lr_prepost.slope+lr_prepost.intercept,'-r')
ax[0].set_title('LCT')
ax[0].set_ylabel("DBS improvement")
ax[0].set_xlabel("Prediction")
# ax[0].set_ylim([0, 1])
# ax[0].set_xlim([0, 1])
text = f"$y={lr_prepost.slope:0.3f}\;x{lr_prepost.intercept:+0.3f}$\n$r = {lr_prepost.rvalue:0.3f}$\n$p = {lr_prepost.pvalue:0.3f}$"
ax[0].text(0.5, 0.5, text,transform=ax[0].transAxes,
     fontsize=14, verticalalignment='top')
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')

lr_pred_qr = linregress(np.asarray(ut_l).ravel(),y_test)
ax[1].scatter(np.asarray(ut_l).ravel(),y_test)
ax[1].plot(np.asarray(ut_l).ravel(),np.asarray(ut_l).ravel()*lr_pred_qr.slope+lr_pred_qr.intercept,'-r')
ax[1].set_title('MLPRegressor')
ax[1].set_ylabel("DBS improvement")
ax[1].set_xlabel("Prediction")
text = f"$y={lr_pred_qr.slope:0.3f}\;x{lr_pred_qr.intercept:+0.3f}$\n$r = {lr_pred_qr.rvalue:0.3f}$\n$p = {lr_pred_qr.pvalue:0.10f}$"
ax[1].text(0.5, 0.5, text,transform=ax[1].transAxes,
     fontsize=14, verticalalignment='top')
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')

plt.style.use('default')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
