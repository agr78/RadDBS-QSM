# %%
# Import libraries
import sys
sys.path.append('../')
import os
os.environ["OMP_NUM_THREADS"] = "1" # export OMP_NUM_THREADS=4
os.environ["OPENBLAS_NUM_THREADS"] = "1" # export OPENBLAS_NUM_THREADS=4 
os.environ["MKL_NUM_THREADS"] = "1" # export MKL_NUM_THREADS=6
os.environ["VECLIB_MAXIMUM_THREADS"] = "1" # export VECLIB_MAXIMUM_THREADS=4
os.environ["NUMEXPR_NUM_THREADS"] = "1" # export NUMEXPR_NUM_THREADS=6
import matplotlib.pyplot as plt
import pandas as pd
import warnings
import sklearn.model_selection as sms
import sklearn.linear_model as slm
import sklearn.preprocessing as skp
import sklearn.feature_selection as skf
import sklearn.utils as sku
from celer import GroupLassoCV
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util

from torch import nn
from sklearn.exceptions import ConvergenceWarning
import joblib
from operator import neg
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
HTML('''<style>.jupyter-matplotlib {background-color: #000;}.widget-label, .jupyter-matplotlib-header{color: #fff;}.jupyter-button {background-color: #333;color: #fff;}</style>''')
# Out:
# <style>.jupyter-matplotlib {background-color: #000;}.widget-label, .jupyter-matplotlib-header{color: #fff;}.jupyter-button {background-color: #333;color: #fff;}</style>

# %%
cv_names = {'CORNELL ID',
            ' OFF (pre-dbs updrs)',
            ' ON (pre-dbs updrs)',
            ' OFF meds ON stim 6mo'}
            # 'Age',
            # 'Sex',
            # 'Ethnicity',
            # 'Race',
            # 'Disease Duration (year)',
            # 'Physician',
            # ' pre op levadopa equivalent dose (mg)',
            # ' Location',
            # ' Target',
            # ' Test medication status'}

# %%
# Get case IDs
case_list = open('/home/ali/RadDBS-QSM/data/docs/cases_90','r')
lines = case_list.read()
lists = np.loadtxt(case_list.name,comments="#", delimiter=",",unpack=False,dtype=str)
case_id = []
for lines in lists:     
    case_id.append(lines[-9:-7])

# Load scores
file_dir = '/home/ali/RadDBS-QSM/data/docs/dbs_03292024.csv'
motor_df = util.filter_data(file_dir,cv_names,True)
# Find cases with all required scores
cv_dict = util.filter_cases(motor_df,cv_names)
subs = cv_dict['CORNELL ID']
# Load extracted features
npy_dir = '/home/ali/RadDBS-QSM/data/npy/'
phi_dir = '/home/ali/RadDBS-QSM/data/phi/phi/'
roi_path = '/data/Ali/atlas/mcgill_pd_atlas/PD25-subcortical-labels.csv'
n_rois = 6
all_rois = False
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595,all_rois)
ids = np.asarray(ID_all).astype(int)

# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(case_id).astype(int),np.asarray(cv_dict['CORNELL ID']).astype(int))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
X_all_c = X_all[c_cases_idx,:,:]
K_all_c = K_all[c_cases_idx,:,:]
R_all_c = R_all[c_cases_idx,:,:]
# Re-index the scored subjects with respect to complete cases
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
per_change = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' OFF meds ON stim 6mo'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_imp = ((cv_dict[' OFF (pre-dbs updrs)']-cv_dict[' ON (pre-dbs updrs)'])/cv_dict[' OFF (pre-dbs updrs)'])[s_cases_idx]
pre_updrs = cv_dict[' OFF (pre-dbs updrs)'][s_cases_idx]
# Reshape keys and ROIs
if all_rois == True:
    K_all_cu = np.empty((K_all_c.shape[0],K_all_c.shape[1],K_all_c.shape[2]+1),dtype=object)
    K_all_cu[:,:,:-1] = K_all_c
    K_all_cu[:,:,-1] = 'pre_updrs'
    K = K_all_cu.reshape((K_all_cu.shape[0],K_all_cu.shape[1]*K_all_cu.shape[2]))[0]
    R = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))
else:
    K = K_all_c.reshape((K_all_c.shape[0],K_all_c.shape[1]*K_all_c.shape[2]))[0]
    R = R_all_c.reshape((R_all_c.shape[0],R_all_c.shape[1]*R_all_c.shape[2]))
# Out:
# Keeping CORNELL ID
# Keeping  OFF (pre-dbs updrs)
# Keeping  ON (pre-dbs updrs)
# Keeping  OFF meds ON stim 6mo
# {'CORNELL ID', ' OFF (pre-dbs updrs)', ' OFF meds ON stim 6mo', ' ON (pre-dbs updrs)'}
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '14', '15', '16', '17', '19', '20', '22', '24', '25', '26', '27', '29', '30', '32', '33', '34', '36', '37', '39', '40', '41', '42', '44', '45', '46', '50', '51', '52', '53', '56', '57', '58', '59', '60', '61', '62', '63', '64', '66', '67', '68', '69', '72', '73', '74', '75', '76', '77', '79', '80', '81', '82', '83', '84', '85', '86', '87', '88', '89', '90']
# Allocated arrays
# Created feature matrix
# Created ROI matrix
# Created feature label matrix

# %%
scoring = 'r2'
results_bls = np.zeros_like(per_change)
results_ls = np.zeros_like(per_change)
results_gls = np.zeros_like(per_change)
gerror = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
err_var = np.zeros_like(per_change)
alphas = np.logspace(-4,4,100)
Ks = []
Kstg = []
w = []
wg = []
pcases = []
pscores = []
s = []

# %%
X = X_all_c.reshape(X_all_c.shape[0],-1)
for cv_name in cv_names:
    if cv_name != ' OFF meds ON stim 6mo':
        print('Appending',cv_name)
        X = np.append(X,cv_dict[cv_name][s_cases_idx].reshape(-1,1),axis=1)
        K = np.append(K,[cv_name],axis=0)
scaler = skp.StandardScaler()
X = scaler.fit_transform(X)
# Out:
# Appending CORNELL ID
# Appending  OFF (pre-dbs updrs)
# Appending  ON (pre-dbs updrs)

# %%
subsc = subs[s_cases_idx]

# %%
results_ls = np.zeros_like(per_change)
c = 0
r = 1
rfs = 100
sc = skp.StandardScaler()
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:].reshape(len(subsc)-1,-1)
    nz = np.var(X_train,axis=0) != 0
    X0_ss0 = sc.fit_transform(X_train[:,nz])
    X_test = X_all_c[test_index,:,:].reshape(1,-1)
    X_test_ss0 = sc.transform(X_test[:,nz])

    y_train = per_change[train_index]
    y_test = per_change[test_index]
    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
      
    # # Cross validation
    # X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
    #                                             X_train,train_index,X_test,
    #                                             test_index,pre_updrs,None,None,None,None,None,None,None,None,None,False,False,False)
    # 10
    cvn = 10
    cv_scores = np.zeros((cvn,1))
    for jj in np.arange(2,cvn):
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=rfs,cv=jj)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj])
        # print('Predicted',est_ls.predict(X0_ss),'for',y_train)
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
      sel = skf.RFECV(lasso,step=rfs,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False)
      est_ls = lasso.fit(X0_ss,y_train)
    results_ls[c] = est_ls.predict(X_test_ss)
    print('Lasso predicts',str(np.round(results_ls[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
  
    c=c+1
# Out:
# LassoCV score for 2 is [0.36163148]
# LassoCV score for 3 is [0.15582665]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.05987344]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.7359 for case with 0.71 and selected CV 2
# LassoCV score for 2 is [0.34994563]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.5555 for case with 0.5 and selected CV 2
# LassoCV score for 2 is [0.29874699]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.15813323]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.5489 for case with 0.67 and selected CV 2
# LassoCV score for 2 is [0.38401881]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.6325 for case with 0.77 and selected CV 2
# LassoCV score for 2 is [0.]
# LassoCV score for 3 is [0.84586705]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.37707635]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.7099 for case with 0.97 and selected CV 3
# LassoCV score for 2 is [0.35180586]
# LassoCV score for 3 is [0.15392497]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.10651404]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.6878 for case with 0.74 and selected CV 2
# LassoCV score for 2 is [0.35174491]
# LassoCV score for 3 is [0.16977776]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.6455 for case with 0.71 and selected CV 2
# LassoCV score for 2 is [0.32937584]
# LassoCV score for 3 is [0.6555728]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.12483745]
# Lasso predicts 0.5571 for case with 0.78 and selected CV 3
# LassoCV score for 2 is [0.27899456]
# LassoCV score for 3 is [0.06469735]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.08438039]
# LassoCV score for 6 is [0.12448917]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.06635962]
# LassoCV score for 9 is [0.03189709]
# Lasso predicts 0.7876 for case with 0.85 and selected CV 2
# LassoCV score for 2 is [0.35784665]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.11536008]
# LassoCV score for 7 is [0.11536008]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.5447 for case with 0.57 and selected CV 2
# LassoCV score for 2 is [0.]
# LassoCV score for 3 is [0.16255163]
# LassoCV score for 4 is [0.13268354]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.06146954]
# LassoCV score for 7 is [0.15115367]
# LassoCV score for 8 is [0.11808548]
# LassoCV score for 9 is [0.04416281]
# Lasso predicts 0.5905 for case with 0.74 and selected CV 3
# LassoCV score for 2 is [0.22876867]
# LassoCV score for 3 is [0.15504096]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.15504096]
# LassoCV score for 7 is [0.11711401]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.6567 for case with 0.71 and selected CV 2
# LassoCV score for 2 is [0.24030885]
# LassoCV score for 3 is [0.14819574]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.7004 for case with 0.81 and selected CV 2
# LassoCV score for 2 is [0.41409508]
# LassoCV score for 3 is [0.2927917]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.17676405]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.13341033]
# Lasso predicts 0.5412 for case with 0.82 and selected CV 2
# LassoCV score for 2 is [0.26181807]
# LassoCV score for 3 is [0.15776002]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.15776002]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.11363325]
# Lasso predicts 0.5337 for case with 0.67 and selected CV 2
# LassoCV score for 2 is [0.]
# LassoCV score for 3 is [0.7729825]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.10846067]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.7438 for case with 0.66 and selected CV 3
# LassoCV score for 2 is [0.17633732]
# LassoCV score for 3 is [0.68581116]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.07463889]
# LassoCV score for 6 is [0.08125867]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.77759495]
# Lasso predicts 0.56 for case with 0.88 and selected CV 9
# LassoCV score for 2 is [0.23168652]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.5414 for case with 0.19 and selected CV 2
# LassoCV score for 2 is [0.20536356]
# LassoCV score for 3 is [0.73466852]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.00151979]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.434 for case with 0.85 and selected CV 3
# LassoCV score for 2 is [0.42445838]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.16173302]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.6806 for case with 0.3 and selected CV 2
# LassoCV score for 2 is [0.36922145]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.13254457]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.]
# Lasso predicts 0.6606 for case with 0.47 and selected CV 2
# LassoCV score for 2 is [0.31181546]
# LassoCV score for 3 is [0.]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.00299429]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.98849502]
# Lasso predicts 0.5416 for case with 0.08 and selected CV 9
# LassoCV score for 2 is [0.24660996]
# LassoCV score for 3 is [0.5463577]
# LassoCV score for 4 is [0.]
# LassoCV score for 5 is [0.]
# LassoCV score for 6 is [0.]
# LassoCV score for 7 is [0.]
# LassoCV score for 8 is [0.]
# LassoCV score for 9 is [0.15304663]
# Lasso predicts 0.7941 for case with 0.52 and selected CV 3
# LassoCV score for 2 is [0.]
# LassoCV score for 3 is [0.]

# %%
results_ls[results_ls>1] = 1
util.eval_prediction(np.vstack((pre_imp,
                               results_ls,
                               )),
                               per_change,
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
