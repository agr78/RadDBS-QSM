# %%
# Import libraries
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from econml.sklearn_extensions.linear_model import WeightedLassoCV
import sklearn.model_selection as sms
import sklearn.linear_model as slm
import sklearn.preprocessing as skp
import sklearn.metrics as sme
import sklearn.feature_selection as skf
import sklearn.ensemble as ske
import sklearn.utils as sku
import sklearn.decomposition as skd
import sklearn.neighbors as skn
from sklearn.exceptions import ConvergenceWarning
from celer import GroupLassoCV
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util
from scipy.spatial import cKDTree
import nibabel as nib
import os
import pickle
from torch import nn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
HTML('''
<style>
.jupyter-matplotlib {
    background-color: #000;
}

.widget-label, .jupyter-matplotlib-header{
    color: #fff;
}

.jupyter-button {
    background-color: #333;
    color: #fff;
}
</style>
''')
# Out:
# <style>
# .jupyter-matplotlib {
#     background-color: #000;
# }
#
# .widget-label, .jupyter-matplotlib-header{
#     color: #fff;
# }
#
# .jupyter-button {
#     background-color: #333;
#     color: #fff;
# }
# </style>

# %%
# Maybe y should also be scaled? 
# Perhaps a transform would be more effective, or scaling implemented with consistent cross-validation
# Different scaling methods? 
#     This seems most important for noise-sensitive models like LARS. All other use StandardScaler()
# Transformers?
# Model-specific scaling methods?
#     Yes, see above
# Common cross-validation function ✓
#     Use built-in functions wherever possible and `utils.gridsearch_pickparams()` elsewhere
# Quantile loss
# RANSAC
# Data augmentation? (Mixup)
# Data generation? (SMOGN)
# Combine CHH dataset ✓
# Implement CV and test ✓
# Print selected features ✓
# Make magnitude templates
# Sample weights ✓
# Look at segmentations by error ✓ (Appears to have most difference in red nucleus, which includes surrounding (white?) matter for underperforming cases)
# Extract features from current (1:6) eroded ROIs
# Extract features from all ROIs
# Plot segmentation variance against error for each case across all ROIs ✓
# Why does excluding the subthalamic nucleus increase the correlation (r=0.5 -> r=0.6)?
# Best performance with all ROIs: cvn=6, k=1800
# Best performance with ROIs 0:4, excluding STN: cvn=6, k=1800
# Should the pre-operative UPDRS be appended once or to each ROI? ✓
# Plot histogram of features for successful and unsuccessful predictions

# %%
# Augment with CHH data
X0_gt = np.load('/home/ali/RadDBS-QSM/data/npy/old/X0_gt_chh_rois.npy')
df = pd.read_csv('/home/ali/RadDBS-QSM/data/xlxs/updrs_iii_chh.csv')
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]
n_rois = 6
# Data
s_directory = open('/home/ali/RadDBS-QSM/data/roi/roi_list','r').read().splitlines()
# Load
with open('/home/ali/RadDBS-QSM/data/pickles/segs_chh', "rb") as fp:  
    segs = pickle.load(fp)
    n_cases = len(segs)
with open('/home/ali/RadDBS-QSM/data/pickles/qsms_chh', "rb") as fp:  
    qsms = pickle.load(fp)
with open('/home/ali/RadDBS-QSM/data/phi/chh/Phi_mcl_gt_roi_chh', "rb") as fp:  
    Phi_gt = pickle.load(fp)
L = int(len(X0_gt)/n_cases)
n_features = int(L/n_rois)
# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][-2:])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
for i in range(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float)                             
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float) 
post_updrs_iii_off =  np.asarray(df[df.columns[6]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float) 

per_change = (pre_updrs_iii_off-post_updrs_iii_off)/pre_updrs_iii_off
pre_updrs_off = pre_updrs_iii_off
X_all_c = X0_gt.reshape(n_cases,n_rois,n_features)
X_all_c = X_all_c[:,0:4,:]
lct_change = (pre_updrs_iii_off-pre_updrs_iii_on)/pre_updrs_iii_off
pre_imp = lct_change
subsc = subject_id_corr
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000001 for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000002 for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000003 for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000004 for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000005 for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000006 for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000007 for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000008 for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000009 for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000010 for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000011 for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000013 for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000014 for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000016 for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000018 for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000019 for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000020 for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000021 for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000022 for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000023 for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000024 for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000025 for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000026 for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000027 for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000028 for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000029 for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000030 for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000031 for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000032 for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000033 for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000034 for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000035 for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000036 for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000037 for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000038 for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000039 for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000040 for case 40.0

# %%
scoring = 'r2'
r = 1
results_bls = np.zeros_like(per_change)
results_ls = np.zeros(r*len(per_change))
results_gls = np.zeros_like(per_change)
gerror = np.zeros_like(per_change)
alphas = np.logspace(-5,-3,100)
Ks = []
Kstg = []
w = []
wg = []
pcases = []

# %%
Js = []
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                X_train,train_index,X_test,
                                                test_index,pre_updrs_off,None,None,None,None,None,None,None,None,None,False,False,False)
    # 10
    cvn = 10
    cv_scores = np.zeros((cvn,1))
    rs = 1
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        np.random.seed(rs)
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        rs = rs+1
        
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=1000,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj])
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)

      # Break any ties
      if np.sum(cv_scores == best_cv) > 1:
        cv_scores_tb = np.zeros((np.sum(cv_scores == best_cv),1))
        for jjj in (cv_scores == cv_scores(best_cv)):
          if jjj > 0:
            skf_g = sms.StratifiedKFold(n_splits=np.arange(2,cvn)[jjj],shuffle=True,random_state=1)
            skf_gen = skf_g.split(X0_ss0,y_cat) 
            X0_sst = sel.fit_transform(X0_ss0,y_train)
            X0_ss = X0_sst
            lasso = slm.LassoLarsCV(max_iter=1000,cv=np.arange(2,cvn)[jjj],n_jobs=-1,normalize=False,eps=0.1)
            est_ls = lasso.fit(X0_ss,y_train)
            cv_scores_tb[jjj] = est_ls.score(X0_ss,y_train)
        best_cv = np.argmax(cv_scores_tb)
      
      # Fit whole dataset with optimal cv
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=1000,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst
      dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
    results_ls[c] = est_ls.predict(X_test_ss)
    print('Lasso predicts',str(np.round(results_ls[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
  
    c=c+1
# Out:
# LassoCV score for 2 is [0.99724066]
# LassoCV score for 3 is [0.98639018]
# LassoCV score for 4 is [0.99361337]
# LassoCV score for 5 is [0.99218086]
# LassoCV score for 6 is [0.98992816]
# LassoCV score for 7 is [0.99815299]
# LassoCV score for 8 is [0.97801476]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.7311 for case with 0.72 and selected CV 9
# LassoCV score for 2 is [0.90631106]
# LassoCV score for 3 is [0.98810373]
# LassoCV score for 4 is [0.95219976]
# LassoCV score for 5 is [0.99979684]
# LassoCV score for 6 is [0.99591903]
# LassoCV score for 7 is [0.9999997]
# LassoCV score for 8 is [0.99925802]
# LassoCV score for 9 is [0.99999999]
# Lasso predicts 0.4944 for case with 0.47 and selected CV 9
# LassoCV score for 2 is [0.99797528]
# LassoCV score for 3 is [0.9999998]
# LassoCV score for 4 is [0.99101211]
# LassoCV score for 5 is [0.99633111]
# LassoCV score for 6 is [0.9841594]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.95732042]
# LassoCV score for 9 is [0.92526924]
# Lasso predicts 0.8307 for case with 0.69 and selected CV 7
# LassoCV score for 2 is [0.81911504]
# LassoCV score for 3 is [0.92204451]
# LassoCV score for 4 is [0.99970248]
# LassoCV score for 5 is [0.99354597]
# LassoCV score for 6 is [0.87892877]
# LassoCV score for 7 is [0.99999987]
# LassoCV score for 8 is [0.99981449]
# LassoCV score for 9 is [0.99999998]
# Lasso predicts 0.6081 for case with 0.42 and selected CV 9
# LassoCV score for 2 is [0.99979787]
# LassoCV score for 3 is [0.99900418]
# LassoCV score for 4 is [0.99272611]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [0.99003318]
# LassoCV score for 7 is [0.99958503]
# LassoCV score for 8 is [0.99787614]
# LassoCV score for 9 is [0.97219282]
# Lasso predicts 0.4734 for case with 0.15 and selected CV 5
# LassoCV score for 2 is [0.99307798]
# LassoCV score for 3 is [0.98801862]
# LassoCV score for 4 is [0.97977331]
# LassoCV score for 5 is [0.99979325]
# LassoCV score for 6 is [0.99999999]
# LassoCV score for 7 is [0.99985204]
# LassoCV score for 8 is [0.99993854]
# LassoCV score for 9 is [0.93712109]
# Lasso predicts 0.4819 for case with 0.44 and selected CV 6
# LassoCV score for 2 is [0.88362228]
# LassoCV score for 3 is [0.99890529]
# LassoCV score for 4 is [0.99999859]
# LassoCV score for 5 is [0.95680301]
# LassoCV score for 6 is [0.99921154]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.99999573]
# LassoCV score for 9 is [0.99986801]
# Lasso predicts 0.7419 for case with 0.88 and selected CV 7
# LassoCV score for 2 is [0.97857824]
# LassoCV score for 3 is [0.88869952]
# LassoCV score for 4 is [0.99913335]
# LassoCV score for 5 is [0.99999979]
# LassoCV score for 6 is [0.99999966]
# LassoCV score for 7 is [0.99983711]
# LassoCV score for 8 is [0.90908099]
# LassoCV score for 9 is [0.99999966]
# Lasso predicts 0.4128 for case with 0.4 and selected CV 5
# LassoCV score for 2 is [0.9174473]
# LassoCV score for 3 is [0.98538651]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.98717408]
# LassoCV score for 6 is [0.99999924]
# LassoCV score for 7 is [0.97749323]
# LassoCV score for 8 is [0.9284636]
# LassoCV score for 9 is [0.96861326]
# Lasso predicts 0.6133 for case with 0.6 and selected CV 4
# LassoCV score for 2 is [0.97682448]
# LassoCV score for 3 is [0.99655302]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.99519762]
# LassoCV score for 6 is [0.99945645]
# LassoCV score for 7 is [0.9999727]
# LassoCV score for 8 is [0.9998876]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.4984 for case with 0.81 and selected CV 4
# LassoCV score for 2 is [0.86718129]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99944328]
# LassoCV score for 5 is [0.9999658]
# LassoCV score for 6 is [0.99999964]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.93072615]
# LassoCV score for 9 is [0.91825096]
# Lasso predicts 0.6554 for case with 0.64 and selected CV 7
# LassoCV score for 2 is [0.890532]
# LassoCV score for 3 is [0.99999926]
# LassoCV score for 4 is [0.99630507]
# LassoCV score for 5 is [0.99999999]
# LassoCV score for 6 is [0.96385438]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.88932491]
# LassoCV score for 9 is [0.94071945]
# Lasso predicts 0.5936 for case with 0.72 and selected CV 7
# LassoCV score for 2 is [0.90507063]
# LassoCV score for 3 is [0.99900923]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.99987942]
# LassoCV score for 8 is [0.98317999]
# LassoCV score for 9 is [0.99791669]
# Lasso predicts 0.6199 for case with 0.31 and selected CV 4
# LassoCV score for 2 is [0.83579438]
# LassoCV score for 3 is [0.97291644]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.99572235]
# LassoCV score for 6 is [0.99360913]
# LassoCV score for 7 is [0.98564174]
# LassoCV score for 8 is [0.99438396]
# LassoCV score for 9 is [0.927148]
# Lasso predicts 0.4949 for case with 0.68 and selected CV 4
# LassoCV score for 2 is [0.98423873]
# LassoCV score for 3 is [0.99992413]
# LassoCV score for 4 is [0.99066017]
# LassoCV score for 5 is [0.99997864]
# LassoCV score for 6 is [0.97479348]
# LassoCV score for 7 is [0.98464049]
# LassoCV score for 8 is [0.99680683]
# LassoCV score for 9 is [0.93751411]
# Lasso predicts 0.3409 for case with 0.34 and selected CV 5
# LassoCV score for 2 is [0.94559591]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99869929]
# LassoCV score for 5 is [0.99750144]
# LassoCV score for 6 is [0.94416514]
# LassoCV score for 7 is [0.98975231]
# LassoCV score for 8 is [0.94180628]
# LassoCV score for 9 is [0.9999998]
# Lasso predicts 0.4496 for case with 0.59 and selected CV 3
# LassoCV score for 2 is [0.91292494]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99997059]
# LassoCV score for 5 is [0.99975372]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [1.]
# LassoCV score for 9 is [0.99999965]
# Lasso predicts 0.6545 for case with 0.94 and selected CV 7
# LassoCV score for 2 is [0.99962002]
# LassoCV score for 3 is [0.99995286]
# LassoCV score for 4 is [0.99994117]
# LassoCV score for 5 is [0.99802233]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.93201862]
# LassoCV score for 8 is [0.98719926]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.6911 for case with 0.84 and selected CV 6
# LassoCV score for 2 is [0.95430683]
# LassoCV score for 3 is [0.99999068]
# LassoCV score for 4 is [0.99994137]
# LassoCV score for 5 is [0.99999098]
# LassoCV score for 6 is [0.99792636]
# LassoCV score for 7 is [0.99999921]
# LassoCV score for 8 is [0.99998965]
# LassoCV score for 9 is [0.99225205]
# Lasso predicts 0.2686 for case with 0.1 and selected CV 7
# LassoCV score for 2 is [0.99935112]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99992376]
# LassoCV score for 5 is [0.99999738]
# LassoCV score for 6 is [0.99971761]
# LassoCV score for 7 is [0.99991737]
# LassoCV score for 8 is [0.96752819]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.4528 for case with 0.41 and selected CV 3
# LassoCV score for 2 is [0.90656044]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.99899144]
# LassoCV score for 6 is [0.99999577]
# LassoCV score for 7 is [0.99843329]
# LassoCV score for 8 is [0.99088861]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.6068 for case with 0.57 and selected CV 3
# LassoCV score for 2 is [0.90315639]
# LassoCV score for 3 is [0.95396949]
# LassoCV score for 4 is [0.99896299]
# LassoCV score for 5 is [0.96969314]
# LassoCV score for 6 is [0.94292461]
# LassoCV score for 7 is [0.99742131]
# LassoCV score for 8 is [0.99977421]
# LassoCV score for 9 is [0.99988239]
# Lasso predicts 0.6793 for case with 0.66 and selected CV 9
# LassoCV score for 2 is [0.98377082]
# LassoCV score for 3 is [0.97796214]
# LassoCV score for 4 is [0.99635848]
# LassoCV score for 5 is [0.95398383]
# LassoCV score for 6 is [0.98475749]
# LassoCV score for 7 is [0.99999994]
# LassoCV score for 8 is [0.99976873]
# LassoCV score for 9 is [0.93178879]
# Lasso predicts 0.5684 for case with 0.63 and selected CV 7
# LassoCV score for 2 is [0.94738993]
# LassoCV score for 3 is [0.99069627]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.99812167]
# LassoCV score for 6 is [0.99961551]
# LassoCV score for 7 is [0.99866375]
# LassoCV score for 8 is [0.99909876]
# LassoCV score for 9 is [0.99769669]
# Lasso predicts 0.6145 for case with 0.47 and selected CV 4
# LassoCV score for 2 is [0.9397798]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99911561]
# LassoCV score for 5 is [0.981038]
# LassoCV score for 6 is [0.99808146]
# LassoCV score for 7 is [0.94184185]
# LassoCV score for 8 is [0.99999938]
# LassoCV score for 9 is [0.99999999]
# Lasso predicts 0.3374 for case with 0.28 and selected CV 3
# LassoCV score for 2 is [0.9937643]
# LassoCV score for 3 is [0.99996081]
# LassoCV score for 4 is [0.99247992]
# LassoCV score for 5 is [0.97230693]
# LassoCV score for 6 is [0.9910048]
# LassoCV score for 7 is [0.94433274]
# LassoCV score for 8 is [1.]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.6947 for case with 0.59 and selected CV 8
# LassoCV score for 2 is [0.9791791]
# LassoCV score for 3 is [0.99771939]
# LassoCV score for 4 is [0.99978518]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [0.96516226]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.99999993]
# LassoCV score for 9 is [0.99999999]
# Lasso predicts 0.6244 for case with 0.53 and selected CV 7
# LassoCV score for 2 is [0.96462723]
# LassoCV score for 3 is [0.99163766]
# LassoCV score for 4 is [0.99609042]
# LassoCV score for 5 is [0.98606625]
# LassoCV score for 6 is [0.96901386]
# LassoCV score for 7 is [0.99212561]
# LassoCV score for 8 is [0.99902267]
# LassoCV score for 9 is [0.999996]
# Lasso predicts 0.6288 for case with 0.86 and selected CV 9
# LassoCV score for 2 is [0.96027224]
# LassoCV score for 3 is [0.99999993]
# LassoCV score for 4 is [0.99909252]
# LassoCV score for 5 is [0.99987062]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.99998578]
# LassoCV score for 8 is [0.96760705]
# LassoCV score for 9 is [0.9992791]
# Lasso predicts 0.4747 for case with 0.48 and selected CV 6
# LassoCV score for 2 is [0.96753194]
# LassoCV score for 3 is [0.99999833]
# LassoCV score for 4 is [0.99995352]
# LassoCV score for 5 is [0.99971354]
# LassoCV score for 6 is [0.97788881]
# LassoCV score for 7 is [0.99999938]
# LassoCV score for 8 is [0.95372985]
# LassoCV score for 9 is [0.99926329]
# Lasso predicts 0.6418 for case with 0.66 and selected CV 7
# LassoCV score for 2 is [0.95889184]
# LassoCV score for 3 is [0.99158425]
# LassoCV score for 4 is [0.99945378]
# LassoCV score for 5 is [0.99999777]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.97174486]
# LassoCV score for 8 is [0.98749752]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.4876 for case with 0.33 and selected CV 6
# LassoCV score for 2 is [0.86677593]
# LassoCV score for 3 is [0.96154302]
# LassoCV score for 4 is [0.99809416]
# LassoCV score for 5 is [0.99993768]
# LassoCV score for 6 is [0.92401303]
# LassoCV score for 7 is [0.92295706]
# LassoCV score for 8 is [0.99177935]
# LassoCV score for 9 is [0.99999999]
# Lasso predicts 0.5155 for case with 0.49 and selected CV 9
# LassoCV score for 2 is [0.98783326]
# LassoCV score for 3 is [0.99995865]
# LassoCV score for 4 is [0.99989564]
# LassoCV score for 5 is [0.98228662]
# LassoCV score for 6 is [0.98994325]
# LassoCV score for 7 is [0.98023206]
# LassoCV score for 8 is [0.9985528]
# LassoCV score for 9 is [0.99992619]
# Lasso predicts 0.7345 for case with 0.78 and selected CV 3
# LassoCV score for 2 is [0.9949386]
# LassoCV score for 3 is [0.99484587]
# LassoCV score for 4 is [0.9998704]
# LassoCV score for 5 is [0.9994395]
# LassoCV score for 6 is [0.97682272]
# LassoCV score for 7 is [0.99999922]
# LassoCV score for 8 is [0.9920298]
# LassoCV score for 9 is [0.99997199]
# Lasso predicts 0.6192 for case with 0.81 and selected CV 7
# LassoCV score for 2 is [0.99604807]
# LassoCV score for 3 is [0.99225123]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.9999375]
# LassoCV score for 6 is [0.95857809]
# LassoCV score for 7 is [0.99525081]
# LassoCV score for 8 is [0.92572923]
# LassoCV score for 9 is [0.99999982]
# Lasso predicts 0.6958 for case with 0.71 and selected CV 4
# LassoCV score for 2 is [0.99965707]
# LassoCV score for 3 is [0.99893393]
# LassoCV score for 4 is [0.99680837]
# LassoCV score for 5 is [0.99705422]
# LassoCV score for 6 is [0.96282888]
# LassoCV score for 7 is [0.95127599]
# LassoCV score for 8 is [0.90584026]
# LassoCV score for 9 is [0.99534103]
# Lasso predicts 0.4526 for case with 0.32 and selected CV 2
# LassoCV score for 2 is [0.95516295]
# LassoCV score for 3 is [0.99301094]
# LassoCV score for 4 is [0.99998627]
# LassoCV score for 5 is [0.93097993]
# LassoCV score for 6 is [0.94899425]
# LassoCV score for 7 is [0.9999689]
# LassoCV score for 8 is [0.96506822]
# LassoCV score for 9 is [0.99997203]
# Lasso predicts 0.7497 for case with 0.83 and selected CV 4

# %%
util.eval_prediction(np.vstack((np.repeat(pre_imp,r),
                               results_ls,
                               )),
                               np.repeat(per_change,r),
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
