# %%
# Import libraries
import sys
sys.path.append('../')
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from econml.sklearn_extensions.linear_model import WeightedLassoCV
import sklearn.model_selection as sms
import sklearn.linear_model as slm
import sklearn.preprocessing as skp
import sklearn.metrics as sme
import sklearn.feature_selection as skf
import sklearn.ensemble as ske
import sklearn.utils as sku
import sklearn.decomposition as skd
import sklearn.neighbors as skn
from sklearn.exceptions import ConvergenceWarning
from celer import GroupLassoCV
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
import numpy as np
import scipy.stats as stats
from IPython.display import HTML
import util
from scipy.spatial import cKDTree
import nibabel as nib
import os
import pickle
from torch import nn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
HTML('''
<style>
.jupyter-matplotlib {
    background-color: #000;
}

.widget-label, .jupyter-matplotlib-header{
    color: #fff;
}

.jupyter-button {
    background-color: #333;
    color: #fff;
}
</style>
''')
# Out:
# <style>
# .jupyter-matplotlib {
#     background-color: #000;
# }
#
# .widget-label, .jupyter-matplotlib-header{
#     color: #fff;
# }
#
# .jupyter-button {
#     background-color: #333;
#     color: #fff;
# }
# </style>

# %%
# Maybe y should also be scaled? 
# Perhaps a transform would be more effective, or scaling implemented with consistent cross-validation
# Different scaling methods? 
#     This seems most important for noise-sensitive models like LARS. All other use StandardScaler()
# Transformers?
# Model-specific scaling methods?
#     Yes, see above
# Common cross-validation function ✓
#     Use built-in functions wherever possible and `utils.gridsearch_pickparams()` elsewhere
# Quantile loss
# RANSAC
# Data augmentation? (Mixup)
# Data generation? (SMOGN)
# Combine CHH dataset ✓
# Implement CV and test ✓
# Print selected features ✓
# Make magnitude templates
# Sample weights ✓
# Look at segmentations by error ✓ (Appears to have most difference in red nucleus, which includes surrounding (white?) matter for underperforming cases)
# Extract features from current (1:6) eroded ROIs
# Extract features from all ROIs
# Plot segmentation variance against error for each case across all ROIs ✓
# Why does excluding the subthalamic nucleus increase the correlation (r=0.5 -> r=0.6)?
# Best performance with all ROIs: cvn=6, k=1800
# Best performance with ROIs 0:4, excluding STN: cvn=6, k=1800
# Should the pre-operative UPDRS be appended once or to each ROI? ✓
# Plot histogram of features for successful and unsuccessful predictions

# %%
# Augment with CHH data
X0_gt = np.load('/home/ali/RadDBS-QSM/data/npy/old/X0_gt_chh_rois.npy')
df = pd.read_csv('/home/ali/RadDBS-QSM/data/xlxs/updrs_iii_chh.csv')
# Patient IDs
subject_id = np.asarray(df[df.columns[0]])[1:]
n_rois = 6
# Data
s_directory = open('/home/ali/RadDBS-QSM/data/roi/roi_list','r').read().splitlines()
# Load
with open('/home/ali/RadDBS-QSM/data/pickles/segs_chh', "rb") as fp:  
    segs = pickle.load(fp)
    n_cases = len(segs)
with open('/home/ali/RadDBS-QSM/data/pickles/qsms_chh', "rb") as fp:  
    qsms = pickle.load(fp)
with open('/home/ali/RadDBS-QSM/data/phi/chh/Phi_mcl_gt_roi_chh', "rb") as fp:  
    Phi_gt = pickle.load(fp)
L = int(len(X0_gt)/n_cases)
n_features = int(L/n_rois)
# Only extract ROI if it is present in all cases
seg_labels_all = segs[0]
case_number = np.zeros_like(np.asarray(s_directory))
for i in range(n_cases):
    case_number[i] = float(s_directory[i][-2:])
subject_id_corr = subject_id[np.in1d(subject_id,case_number)]
for i in range(n_cases):
    try:
        print('Found ROIs',str(np.unique(segs[i])),'at segmentation directory file',s_directory[i],'for case',str(subject_id_corr[i]))
    except:
        print('Case',subject_id[i],'quarantined')
pre_updrs_iii_off =  np.asarray(df[df.columns[3]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float)                             
pre_updrs_iii_on =  np.asarray(df[df.columns[4]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float) 
post_updrs_iii_off =  np.asarray(df[df.columns[6]][1:][np.in1d(subject_id,subject_id_corr)]).astype(float) 

per_change = (pre_updrs_iii_off-post_updrs_iii_off)/pre_updrs_iii_off
pre_updrs_off = pre_updrs_iii_off
X_all_c = X0_gt.reshape(n_cases,n_rois,n_features)
X_all_c = X_all_c[:,0:4,:]
lct_change = (pre_updrs_iii_off-pre_updrs_iii_on)/pre_updrs_iii_off
pre_imp = lct_change
subsc = subject_id_corr
# Out:
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000001 for case 1.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000002 for case 2.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000003 for case 3.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000004 for case 4.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000005 for case 5.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000006 for case 6.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000007 for case 7.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000008 for case 8.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000009 for case 9.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000010 for case 10.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000011 for case 11.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000013 for case 13.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000014 for case 14.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000016 for case 16.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000018 for case 18.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000019 for case 19.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000020 for case 20.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000021 for case 21.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000022 for case 22.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000023 for case 23.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000024 for case 24.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000025 for case 25.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000026 for case 26.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000027 for case 27.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000028 for case 28.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000029 for case 29.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000030 for case 30.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000031 for case 31.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000032 for case 32.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000033 for case 33.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000034 for case 34.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000035 for case 35.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000036 for case 36.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000037 for case 37.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000038 for case 38.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000039 for case 39.0
# Found ROIs [0. 1. 2. 3. 4. 5. 6.] at segmentation directory file 00000040 for case 40.0

# %%
scoring = 'r2'
r = 1
results_bls = np.zeros_like(per_change)
results_ls = np.zeros(r*len(per_change))
results_gls = np.zeros_like(per_change)
gerror = np.zeros_like(per_change)
alphas = np.logspace(-5,-3,100)
Ks = []
Kstg = []
w = []
wg = []
pcases = []

# %%
Js = []
err_var = np.zeros_like(per_change)
rerror = np.zeros_like(per_change)
kappa = []
c = 0
for j in np.arange(len(subsc)):
    test_id = subsc[j]
    test_index = subsc == test_id
    train_index = subsc != test_id
    X_train = X_all_c[train_index,:,:]
    X_test = X_all_c[test_index,:,:]
    y_train = per_change[train_index]
    y_test = per_change[test_index]

    y_cat = y_train <= 0.3
    idy = np.where(y_cat==1)
    # Cross validation
    X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                                  X_train,train_index,X_test,
                                                  test_index,pre_updrs_off,None,None,None,None,None,None,None,None,None,False,False,False)
    cvn = 10
    cv_scores = np.zeros((cvn,1))
    for jj in np.arange(2,cvn):
      # Resample to avoid stratification errors
      while np.sum(y_cat) < cvn:
        idyr = np.random.choice(np.asarray(idy).ravel())
        X0_ss0 = np.append(X0_ss0,X0_ss0[idyr,:].reshape(1,-1),axis=0)
        y_train = np.append(y_train,y_train[idyr])
        y_cat = y_train <= 0.3
        
      skf_g = sms.StratifiedKFold(n_splits=jj,shuffle=True,random_state=0)
      skf_gen = skf_g.split(X0_ss0,y_cat)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=jj,n_jobs=-1,normalize=False,eps=0.1)
      with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):
        # Feature selection
        warnings.filterwarnings("ignore", category=ConvergenceWarning)
        sel = skf.RFECV(lasso,step=1000,cv=skf_gen)
        X0_sst = sel.fit_transform(X0_ss0,y_train)
        X0_ss = X0_sst
        est_ls = lasso.fit(X0_ss,y_train)
        cv_scores[jj] = est_ls.score(X0_ss,y_train)
        print('LassoCV score for',jj,'is',cv_scores[jj])
        
    with warnings.catch_warnings() and np.errstate(divide='ignore', invalid='ignore'):        
      best_cv = np.argmax(cv_scores)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      sel = skf.RFECV(lasso,step=1000,cv=best_cv)
      X0_sst = sel.fit_transform(X0_ss0,y_train)
      X_test_sst = sel.transform(X_test_ss0)
      X0_ss = X0_sst
      X_test_ss = X_test_sst
      dx, y_n = cKDTree(X0_ss).query(X_test_ss, k=1)

    # LASSO
    with warnings.catch_warnings():
      warnings.filterwarnings("ignore", category=ConvergenceWarning)
      lasso = slm.LassoLarsCV(max_iter=1000,cv=best_cv,n_jobs=-1,normalize=False,eps=0.1)
      est_ls = lasso.fit(X0_ss,y_train)
    results_ls[c] = est_ls.predict(X_test_ss)
    print('Lasso predicts',str(np.round(results_ls[c],4)),
              'for case with',str(np.round(np.repeat(per_change,r)[c],2)),'and selected CV',best_cv)
  
    c=c+1
# Out:
# LassoCV score for 2 is [0.99998361]
# LassoCV score for 3 is [0.99521978]
# LassoCV score for 4 is [0.98877436]
# LassoCV score for 5 is [0.9955407]
# LassoCV score for 6 is [0.99907853]
# LassoCV score for 7 is [0.98901727]
# LassoCV score for 8 is [0.99993534]
# LassoCV score for 9 is [0.99995832]
# Lasso predicts 0.7907 for case with 0.72
# LassoCV score for 2 is [0.87000297]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.96545421]
# LassoCV score for 5 is [0.99395764]
# LassoCV score for 6 is [0.99643999]
# LassoCV score for 7 is [0.99974931]
# LassoCV score for 8 is [0.99999126]
# LassoCV score for 9 is [0.9989427]
# Lasso predicts 0.4938 for case with 0.47
# LassoCV score for 2 is [0.89752342]
# LassoCV score for 3 is [0.99860111]
# LassoCV score for 4 is [0.98825414]
# LassoCV score for 5 is [0.98079094]
# LassoCV score for 6 is [0.99932653]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.93584915]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.8319 for case with 0.69
# LassoCV score for 2 is [0.79571178]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.9998341]
# LassoCV score for 5 is [0.99999998]
# LassoCV score for 6 is [0.89113452]
# LassoCV score for 7 is [0.99975384]
# LassoCV score for 8 is [0.99999999]
# LassoCV score for 9 is [0.9999997]
# Lasso predicts 0.551 for case with 0.42
# LassoCV score for 2 is [0.9989496]
# LassoCV score for 3 is [0.99999995]
# LassoCV score for 4 is [0.99803541]
# LassoCV score for 5 is [0.99977301]
# LassoCV score for 6 is [0.98435643]
# LassoCV score for 7 is [0.96941334]
# LassoCV score for 8 is [0.99068009]
# LassoCV score for 9 is [0.97378861]
# Lasso predicts 0.3483 for case with 0.15
# LassoCV score for 2 is [0.91098958]
# LassoCV score for 3 is [0.99999999]
# LassoCV score for 4 is [0.99543199]
# LassoCV score for 5 is [0.98580456]
# LassoCV score for 6 is [0.99999998]
# LassoCV score for 7 is [0.99671852]
# LassoCV score for 8 is [0.99948062]
# LassoCV score for 9 is [0.92796131]
# Lasso predicts 0.4875 for case with 0.44
# LassoCV score for 2 is [0.8046823]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.98125413]
# LassoCV score for 5 is [0.92695028]
# LassoCV score for 6 is [0.99576219]
# LassoCV score for 7 is [0.96946803]
# LassoCV score for 8 is [0.99549964]
# LassoCV score for 9 is [0.91686614]
# Lasso predicts 0.7559 for case with 0.88
# LassoCV score for 2 is [0.98492522]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [0.99693558]
# LassoCV score for 6 is [0.99996675]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.99963404]
# LassoCV score for 9 is [0.99966608]
# Lasso predicts 0.402 for case with 0.4
# LassoCV score for 2 is [0.97969335]
# LassoCV score for 3 is [0.99927807]
# LassoCV score for 4 is [0.99770983]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [0.95963043]
# LassoCV score for 7 is [0.96384294]
# LassoCV score for 8 is [0.94079604]
# LassoCV score for 9 is [0.99549028]
# Lasso predicts 0.5936 for case with 0.6
# LassoCV score for 2 is [0.97544032]
# LassoCV score for 3 is [0.92115234]
# LassoCV score for 4 is [0.99998569]
# LassoCV score for 5 is [0.99700729]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.99999983]
# LassoCV score for 8 is [1.]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.4995 for case with 0.81
# LassoCV score for 2 is [0.99824238]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99852389]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [0.99879515]
# LassoCV score for 7 is [0.99725425]
# LassoCV score for 8 is [0.95641454]
# LassoCV score for 9 is [0.92476874]
# Lasso predicts 0.7338 for case with 0.64
# LassoCV score for 2 is [0.97008861]
# LassoCV score for 3 is [0.97415332]
# LassoCV score for 4 is [0.99315704]
# LassoCV score for 5 is [0.99680611]
# LassoCV score for 6 is [0.98605211]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.92353836]
# LassoCV score for 9 is [0.91937158]
# Lasso predicts 0.5936 for case with 0.72
# LassoCV score for 2 is [0.85013045]
# LassoCV score for 3 is [0.99995325]
# LassoCV score for 4 is [0.99999997]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.99981267]
# LassoCV score for 8 is [0.99931471]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.6217 for case with 0.31
# LassoCV score for 2 is [0.94526539]
# LassoCV score for 3 is [0.9999948]
# LassoCV score for 4 is [0.99999959]
# LassoCV score for 5 is [0.99989584]
# LassoCV score for 6 is [0.9642098]
# LassoCV score for 7 is [0.97059028]
# LassoCV score for 8 is [0.99709176]
# LassoCV score for 9 is [0.95949414]
# Lasso predicts 0.5129 for case with 0.68
# LassoCV score for 2 is [0.98283863]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99694974]
# LassoCV score for 5 is [0.98070446]
# LassoCV score for 6 is [0.99590749]
# LassoCV score for 7 is [0.95700917]
# LassoCV score for 8 is [0.91679746]
# LassoCV score for 9 is [0.93795589]
# Lasso predicts 0.4238 for case with 0.34
# LassoCV score for 2 is [0.98353249]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99682358]
# LassoCV score for 5 is [0.9972034]
# LassoCV score for 6 is [0.95137972]
# LassoCV score for 7 is [0.99959095]
# LassoCV score for 8 is [0.9065899]
# LassoCV score for 9 is [0.95664796]
# Lasso predicts 0.4496 for case with 0.59
# LassoCV score for 2 is [0.97987931]
# LassoCV score for 3 is [0.99999632]
# LassoCV score for 4 is [0.99994803]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [0.90550516]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [1.]
# LassoCV score for 9 is [0.85178161]
# Lasso predicts 0.6547 for case with 0.94
# LassoCV score for 2 is [0.97498781]
# LassoCV score for 3 is [0.99175282]
# LassoCV score for 4 is [0.99993098]
# LassoCV score for 5 is [0.99999773]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.99973576]
# LassoCV score for 8 is [0.9516887]
# LassoCV score for 9 is [0.99999457]
# Lasso predicts 0.7166 for case with 0.84
# LassoCV score for 2 is [0.91964817]
# LassoCV score for 3 is [0.99929498]
# LassoCV score for 4 is [0.9999999]
# LassoCV score for 5 is [0.99090148]
# LassoCV score for 6 is [0.99992582]
# LassoCV score for 7 is [0.99999962]
# LassoCV score for 8 is [0.94044621]
# LassoCV score for 9 is [0.99968103]
# Lasso predicts 0.2311 for case with 0.1
# LassoCV score for 2 is [0.7130939]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.96829649]
# LassoCV score for 5 is [0.99999993]
# LassoCV score for 6 is [0.99956941]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.99999711]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.4528 for case with 0.41
# LassoCV score for 2 is [0.91965517]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [1.]
# LassoCV score for 5 is [1.]
# LassoCV score for 6 is [0.99995007]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.9990519]
# LassoCV score for 9 is [0.99999838]
# Lasso predicts 0.6623 for case with 0.57
# LassoCV score for 2 is [0.83874377]
# LassoCV score for 3 is [0.99317836]
# LassoCV score for 4 is [0.99986449]
# LassoCV score for 5 is [0.96556367]
# LassoCV score for 6 is [0.90882028]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.99512275]
# LassoCV score for 9 is [0.98900193]
# Lasso predicts 0.7751 for case with 0.66
# LassoCV score for 2 is [0.93347483]
# LassoCV score for 3 is [0.97974656]
# LassoCV score for 4 is [0.99946809]
# LassoCV score for 5 is [0.94952607]
# LassoCV score for 6 is [0.99998351]
# LassoCV score for 7 is [0.99999989]
# LassoCV score for 8 is [0.99999966]
# LassoCV score for 9 is [0.99805922]
# Lasso predicts 0.6349 for case with 0.63
# LassoCV score for 2 is [0.95899029]
# LassoCV score for 3 is [0.98382349]
# LassoCV score for 4 is [0.99959891]
# LassoCV score for 5 is [0.99750212]
# LassoCV score for 6 is [0.97384025]
# LassoCV score for 7 is [0.99783993]
# LassoCV score for 8 is [0.99997848]
# LassoCV score for 9 is [0.95259612]
# Lasso predicts 0.583 for case with 0.47
# LassoCV score for 2 is [0.99999963]
# LassoCV score for 3 is [0.99695142]
# LassoCV score for 4 is [0.99907295]
# LassoCV score for 5 is [0.99985051]
# LassoCV score for 6 is [0.98409319]
# LassoCV score for 7 is [0.94737001]
# LassoCV score for 8 is [0.99987924]
# LassoCV score for 9 is [0.99871558]
# Lasso predicts 0.4014 for case with 0.28
# LassoCV score for 2 is [0.99939436]
# LassoCV score for 3 is [0.99965321]
# LassoCV score for 4 is [0.96718322]
# LassoCV score for 5 is [0.99999998]
# LassoCV score for 6 is [1.]
# LassoCV score for 7 is [0.93184295]
# LassoCV score for 8 is [0.95620045]
# LassoCV score for 9 is [0.9933576]
# Lasso predicts 0.6406 for case with 0.59
# LassoCV score for 2 is [0.98069825]
# LassoCV score for 3 is [0.99703111]
# LassoCV score for 4 is [0.98519778]
# LassoCV score for 5 is [0.98713881]
# LassoCV score for 6 is [0.96318713]
# LassoCV score for 7 is [0.96525359]
# LassoCV score for 8 is [0.92036967]
# LassoCV score for 9 is [0.99999993]
# Lasso predicts 0.6358 for case with 0.53
# LassoCV score for 2 is [0.93710976]
# LassoCV score for 3 is [0.99984787]
# LassoCV score for 4 is [0.99388896]
# LassoCV score for 5 is [0.99217393]
# LassoCV score for 6 is [0.97367955]
# LassoCV score for 7 is [0.99997826]
# LassoCV score for 8 is [0.99990267]
# LassoCV score for 9 is [0.9985539]
# Lasso predicts 0.6093 for case with 0.86
# LassoCV score for 2 is [0.99330464]
# LassoCV score for 3 is [0.99999999]
# LassoCV score for 4 is [0.99999984]
# LassoCV score for 5 is [0.98628999]
# LassoCV score for 6 is [0.927284]
# LassoCV score for 7 is [0.93509464]
# LassoCV score for 8 is [0.99999086]
# LassoCV score for 9 is [0.99999996]
# Lasso predicts 0.4549 for case with 0.48
# LassoCV score for 2 is [0.97964796]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.99709764]
# LassoCV score for 5 is [0.99962902]
# LassoCV score for 6 is [0.99999986]
# LassoCV score for 7 is [0.97084919]
# LassoCV score for 8 is [0.99999997]
# LassoCV score for 9 is [0.99999321]
# Lasso predicts 0.6355 for case with 0.66
# LassoCV score for 2 is [0.94853054]
# LassoCV score for 3 is [0.99999592]
# LassoCV score for 4 is [0.9995637]
# LassoCV score for 5 is [0.99998407]
# LassoCV score for 6 is [0.99999985]
# LassoCV score for 7 is [0.99989438]
# LassoCV score for 8 is [0.99999001]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.5291 for case with 0.33
# LassoCV score for 2 is [0.91371042]
# LassoCV score for 3 is [0.99036574]
# LassoCV score for 4 is [0.9966945]
# LassoCV score for 5 is [0.99989982]
# LassoCV score for 6 is [0.93453305]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.92174076]
# LassoCV score for 9 is [0.99998691]
# Lasso predicts 0.3763 for case with 0.49
# LassoCV score for 2 is [0.9974434]
# LassoCV score for 3 is [0.99763919]
# LassoCV score for 4 is [0.9974434]
# LassoCV score for 5 is [0.98740433]
# LassoCV score for 6 is [0.99126231]
# LassoCV score for 7 is [0.99271658]
# LassoCV score for 8 is [0.99387834]
# LassoCV score for 9 is [0.98948065]
# Lasso predicts 0.7315 for case with 0.78
# LassoCV score for 2 is [0.92964201]
# LassoCV score for 3 is [0.99347401]
# LassoCV score for 4 is [0.99994722]
# LassoCV score for 5 is [0.99478566]
# LassoCV score for 6 is [0.94740665]
# LassoCV score for 7 is [0.99594315]
# LassoCV score for 8 is [0.96502248]
# LassoCV score for 9 is [0.99728193]
# Lasso predicts 0.5911 for case with 0.81
# LassoCV score for 2 is [0.98696941]
# LassoCV score for 3 is [0.99168198]
# LassoCV score for 4 is [0.97078456]
# LassoCV score for 5 is [0.99380699]
# LassoCV score for 6 is [0.99584084]
# LassoCV score for 7 is [0.99957355]
# LassoCV score for 8 is [0.93864226]
# LassoCV score for 9 is [1.]
# Lasso predicts 0.7009 for case with 0.71
# LassoCV score for 2 is [0.99964018]
# LassoCV score for 3 is [0.9998243]
# LassoCV score for 4 is [0.99732524]
# LassoCV score for 5 is [0.9929638]
# LassoCV score for 6 is [0.99757507]
# LassoCV score for 7 is [1.]
# LassoCV score for 8 is [0.90571275]
# LassoCV score for 9 is [0.99979779]
# Lasso predicts 0.5072 for case with 0.32
# LassoCV score for 2 is [0.99409187]
# LassoCV score for 3 is [1.]
# LassoCV score for 4 is [0.96870781]
# LassoCV score for 5 is [0.92901181]
# LassoCV score for 6 is [0.96675198]
# LassoCV score for 7 is [0.9083718]
# LassoCV score for 8 is [0.93014058]
# LassoCV score for 9 is [0.94607061]
# Lasso predicts 0.7387 for case with 0.83

# %%
util.eval_prediction(np.vstack((np.repeat(pre_imp,r),
                               results_ls,
                               )),
                               np.repeat(per_change,r),
                               ['LCT',
                                'Lasso',
                                ],(15,5))
plt.ylim([0,2])
plt.xlim([0,2])
plt.style.use('default')
