# %%
# Import libraries
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn.svm import SVR
import sklearn.model_selection as sms
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import r2_score
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import os
import pickle
import pandas as pd
import logging
from scipy.stats import linregress
import smogn
import pandas
from collections import Counter
from multiprocessing import Pool
from notebook import notebookapp
from numpy import matlib
import random
from scipy import ndimage
from util import pyvis
from util import extract
from loader import data_loader
from IPython.display import HTML
import util
import smogn
from smogn.phi import phi
from smogn.phi_ctrl_pts import phi_ctrl_pts
import warnings
from multiprocessing import Pool
import sklearn.linear_model as skl
import sklearn.neural_network as snn

# %%
HTML('''
<style>
.jupyter-matplotlib {
    background-color: #000;
}

.widget-label, .jupyter-matplotlib-header{
    color: #fff;
}

.jupyter-button {
    background-color: #333;
    color: #fff;
}
</style>
''')
# Out:
# <style>
# .jupyter-matplotlib {
#     background-color: #000;
# }
#
# .widget-label, .jupyter-matplotlib-header{
#     color: #fff;
# }
#
# .jupyter-button {
#     background-color: #333;
#     color: #fff;
# }
# </style>

# %%
# Get case IDs
case_list = open('/home/ali/RadDBS-QSM/data/docs/cases_90','r')
lines = case_list.read()
lists = np.loadtxt(case_list.name,comments="#", delimiter=",",unpack=False,dtype=str)
case_id = []
for lines in lists:     
    case_id.append(lines[-9:-7])

# Load scores
file_dir = '/home/ali/RadDBS-QSM/data/docs/QSM anonymus- 6.22.2023-1528.csv'
motor_df = util.filter_scores(file_dir,'pre-dbs updrs','stim','CORNELL ID')
# Find cases with all required scores
subs,pre_imp,post_imp,pre_updrs_off = util.get_full_cases(motor_df,
                                                          'CORNELL ID',
                                                          'OFF (pre-dbs updrs)',
                                                          'ON (pre-dbs updrs)',
                                                          'OFF meds ON stim 6mo')
# Load extracted features
npy_dir = '/home/ali/RadDBS-QSM/data/npy/'
phi_dir = '/home/ali/RadDBS-QSM/data/phi/'
roi_path = '/data/Ali/atlas/mcgill_pd_atlas/PD25-subcortical-labels.csv'
n_rois = 6
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595)
ids = np.asarray(ID_all).astype(int)
# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(case_id).astype(int),np.asarray(subs).astype(int))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
X_all_c = X_all[c_cases_idx,:,:]
K_all_c = K_all[c_cases_idx,:,:]
R_all_c = R_all[c_cases_idx,:,:]
# Re-index the scored subjects with respect to complete cases
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
pre_imp = pre_imp[s_cases_idx]
post_imp = post_imp[s_cases_idx]
pre_updrs_off = pre_updrs_off[s_cases_idx]
per_change = post_imp

# %%
# X_train,X_test,y_train,y_test,train_index,test_index = util.set_split(X_all_c,per_change,1,0.1)
# X0_tt,scaler = util.make_feature_matrix(X_train,pre_updrs_off[train_index])
# n = 10
# def loop(j):
#         # Reload training data
#         X_smogn1,y_smogn1 = util.rad_smogn(X0_tt,
#                                                   y_train,
#                                                   np.min(y_train),
#                                                   np.mean(y_train),
#                                                   1,0,0.5,0.02)
#         return np.hstack((X_smogn1,y_smogn1.reshape(len(y_smogn1),1)))
# pool = Pool(os.cpu_count())
# packet = [*zip(np.arange(n))]
# results = pool.map(loop,np.arange(n))

# %%
# X_train_aug = np.vstack((X0_tt,(np.asarray(results)[:,:,:-1]).
#                          reshape(np.asarray(results).shape[0]*np.asarray(results).shape[1],
#                                         (np.asarray(results).shape[2]-1))))
# y_train_aug = np.hstack((y_train.ravel(),
#                          (np.asarray(results)[:,:,-1]).
#                          reshape(np.asarray(results).shape[0]*np.asarray(results).shape[1])))
# X_train_aug = X_train_aug[y_train_aug>0,:]
# y_train_aug = y_train_aug[y_train_aug>0]

# %%
X_train,X_test,y_train,y_test,train_index,test_index = util.set_split(X_all_c,per_change,1,0.1)
X0_tt,scaler = util.make_feature_matrix(X_train,pre_updrs_off[train_index])
entropy0 = util.calc_entropy(X0_tt.ravel())

# %%
X_smogn1,y_smogn1 = util.rad_smogn(X0_tt,
                                                  y_train,
                                                  np.max(y_train),
                                                  np.mean(y_train),
                                                  1,0,0.5,0.02)
X_smogn2,y_smogn2 = util.rad_smogn(X0_tt,
                                                  y_train,
                                                  np.min(y_train),
                                                  np.mean(y_train),
                                                  1,0,0.5,0.05)
X_smogn3,y_smogn3 = util.rad_smogn(X0_tt,
                                                  y_train,
                                                  np.min(y_train),
                                                  np.mean(y_train),
                                                  1,0,0.5,0.075)
X_smogn4,y_smogn4 = util.rad_smogn(X0_tt,
                                                  y_train,
                                                  np.min(y_train),
                                                  np.mean(y_train),
                                                  1,0,0.5,0.1)

# X_smogn5,y_smogn5 = util.rad_smogn(X0_tt,
#                                                   y_train,
#                                                   np.max(y_train),
#                                                   np.mean(y_train),
#                                                   1,0,0.5,0.02)


X_train_aug = np.vstack((X0_tt,X_smogn1,X_smogn2,X_smogn3,X_smogn4))
entropy_aug = util.calc_entropy(X_train_aug.ravel())
print('Entropy of augmented features is',str(entropy_aug),'and of entropy original features is',str(entropy0))
y_train_aug = np.hstack((y_train.ravel(),y_smogn1.ravel(),y_smogn2.ravel(),
                         y_smogn3.ravel(),y_smogn4.ravel()))
X_train_aug = X_train_aug[y_train_aug>0,:]
y_train_aug = y_train_aug[y_train_aug>0]
# Out:
# Prior to SMOGN sampling, mean is 1.28684640352781e-16 standard deviation is 0.959551639241436
# dist_matrix: 100%|##########| 12/12 [00:13<00:00,  1.13s/it]
# r_index: 100%|##########| 2/2 [00:02<00:00,  1.28s/it]
# dist_matrix: 100%|##########| 11/11 [00:11<00:00,  1.03s/it]
# r_index: 100%|##########| 3/3 [00:03<00:00,  1.28s/it]
# (33, 9576)
# After SMOGN sampling, mean is 0.022941272463135102 standard deviation is 0.90123060210145
# After rescaling, SMOGN mean is 0.022941272463135102 standard deviation is 0.90123060210145
# Prior to SMOGN sampling, mean is 1.28684640352781e-16 standard deviation is 0.959551639241436
# dist_matrix: 100%|##########| 6/6 [00:03<00:00,  1.79it/s]
# synth_matrix: 100%|##########| 6/6 [00:15<00:00,  2.55s/it]
# r_index: 100%|##########| 3/3 [00:03<00:00,  1.26s/it]
# (36, 9576)
# After SMOGN sampling, mean is 0.08437751416892639 standard deviation is 0.7624007830855452
# After rescaling, SMOGN mean is 0.08437751416892639 standard deviation is 0.7624007830855452
# Prior to SMOGN sampling, mean is 1.28684640352781e-16 standard deviation is 0.959551639241436
# dist_matrix: 100%|##########| 6/6 [00:03<00:00,  1.78it/s]
# synth_matrix: 100%|##########| 6/6 [00:15<00:00,  2.55s/it]
# r_index: 100%|##########| 3/3 [00:03<00:00,  1.28s/it]
# (36, 9576)
# After SMOGN sampling, mean is 0.08926035047660369 standard deviation is 0.7736628970234279
# After rescaling, SMOGN mean is 0.08926035047660369 standard deviation is 0.7736628970234279
# Prior to SMOGN sampling, mean is 1.28684640352781e-16 standard deviation is 0.959551639241436
# dist_matrix: 100%|##########| 6/6 [00:03<00:00,  1.78it/s]
# synth_matrix: 100%|##########| 6/6 [00:15<00:00,  2.58s/it]
# r_index: 100%|##########| 3/3 [00:03<00:00,  1.27s/it]
# (36, 9576)
# After SMOGN sampling, mean is 0.09243924621197114 standard deviation is 0.8175653142520445
# After rescaling, SMOGN mean is 0.09243924621197114 standard deviation is 0.8175653142520445
# Entropy of augmented features is 15.638765416825805 and of entropy original features is 17.138118956127148

# %%
scaler00 = StandardScaler()
X_train_aug = scaler00.fit_transform(X_train_aug)

# %%
# mlpr = snn.MLPRegressor(max_iter=5000,verbose=True)

# param_list = {"hidden_layer_sizes": [(X_train.shape[0],X_train.shape[1],X_train.shape[2])],
#               "activation": ["identity", "logistic", "tanh", "relu"], 
#               "solver": ["lgbfs","sgd", "adam"], 
#               "alpha": [1e-1,1e-2,1e-3]}
# gridCV = sms.GridSearchCV(estimator=mlpr,param_grid=param_list,n_jobs=8,return_train_score=True)

# splits = KFold(n_splits=5)

# #plt.figure(1)
# index = 1

# for train_index, test_index in splits.split(X_train_aug):

#     training_set = X_train_aug[train_index]
#     testing_set = X_train_aug[test_index]

#     train_index_array = train_index.reshape(-1,1)
#     test_index_array = test_index.reshape(-1,1)

#     gridCV.fit(training_set,y_train_aug[train_index])
#     predicted = gridCV.predict(testing_set)
#     print('Prediction',str(predicted),'with actual',str(y_train_aug[test_index]))
#     parameters = mlpr.get_params()
#     lrr = linregress(predicted,y_train_aug[test_index])
#     print(lrr.rvalue)
#     # plt.subplot(310 + index)
#     # plt.plot(predicted)
#     # plt.plot([None for i in training_set] + [x for x in testing_set])
#     index += 1

#     train_index.flatten() 
#     test_index.flatten()

# %%
# Predict

#X_train_in = scaler.fit_transform(X_train_aug)
reg_l = snn.MLPRegressor(hidden_layer_sizes=(X_train.shape[0],X_train.shape[1],X_train.shape[2]),
                         activation='relu',
                         max_iter=1000,
                        # learning_rate_init = 1e-4,
                        # learning_rate = 'invscaling',
                        #  beta_1=0.9,
                        #  beta_2=0.999,
                         tol=1e-6,
                         solver='adam',
                         epsilon=1e-1,
                         alpha=0.9,
                         verbose=True,
                         n_iter_no_change=700,
                         early_stopping=True,
                         random_state=1,
                         warm_start=True,
                         batch_size=7).fit(X_train_aug,y_train_aug)

# from sklearn.model_selection import cross_val_score
# cross_val_score(reg_l,X_train_aug,y_train_aug)

X_test_in = util.scale_feature_matrix(X_test,pre_updrs_off[test_index],scaler)
ut_l = reg_l.predict(X_test_in.reshape(X_test_in.shape[0],X_test_in.shape[1]*X_test_in.shape[2]))
lr_pred_qr = linregress(np.asarray(ut_l).ravel(),y_test)
print('Predicted improvement of ',ut_l, 'with true improvement', y_test)
lr = linregress(np.asarray(ut_l).ravel(),y_test)
lr.rvalue
# pool = Pool(os.cpu_count())
# packet = [*zip(np.arange(n))]
# results = pool.map(loop,np.arange(n))
# Out:
# Iteration 1, loss = 7.39827063
# Validation score: -6.221487
# Iteration 2, loss = 7.32507336
# Validation score: -3.781475
# Iteration 3, loss = 7.22975024
# Validation score: -1.808895
# Iteration 4, loss = 7.13533331
# Validation score: -0.549015
# Iteration 5, loss = 7.04501939
# Validation score: -0.187987
# Iteration 6, loss = 6.96762963
# Validation score: -0.261380
# Iteration 7, loss = 6.89827401
# Validation score: -0.237155
# Iteration 8, loss = 6.83497760
# Validation score: -0.332942
# Iteration 9, loss = 6.77636181
# Validation score: -0.417616
# Iteration 10, loss = 6.72139912
# Validation score: -0.525237
# Iteration 11, loss = 6.66353979
# Validation score: -0.620827
# Iteration 12, loss = 6.60788132
# Validation score: -0.808146
# Iteration 13, loss = 6.54923488
# Validation score: -0.880263
# Iteration 14, loss = 6.49154142
# Validation score: -1.091275
# Iteration 15, loss = 6.43390956
# Validation score: -1.358051
# Iteration 16, loss = 6.37267940
# Validation score: -1.284697
# Iteration 17, loss = 6.31051774
# Validation score: -1.303545
# Iteration 18, loss = 6.24785143
# Validation score: -1.569822
# Iteration 19, loss = 6.18447299
# Validation score: -1.724399
# Iteration 20, loss = 6.12082403
# Validation score: -1.657229
# Iteration 21, loss = 6.05684989
# Validation score: -1.533527
# Iteration 22, loss = 5.99120875
# Validation score: -1.756324
# Iteration 23, loss = 5.92465121
# Validation score: -1.810874
# Iteration 24, loss = 5.85865259
# Validation score: -1.760512
# Iteration 25, loss = 5.79215697
# Validation score: -1.844603
# Iteration 26, loss = 5.72538080
# Validation score: -1.824142
# Iteration 27, loss = 5.65771030
# Validation score: -1.786525
# Iteration 28, loss = 5.59135735
# Validation score: -1.795016
# Iteration 29, loss = 5.52232660
# Validation score: -1.584752
# Iteration 30, loss = 5.45312450
# Validation score: -1.728319
# Iteration 31, loss = 5.38628900
# Validation score: -1.928466
# Iteration 32, loss = 5.31614110
# Validation score: -1.753719
# Iteration 33, loss = 5.24773059
# Validation score: -1.660097
# Iteration 34, loss = 5.18145673
# Validation score: -1.721953
# Iteration 35, loss = 5.11230542
# Validation score: -1.806138
# Iteration 36, loss = 5.04322159
# Validation score: -1.644887
# Iteration 37, loss = 4.97517846
# Validation score: -1.723559
# Iteration 38, loss = 4.90741681
# Validation score: -1.666134
# Iteration 39, loss = 4.83977539
# Validation score: -1.671454
# Iteration 40, loss = 4.77219241
# Validation score: -0.567555
# Iteration 401, loss = 0.08475453
# Validation score: -0.475422
# Iteration 402, loss = 0.08382157
# Validation score: -0.486523
# Iteration 403, loss = 0.08479623
# Validation score: -0.586201
# Iteration 404, loss = 0.08376400
# Validation score: -0.518899
# Iteration 405, loss = 0.08373700
# Validation score: -0.527512
# Iteration 406, loss = 0.08351450
# Validation score: -0.491213
# Iteration 407, loss = 0.08373462
# Validation score: -0.478457
# Iteration 408, loss = 0.08350916
# Validation score: -0.522009
# Iteration 409, loss = 0.08434213
# Validation score: -0.581286
# Iteration 410, loss = 0.08358121
# Validation score: -0.527603
# Iteration 411, loss = 0.08386741
# Validation score: -0.469381
# Iteration 412, loss = 0.08372684
# Validation score: -0.536427
# Iteration 413, loss = 0.08399941
# Validation score: -0.498711
# Iteration 414, loss = 0.08339595
# Validation score: -0.509343
# Iteration 415, loss = 0.08353211
# Validation score: -0.558271
# Iteration 416, loss = 0.08335760
# Validation score: -0.526432
# Iteration 417, loss = 0.08325822
# Validation score: -0.520890
# Iteration 418, loss = 0.08332454
# Validation score: -0.517823
# Iteration 419, loss = 0.08326051
# Validation score: -0.499818
# Iteration 420, loss = 0.08320462
# Validation score: -0.486457
# Iteration 421, loss = 0.08314842
# Validation score: -0.514313
# Iteration 422, loss = 0.08362776
# Validation score: -0.492619
# Iteration 423, loss = 0.08303492
# Validation score: -0.512951
# Iteration 424, loss = 0.08317359
# Validation score: -0.571793
# Iteration 425, loss = 0.08298257
# Validation score: -0.520724
# Iteration 426, loss = 0.08298856
# Validation score: -0.528554
# Iteration 427, loss = 0.08288238
# Validation score: -0.524861
# Iteration 428, loss = 0.08283593
# Validation score: -0.507671
# Iteration 429, loss = 0.08283889
# Validation score: -0.501785
# Iteration 430, loss = 0.08285688
# Validation score: -0.496610
# Iteration 431, loss = 0.08333375
# Validation score: -0.450235
# Iteration 432, loss = 0.08296988
# Validation score: -0.459775
# Iteration 433, loss = 0.08294913
# Validation score: -0.542371
# Iteration 434, loss = 0.08330349
# Validation score: -0.525353
# Iteration 435, loss = 0.08279397
# Validation score: -0.572163
# Iteration 436, loss = 0.08272990
# Validation score: -0.565179
# Iteration 437, loss = 0.08322114
# Validation score: -0.478017
# Iteration 438, loss = 0.08277662
# Validation score: -0.514747
# Iteration 439, loss = 0.08277724
# Validation score: -0.508130
# Iteration 440, loss = 0.08318120
# Validation score: -0.546351
# Iteration 441, loss = 0.08265812
# Validation score: -0.532874
# Iteration 442, loss = 0.08259505
# Validation score: -0.501813
# Iteration 443, loss = 0.08362765
# Validation score: -0.468091
# Iteration 444, loss = 0.08252977
# Validation score: -0.526839
# Iteration 445, loss = 0.08264000
# Validation score: -0.537127
# Iteration 446, loss = 0.08286581
# Validation score: -0.588918
# Iteration 447, loss = 0.08272743
# Validation score: -0.511531
# Iteration 448, loss = 0.08291025
# Validation score: -0.540900
# Iteration 449, loss = 0.08284933
# Validation score: -0.501139
# Iteration 450, loss = 0.08257540
# Validation score: -0.515769
# Iteration 451, loss = 0.08336672
# Validation score: -0.480567
# Iteration 555, loss = 0.08166662
# Validation score: -0.526088
# Iteration 556, loss = 0.08181456
# Validation score: -0.542169
# Iteration 557, loss = 0.08172899
# Validation score: -0.502332
# Iteration 558, loss = 0.08179977
# Validation score: -0.521646
# Iteration 559, loss = 0.08273727
# Validation score: -0.595101
# Iteration 560, loss = 0.08255816
# Validation score: -0.485583
# Iteration 561, loss = 0.08163058
# Validation score: -0.508290
# Iteration 562, loss = 0.08219589
# Validation score: -0.534050
# Iteration 563, loss = 0.08154382
# Validation score: -0.547471
# Iteration 564, loss = 0.08173486
# Validation score: -0.545659
# Iteration 565, loss = 0.08160995
# Validation score: -0.535324
# Iteration 566, loss = 0.08152599
# Validation score: -0.501972
# Iteration 567, loss = 0.08216920
# Validation score: -0.491888
# Iteration 568, loss = 0.08168627
# Validation score: -0.494519
# Iteration 569, loss = 0.08374739
# Validation score: -0.626354
# Iteration 570, loss = 0.08152483
# Validation score: -0.553482
# Iteration 571, loss = 0.08165186
# Validation score: -0.518415
# Iteration 572, loss = 0.08190950
# Validation score: -0.524880
# Iteration 573, loss = 0.08206721
# Validation score: -0.513845
# Iteration 574, loss = 0.08167114
# Validation score: -0.513048
# Iteration 575, loss = 0.08166389
# Validation score: -0.534604
# Iteration 576, loss = 0.08167152
# Validation score: -0.535746
# Iteration 577, loss = 0.08253736
# Validation score: -0.592010
# Iteration 578, loss = 0.08167200
# Validation score: -0.532132
# Iteration 579, loss = 0.08241454
# Validation score: -0.470901
# Iteration 580, loss = 0.08151912
# Validation score: -0.514269
# Iteration 581, loss = 0.08211690
# Validation score: -0.576209
# Iteration 582, loss = 0.08168555
# Validation score: -0.553780
# Iteration 583, loss = 0.08196674
# Validation score: -0.503795
# Iteration 584, loss = 0.08230342
# Validation score: -0.546502
# Iteration 585, loss = 0.08186505
# Validation score: -0.487326
# Iteration 586, loss = 0.08156845
# Validation score: -0.491677
# Iteration 587, loss = 0.08170389
# Validation score: -0.553247
# Iteration 588, loss = 0.08164116
# Validation score: -0.578965
# Iteration 589, loss = 0.08175735
# Validation score: -0.529057
# Iteration 590, loss = 0.08224912
# Validation score: -0.584167
# Iteration 591, loss = 0.08196692
# Validation score: -0.505600
# Iteration 592, loss = 0.08179343
# Validation score: -0.503894
# Iteration 593, loss = 0.08160519
# Validation score: -0.522957
# Iteration 594, loss = 0.08179356
# Validation score: -0.515482
# Iteration 595, loss = 0.08156505
# Validation score: -0.557705
# Iteration 596, loss = 0.08167794
# Validation score: -0.577706
# Iteration 597, loss = 0.08186720
# Validation score: -0.489499
# Iteration 598, loss = 0.08156341
# Validation score: -0.491849
# Iteration 599, loss = 0.08157627
# Validation score: -0.513605
# Iteration 600, loss = 0.08137861
# Validation score: -0.549783
# Iteration 601, loss = 0.08148581
# Validation score: -0.538774
# Iteration 602, loss = 0.08184151
# Validation score: -0.494925
# Iteration 603, loss = 0.08177577
# Validation score: -0.588379
# Iteration 604, loss = 0.08144098
# Validation score: -0.548360
# Iteration 605, loss = 0.08198414
# Validation score: -0.495681
# Iteration 606, loss = 0.08163420
# Validation score: -0.513565
# Iteration 607, loss = 0.08240114
# Validation score: -0.612572
# Iteration 608, loss = 0.08166335
# Validation score: -0.526111
# Iteration 609, loss = 0.08157151
# Validation score: -0.495303
# Iteration 610, loss = 0.08209784
# Validation score: -0.569536
# Iteration 611, loss = 0.08138620
# Validation score: -0.535615
# Iteration 612, loss = 0.08165547
# Validation score: -0.516979
# Iteration 613, loss = 0.08150171
# Validation score: -0.524493
# Iteration 614, loss = 0.08196910
# Validation score: -0.580713
# Iteration 615, loss = 0.08143430
# Validation score: -0.514533
# Iteration 616, loss = 0.08202292
# Validation score: -0.467489
# Iteration 617, loss = 0.08160114
# Validation score: -0.525760
# Iteration 618, loss = 0.08144046
# Validation score: -0.532251
# Iteration 619, loss = 0.08131269
# Validation score: -0.539871
# Iteration 620, loss = 0.08153510
# Validation score: -0.542990
# Iteration 621, loss = 0.08199414
# Validation score: -0.584041
# Iteration 622, loss = 0.08136987
# Validation score: -0.527232
# Iteration 623, loss = 0.08177034
# Validation score: -0.473123
# Iteration 624, loss = 0.08144249
# Validation score: -0.517702
# Iteration 625, loss = 0.08162202
# Validation score: -0.565888
# Iteration 626, loss = 0.08200911
# Validation score: -0.534078
# Iteration 627, loss = 0.08164380
# Validation score: -0.570631
# Iteration 628, loss = 0.08152358
# Validation score: -0.545003
# Iteration 629, loss = 0.08160832
# Validation score: -0.581525
# Iteration 630, loss = 0.08140593
# Validation score: -0.535562
# Iteration 631, loss = 0.08169085
# Validation score: -0.572989
# Iteration 632, loss = 0.08154546
# Validation score: -0.553774
# Iteration 633, loss = 0.08146331
# Validation score: -0.545297
# Iteration 634, loss = 0.08151568
# Validation score: -0.498470
# Iteration 635, loss = 0.08151345
# Validation score: -0.524353
# Iteration 636, loss = 0.08131165
# Validation score: -0.514118
# Iteration 637, loss = 0.08236148
# Validation score: -0.476823
# Iteration 638, loss = 0.08165886
# Validation score: -0.479189
# Iteration 639, loss = 0.08117386
# Validation score: -0.538448
# Iteration 640, loss = 0.08128127
# Validation score: -0.566151
# Iteration 641, loss = 0.08165716
# Validation score: -0.595535
# Iteration 642, loss = 0.08159627
# Validation score: -0.615195
# Iteration 643, loss = 0.08133231
# Validation score: -0.556133
# Iteration 644, loss = 0.08167507
# Validation score: -0.510076
# Iteration 645, loss = 0.08148018
# Validation score: -0.552046
# Iteration 646, loss = 0.08136880
# Validation score: -0.520923
# Iteration 647, loss = 0.08150353
# Validation score: -0.536286
# Iteration 648, loss = 0.08267481
# Validation score: -0.453968
# Iteration 649, loss = 0.08220843
# Validation score: -0.558520
# Iteration 650, loss = 0.08243531
# Validation score: -0.496954
# Iteration 651, loss = 0.08145271
# Validation score: -0.565125
# Iteration 652, loss = 0.08138597
# Validation score: -0.562365
# Iteration 653, loss = 0.08168271
# Validation score: -0.610954
# Iteration 654, loss = 0.08170327
# Validation score: -0.578695
# Iteration 655, loss = 0.08262239
# Validation score: -0.471862
# Iteration 656, loss = 0.08178978
# Validation score: -0.471880
# Iteration 657, loss = 0.08145392
# Validation score: -0.541491
# Iteration 658, loss = 0.08157873
# Validation score: -0.547754
# Iteration 659, loss = 0.08189303
# Validation score: -0.617870
# Iteration 660, loss = 0.08138795
# Validation score: -0.550604
# Iteration 661, loss = 0.08194353
# Validation score: -0.508739
# Iteration 662, loss = 0.08133564
# Validation score: -0.529163
# Iteration 663, loss = 0.08147114
# Validation score: -0.551878
# Iteration 664, loss = 0.08153542
# Validation score: -0.590268
# Iteration 665, loss = 0.08130011
# Validation score: -0.557912
# Iteration 666, loss = 0.08160577
# Validation score: -0.524706
# Iteration 667, loss = 0.08134656
# Validation score: -0.531540
# Iteration 668, loss = 0.08184725
# Validation score: -0.599930
# Iteration 669, loss = 0.08132047
# Validation score: -0.536013
# Iteration 670, loss = 0.08146476
# Validation score: -0.553558
# Iteration 671, loss = 0.08160882
# Validation score: -0.539365
# Iteration 672, loss = 0.08143516
# Validation score: -0.536275
# Iteration 673, loss = 0.08134743
# Validation score: -0.491523
# Iteration 674, loss = 0.08148224
# Validation score: -0.496703
# Iteration 675, loss = 0.08148147
# Validation score: -0.538931
# Iteration 676, loss = 0.08136225
# Validation score: -0.534695
# Iteration 677, loss = 0.08135177
# Validation score: -0.544108
# Iteration 678, loss = 0.08138093
# Validation score: -0.572187
# Iteration 679, loss = 0.08190585
# Validation score: -0.597975
# Iteration 680, loss = 0.08117507
# Validation score: -0.543351
# Iteration 681, loss = 0.08155877
# Validation score: -0.536930
# Iteration 682, loss = 0.08134952
# Validation score: -0.516583
# Iteration 683, loss = 0.08157996
# Validation score: -0.491787
# Iteration 684, loss = 0.08146129
# Validation score: -0.535101
# Iteration 685, loss = 0.08147447
# Validation score: -0.562890
# Iteration 686, loss = 0.08158924
# Validation score: -0.581677
# Iteration 687, loss = 0.08165845
# Validation score: -0.554953
# Iteration 688, loss = 0.08158168
# Validation score: -0.580052
# Iteration 689, loss = 0.08157261
# Validation score: -0.504728
# Iteration 690, loss = 0.08139369
# Validation score: -0.527490
# Iteration 691, loss = 0.08139094
# Validation score: -0.521030
# Iteration 692, loss = 0.08176944
# Validation score: -0.511132
# Iteration 693, loss = 0.08155387
# Validation score: -0.517896
# Iteration 694, loss = 0.08125150
# Validation score: -0.565035
# Iteration 695, loss = 0.08159338
# Validation score: -0.598875
# Iteration 696, loss = 0.08125388
# Validation score: -0.570491
# Iteration 697, loss = 0.08169073
# Validation score: -0.534749
# Iteration 698, loss = 0.08190701
# Validation score: -0.588812
# Iteration 699, loss = 0.08127734
# Validation score: -0.563844
# Iteration 700, loss = 0.08152269
# Validation score: -0.520119
# Iteration 701, loss = 0.08184968
# Validation score: -0.556900
# Iteration 702, loss = 0.08207222
# Validation score: -0.473272
# Iteration 703, loss = 0.08172042
# Validation score: -0.550930
# Iteration 704, loss = 0.08154776
# Validation score: -0.540828
# Iteration 705, loss = 0.08163601
# Validation score: -0.500465
# Iteration 706, loss = 0.08146290
# Validation score: -0.550387
# Validation score did not improve more than tol=0.000001 for 700 consecutive epochs. Stopping.
# Predicted improvement of  [0.68902566 0.51906508 0.50758344 0.42194794 0.32555077] with true improvement [0.95238095 0.88888889 0.88311688 0.66666667 0.48571429]
# 0.9112609053320916

# %%
# np.save('X_test_in.npy',X_test_in)
# np.save('X_train_aug.npy',X_train_aug)
# np.save('y_train_aug.npy',y_train_aug)

# %%
n = X_test.shape[0]
results = ut_l
# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
# Cross validation results
[fig,ax] = plt.subplots(1,2,sharex=True, sharey=True)
lr_prepost = linregress(pre_imp[test_index],y_test)
ax[0].scatter(pre_imp[test_index],y_test)
ax[0].plot(pre_imp[test_index],pre_imp[test_index]*lr_prepost.slope+lr_prepost.intercept,'-r')
ax[0].set_title('LCT')
ax[0].set_ylabel("DBS improvement")
ax[0].set_xlabel("Prediction")
# ax[0].set_ylim([0, 1])
# ax[0].set_xlim([0, 1])
text = f"$y={lr_prepost.slope:0.3f}\;x{lr_prepost.intercept:+0.3f}$\n$r = {lr_prepost.rvalue:0.3f}$\n$p = {lr_prepost.pvalue:0.3f}$"
ax[0].text(0.5, 0.5, text,transform=ax[0].transAxes,
     fontsize=14, verticalalignment='top')
ax[0].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[0].vlines(0.3,0,2,linestyle='dashed',color='black')

lr_pred_qr = linregress(np.asarray(ut_l).ravel(),y_test)
ax[1].scatter(np.asarray(ut_l).ravel(),y_test)
ax[1].plot(np.asarray(ut_l).ravel(),np.asarray(ut_l).ravel()*lr_pred_qr.slope+lr_pred_qr.intercept,'-r')
ax[1].set_title('MLPRegressor with SMOGN')
ax[1].set_ylabel("DBS improvement")
ax[1].set_xlabel("Prediction")
text = f"$y={lr_pred_qr.slope:0.3f}\;x{lr_pred_qr.intercept:+0.3f}$\n$r = {lr_pred_qr.rvalue:0.3f}$\n$p = {lr_pred_qr.pvalue:0.10f}$"
ax[1].text(0.5, 0.5, text,transform=ax[1].transAxes,
     fontsize=14, verticalalignment='top')
ax[1].hlines(0.3,0,2,linestyle='dashed',color='black')
ax[1].vlines(0.3,0,2,linestyle='dashed',color='black')

plt.style.use('default')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# n = X0_t.shape[0]
# def loop(j):
#         # Reload training data
#         X_in = X_all_c[:n,:,:]
#         per_change_in = per_change[:n]
#         pre_updrs_off_in = pre_updrs_off[:n]
#         # Delete test case
#         X_in = np.delete(X_in,j,axis=0)
#         pre_updrs_off_in = np.delete(pre_updrs_off[:n],j)
#         per_change_in = np.delete(per_change[:n],j)
#         # Concatenate pre-updrs, scale, and reshape
#         X_in_t,scaler = util.make_feature_matrix(X_in,pre_updrs_off_in)
#         reg_l = ElasticNetCV().fit(X_in_t,per_change_in)
#         # Predict
#         X_test = util.scale_feature_matrix(np.expand_dims(X_all_c[j,:,:],axis=0),pre_updrs_off[j],scaler)
#         ut_l = reg_l.predict(X_test.reshape(1, -1))
#         # ut = reg.predict(X_test.reshape(1, -1))
#         print('Predicted improvement of ',ut_l, 'with true improvement', per_change[j])
#         #print('SMOGN predicted improvement of ',ut, 'with true improvement', per_change[j])
#         return ut_l
# pool = Pool(os.cpu_count())
# packet = [*zip(np.arange(n))]
# results = pool.map(loop,np.arange(n))
