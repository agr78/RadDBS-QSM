# %%
# Import libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn.svm as svm
import sklearn.pipeline as spl
import sklearn.kernel_ridge as skr
import sklearn.model_selection as sms
import sklearn.linear_model as slm
import sklearn.preprocessing as skp
import sklearn.neural_network as snn
import sklearn.metrics as sme
import sklearn.decomposition as sdc
import sklearn.cross_decomposition as skd
import sklearn.feature_selection as skf
import sklearn.ensemble as ske
from sklearnex import patch_sklearn, config_context
from sklearn.cluster import DBSCAN
import numpy as np
from IPython.display import HTML
import util

patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
HTML('''
<style>
.jupyter-matplotlib {
    background-color: #000;
}

.widget-label, .jupyter-matplotlib-header{
    color: #fff;
}

.jupyter-button {
    background-color: #333;
    color: #fff;
}
</style>
''')
# Out:
# <style>
# .jupyter-matplotlib {
#     background-color: #000;
# }
#
# .widget-label, .jupyter-matplotlib-header{
#     color: #fff;
# }
#
# .jupyter-button {
#     background-color: #333;
#     color: #fff;
# }
# </style>

# %%
# Maybe y should also be scaled? 
#     Performed poorly using Standard and MinMax scalers. Trying with LOOCV to see if predictions stabilize.
#     Does not appear to stabilize predictions with LOOCV (using StandardScaler())
# Perhaps a transform would be more effective, or scaling implemented with consistent cross-validation
# Different scaling methods? 
#     This seems most important for noise-sensitive models like LARS. All other use StandardScaler()
# Transformers?
# Model-specific scaling methods?
#     Yes, see above
# Common cross-validation function?
#     Use built-in functions wherever possible and `utils.gridsearch_pickparams()` elsewhere
# Quantile loss
# RANSAC
# Data augmentation? (Mixup)
# Data generation? (SMOGN)

# %%
# Get case IDs
case_list = open('/home/ali/RadDBS-QSM/data/docs/cases_90','r')
lines = case_list.read()
lists = np.loadtxt(case_list.name,comments="#", delimiter=",",unpack=False,dtype=str)
case_id = []
for lines in lists:     
    case_id.append(lines[-9:-7])

# Load scores
file_dir = '/home/ali/RadDBS-QSM/data/docs/QSM anonymus- 6.22.2023-1528.csv'
motor_df = util.filter_scores(file_dir,'pre-dbs updrs','stim','CORNELL ID')
# Find cases with all required scores
subs,pre_imp,post_imp,pre_updrs_off = util.get_full_cases(motor_df,
                                                          'CORNELL ID',
                                                          'OFF (pre-dbs updrs)',
                                                          'ON (pre-dbs updrs)',
                                                          'OFF meds ON stim 6mo')
# Load extracted features
npy_dir = '/home/ali/RadDBS-QSM/data/npy/'
phi_dir = '/home/ali/RadDBS-QSM/data/phi/'
roi_path = '/data/Ali/atlas/mcgill_pd_atlas/PD25-subcortical-labels.csv'
n_rois = 6
Phi_all, X_all, R_all, K_all, ID_all = util.load_featstruct(phi_dir,npy_dir+'X/',npy_dir+'R/',npy_dir+'K/',n_rois,1595)
ids = np.asarray(ID_all).astype(int)
# Find overlap between scored subjects and feature extraction cases
c_cases = np.intersect1d(np.asarray(case_id).astype(int),np.asarray(subs).astype(int))
# Complete case indices with respect to feature matrix
c_cases_idx = np.in1d(ids,c_cases)
X_all_c = X_all[c_cases_idx,:,:]
K_all_c = K_all[c_cases_idx,:,:]
R_all_c = R_all[c_cases_idx,:,:]
# Re-index the scored subjects with respect to complete cases
s_cases_idx = np.in1d(subs,ids[c_cases_idx])
pre_imp = pre_imp[s_cases_idx]
post_imp = post_imp[s_cases_idx]
pre_updrs_off = pre_updrs_off[s_cases_idx]
per_change = post_imp

# %%
X_train,X_test,y_train,y_test,train_index,test_index = util.set_split(X_all_c,per_change,1,5/len(X_all_c))
# Choose scaling
X0_ss0,scaler_ss,X_test_ss0 = util.model_scale(skp.StandardScaler(),
                                             X_train,train_index,X_test,test_index,pre_updrs_off)
X_smogn1,y_smogn1 = util.rad_smogn(X0_ss0,y_train,np.min(y_train),np.median(y_train),1,0,0.5,0.02)
X_smogn2,y_smogn2 = util.rad_smogn(X0_ss0,y_train,np.max(y_train),np.median(y_train),1,0,0.5,0.02)
X_smogn3,y_smogn3 = util.rad_smogn(X0_ss0,y_train,np.min(y_train),np.median(y_train),1,0,0.5,0.02)
X_smogn4,y_smogn4 = util.rad_smogn(X0_ss0,y_train,np.max(y_train),np.median(y_train),1,0,0.5,0.02)
X_smogn = np.vstack((X_smogn1,X_smogn2,X_smogn3,X_smogn4))
y_smogn = np.hstack((y_smogn1,y_smogn2,y_smogn3,y_smogn4))
# Cross validation
cvn = 8

# X0_mm,scaler_mm,X_test_mm = util.model_scale(skp.MinMaxScaler(),
#                                              X_train,train_index,X_test,test_index,pre_updrs_off)
# X0_ma,scaler_ma,X_test_ma = util.model_scale(skp.MaxAbsScaler(),
#                                              X_train,train_index,X_test,test_index,pre_updrs_off)
# X0_rs,scaler_rs,X_test_rs = util.model_scale(skp.RobustScaler(),
#                                              X_train,train_index,X_test,test_index,pre_updrs_off)
# Feature selection
sel = skf.SelectKBest(skf.f_regression,k=10)
X0_ss = sel.fit_transform(X0_ss0,y_train)
X_test_ss = (sel.transform(X_test_ss0.reshape(X_test_ss0.shape[0],X_test_ss0.shape[1]*X_test_ss0.shape[2]))).reshape((X_test_ss0.shape[0],1,-1))
# Out:
# Prior to SMOGN sampling, mean is 1.0543519132693535e-16 standard deviation is 0.9595516392414363
# dist_matrix: 100%|##########| 6/6 [00:04<00:00,  1.41it/s]
# synth_matrix: 100%|##########| 6/6 [00:21<00:00,  3.51s/it]
# r_index: 100%|##########| 3/3 [00:05<00:00,  1.85s/it]
# (36, 9576)
# After SMOGN sampling, mean is 0.0762025251559603 standard deviation is 0.7282588826202318
# After rescaling, SMOGN mean is 0.0762025251559603 standard deviation is 0.7282588826202318
# Prior to SMOGN sampling, mean is 1.0543519132693535e-16 standard deviation is 0.9595516392414363
# dist_matrix: 100%|##########| 10/10 [00:11<00:00,  1.19s/it]
# r_index: 100%|##########| 3/3 [00:05<00:00,  1.81s/it]
# dist_matrix: 100%|##########| 12/12 [00:17<00:00,  1.44s/it]
# r_index: 100%|##########| 2/2 [00:03<00:00,  1.91s/it]
# (33, 9576)
# After SMOGN sampling, mean is 0.0155842624278955 standard deviation is 0.8477312025418422
# After rescaling, SMOGN mean is 0.0155842624278955 standard deviation is 0.8477312025418422
# Prior to SMOGN sampling, mean is 1.0543519132693535e-16 standard deviation is 0.9595516392414363
# dist_matrix: 100%|##########| 6/6 [00:04<00:00,  1.41it/s]
# synth_matrix: 100%|##########| 6/6 [00:21<00:00,  3.56s/it]
# r_index: 100%|##########| 3/3 [00:05<00:00,  1.82s/it]
# (36, 9576)
# After SMOGN sampling, mean is 0.08505651018759823 standard deviation is 0.8326008635223346
# After rescaling, SMOGN mean is 0.08505651018759823 standard deviation is 0.8326008635223346
# Prior to SMOGN sampling, mean is 1.0543519132693535e-16 standard deviation is 0.9595516392414363
# dist_matrix: 100%|##########| 10/10 [00:19<00:00,  1.98s/it]
# r_index: 100%|##########| 3/3 [00:05<00:00,  1.91s/it]
# dist_matrix: 100%|##########| 12/12 [00:17<00:00,  1.49s/it]
# r_index: 100%|##########| 2/2 [00:03<00:00,  1.84s/it]
# (33, 9576)
# After SMOGN sampling, mean is 0.014342326647197048 standard deviation is 0.843353387671261
# After rescaling, SMOGN mean is 0.014342326647197048 standard deviation is 0.843353387671261

# %%
scoring = 'r2'
print(y_test)
print(y_test.mean())
print(y_train.mean())
# Out:
# [0.35897436 0.96774194 0.74418605 0.67241379 0.51724138]
# 0.6521115026767302
# 0.6271484026239459

# %%
alphas = np.logspace(-9,-2,10)

# %%
lr = slm.LinearRegression()
est_lr = lr.fit(X0_ss,y_train)
results_lr = est_lr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))
print(results_lr)
# Out:
# [0.55615146 0.40614766 0.63966888 0.50809582 0.71590003]

# %%
br_grid = {'alpha_1': alphas[-5:-4], 'alpha_2': alphas[-5:-4]}

best_params = util.gridsearch_pickparams(slm.BayesianRidge(),cvn,
                                         br_grid,scaler_ss,X_train,
                                         train_index,X_test,test_index,pre_updrs_off,y_train.ravel(),scoring,8)
br = slm.BayesianRidge(alpha_1=best_params['alpha_1'],alpha_2=best_params['alpha_2'])
br.fit(X0_ss, y_train)
results_br = np.asarray(br.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()
print(results_br)
# Out:
# Fitting 8 folds for each of 1 candidates, totalling 8 fits
# [0.61181829 0.4294198  0.70001798 0.54398614 0.63946169]

# %%
mlp_grid = {'hidden_layer_sizes': [(X_train.shape[1],X_train.shape[2])],
          'activation': ['relu'],
          'alpha': alphas,
          'epsilon': [1e0],
          'solver': ['adam'],
          'max_iter':[5000]}

best_params = util.gridsearch_pickparams(snn.MLPRegressor(),
                                         cvn,mlp_grid,scaler_ss,X_train,
                                         train_index,X_test,test_index,pre_updrs_off,y_train,scoring,-1)

mlp = snn.MLPRegressor(hidden_layer_sizes=best_params["hidden_layer_sizes"], 
                        activation=best_params["activation"],
                        solver=best_params["solver"],
                        alpha=best_params['alpha'],
                        epsilon=best_params["epsilon"],
                        max_iter=5000, 
                        n_iter_no_change=500, 
                        verbose=True,
                        early_stopping=True,
                        random_state=1,
                        batch_size=len(X0_ss)//cvn)

mlp.fit(X0_ss,y_train)
results_mlp = mlp.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))

print(results_mlp)
# Out:
# Fitting 8 folds for each of 10 candidates, totalling 80 fits
# Iteration 1, loss = 0.19971765
# Validation score: -8.333496
# Iteration 2, loss = 0.19860702
# Validation score: -8.263628
# Iteration 3, loss = 0.19716543
# Validation score: -8.168976
# Iteration 4, loss = 0.19517592
# Validation score: -8.064943
# Iteration 5, loss = 0.19304439
# Validation score: -7.940429
# Iteration 6, loss = 0.19068048
# Validation score: -7.802180
# Validation score: 0.621996
# Iteration 729, loss = 0.01454526
# Validation score: 0.620387
# Iteration 730, loss = 0.01453788
# Validation score: 0.620107
# Iteration 731, loss = 0.01453720
# Validation score: 0.618688
# Iteration 732, loss = 0.01453839
# Validation score: 0.620215
# Iteration 733, loss = 0.01452314
# Validation score: 0.620557
# Iteration 734, loss = 0.01452699
# Validation score: 0.620955
# Iteration 735, loss = 0.01452413
# Validation score: 0.623658
# Iteration 736, loss = 0.01451692
# Validation score: 0.624291
# Iteration 737, loss = 0.01451187
# Validation score: 0.624397
# Iteration 738, loss = 0.01451123
# Validation score: 0.625894
# Iteration 739, loss = 0.01450458
# Validation score: 0.625722
# Iteration 740, loss = 0.01450357
# Validation score: 0.624858
# Iteration 741, loss = 0.01450049
# Validation score: 0.624610
# Iteration 742, loss = 0.01450527
# Validation score: 0.626902
# Iteration 743, loss = 0.01449428
# Validation score: 0.624475
# Iteration 744, loss = 0.01448719
# Validation score: 0.624348
# Iteration 745, loss = 0.01449614
# Validation score: 0.621194
# Iteration 746, loss = 0.01448183
# Validation score: 0.622256
# Iteration 747, loss = 0.01448425
# Validation score: 0.626678
# Iteration 748, loss = 0.01447718
# Validation score: 0.628496
# Iteration 749, loss = 0.01447018
# Validation score: 0.626635
# Iteration 750, loss = 0.01446970
# Validation score: 0.627373
# Iteration 751, loss = 0.01447043
# Validation score: 0.628806
# Iteration 752, loss = 0.01445951
# Validation score: 0.627034
# Iteration 753, loss = 0.01445638
# Validation score: 0.624709
# Iteration 754, loss = 0.01445239
# Validation score: 0.623188
# Iteration 755, loss = 0.01445229
# Validation score: 0.623677
# Iteration 756, loss = 0.01444644
# Validation score: 0.623937
# Iteration 757, loss = 0.01444024
# Validation score: 0.622645
# Iteration 758, loss = 0.01443815
# Validation score: 0.622404
# Iteration 759, loss = 0.01443712
# Validation score: 0.622392
# Iteration 760, loss = 0.01443010
# Validation score: 0.620394
# Iteration 761, loss = 0.01443756
# Validation score: 0.616906
# Iteration 762, loss = 0.01442488
# Validation score: 0.616314
# Iteration 763, loss = 0.01441984
# Validation score: 0.617085
# Iteration 764, loss = 0.01442023
# Validation score: 0.616208
# Iteration 765, loss = 0.01441445
# Validation score: 0.621026
# Iteration 766, loss = 0.01440613
# Validation score: 0.622107
# Iteration 767, loss = 0.01441144
# Validation score: 0.620528
# Iteration 768, loss = 0.01439942
# Validation score: 0.621803
# Iteration 769, loss = 0.01439093
# Validation score: 0.624965
# Iteration 770, loss = 0.01439299
# Validation score: 0.627173
# Iteration 771, loss = 0.01440686
# Validation score: 0.632169
# Iteration 772, loss = 0.01439098
# Validation score: 0.632316
# Iteration 773, loss = 0.01438615
# Validation score: 0.630115
# Iteration 774, loss = 0.01438001
# Validation score: 0.630135
# Iteration 775, loss = 0.01437867
# Validation score: 0.629364
# Iteration 776, loss = 0.01437476
# Validation score: 0.627981
# Iteration 777, loss = 0.01436916
# Validation score: 0.627347
# Iteration 778, loss = 0.01436812
# Validation score: 0.624701
# Iteration 779, loss = 0.01436246
# Validation score: 0.622715
# Iteration 780, loss = 0.01436104
# Validation score: 0.622131
# Iteration 781, loss = 0.01435787
# Validation score: 0.621045
# Iteration 782, loss = 0.01435279
# Validation score: 0.621907
# Iteration 783, loss = 0.01434741
# Validation score: 0.621803
# Iteration 784, loss = 0.01434894
# Validation score: 0.623190
# Iteration 785, loss = 0.01434077
# Validation score: 0.623518
# Iteration 786, loss = 0.01433920
# Validation score: 0.623433
# Iteration 787, loss = 0.01433550
# Validation score: 0.622293
# Iteration 788, loss = 0.01433336
# Validation score: 0.621961
# Iteration 789, loss = 0.01433300
# Validation score: 0.623183
# Iteration 790, loss = 0.01432563
# Validation score: 0.621889
# Iteration 791, loss = 0.01432219
# Validation score: 0.621367
# Iteration 792, loss = 0.01432098
# Validation score: 0.619976
# Iteration 793, loss = 0.01432712
# Validation score: 0.617847
# Iteration 794, loss = 0.01432049
# Validation score: 0.619224
# Iteration 795, loss = 0.01430873
# Validation score: 0.618157
# Iteration 796, loss = 0.01431349
# Validation score: 0.615391
# Iteration 797, loss = 0.01430381
# Validation score: 0.615735
# Iteration 798, loss = 0.01430116
# Validation score: 0.618278
# Iteration 799, loss = 0.01429835
# Validation score: 0.617668
# Iteration 800, loss = 0.01429723
# Validation score: 0.615039
# Iteration 801, loss = 0.01429356
# Validation score: 0.613111
# Iteration 802, loss = 0.01428769
# Validation score: 0.614478
# Iteration 803, loss = 0.01428753
# Validation score: 0.613978
# Iteration 804, loss = 0.01427858
# Validation score: 0.613156
# Iteration 805, loss = 0.01428055
# Validation score: 0.612805
# Iteration 806, loss = 0.01427170
# Validation score: 0.615121
# Iteration 807, loss = 0.01427598
# Validation score: 0.617821
# Iteration 808, loss = 0.01427594
# Validation score: 0.619190
# Iteration 809, loss = 0.01426397
# Validation score: 0.618235
# Iteration 810, loss = 0.01426288
# Validation score: 0.619224
# Iteration 811, loss = 0.01425906
# Validation score: 0.620946
# Iteration 812, loss = 0.01425579
# Validation score: 0.619727
# Iteration 813, loss = 0.01425011
# Validation score: 0.619448
# Iteration 814, loss = 0.01425644
# Validation score: 0.621075
# Iteration 815, loss = 0.01424417
# Validation score: 0.620891
# Iteration 816, loss = 0.01424327
# Validation score: 0.619359
# Iteration 817, loss = 0.01424356
# Validation score: 0.617416
# Iteration 818, loss = 0.01423459
# Validation score: 0.618549
# Iteration 819, loss = 0.01424045
# Validation score: 0.622164
# Iteration 820, loss = 0.01423214
# Validation score: 0.623853
# Iteration 821, loss = 0.01422828
# Validation score: 0.625057
# Iteration 822, loss = 0.01422344
# Validation score: 0.624566
# Iteration 823, loss = 0.01422221
# Validation score: 0.625611
# Iteration 824, loss = 0.01422009
# Validation score: 0.623412
# Iteration 825, loss = 0.01422068
# Validation score: 0.626002
# Iteration 826, loss = 0.01421596
# Validation score: 0.626009
# Iteration 827, loss = 0.01420696
# Validation score: 0.624039
# Iteration 828, loss = 0.01420903
# Validation score: 0.621830
# Iteration 829, loss = 0.01420640
# Validation score: 0.620046
# Iteration 830, loss = 0.01420601
# Validation score: 0.622377
# Iteration 831, loss = 0.01419648
# Iteration 883, loss = 0.01405287
# Validation score: 0.603088
# Iteration 884, loss = 0.01405206
# Validation score: 0.603697
# Iteration 885, loss = 0.01404987
# Validation score: 0.605804
# Iteration 886, loss = 0.01403947
# Validation score: 0.607537
# Iteration 887, loss = 0.01404009
# Validation score: 0.608440
# Iteration 888, loss = 0.01403725
# Validation score: 0.608408
# Iteration 889, loss = 0.01403320
# Validation score: 0.608423
# Iteration 890, loss = 0.01402989
# Validation score: 0.606231
# Iteration 891, loss = 0.01402571
# Validation score: 0.605312
# Iteration 892, loss = 0.01402699
# Validation score: 0.603685
# Iteration 893, loss = 0.01402792
# Validation score: 0.605934
# Iteration 894, loss = 0.01402126
# Validation score: 0.607032
# Iteration 895, loss = 0.01401592
# Validation score: 0.606262
# Iteration 896, loss = 0.01401878
# Validation score: 0.608603
# Iteration 897, loss = 0.01400859
# Validation score: 0.609352
# Iteration 898, loss = 0.01400574
# Validation score: 0.612252
# Iteration 899, loss = 0.01401022
# Validation score: 0.614766
# Iteration 900, loss = 0.01399738
# Validation score: 0.614498
# Iteration 901, loss = 0.01399471
# Validation score: 0.615014
# Iteration 902, loss = 0.01400185
# Validation score: 0.618159
# Iteration 903, loss = 0.01399529
# Validation score: 0.618268
# Iteration 904, loss = 0.01398449
# Validation score: 0.615932
# Iteration 905, loss = 0.01398357
# Validation score: 0.618210
# Iteration 906, loss = 0.01398167
# Validation score: 0.618650
# Iteration 907, loss = 0.01398331
# Validation score: 0.617361
# Iteration 908, loss = 0.01397392
# Validation score: 0.616758
# Iteration 909, loss = 0.01397716
# Validation score: 0.617744
# Iteration 910, loss = 0.01396854
# Validation score: 0.617812
# Iteration 911, loss = 0.01396670
# Validation score: 0.617800
# Validation score did not improve more than tol=0.000100 for 500 consecutive epochs. Stopping.
# [0.5471448  0.50052748 0.81335902 0.49976674 0.55343693]

# %%
lasso = slm.LassoCV(
    alphas=alphas,
    cv=cvn, 
    verbose=True,
    random_state=1,
    max_iter=100000,
    tol=1e-3,
    n_jobs=-1)

est_ls = lasso.fit(X0_ss,y_train)
results_ls = est_ls.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))
print(results_ls)
# Out:
# [0.61131051 0.43543616 0.67958676 0.55930719 0.65621193]
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# ................................................................................[Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s finished

# %%
ridge = slm.RidgeCV(
    alphas=alphas,
    scoring=scoring,
    cv=cvn)

est_rr = ridge.fit(X0_ss,y_train)
results_rr = est_rr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))
print(results_rr)
# Out:
# [0.55989548 0.40859839 0.64048273 0.51317113 0.71262102]

# %%
lars = slm.LarsCV(
    cv=cvn, 
    max_iter=1000,
    max_n_alphas=10000,
    verbose=True,
    normalize=False,
    eps=np.finfo(float).eps,
    n_jobs=-1)

est_lars = lars.fit(X0_ss,y_train)
results_lars = est_lars.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))
print(results_lars)
# Out:
# [ 1.27848154  1.50600847 -0.47166627 -4.46411206 -2.39640961]
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s finished

# %%
krr_grid = {'kernel': ['linear','rbf'],
          'alpha': [alphas]}

best_params = util.gridsearch_pickparams(skr.KernelRidge(),
                                         cvn,krr_grid,scaler_ss,X_train,train_index,
                                         X_test,test_index,pre_updrs_off,y_train,scoring,-1)
krr = skr.KernelRidge(kernel=best_params['kernel'],alpha=best_params['alpha'])
krr.fit(X0_ss, y_train)
results_krr = krr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))
print(results_krr)
# Out:
# Fitting 8 folds for each of 2 candidates, totalling 16 fits
# [0.35478094 0.60286913 0.71447045 0.51478752 0.66576607]

# %%
gsc = slm.ElasticNetCV(
    alphas=alphas,
    cv=cvn, 
    max_iter=10000,
    verbose=True,
    n_jobs=-1)

est_en = gsc.fit(X0_ss,y_train)
results_en = est_en.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))
print(results_en)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 32 concurrent workers.
# ................................................................................[Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    0.1s finished
# [0.61012524 0.42666874 0.68175334 0.55678574 0.65691615]

# %%
pls_grid = {'n_components': np.flip(np.arange(5,int(len(X_train)))),
            'scale': [True,False]}

best_params = util.gridsearch_pickparams(skd.PLSRegression(),cvn,
                                         pls_grid,scaler_ss,X_train,
                                         train_index,X_test,test_index,pre_updrs_off,y_train,scoring,-1)
pls = skd.PLSRegression(n_components=best_params['n_components'],scale=best_params['scale'],max_iter=10000)
pls.fit(X0_ss, y_train)
results_pls = (pls.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()

print(results_pls)
# Out:
# Fitting 8 folds for each of 74 candidates, totalling 592 fits
# [0.57873083 0.41877063 0.64969663 0.55284606 0.6993595 ]

# %%
pcr = spl.make_pipeline(sdc.PCA(),slm.LinearRegression())
pcr.fit(X0_ss, y_train)
results_pcr = np.asarray(pcr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()
print(results_pcr)
# Out:
# [0.55615146 0.40614766 0.63966888 0.50809582 0.71590003]

# %%
omp = slm.OrthogonalMatchingPursuitCV(normalize=True,cv=cvn,max_iter=len(X_train)//2,verbose=True)
omp.fit(X0_ss, y_train)
results_omp = np.asarray(omp.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()
print(results_omp)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-d26d24748f8b> in <module>
#       1 omp = slm.OrthogonalMatchingPursuitCV(normalize=True,cv=cvn,max_iter=len(X_train)//2,verbose=True)
# ----> 2 omp.fit(X0_ss, y_train)
#       3 results_omp = np.asarray(omp.predict(X_test_ss.reshape([X_test_ss.shape[0],
#       4                                            X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()
#       5 print(results_omp)
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/sklearn/linear_model/_omp.py in fit(self, X, y)
#    1044                 max_iter,
#    1045             )
# -> 1046             for train, test in cv.split(X)
#    1047         )
#    1048
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     862                 return False
#     863             else:
# --> 864                 self._dispatch(tasks)
#     865                 return True
#     866
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     263             return [func(*args, **kwargs)
# --> 264                     for func, args, kwargs in self.items]
#     265
#     266     def __reduce__(self):
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     262         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     263             return [func(*args, **kwargs)
# --> 264                     for func, args, kwargs in self.items]
#     265
#     266     def __reduce__(self):
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/sklearn/linear_model/_omp.py in _omp_path_residues(X_train, y_train, X_test, y_test, copy, fit_intercept, normalize, max_iter)
#     856         precompute=False,
#     857         copy_X=False,
# --> 858         return_path=True,
#     859     )
#     860     if coefs.ndim == 1:
#
# ~/anaconda3/envs/pdradenv/lib/python3.7/site-packages/sklearn/linear_model/_omp.py in orthogonal_mp(X, y, n_nonzero_coefs, tol, precompute, copy_X, return_path, return_n_iter)
#     387     if tol is None and n_nonzero_coefs > X.shape[1]:
#     388         raise ValueError(
# --> 389             "The number of atoms cannot be more than the number of features"
#     390         )
#     391     if precompute == "auto":
#
# ValueError: The number of atoms cannot be more than the number of features

# %%
rsr = slm.RANSACRegressor(random_state=1,min_samples=len(X0_ss)).fit(X0_ss, y_train)
results_rsr = rsr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]])).ravel()
print(results_rsr)
# Out:
# [0.64530668 0.6659428  0.53926421 0.7953765  0.43625847]

# %%
# Very slow on leave one out
# ard_grid = {'alpha_1': alphas[-5:-4], 'alpha_2': alphas[-5:-4], 'lambda_1': alphas[-5:-4], 'lambda_2': alphas[-5:-4]}
# best_params = util.gridsearch_pickparams(slm.ARDRegression(),cvn,
#                                          ard_grid,scaler_ss,X_train,
#                                          train_index,X_test,test_index,pre_updrs_off,y_train,scoring,8)
# ard = slm.ARDRegression(alpha_1=best_params['alpha_1'],alpha_2=best_params['alpha_2'],
#                        lambda_1=best_params['lambda_1'],lambda_2=best_params['lambda_2'])
# ard.fit(X0_ss,y_train)
# results_ard = np.asarray(ard.predict(X_test_ss.reshape([X_test_ss.shape[0],
#                                            X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()

# %%
svr_grid = {'kernel': ['linear','rbf'],
          'epsilon': [1e-2,1e-1,1.5e-1,2.5e-1],
          'C': [1e0,1e1,1e2,1e3]}
best_params = util.gridsearch_pickparams(svm.SVR(),
                                         cvn,svr_grid,scaler_ss,X_train,
                                         train_index,X_test,test_index,pre_updrs_off,y_train,scoring,-1)
svr = svm.SVR(kernel=best_params['kernel'],epsilon=best_params['epsilon'])
svr.fit(X0_ss, y_train)
results_svr = np.asarray(svr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()
print(results_svr)
# Out:
# Fitting 8 folds for each of 32 candidates, totalling 256 fits
# [0.65525462 0.55928516 0.65181429 0.61818073 0.45160369]

# %%
best_params
# Out:
# {'C': 1.0, 'epsilon': 0.01, 'kernel': 'rbf'}

# %%
gbr_grid = {'max_depth':[3,6,9,12,15,20,100]}
best_params = util.gridsearch_pickparams(ske.GradientBoostingRegressor(random_state=1),cvn,
                                         gbr_grid,scaler_ss,X_train,
                                         train_index,X_test,test_index,pre_updrs_off,y_train,scoring,8)
gbr = ske.GradientBoostingRegressor(random_state=1,learning_rate=0.001,max_depth=best_params['max_depth'],n_estimators=100)
gbr.fit(X0_ss, y_train)
results_gbr = np.asarray(gbr.predict(X_test_ss.reshape([X_test_ss.shape[0],
                                           X_test_ss.shape[1]*X_test_ss.shape[2]]))).ravel()
# Out:
# Fitting 8 folds for each of 7 candidates, totalling 56 fits

# %%
util.eval_prediction(np.vstack((pre_imp[test_index],
                               results_lr.ravel(),
                               results_mlp,
                               results_ls,
                               results_lars,
                               results_en,
                               results_rr.ravel(),
                               results_krr.ravel(),
                               results_pcr,
                               results_pls,
                               results_omp,
                               results_br,
                               results_rsr,
                               results_svr,
                               results_gbr)),
                               y_test,
                               ['LCT','Regression','MLP','Lasso','LARS',
                                'ElasticNet','Ridge','KernelRidge','PCR',
                                'PLS','OMP','Bayesian','RANSAC','SVR','GBR'],(70,5))
plt.ylim([0,2])
plt.xlim([0,2])
# Out:
# (0.0, 2.0)

# %%
# np.save('X_test.npy',X_test)
# np.save('X_train.npy',X_train)
# np.save('y_test.npy',y_test)
# np.save('y_train.npy',y_train)
# np.save('test_index.npy',test_index)
# np.save('train_index.npy',train_index)
