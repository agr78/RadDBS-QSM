# %%
# Preliminary data notebook for
# NIH: Imaging Guided Intervention Surgery Study Section

# Exploratory aim: evaluate presurgical scans between STN and GPi targets
#   Given retrospective GPi acquisitions?
#   Search for radiomic differentiators for STN versus GPi selection in presurgical scans

# %%
# Import libraries
from datetime import date, datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn import metrics   
from sklearn.linear_model import LassoCV
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import scipy.stats as stats
import os
import pickle

# %matplotlib widget

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2

load_data = 0
rextract = 0
retrain = 1
# Load data
# fig,ax = plt.subplots(2,5)
segs = []
qsms = []
voxel_sizes = []
trackers = []
directory = 'F:\dbs\stn-dbs\Cornell_anonymized'
case_list = []
if load_data == 1:
    for filename in os.listdir(directory):
        f = os.path.join(directory,filename)
        print(f)
    
        seg = nib.load(f+'/Rh Mri Brain With Without Contrast/seg.nii.gz')
                    
        voxel_size = seg.header['pixdim'][0:3]
        voxel_sizes.append(voxel_size)
        segs.append(seg.get_fdata())

        qsm = nib.load(f+'/Rh Mri Brain With Without Contrast/qsm.nii.gz')
        qsms.append(qsm.get_fdata())
            
        case_list.append(filename)
        n_cases = len(segs)

        label_min = np.partition(np.unique(seg.get_fdata().ravel()),1)[1]
        label_max = np.amax(seg.get_fdata())

# %%
# Define feature extraction
extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.enableAllFeatures()
extractor.enableAllImageTypes()

# Generate feature structure Phi from all ROIs and all cases
if rextract == 1:
    Phi = []

    # Training cases
    for i in range(n_cases):
        seg_sitk = sitk.GetImageFromArray(segs[i])
        seg_sitk.SetSpacing(voxel_sizes[i].tolist())
        qsm_sitk = sitk.GetImageFromArray(qsms[i])
        qsm_sitk.SetSpacing(voxel_sizes[i].tolist())
        for j in range(int(label_min),int(label_max+1)):
            featureVector = extractor.execute(qsm_sitk,seg_sitk,label=j)
            Phi.append(featureVector)
    # Save feature vector
    with open('../features/Phi_57','wb') as fp:  
        pickle.dump(Phi,fp)

# %%
with open('../features/Phi_57','rb') as fp:  
    Phi = pickle.load(fp)

# %%
# %%html
#    <style>
#    .cell-output-ipywidget-background {
#       background-color: transparent !important;
#    }
#    .jp-OutputArea-output {
#       background-color: transparent;
#    }
#    </style>
# Out:
#    <style>
#    .cell-output-ipywidget-background {
#       background-color: transparent !important;
#    }
#    .jp-OutputArea-output {
#       background-color: transparent;
#    }
#    </style>

# %%
# UPDRS features
subject_id = np.array((1,2,3,6,9,10,11,12,13,15,16,20,25,26,27,28,29,34,35,41,43,44,45,46,52,54))
pre_updrs_iii_off = np.array((65,22,45,63,63,27,57,42,54,67,33,27,50,77,43,31,56,81,40,28,52,32,33,18,58,63))
pre_updrs_iii_on = np.array((54,7,13,32,21,14,11,14,28,65,9,4,26,55,14,8,24,20,17,0,29,13,26,0,27,36))
post_updrs_iii_off = np.array((11,2,20,3,7,11,15,21,16,21,4,9,15,9,11,4,8,25,13,16,7,26,2,8,19,8))
per_change = (pre_updrs_iii_off-post_updrs_iii_off)/pre_updrs_iii_off
lct_change = (pre_updrs_iii_off-pre_updrs_iii_on)/(pre_updrs_iii_off)

# %%
n_cases = subject_id.__len__()
x_row = []
per_change_train = []
ut = np.zeros((subject_id.__len__()))
ut_clf = np.zeros((subject_id.__len__()))
clf_alphas = np.zeros((subject_id.__len__()))
sfm_alphas = np.zeros((subject_id.__len__()))
svr_cs = np.zeros((subject_id.__len__()))
svr_epsilons = np.zeros((subject_id.__len__()))
for j in np.arange(1,np.max(subject_id)+1):
    feat_counts = 0
    if j in subject_id:
        # Extract numeric feature values
        n_ROIs = 2

        keys = []
        if [subject_id == j].__len__()>0:
                for iii in np.arange(0,n_ROIs):
                    featureVector = Phi[2*(j-1)+iii]
                    print('Appending feature vectors at index ',2*j+iii,' for case ',j,' ROI number ',iii)
                    for key,value in six.iteritems(featureVector):
                        if 'diagnostic' in key:
                            next
                        else:
                            try:
                                x_row.append(value.ravel())
                                keys.append(key)
                                feat_counts = feat_counts+1  
                            except:
                                x_row.append(value)
                                keys.append(key)
                                feat_counts = feat_counts+1

        if iii == 1 and pre_updrs_iii_off[subject_id == j].__len__()>0:
            x_row.append((pre_updrs_iii_off[subject_id == j]))
            x_row.append(pre_updrs_iii_on[subject_id == j])
            keys.append('pre_updrs_iii_off')
            print('Appending pre-UPDRS off score for case ',j)
            keys.append('pre_updrs_iii_on')
            print('Appending pre-UPDRS on score for case ',j)
            per_change_train.append(per_change[subject_id == j])
            print('Appending target for case ',j)
        jj = int(np.where(subject_id==j)[0])
    print('Appended ',feat_counts,' features to case ',j)            

X0 = np.array(x_row)
X = X0.reshape((n_cases,int(len(X0)/(n_cases))))
# Normalize testing and training cases together
#   Set with_mean=False to preserve data sparsity
#   And with_std=False 
#   However,need a significant number of samples to do this
scaler = RobustScaler()
X_t = scaler.fit_transform(X)
# Out:
# Appending feature vectors at index  2  for case  1  ROI number  0
# Appending feature vectors at index  3  for case  1  ROI number  1
# Appending pre-UPDRS off score for case  1
# Appending pre-UPDRS on score for case  1
# Appending target for case  1
# Appended  3376  features to case  1
# Appending feature vectors at index  4  for case  2  ROI number  0
# Appending feature vectors at index  5  for case  2  ROI number  1
# Appending pre-UPDRS off score for case  2
# Appending pre-UPDRS on score for case  2
# Appending target for case  2
# Appended  3376  features to case  2
# Appending feature vectors at index  6  for case  3  ROI number  0
# Appending feature vectors at index  7  for case  3  ROI number  1
# Appending pre-UPDRS off score for case  3
# Appending pre-UPDRS on score for case  3
# Appending target for case  3
# Appended  3376  features to case  3
# Appended  0  features to case  4
# Appended  0  features to case  5
# Appending feature vectors at index  12  for case  6  ROI number  0
# Appending feature vectors at index  13  for case  6  ROI number  1
# Appending pre-UPDRS off score for case  6
# Appending pre-UPDRS on score for case  6
# Appending target for case  6
# Appended  3376  features to case  6
# Appended  0  features to case  7
# Appended  0  features to case  8
# Appending feature vectors at index  18  for case  9  ROI number  0
# Appending feature vectors at index  19  for case  9  ROI number  1
# Appending pre-UPDRS off score for case  9
# Appending pre-UPDRS on score for case  9
# Appending target for case  9
# Appended  3376  features to case  9
# Appending feature vectors at index  20  for case  10  ROI number  0
# Appending feature vectors at index  21  for case  10  ROI number  1
# Appending pre-UPDRS off score for case  10
# Appending pre-UPDRS on score for case  10
# Appending target for case  10
# Appended  3376  features to case  10
# Appending feature vectors at index  22  for case  11  ROI number  0
# Appending feature vectors at index  23  for case  11  ROI number  1
# Appending pre-UPDRS off score for case  11
# Appending pre-UPDRS on score for case  11
# Appending target for case  11
# Appended  3376  features to case  11
# Appending feature vectors at index  24  for case  12  ROI number  0
# Appending feature vectors at index  25  for case  12  ROI number  1
# Appending pre-UPDRS off score for case  12
# Appending pre-UPDRS on score for case  12
# Appending target for case  12
# Appended  3376  features to case  12
# Appending feature vectors at index  26  for case  13  ROI number  0
# Appending feature vectors at index  27  for case  13  ROI number  1
# Appending pre-UPDRS off score for case  13
# Appending pre-UPDRS on score for case  13
# Appending target for case  13
# Appended  3376  features to case  13
# Appended  0  features to case  14
# Appending feature vectors at index  30  for case  15  ROI number  0
# Appending feature vectors at index  31  for case  15  ROI number  1
# Appending pre-UPDRS off score for case  15
# Appending pre-UPDRS on score for case  15
# Appending target for case  15
# Appended  3376  features to case  15
# Appending feature vectors at index  32  for case  16  ROI number  0
# Appending feature vectors at index  33  for case  16  ROI number  1
# Appending pre-UPDRS off score for case  16
# Appending pre-UPDRS on score for case  16
# Appending target for case  16
# Appended  3376  features to case  16
# Appended  0  features to case  17
# Appended  0  features to case  18
# Appended  0  features to case  19
# Appending feature vectors at index  40  for case  20  ROI number  0
# Appending feature vectors at index  41  for case  20  ROI number  1
# Appending pre-UPDRS off score for case  20
# Appending pre-UPDRS on score for case  20
# Appending target for case  20
# Appended  3376  features to case  20
# Appended  0  features to case  21
# Appended  0  features to case  22
# Appended  0  features to case  23
# Appended  0  features to case  24
# Appending feature vectors at index  50  for case  25  ROI number  0
# Appending feature vectors at index  51  for case  25  ROI number  1
# Appending pre-UPDRS off score for case  25
# Appending pre-UPDRS on score for case  25
# Appending target for case  25
# Appended  3376  features to case  25
# Appending feature vectors at index  52  for case  26  ROI number  0
# Appending feature vectors at index  53  for case  26  ROI number  1
# Appending pre-UPDRS off score for case  26
# Appending pre-UPDRS on score for case  26
# Appending target for case  26
# Appended  3376  features to case  26
# Appending feature vectors at index  54  for case  27  ROI number  0
# Appending feature vectors at index  55  for case  27  ROI number  1
# Appending pre-UPDRS off score for case  27
# Appending pre-UPDRS on score for case  27
# Appending target for case  27
# Appended  3376  features to case  27
# Appending feature vectors at index  56  for case  28  ROI number  0
# Appending feature vectors at index  57  for case  28  ROI number  1
# Appending pre-UPDRS off score for case  28
# Appending pre-UPDRS on score for case  28
# Appending target for case  28
# Appended  3376  features to case  28
# Appending feature vectors at index  58  for case  29  ROI number  0
# Appending feature vectors at index  59  for case  29  ROI number  1
# Appending pre-UPDRS off score for case  29
# Appending pre-UPDRS on score for case  29
# Appending target for case  29
# Appended  3376  features to case  29
# Appended  0  features to case  30
# Appended  0  features to case  31
# Appended  0  features to case  32
# Appended  0  features to case  33
# Appending feature vectors at index  68  for case  34  ROI number  0
# Appending feature vectors at index  69  for case  34  ROI number  1
# Appending pre-UPDRS off score for case  34
# Appending pre-UPDRS on score for case  34
# Appending target for case  34
# Appended  3376  features to case  34
# Appending feature vectors at index  70  for case  35  ROI number  0
# Appending feature vectors at index  71  for case  35  ROI number  1
# Appending pre-UPDRS off score for case  35
# Appending pre-UPDRS on score for case  35
# Appending target for case  35
# Appended  3376  features to case  35
# Appended  0  features to case  36
# Appended  0  features to case  37
# Appended  0  features to case  38
# Appended  0  features to case  39
# Appended  0  features to case  40
# Appending feature vectors at index  82  for case  41  ROI number  0
# Appending feature vectors at index  83  for case  41  ROI number  1
# Appending pre-UPDRS off score for case  41
# Appending pre-UPDRS on score for case  41
# Appending target for case  41
# Appended  3376  features to case  41
# Appended  0  features to case  42
# Appending feature vectors at index  86  for case  43  ROI number  0
# Appending feature vectors at index  87  for case  43  ROI number  1
# Appending pre-UPDRS off score for case  43
# Appending pre-UPDRS on score for case  43
# Appending target for case  43
# Appended  3376  features to case  43
# Appending feature vectors at index  88  for case  44  ROI number  0
# Appending feature vectors at index  89  for case  44  ROI number  1
# Appending pre-UPDRS off score for case  44
# Appending pre-UPDRS on score for case  44
# Appending target for case  44
# Appended  3376  features to case  44
# Appending feature vectors at index  90  for case  45  ROI number  0
# Appending feature vectors at index  91  for case  45  ROI number  1
# Appending pre-UPDRS off score for case  45
# Appending pre-UPDRS on score for case  45
# Appending target for case  45
# Appended  3376  features to case  45
# Appending feature vectors at index  92  for case  46  ROI number  0
# Appending feature vectors at index  93  for case  46  ROI number  1
# Appending pre-UPDRS off score for case  46
# Appending pre-UPDRS on score for case  46
# Appending target for case  46
# Appended  3376  features to case  46
# Appended  0  features to case  47
# Appended  0  features to case  48
# Appended  0  features to case  49
# Appended  0  features to case  50
# Appended  0  features to case  51
# Appending feature vectors at index  104  for case  52  ROI number  0
# Appending feature vectors at index  105  for case  52  ROI number  1
# Appending pre-UPDRS off score for case  52
# Appending pre-UPDRS on score for case  52
# Appending target for case  52
# Appended  3376  features to case  52
# Appended  0  features to case  53
# Appending feature vectors at index  108  for case  54  ROI number  0
# Appending feature vectors at index  109  for case  54  ROI number  1
# Appending pre-UPDRS off score for case  54
# Appending pre-UPDRS on score for case  54
# Appending target for case  54
# Appended  3376  features to case  54

# %%
fig,ax = plt.subplots(2,1)
plt.style.use('dark_background')
im0 = ax[0].pcolor(X)
im1 = ax[1].pcolor(X_t)
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xlabel('Feature index')
ax[0].set_ylabel('Case')
ax[1].set_ylabel('Case')
divider0 = make_axes_locatable(ax[0])
divider1 = make_axes_locatable(ax[1])
cax0 = divider0.append_axes('right',size='5%',pad=0.05)
fig.colorbar(im0,cax=cax0,orientation='vertical')
cax1 = divider1.append_axes('right',size='5%',pad=0.05)
fig.colorbar(im1,cax=cax1,orientation='vertical')
ax[1].set_title('Standardized feature matrix')
ax[0].set_title('Feature matrix $X$');

plt.tight_layout()
fig.set_size_inches(20,10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if retrain == 1:
    #fig,ax = plt.subplots(1,1)
    for j in np.arange(1,np.max(subject_id)):
        if j in subject_id:
            # Remove the test case
            jj = int(np.where(subject_id==j)[0])
            X_j = np.delete(X_t,jj,0)
            pupdrs_j = np.delete(post_updrs_iii_off,jj,0)
            per_change_train_j = np.delete(per_change_train,jj,0)
            # Debug
            print('Excluding subject',str(subject_id[jj]),'at index',jj,'in target vector','from training feature vector of shape',str(X_t.shape),'by deleting row',str(jj),'to create new training feature vector of shape',str(X_j.shape))
            if (sum(sum(np.isnan(X))))>0:
                print('NaN detected in feature vector')

            # Cross-validation for model selection
            cv = KFold((X_j.shape[0]-2))
            # Identify most important features
            # Do not assume data is centered,fit_intercept=True
            clf_in = LassoCV(fit_intercept=True,max_iter=100000,cv=cv).fit(X_j,np.ravel(per_change_train_j))

            clf_alphas[jj] = clf_in.alpha_
            ut[jj] = clf_in.predict(X_t[jj,:].reshape(1,-1))
            print('Predicted percentage change of',ut[jj],'for case',subject_id[jj],'with alpha',clf_in.alpha_)
            print('True percentage change',per_change_train[jj])
# Out:
# Excluding subject 1 at index 0 in target vector from training feature vector of shape (26, 3378) by deleting row 0 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6884000010489201 for case 1 with alpha 2195.716479676794
# True percentage change [0.83076923]
# Excluding subject 2 at index 1 in target vector from training feature vector of shape (26, 3378) by deleting row 1 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7035237713538882 for case 2 with alpha 166.8914666613107
# True percentage change [0.90909091]
# Excluding subject 3 at index 2 in target vector from training feature vector of shape (26, 3378) by deleting row 2 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7016372870950028 for case 3 with alpha 2072.517199947428
# True percentage change [0.55555556]
# Excluding subject 6 at index 3 in target vector from training feature vector of shape (26, 3378) by deleting row 3 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.9138505083955971 for case 6 with alpha 1938.145705853782
# True percentage change [0.95238095]
# Excluding subject 9 at index 4 in target vector from training feature vector of shape (26, 3378) by deleting row 4 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.9626320515704989 for case 9 with alpha 1285.8264281530612
# True percentage change [0.88888889]
# Excluding subject 10 at index 5 in target vector from training feature vector of shape (26, 3378) by deleting row 5 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6998558717884538 for case 10 with alpha 2089.096813161523
# True percentage change [0.59259259]
# Excluding subject 11 at index 6 in target vector from training feature vector of shape (26, 3378) by deleting row 6 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.8829891278348714 for case 11 with alpha 23.093097947502912
# True percentage change [0.73684211]
# Excluding subject 12 at index 7 in target vector from training feature vector of shape (26, 3378) by deleting row 7 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7043094100547904 for case 12 with alpha 2047.6477801262854
# True percentage change [0.5]
# Excluding subject 13 at index 8 in target vector from training feature vector of shape (26, 3378) by deleting row 8 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6945116258690983 for case 13 with alpha 2138.835652803814
# True percentage change [0.7037037]
# Excluding subject 15 at index 9 in target vector from training feature vector of shape (26, 3378) by deleting row 9 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6953358628021037 for case 15 with alpha 2131.1644884808748
# True percentage change [0.68656716]
# Excluding subject 16 at index 10 in target vector from training feature vector of shape (26, 3378) by deleting row 10 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6860903898741367 for case 16 with alpha 2217.212006179545
# True percentage change [0.87878788]
# Excluding subject 20 at index 11 in target vector from training feature vector of shape (26, 3378) by deleting row 11 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6962930411757275 for case 20 with alpha 2122.2560395897185
# True percentage change [0.66666667]
# Excluding subject 25 at index 12 in target vector from training feature vector of shape (26, 3378) by deleting row 12 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6946897673999018 for case 25 with alpha 2137.1776914824063
# True percentage change [0.7]
# Excluding subject 26 at index 13 in target vector from training feature vector of shape (26, 3378) by deleting row 13 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7194909187143046 for case 26 with alpha 726.6715391837417
# True percentage change [0.88311688]
# Excluding subject 27 at index 14 in target vector from training feature vector of shape (26, 3378) by deleting row 14 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6925644975110115 for case 27 with alpha 2156.957555619222
# True percentage change [0.74418605]
# Excluding subject 28 at index 15 in target vector from training feature vector of shape (26, 3378) by deleting row 15 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6864665244837542 for case 28 with alpha 2213.711325383607
# True percentage change [0.87096774]
# Excluding subject 29 at index 16 in target vector from training feature vector of shape (26, 3378) by deleting row 16 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6871314767428618 for case 29 with alpha 2207.522621833648
# True percentage change [0.85714286]
# Excluding subject 34 at index 17 in target vector from training feature vector of shape (26, 3378) by deleting row 17 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6951054309713289 for case 34 with alpha 2133.3091150657824
# True percentage change [0.69135802]
# Excluding subject 35 at index 18 in target vector from training feature vector of shape (26, 3378) by deleting row 18 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6958922227318537 for case 35 with alpha 2125.9864525628905
# True percentage change [0.675]
# Excluding subject 41 at index 19 in target vector from training feature vector of shape (26, 3378) by deleting row 19 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7077449967176079 for case 41 with alpha 2015.6728117848115
# True percentage change [0.42857143]
# Excluding subject 43 at index 20 in target vector from training feature vector of shape (26, 3378) by deleting row 20 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6867350628967046 for case 43 with alpha 2211.2120412576605
# True percentage change [0.86538462]
# Excluding subject 44 at index 21 in target vector from training feature vector of shape (26, 3378) by deleting row 21 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7193401017144567 for case 44 with alpha 1907.7572936323402
# True percentage change [0.1875]
# Excluding subject 45 at index 22 in target vector from training feature vector of shape (26, 3378) by deleting row 22 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6831753466439793 for case 45 with alpha 2244.342282348067
# True percentage change [0.93939394]
# Excluding subject 46 at index 23 in target vector from training feature vector of shape (26, 3378) by deleting row 23 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.7016372870949793 for case 46 with alpha 2072.517199947428
# True percentage change [0.55555556]
# Excluding subject 52 at index 24 in target vector from training feature vector of shape (26, 3378) by deleting row 24 to create new training feature vector of shape (25, 3378)
# Predicted percentage change of 0.6960166146627146 for case 52 with alpha 2124.828738191907
# True percentage change [0.67241379]

# %%
np.mean(per_change)
# Out:
# 0.7248250925500659

# %%
if retrain == 1:
    #fig,ax = plt.subplots(1,1)
    for j in np.arange(1,np.max(subject_id)):
        if j in subject_id:
            # Remove the test case
            jj = int(np.where(subject_id==j)[0])
            X_j = np.delete(X_t,jj,0)
            per_change_train_j = np.delete(per_change_train,jj,0)
            # Debug
            print('Excluding subject',str(subject_id[jj]),'at index',jj,'in target vector','from training feature vector of shape',str(X_t.shape),'by deleting row',str(jj),'to create new training feature vector of shape',str(X_j.shape))

            clf = Lasso(alpha=np.median(clf_alphas),fit_intercept=True,max_iter=10000).fit(X_j,np.ravel(per_change_train_j))
            ut_clf[jj] = clf.predict(X_t[jj,:].reshape(1,-1))
# Out:
# Excluding subject 1 at index 0 in target vector from training feature vector of shape (26, 3378) by deleting row 0 to create new training feature vector of shape (25, 3378)
# Excluding subject 2 at index 1 in target vector from training feature vector of shape (26, 3378) by deleting row 1 to create new training feature vector of shape (25, 3378)
# Excluding subject 3 at index 2 in target vector from training feature vector of shape (26, 3378) by deleting row 2 to create new training feature vector of shape (25, 3378)
# Excluding subject 6 at index 3 in target vector from training feature vector of shape (26, 3378) by deleting row 3 to create new training feature vector of shape (25, 3378)
# Excluding subject 9 at index 4 in target vector from training feature vector of shape (26, 3378) by deleting row 4 to create new training feature vector of shape (25, 3378)
# Excluding subject 10 at index 5 in target vector from training feature vector of shape (26, 3378) by deleting row 5 to create new training feature vector of shape (25, 3378)
# Excluding subject 11 at index 6 in target vector from training feature vector of shape (26, 3378) by deleting row 6 to create new training feature vector of shape (25, 3378)
# Excluding subject 12 at index 7 in target vector from training feature vector of shape (26, 3378) by deleting row 7 to create new training feature vector of shape (25, 3378)
# Excluding subject 13 at index 8 in target vector from training feature vector of shape (26, 3378) by deleting row 8 to create new training feature vector of shape (25, 3378)
# Excluding subject 15 at index 9 in target vector from training feature vector of shape (26, 3378) by deleting row 9 to create new training feature vector of shape (25, 3378)
# Excluding subject 16 at index 10 in target vector from training feature vector of shape (26, 3378) by deleting row 10 to create new training feature vector of shape (25, 3378)
# Excluding subject 20 at index 11 in target vector from training feature vector of shape (26, 3378) by deleting row 11 to create new training feature vector of shape (25, 3378)
# Excluding subject 25 at index 12 in target vector from training feature vector of shape (26, 3378) by deleting row 12 to create new training feature vector of shape (25, 3378)
# Excluding subject 26 at index 13 in target vector from training feature vector of shape (26, 3378) by deleting row 13 to create new training feature vector of shape (25, 3378)
# Excluding subject 27 at index 14 in target vector from training feature vector of shape (26, 3378) by deleting row 14 to create new training feature vector of shape (25, 3378)
# Excluding subject 28 at index 15 in target vector from training feature vector of shape (26, 3378) by deleting row 15 to create new training feature vector of shape (25, 3378)
# Excluding subject 29 at index 16 in target vector from training feature vector of shape (26, 3378) by deleting row 16 to create new training feature vector of shape (25, 3378)
# Excluding subject 34 at index 17 in target vector from training feature vector of shape (26, 3378) by deleting row 17 to create new training feature vector of shape (25, 3378)
# Excluding subject 35 at index 18 in target vector from training feature vector of shape (26, 3378) by deleting row 18 to create new training feature vector of shape (25, 3378)
# Excluding subject 41 at index 19 in target vector from training feature vector of shape (26, 3378) by deleting row 19 to create new training feature vector of shape (25, 3378)
# Excluding subject 43 at index 20 in target vector from training feature vector of shape (26, 3378) by deleting row 20 to create new training feature vector of shape (25, 3378)
# Excluding subject 44 at index 21 in target vector from training feature vector of shape (26, 3378) by deleting row 21 to create new training feature vector of shape (25, 3378)
# Excluding subject 45 at index 22 in target vector from training feature vector of shape (26, 3378) by deleting row 22 to create new training feature vector of shape (25, 3378)
# Excluding subject 46 at index 23 in target vector from training feature vector of shape (26, 3378) by deleting row 23 to create new training feature vector of shape (25, 3378)
# Excluding subject 52 at index 24 in target vector from training feature vector of shape (26, 3378) by deleting row 24 to create new training feature vector of shape (25, 3378)

# %%
if retrain == 1:
    with open('lasso_pred.npy','wb') as f:
        np.save(f,ut)
else:
    with open('lasso_pred.npy','rb') as f:
        ut = np.load(f)

# %%
feats = np.where(abs(clf.coef_)>0)
with open('lasso_feats.txt','w') as f:
    f.write('Lasso selected features from model trained on '+str(datetime.now())+'\n')
    for k in feats[0]:
            with open('lasso_feats.txt','a') as f:
                f.write(keys[k]+'\n')
            print(keys[k])
# Out:
# square_ngtdm_Coarseness
# square_ngtdm_Coarseness

# %%
[fig,ax] = plt.subplots(1,2,sharex=True,sharey=True)
ax[0].hist([lct_change],bins=np.linspace(0,1))
ax[0].set_title('Medication response')
ax[0].set_xlabel('Improvement')
ax[0].set_ylabel('Frequency')
ax[1].hist([ut],bins=np.linspace(0,1))
ax[1].set_title('Lasso prediction')
ax[1].set_xlabel('Improvement')
ax[1].set_ylabel('Frequency')
fig.set_size_inches(12,6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = per_change
y = ut_clf

slope,intercept = np.polyfit(x,y,1)  # linear model adjustment
y_model = np.polyval([slope,intercept],x)   # modeling...

x_mean = np.mean(x)
y_mean = np.mean(y)
n = x.size                        # number of samples
m = 2                             # number of parameters
dof = n-m                       # degrees of freedom
t = stats.t.ppf(0.975,dof)       # Students statistic of interval confidence
residual_ut = y-y_model
std_error = (np.sum(residual_ut**2)/dof)**(1/2)   # Standard deviation of the error

# Pearson's correlation coefficient
numerator = np.sum((x-x_mean)*(y-y_mean))
denominator = (np.sum((x-x_mean)**2)*np.sum((y-y_mean)**2))**.5
correlation_coef = numerator/denominator
r = correlation_coef
tr = r*np.sqrt(n-2)/(np.sqrt(1-r**2))
# p-value for 2-sided test
pv = 2*(1-stats.t.cdf(abs(tr), dof))
# # mean squared error
MSE = 1/n*np.sum((y-y_model)**2)

# to plot the adjusted model
x_line = np.linspace(0,np.max(x),100)
y_line = np.polyval([slope,intercept],x_line)

# confidence interval
ci = t*std_error*(1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5
# predicting interval
pi = t*std_error*(1+1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5  


plt.rcParams.update({'font.size': 14})
[fig,ax] = plt.subplots(1,2,sharex=True,sharey=True)

ax[0].plot(x,y,'o',color = 'white')
ax[0].plot(x_line,y_line,color = 'red')
ax[0].fill_between(x_line,y_line+pi,y_line-pi,color = 'red',label = '95% prediction interval')
ax[0].fill_between(x_line,y_line+ci,y_line-ci,color = 'orange',label = '95% confidence interval')

ax[0].set_xlabel('UPDRS-III pre/post DBS percent improvement')
ax[0].set_ylabel('Percent improvement')
ax[0].set_title('Lasso prediction')

ax[0].text(0.01,0.1,'$y$ = '+ str(np.round(slope,2))+'$x$'+'+'+str(np.round(intercept,3)),color='w')
ax[0].text(0.01,0.005,'$r$ = '+str(np.round(r,2))+', $p$ = '+str(round(pv,3)),color='w')

ax[0].margins(x=0)
fig.set_size_inches(20,10)
ax[0].legend(bbox_to_anchor=(1,1),fontsize=12)


## Medication response
x = per_change
y = lct_change

# Fit and evaluate linear model
slope,intercept = np.polyfit(x,y,1)
y_model = np.polyval([slope,intercept],x)   

# Prepare correlation stats
x_mean = np.mean(x)
y_mean = np.mean(y)
# Sample size
n = x.size         
# Parameters assuming a normal distribution              
m = 2
# Degrees of freedom                            
dof = n-m
# Students statistic of interval confidence                      
t = stats.t.ppf(0.975,dof)      
# Standard deviation of the error
residual_lct = y-y_model
std_error = (np.sum(residual_lct**2)/dof)**(1/2)   

# Pearson's correlation coefficient
numerator = np.sum((x-x_mean)*(y-y_mean))
denominator = (np.sum((x-x_mean)**2)*np.sum((y-y_mean)**2))**.5
correlation_coef = numerator/denominator
r = correlation_coef
tr = r*np.sqrt(n-2)/(np.sqrt(1-r**2))
# p-value for 2-sided test
pv = 2*(1-stats.t.cdf(abs(tr), dof))
# # mean squared error
MSE = 1/n*np.sum((y-y_model)**2)

# to plot the adjusted model
x_line = np.linspace(0,np.max(x),100)
y_line = np.polyval([slope,intercept],x_line)

# confidence interval
ci = t*std_error*(1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5
# predicting interval
pi = t*std_error*(1+1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5  



ax[1].plot(x,y,'o',color = 'white')
ax[1].plot(x_line,y_line,color = 'red')
ax[1].fill_between(x_line,y_line+pi,y_line-pi,color = 'red',label = '95% prediction interval')
ax[1].fill_between(x_line,y_line+ci,y_line-ci,color = 'orange',label = '95% confidence interval')

ax[1].set_xlabel('UPDRS-III pre/post DBS percent improvement')
ax[1].set_ylabel('Percent improvement')
ax[1].set_title('Medication response')


ax[1].text(0.01,0.1,'$y$ = '+ str(np.round(slope,2))+'$x$'+'+'+str(np.round(intercept,3)),color='w')
ax[1].text(0.01,0.005,'$r$ = '+str(np.round(r,2))+', $p$ = '+str(round(pv,3)),color='w')

ax[1].margins(x=0)
fig.set_size_inches(20,10)
ax[1].legend(bbox_to_anchor=(1,1),fontsize=12)
fig.suptitle('UPDRS-III Improvement')
fig.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
[fig,ax] = plt.subplots(1,2,sharex=False,sharey=True)
ax[0].hist([residual_lct])
ax[0].set_title('Medication response residuals')
ax[0].set_xlabel('Residual')
ax[0].set_ylabel('Frequency')
ax[1].hist([residual_ut])
ax[1].set_title('Lasso prediction residuals')
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Frequency')
fig.set_size_inches(12,6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
