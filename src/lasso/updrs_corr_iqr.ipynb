# %%
# Preliminary data notebook for
# NIH: Imaging Guided Intervention Surgery Study Section

# Exploratory aim: evaluate presurgical scans between STN and GPi targets
#   Given retrospective GPi acquisitions?
#   Search for radiomic differentiators for STN versus GPi selection in presurgical scans

# %%
# Import libraries
from datetime import date, datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
import nibabel as nib
from sklearn import metrics   
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import KFold
import SimpleITK as sitk
import six
from radiomics import featureextractor 
import numpy as np
import scipy.stats as stats
from scipy.stats import linregress
import os
import pickle
import pandas as pd
os.chdir('../util')
from util import scores_df
from util import iqr_exclude
# %matplotlib widget

# %%
# Set window level
level = 0
window = 500
m1=level-window/2
m2=level+window/2

load_data = 0
rextract = 0
retrain = 1
# Load data
# fig,ax = plt.subplots(2,5)
segs = []
qsms = []
voxel_sizes = []
trackers = []
directory = 'F:\dbs\stn-dbs\Cornell_anonymized'
case_list = []
if load_data == 1:
    for filename in os.listdir(directory):
        f = os.path.join(directory,filename)
        print(f)
    
        seg = nib.load(f+'/Rh Mri Brain With Without Contrast/seg.nii.gz')
                    
        voxel_size = seg.header['pixdim'][0:3]
        voxel_sizes.append(voxel_size)
        segs.append(seg.get_fdata())

        qsm = nib.load(f+'/Rh Mri Brain With Without Contrast/qsm.nii.gz')
        qsms.append(qsm.get_fdata())
            
        case_list.append(filename)
        n_cases = len(segs)

        label_min = np.partition(np.unique(seg.get_fdata().ravel()),1)[1]
        label_max = np.amax(seg.get_fdata())

# %%
# Define feature extraction
extractor = featureextractor.RadiomicsFeatureExtractor()
extractor.enableAllFeatures()
extractor.enableAllImageTypes()

# Generate feature structure Phi from all ROIs and all cases
if rextract == 1:
    Phi = []

    # Training cases
    for i in range(n_cases):
        seg_sitk = sitk.GetImageFromArray(segs[i])
        seg_sitk.SetSpacing(voxel_sizes[i].tolist())
        qsm_sitk = sitk.GetImageFromArray(qsms[i])
        qsm_sitk.SetSpacing(voxel_sizes[i].tolist())
        for j in range(int(label_min),int(label_max+1)):
            featureVector = extractor.execute(qsm_sitk,seg_sitk,label=j)
            Phi.append(featureVector)
    # Save feature vector
    with open('../features/Phi_stn_sn_dn','wb') as fp:  
        pickle.dump(Phi,fp)

# %%
with open('../features/Phi_stn_sn_dn','rb') as fp:  
    Phi = pickle.load(fp)

# %%
# %%html
#    <style>
#    .cell-output-ipywidget-background {
#       background-color: transparent !important;
#    }
#    .jp-OutputArea-output {
#       background-color: transparent;
#    }
#    </style>
# Out:
#    <style>
#    .cell-output-ipywidget-background {
#       background-color: transparent !important;
#    }
#    .jp-OutputArea-output {
#       background-color: transparent;
#    }
#    </style>

# %%
# Mt. Sinai data location
file_dir = '/data/Ali/RadDBS-QSM/src/csv'
# Load patient data
os.chdir(file_dir)
df = pd.read_csv('VRS_QSM patient UPDRS post-scoring - Copy.csv')

# %%
df_out,anon_ids,complete_cases = scores_df(file_dir,'VRS_QSM patient UPDRS post-scoring - Copy.csv','MDS-UPDRS: Part III (Motor)','Pre-DBS, On Meds','Post-DBS, Off Meds, Stim On');
# Out:
# Dropping NaN column at Unnamed: 1
# Dropping NaN column at Post-Op MRI Brain
# Renaming Unnamed: 6 as SAS Pre-DBS OFF
# Renaming Unnamed: 7 as SAS Post-DBS ON
# Renaming Unnamed: 8 as SAS Post-DBS OFF
# Renaming Unnamed: 11 as BAI Pre-DBS OFF
# Renaming Unnamed: 12 as BAI Post-DBS ON
# Renaming Unnamed: 13 as BAI Post-DBS OFF
# Renaming Unnamed: 16 as BDI-II Pre-DBS OFF
# Renaming Unnamed: 17 as BDI-II Post-DBS ON
# Renaming Unnamed: 18 as BDI-II Post-DBS OFF
# Renaming Unnamed: 20 as MDS-UPDRS: Part I (Mood and Cognitive) Anxiety
# Renaming Unnamed: 21 as MDS-UPDRS: Part I (Mood and Cognitive) Apathy
# Renaming Unnamed: 22 as MDS-UPDRS: Part I (Mood and Cognitive) Post-DBS
# Renaming Unnamed: 24 as MDS-UPDRS: Part III (Motor) Pre-DBS, Off Meds
# Renaming Unnamed: 25 as MDS-UPDRS: Part III (Motor) Post-DBS, Off Meds, Stim Off
# Renaming Unnamed: 26 as MDS-UPDRS: Part III (Motor) Post-DBS, OnMeds, Stim Off
# Renaming Unnamed: 27 as MDS-UPDRS: Part III (Motor) Post-DBS, Off Meds, Stim On
# Renaming Unnamed: 28 as MDS-UPDRS: Part III (Motor) Post-DBS, On Meds, Stim On

# %%
pre_updrs_iii_off = df_out['Pre-DBS, Off Meds'].to_numpy().astype('float')
pre_updrs_iii_on = df_out['Pre-DBS, On Meds'].to_numpy().astype('float')
post_updrs_iii_off = df_out['Post-DBS, Off Meds, Stim On'].to_numpy().astype('float')
per_change = (pre_updrs_iii_off-post_updrs_iii_off)/pre_updrs_iii_off
lct_change = (pre_updrs_iii_off-pre_updrs_iii_on)/(pre_updrs_iii_off)

# %%
df_out
# Out:
# 0  Anonymous ID Pre-DBS, On Meds Pre-DBS, Off Meds  \
# 1           1.0               54                65
# 2           2.0                7                22
# 3           3.0               13                45
# 4           4.0               16                35
# 5           5.0               12                48
# 6           6.0               32                63
# 7           7.0                8                31
# 8           8.0                8                61
# 9           9.0               21                63
# 10         10.0               14                27
# 11         11.0               11                57
# 12         12.0               14                42
# 13         13.0               28                54
# 14         14.0               13                57
# 15         15.0               65                67
# 16         16.0                9                33
# 17         17.0               10                57
# 18         18.0                8                48
# 19         19.0                5                30
# 20         20.0                4                27
# 21         21.0                6                51
# 22         22.0               22                53
# 23         23.0               17                50
# 24         24.0                8                33
# 25         25.0               26                50
# 26         26.0               55                77
# 27         27.0               14                43
# 28         28.0                8                31
# 29         29.0               24                56
# 30         30.0               24                46
# 31         31.0               15                57
# 32         32.0                1                36
# 33         33.0               12                36
# 34         34.0               20                81
# 35         35.0               17                40
# 36         36.0               12                49
# 37         37.0              NaN               NaN
# 38         38.0               17                50
# 39         39.0               23                46
# 40         40.0               32                70
# 41         41.0                0                28
# 42         42.0                7                47
# 43         43.0               29                52
# 44         44.0               13                32
# 45         45.0               26                33
# 46         46.0                0                18
# 47         47.0               15                65
# 48         48.0               35                70
# 49         49.0                5                19
# 50         50.0                7                33
# 51         51.0               28                43
# 52         52.0               27                58
# 53         53.0               47                77
# 54         54.0               36                63
# 55         55.0               29                40
# 56         56.0               20                81
#
# 0  Post-DBS, Off Meds, Stim Off Post-DBS, OnMeds, Stim Off  \
# 1                            30                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                            12                        NaN
# 5                           NaN                        NaN
# 6                            17                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                           NaN                        NaN
# 10                           37                        NaN
# 11                          NaN                         17
# 12                          NaN                        NaN
# 13                          NaN                        NaN
# 14                          NaN                        NaN
# 15                          NaN                         14
# 16                           17                         14
# 17                          NaN                        NaN
# 18                          NaN                         15
# 19                           15                        NaN
# 20                           31                        NaN
# 21                          NaN                        NaN
# 22                          NaN                        NaN
# 23                          NaN                         21
# 24                          NaN                        NaN
# 25                          NaN                        NaN
# 26                           19                        NaN
# 27                           23                        NaN
# 28                            9                        NaN
# 29                          NaN                        NaN
# 30                          NaN                        NaN
# 31                          NaN                        NaN
# 32                          NaN                        NaN
# 33                          NaN                        NaN
# 34                           34                         17
# 35                          NaN                        NaN
# 36                          NaN                          3
# 37                          NaN                        NaN
# 38                          NaN                        NaN
# 39                          NaN                        NaN
# 40                          NaN                        NaN
# 41                          NaN                        NaN
# 42                          NaN                        NaN
# 43                          NaN                        NaN
# 44                          NaN                        NaN
# 45                          NaN                        NaN
# 46                           14                          8
# 47                          NaN                        NaN
# 48                          NaN                        NaN
# 49                          NaN                        NaN
# 50                           23                          8
# 51                          NaN                        NaN
# 52                          NaN                        NaN
# 53                          NaN                         26
# 54                          NaN                        NaN
# 55                           37                        NaN
# 56                          NaN                        NaN
#
# 0  Post-DBS, Off Meds, Stim On Post-DBS, On Meds, Stim On
# 1                           11                        NaN
# 2                            2                        NaN
# 3                           20                        NaN
# 4                          NaN                          5
# 5                          NaN                         22
# 6                            3                        NaN
# 7                          NaN                          5
# 8                          NaN                          6
# 9                            7                        NaN
# 10                          11                          6
# 11                          15                          0
# 12                          21                         14
# 13                          16                         11
# 14                         NaN                          8
# 15                          21                        NaN
# 16                           4                          3
# 17                         NaN                         16
# 18                         NaN                          6
# 19                         NaN                          4
# 20                           9                          2
# 21                         NaN                          5
# 22                         NaN                         17
# 23                         NaN                        NaN
# 24                         NaN                          8
# 25                          15                        NaN
# 26                           9                        NaN
# 27                          11                        NaN
# 28                           4                        NaN
# 29                           8                         11
# 30                         NaN                          9
# 31                         NaN                         11
# 32                         NaN                          7
# 33                         NaN                          6
# 34                          25                         12
# 35                          13                        NaN
# 36                         NaN                        NaN
# 37                         NaN                        NaN
# 38                         NaN                          9
# 39                         NaN                         14
# 40                         NaN                         21
# 41                          16                          6
# 42                         NaN                        NaN
# 43                           7                        NaN
# 44                          26                          9
# 45                           2                        NaN
# 46                           8                          6
# 47                         NaN                         22
# 48                         NaN                        NaN
# 49                         NaN                         11
# 50                         NaN                          3
# 51                         NaN                          5
# 52                          19                         12
# 53                         NaN                         19
# 54                           8                        NaN
# 55                         NaN                         13
# 56                         NaN                          7

# %%
n_cases = complete_cases.__len__()
Phi_id = []
x_row = []
per_change_train = []
ut = np.zeros(n_cases)
ut_clf = np.zeros(n_cases)
clf_alphas = np.zeros(n_cases)

for j in complete_cases:
    feat_counts = 0
    n_ROIs = 2
    keys = []
    for iii in np.arange(0,n_ROIs):
        featureVector = Phi[int(2*(j-1)+iii)][0]
        Phi_id.append(Phi[int(2*(j-1)+iii)][1])
        print('Appending feature vectors at index ',2*(j-1)+iii,' for case ',j,' ROI number ',iii)
        for key,value in six.iteritems(featureVector):
            if 'diagnostic' in key:
                next
            else:
                x_row.append(value)
                keys.append(key)
                feat_counts = feat_counts+1  

    if iii == 1:
            x_row.append(pre_updrs_iii_off[int(j)-1])
            x_row.append(pre_updrs_iii_on[int(j)-1])
            keys.append('pre_updrs_iii_off')
            print('Appending pre-UPDRS off score for case ',j)
            keys.append('pre_updrs_iii_on')
            print('Appending pre-UPDRS on score for case ',j)
            per_change_train.append(per_change[int(j)-1])
            print('Appending target for case ',j)
      
    print('Appended ',feat_counts,' features to case ',j)            

X0 = np.array(x_row)
X = X0.reshape((n_cases,int(len(X0)/(n_cases))))
# Normalize testing and training cases together
#   Set with_mean=False to preserve data sparsity
#   And with_std=False 
#   However,need a significant number of samples to do this
scaler = MinMaxScaler()
X_t = scaler.fit_transform(X)
# Out:
# Appending feature vectors at index  0.0  for case  1.0  ROI number  0
# Appending feature vectors at index  1.0  for case  1.0  ROI number  1
# Appending pre-UPDRS off score for case  1.0
# Appending pre-UPDRS on score for case  1.0
# Appending target for case  1.0
# Appended  3376  features to case  1.0
# Appending feature vectors at index  2.0  for case  2.0  ROI number  0
# Appending feature vectors at index  3.0  for case  2.0  ROI number  1
# Appending pre-UPDRS off score for case  2.0
# Appending pre-UPDRS on score for case  2.0
# Appending target for case  2.0
# Appended  3376  features to case  2.0
# Appending feature vectors at index  4.0  for case  3.0  ROI number  0
# Appending feature vectors at index  5.0  for case  3.0  ROI number  1
# Appending pre-UPDRS off score for case  3.0
# Appending pre-UPDRS on score for case  3.0
# Appending target for case  3.0
# Appended  3376  features to case  3.0
# Appending feature vectors at index  10.0  for case  6.0  ROI number  0
# Appending feature vectors at index  11.0  for case  6.0  ROI number  1
# Appending pre-UPDRS off score for case  6.0
# Appending pre-UPDRS on score for case  6.0
# Appending target for case  6.0
# Appended  3376  features to case  6.0
# Appending feature vectors at index  16.0  for case  9.0  ROI number  0
# Appending feature vectors at index  17.0  for case  9.0  ROI number  1
# Appending pre-UPDRS off score for case  9.0
# Appending pre-UPDRS on score for case  9.0
# Appending target for case  9.0
# Appended  3376  features to case  9.0
# Appending feature vectors at index  18.0  for case  10.0  ROI number  0
# Appending feature vectors at index  19.0  for case  10.0  ROI number  1
# Appending pre-UPDRS off score for case  10.0
# Appending pre-UPDRS on score for case  10.0
# Appending target for case  10.0
# Appended  3376  features to case  10.0
# Appending feature vectors at index  20.0  for case  11.0  ROI number  0
# Appending feature vectors at index  21.0  for case  11.0  ROI number  1
# Appending pre-UPDRS off score for case  11.0
# Appending pre-UPDRS on score for case  11.0
# Appending target for case  11.0
# Appended  3376  features to case  11.0
# Appending feature vectors at index  22.0  for case  12.0  ROI number  0
# Appending feature vectors at index  23.0  for case  12.0  ROI number  1
# Appending pre-UPDRS off score for case  12.0
# Appending pre-UPDRS on score for case  12.0
# Appending target for case  12.0
# Appended  3376  features to case  12.0
# Appending feature vectors at index  24.0  for case  13.0  ROI number  0
# Appending feature vectors at index  25.0  for case  13.0  ROI number  1
# Appending pre-UPDRS off score for case  13.0
# Appending pre-UPDRS on score for case  13.0
# Appending target for case  13.0
# Appended  3376  features to case  13.0
# Appending feature vectors at index  28.0  for case  15.0  ROI number  0
# Appending feature vectors at index  29.0  for case  15.0  ROI number  1
# Appending pre-UPDRS off score for case  15.0
# Appending pre-UPDRS on score for case  15.0
# Appending target for case  15.0
# Appended  3376  features to case  15.0
# Appending feature vectors at index  30.0  for case  16.0  ROI number  0
# Appending feature vectors at index  31.0  for case  16.0  ROI number  1
# Appending pre-UPDRS off score for case  16.0
# Appending pre-UPDRS on score for case  16.0
# Appending target for case  16.0
# Appended  3376  features to case  16.0
# Appending feature vectors at index  38.0  for case  20.0  ROI number  0
# Appending feature vectors at index  39.0  for case  20.0  ROI number  1
# Appending pre-UPDRS off score for case  20.0
# Appending pre-UPDRS on score for case  20.0
# Appending target for case  20.0
# Appended  3376  features to case  20.0
# Appending feature vectors at index  48.0  for case  25.0  ROI number  0
# Appending feature vectors at index  49.0  for case  25.0  ROI number  1
# Appending pre-UPDRS off score for case  25.0
# Appending pre-UPDRS on score for case  25.0
# Appending target for case  25.0
# Appended  3376  features to case  25.0
# Appending feature vectors at index  50.0  for case  26.0  ROI number  0
# Appending feature vectors at index  51.0  for case  26.0  ROI number  1
# Appending pre-UPDRS off score for case  26.0
# Appending pre-UPDRS on score for case  26.0
# Appending target for case  26.0
# Appended  3376  features to case  26.0
# Appending feature vectors at index  52.0  for case  27.0  ROI number  0
# Appending feature vectors at index  53.0  for case  27.0  ROI number  1
# Appending pre-UPDRS off score for case  27.0
# Appending pre-UPDRS on score for case  27.0
# Appending target for case  27.0
# Appended  3376  features to case  27.0
# Appending feature vectors at index  54.0  for case  28.0  ROI number  0
# Appending feature vectors at index  55.0  for case  28.0  ROI number  1
# Appending pre-UPDRS off score for case  28.0
# Appending pre-UPDRS on score for case  28.0
# Appending target for case  28.0
# Appended  3376  features to case  28.0
# Appending feature vectors at index  56.0  for case  29.0  ROI number  0
# Appending feature vectors at index  57.0  for case  29.0  ROI number  1
# Appending pre-UPDRS off score for case  29.0
# Appending pre-UPDRS on score for case  29.0
# Appending target for case  29.0
# Appended  3376  features to case  29.0
# Appending feature vectors at index  66.0  for case  34.0  ROI number  0
# Appending feature vectors at index  67.0  for case  34.0  ROI number  1
# Appending pre-UPDRS off score for case  34.0
# Appending pre-UPDRS on score for case  34.0
# Appending target for case  34.0
# Appended  3376  features to case  34.0
# Appending feature vectors at index  68.0  for case  35.0  ROI number  0
# Appending feature vectors at index  69.0  for case  35.0  ROI number  1
# Appending pre-UPDRS off score for case  35.0
# Appending pre-UPDRS on score for case  35.0
# Appending target for case  35.0
# Appended  3376  features to case  35.0
# Appending feature vectors at index  80.0  for case  41.0  ROI number  0
# Appending feature vectors at index  81.0  for case  41.0  ROI number  1
# Appending pre-UPDRS off score for case  41.0
# Appending pre-UPDRS on score for case  41.0
# Appending target for case  41.0
# Appended  3376  features to case  41.0
# Appending feature vectors at index  84.0  for case  43.0  ROI number  0
# Appending feature vectors at index  85.0  for case  43.0  ROI number  1
# Appending pre-UPDRS off score for case  43.0
# Appending pre-UPDRS on score for case  43.0
# Appending target for case  43.0
# Appended  3376  features to case  43.0
# Appending feature vectors at index  86.0  for case  44.0  ROI number  0
# Appending feature vectors at index  87.0  for case  44.0  ROI number  1
# Appending pre-UPDRS off score for case  44.0
# Appending pre-UPDRS on score for case  44.0
# Appending target for case  44.0
# Appended  3376  features to case  44.0
# Appending feature vectors at index  88.0  for case  45.0  ROI number  0
# Appending feature vectors at index  89.0  for case  45.0  ROI number  1
# Appending pre-UPDRS off score for case  45.0
# Appending pre-UPDRS on score for case  45.0
# Appending target for case  45.0
# Appended  3376  features to case  45.0
# Appending feature vectors at index  90.0  for case  46.0  ROI number  0
# Appending feature vectors at index  91.0  for case  46.0  ROI number  1
# Appending pre-UPDRS off score for case  46.0
# Appending pre-UPDRS on score for case  46.0
# Appending target for case  46.0
# Appended  3376  features to case  46.0
# Appending feature vectors at index  102.0  for case  52.0  ROI number  0
# Appending feature vectors at index  103.0  for case  52.0  ROI number  1
# Appending pre-UPDRS off score for case  52.0
# Appending pre-UPDRS on score for case  52.0
# Appending target for case  52.0
# Appended  3376  features to case  52.0
# Appending feature vectors at index  106.0  for case  54.0  ROI number  0
# Appending feature vectors at index  107.0  for case  54.0  ROI number  1
# Appending pre-UPDRS off score for case  54.0
# Appending pre-UPDRS on score for case  54.0
# Appending target for case  54.0
# Appended  3376  features to case  54.0

# %%
x_m = iqr_exclude(np.asarray(per_change_train))
complete_cases_iqr = (np.asarray(complete_cases)).astype(int)[x_m]
# Out:
# 75th percentile at 0.8725038402457758
# 25th percentile at 0.6681034482758621
# Interquartile range of 0.20440039196991366
# Upper bound of 1.0769042322156894
# Lower bound of 0.46370305630594844
# Excluded 14 outliers

# %%
complete_cases = complete_cases_iqr

# %%
n_cases = complete_cases.__len__()
Phi_id = []
x_row = []
per_change_train = []
ut = np.zeros(n_cases)
ut_clf = np.zeros(n_cases)
clf_alphas = np.zeros(n_cases)

for j in complete_cases:
    feat_counts = 0
    n_ROIs = 2
    keys = []
    for iii in np.arange(0,n_ROIs):
        featureVector = Phi[int(2*(j-1)+iii)][0]
        Phi_id.append(Phi[int(2*(j-1)+iii)][1])
        print('Appending feature vectors at index ',2*(j-1)+iii,' for case ',j,' ROI number ',iii)
        for key,value in six.iteritems(featureVector):
            if 'diagnostic' in key:
                next
            else:
                x_row.append(value)
                keys.append(key)
                feat_counts = feat_counts+1  

    if iii == 1:
            x_row.append(pre_updrs_iii_off[int(j)-1])
            x_row.append(pre_updrs_iii_on[int(j)-1])
            keys.append('pre_updrs_iii_off')
            print('Appending pre-UPDRS off score for case ',j)
            keys.append('pre_updrs_iii_on')
            print('Appending pre-UPDRS on score for case ',j)
            per_change_train.append(per_change[int(j)-1])
            print('Appending target for case ',j)
      
    print('Appended ',feat_counts,' features to case ',j)            

X0 = np.array(x_row)
X = X0.reshape((n_cases,int(len(X0)/(n_cases))))
# Normalize testing and training cases together
#   Set with_mean=False to preserve data sparsity
#   And with_std=False 
#   However,need a significant number of samples to do this
scaler = MinMaxScaler()
X_t = scaler.fit_transform(X)
# Out:
# Appending feature vectors at index  0  for case  1  ROI number  0
# Appending feature vectors at index  1  for case  1  ROI number  1
# Appending pre-UPDRS off score for case  1
# Appending pre-UPDRS on score for case  1
# Appending target for case  1
# Appended  3376  features to case  1
# Appending feature vectors at index  20  for case  11  ROI number  0
# Appending feature vectors at index  21  for case  11  ROI number  1
# Appending pre-UPDRS off score for case  11
# Appending pre-UPDRS on score for case  11
# Appending target for case  11
# Appended  3376  features to case  11
# Appending feature vectors at index  24  for case  13  ROI number  0
# Appending feature vectors at index  25  for case  13  ROI number  1
# Appending pre-UPDRS off score for case  13
# Appending pre-UPDRS on score for case  13
# Appending target for case  13
# Appended  3376  features to case  13
# Appending feature vectors at index  28  for case  15  ROI number  0
# Appending feature vectors at index  29  for case  15  ROI number  1
# Appending pre-UPDRS off score for case  15
# Appending pre-UPDRS on score for case  15
# Appending target for case  15
# Appended  3376  features to case  15
# Appending feature vectors at index  48  for case  25  ROI number  0
# Appending feature vectors at index  49  for case  25  ROI number  1
# Appending pre-UPDRS off score for case  25
# Appending pre-UPDRS on score for case  25
# Appending target for case  25
# Appended  3376  features to case  25
# Appending feature vectors at index  52  for case  27  ROI number  0
# Appending feature vectors at index  53  for case  27  ROI number  1
# Appending pre-UPDRS off score for case  27
# Appending pre-UPDRS on score for case  27
# Appending target for case  27
# Appended  3376  features to case  27
# Appending feature vectors at index  54  for case  28  ROI number  0
# Appending feature vectors at index  55  for case  28  ROI number  1
# Appending pre-UPDRS off score for case  28
# Appending pre-UPDRS on score for case  28
# Appending target for case  28
# Appended  3376  features to case  28
# Appending feature vectors at index  56  for case  29  ROI number  0
# Appending feature vectors at index  57  for case  29  ROI number  1
# Appending pre-UPDRS off score for case  29
# Appending pre-UPDRS on score for case  29
# Appending target for case  29
# Appended  3376  features to case  29
# Appending feature vectors at index  66  for case  34  ROI number  0
# Appending feature vectors at index  67  for case  34  ROI number  1
# Appending pre-UPDRS off score for case  34
# Appending pre-UPDRS on score for case  34
# Appending target for case  34
# Appended  3376  features to case  34
# Appending feature vectors at index  68  for case  35  ROI number  0
# Appending feature vectors at index  69  for case  35  ROI number  1
# Appending pre-UPDRS off score for case  35
# Appending pre-UPDRS on score for case  35
# Appending target for case  35
# Appended  3376  features to case  35
# Appending feature vectors at index  84  for case  43  ROI number  0
# Appending feature vectors at index  85  for case  43  ROI number  1
# Appending pre-UPDRS off score for case  43
# Appending pre-UPDRS on score for case  43
# Appending target for case  43
# Appended  3376  features to case  43
# Appending feature vectors at index  102  for case  52  ROI number  0
# Appending feature vectors at index  103  for case  52  ROI number  1
# Appending pre-UPDRS off score for case  52
# Appending pre-UPDRS on score for case  52
# Appending target for case  52
# Appended  3376  features to case  52

# %%
fig,ax = plt.subplots(2,1)
plt.style.use('dark_background')
im0 = ax[0].pcolor(X)
im1 = ax[1].pcolor(X_t)
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xlabel('Feature index')
ax[0].set_ylabel('Case')
ax[1].set_ylabel('Case')
divider0 = make_axes_locatable(ax[0])
divider1 = make_axes_locatable(ax[1])
cax0 = divider0.append_axes('right',size='5%',pad=0.05)
fig.colorbar(im0,cax=cax0,orientation='vertical')
cax1 = divider1.append_axes('right',size='5%',pad=0.05)
fig.colorbar(im1,cax=cax1,orientation='vertical')
ax[1].set_title('Standardized feature matrix')
ax[0].set_title('Feature matrix $X$');

plt.tight_layout()
fig.set_size_inches(20,10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Phi_y = np.vstack((X_t.T,per_change_train))
Phi_y = Phi_y.T
Phi_cov = np.cov(Phi_y.T)
Phi_corr = np.corrcoef(Phi_y.T)
# Out:
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/numpy/lib/function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /data/Ali/anaconda3/envs/pdradenv/lib/python3.7/site-packages/numpy/lib/function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
nan_feats = 0
for kk in np.arange(feat_counts):
    if np.isnan(Phi_corr[kk,kk]):
        print('NaN detected at correlation matrix diagonal entry',kk, 'feature', keys[kk],'with covariance matrix value',Phi_cov[kk,kk])
        nan_feats = nan_feats+1
# Out:
# NaN detected at correlation matrix diagonal entry 110 feature exponential_firstorder_Entropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 123 feature exponential_firstorder_Uniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 125 feature exponential_glcm_Autocorrelation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 126 feature exponential_glcm_ClusterProminence with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 127 feature exponential_glcm_ClusterShade with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 128 feature exponential_glcm_ClusterTendency with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 129 feature exponential_glcm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 130 feature exponential_glcm_Correlation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 131 feature exponential_glcm_DifferenceAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 132 feature exponential_glcm_DifferenceEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 133 feature exponential_glcm_DifferenceVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 134 feature exponential_glcm_Id with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 135 feature exponential_glcm_Idm with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 136 feature exponential_glcm_Idmn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 137 feature exponential_glcm_Idn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 138 feature exponential_glcm_Imc1 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 139 feature exponential_glcm_Imc2 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 140 feature exponential_glcm_InverseVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 141 feature exponential_glcm_JointAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 142 feature exponential_glcm_JointEnergy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 143 feature exponential_glcm_JointEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 144 feature exponential_glcm_MCC with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 145 feature exponential_glcm_MaximumProbability with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 146 feature exponential_glcm_SumAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 147 feature exponential_glcm_SumEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 148 feature exponential_glcm_SumSquares with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 154 feature exponential_gldm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 155 feature exponential_gldm_HighGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 159 feature exponential_gldm_LowGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 164 feature exponential_glrlm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 165 feature exponential_glrlm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 166 feature exponential_glrlm_HighGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 170 feature exponential_glrlm_LowGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 179 feature exponential_glszm_GrayLevelNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 180 feature exponential_glszm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 181 feature exponential_glszm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 182 feature exponential_glszm_HighGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 186 feature exponential_glszm_LowGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry
verage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 514 feature lbp-3D-m2_glcm_JointEnergy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 515 feature lbp-3D-m2_glcm_JointEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 516 feature lbp-3D-m2_glcm_MCC with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 517 feature lbp-3D-m2_glcm_MaximumProbability with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 518 feature lbp-3D-m2_glcm_SumAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 519 feature lbp-3D-m2_glcm_SumEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 520 feature lbp-3D-m2_glcm_SumSquares with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 526 feature lbp-3D-m2_gldm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 527 feature lbp-3D-m2_gldm_HighGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 531 feature lbp-3D-m2_gldm_LowGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 536 feature lbp-3D-m2_glrlm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 537 feature lbp-3D-m2_glrlm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 538 feature lbp-3D-m2_glrlm_HighGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 542 feature lbp-3D-m2_glrlm_LowGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 551 feature lbp-3D-m2_glszm_GrayLevelNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 552 feature lbp-3D-m2_glszm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 553 feature lbp-3D-m2_glszm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 554 feature lbp-3D-m2_glszm_HighGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 558 feature lbp-3D-m2_glszm_LowGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 559 feature lbp-3D-m2_glszm_SizeZoneNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 560 feature lbp-3D-m2_glszm_SizeZoneNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 564 feature lbp-3D-m2_glszm_ZoneEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 566 feature lbp-3D-m2_glszm_ZoneVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 567 feature lbp-3D-m2_ngtdm_Busyness with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 568 feature lbp-3D-m2_ngtdm_Coarseness with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 569 feature lbp-3D-m2_ngtdm_Complexity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 570 feature lbp-3D-m2_ngtdm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 571 feature lbp-3D-m2_ngtdm_Strength with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 761 feature square_firstorder_Entropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 774 feature square_firstorder_Uniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 776 feature square_glcm_Autocorrelation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 777 feature square_glcm_ClusterProminence with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 778 feature square_glcm_ClusterShade with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 779 feature square_glcm_ClusterTendency with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 780 feature square_glcm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 781 feature square_glcm_Correlation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 782 feature square_glcm_DifferenceAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 783 feature square_glcm_DifferenceEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 784 feature square_glcm_DifferenceVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 785 feature square_glcm_Id with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 786 feature square_glcm_Idm with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 787 feature square_glcm_Idmn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 788 feature square_glcm_Idn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 789 feature square_glcm_Imc1 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 790 feature square_glcm_Imc2 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 791 feature square_glcm_InverseVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 792 feature square_glcm_JointAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 793 feature square_glcm_JointEnergy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 794 feature square_glcm_JointEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 795 feature square_glcm_MCC with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 796 feature square_glcm_MaximumProbability with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 797 feature square_glcm_SumAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 798 feature square_glcm_SumEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 799 feature square_glcm_SumSquares with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 805 feature square_gldm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 806 feature square_gldm_HighGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 810 feature square_gldm_LowGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 815 feature square_glrlm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 816 feature square_glrlm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 817 feature square_glrlm_HighGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 821 feature square_glrlm_LowGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 830 feature square_glszm_GrayLevelNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 831 feature square_glszm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 832 feature square_glszm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 833 feature square_glszm_HighGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 837 feature square_glszm_LowGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 838 feature square_glszm_SizeZoneNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 839 feature square_glszm_SizeZoneNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 843 feature square_glszm_ZoneEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 845 feature square_glszm_ZoneVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 846 feature square_ngtdm_Busyness with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 847 feature square_ngtdm_Coarseness with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 848 feature square_ngtdm_Complexity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 849 feature square_ngtdm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 850 feature square_ngtdm_Strength with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1798 feature exponential_firstorder_Entropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1811 feature exponential_firstorder_Uniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1813 feature exponential_glcm_Autocorrelation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1814 feature exponential_glcm_ClusterProminence with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1815 feature exponential_glcm_ClusterShade with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1816 feature exponential_glcm_ClusterTendency with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1817 feature exponential_glcm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1818 feature exponential_glcm_Correlation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1819 feature exponential_glcm_DifferenceAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1820 feature exponential_glcm_DifferenceEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1821 feature exponential_glcm_DifferenceVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1822 feature exponential_glcm_Id with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1823 feature exponential_glcm_Idm with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1824 feature exponential_glcm_Idmn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1825 feature exponential_glcm_Idn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1826 feature exponential_glcm_Imc1 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1827 feature exponential_glcm_Imc2 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1828 feature exponential_glcm_InverseVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1829 feature exponential_glcm_JointAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1830 feature exponential_glcm_JointEnergy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1831 feature exponential_glcm_JointEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1832 feature exponential_glcm_MCC with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1833 feature exponential_glcm_MaximumProbability with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1834 feature exponential_glcm_SumAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1835 feature exponential_glcm_SumEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1836 feature exponential_glcm_SumSquares with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1842 feature exponential_gldm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1843 feature exponential_gldm_HighGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1847 feature exponential_gldm_LowGrayLevelEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1852 feature exponential_glrlm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1853 feature exponential_glrlm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1854 feature exponential_glrlm_HighGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1858 feature exponential_glrlm_LowGrayLevelRunEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1867 feature exponential_glszm_GrayLevelNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1868 feature exponential_glszm_GrayLevelNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1869 feature exponential_glszm_GrayLevelVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1870 feature exponential_glszm_HighGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1874 feature exponential_glszm_LowGrayLevelZoneEmphasis with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1875 feature exponential_glszm_SizeZoneNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1876 feature exponential_glszm_SizeZoneNonUniformityNormalized with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1880 feature exponential_glszm_ZoneEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1882 feature exponential_glszm_ZoneVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1883 feature exponential_ngtdm_Busyness with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1884 feature exponential_ngtdm_Coarseness with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1885 feature exponential_ngtdm_Complexity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1886 feature exponential_ngtdm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1887 feature exponential_ngtdm_Strength with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1984 feature lbp-2D_firstorder_Entropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1987 feature lbp-2D_firstorder_Maximum with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1990 feature lbp-2D_firstorder_Median with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1991 feature lbp-2D_firstorder_Minimum with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1992 feature lbp-2D_firstorder_Range with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1997 feature lbp-2D_firstorder_Uniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 1999 feature lbp-2D_glcm_Autocorrelation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2000 feature lbp-2D_glcm_ClusterProminence with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2001 feature lbp-2D_glcm_ClusterShade with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2002 feature lbp-2D_glcm_ClusterTendency with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2003 feature lbp-2D_glcm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2004 feature lbp-2D_glcm_Correlation with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2005 feature lbp-2D_glcm_DifferenceAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2006 feature lbp-2D_glcm_DifferenceEntropy with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2007 feature lbp-2D_glcm_DifferenceVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2008 feature lbp-2D_glcm_Id with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2009 feature lbp-2D_glcm_Idm with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2010 feature lbp-2D_glcm_Idmn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2011 feature lbp-2D_glcm_Idn with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2012 feature lbp-2D_glcm_Imc1 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2013 feature lbp-2D_glcm_Imc2 with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2014 feature lbp-2D_glcm_InverseVariance with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2015 feature lbp-2D_glcm_JointAverage with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 
covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2257 feature lbp-3D-m2_ngtdm_Complexity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2258 feature lbp-3D-m2_ngtdm_Contrast with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2259 feature lbp-3D-m2_ngtdm_Strength with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2518 feature square_glszm_GrayLevelNonUniformity with covariance matrix value 0.0
# NaN detected at correlation matrix diagonal entry 2526 feature square_glszm_SizeZoneNonUniformity with covariance matrix value 0.0

# %%
with np.printoptions(threshold=np.inf):
    target_corr = np.sort(Phi_corr[-1,:-1])
    target_arg = np.argsort(Phi_corr[-1,:-1])
    high_corr = np.where(abs(target_corr)>0.70)
 
print('Found',high_corr[0].__len__(),'highly correlated features')
# Out:
# Found 12 highly correlated features

# %%
high_corr
# Out:
# (array([   0, 2934, 2935, 2936, 2937, 2938, 2939, 2940, 2941, 2942, 2943,
#         2944]),)

# %%
high_corr_keys = []
for k in np.arange(0,high_corr[0].__len__()):
    with np.printoptions(threshold=np.inf):
        print('Feature',keys[high_corr[0][k]],'has correlation',target_corr[[high_corr[0][k]]],'with UPDRS-III percent improvement')
        high_corr_keys.append(keys[high_corr[0][k]])
# Out:
# Feature original_shape_Elongation has correlation [-0.87204304] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Correlation has correlation [0.71058812] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_DifferenceAverage has correlation [0.7183329] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_DifferenceEntropy has correlation [0.71863731] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_DifferenceVariance has correlation [0.72278329] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Id has correlation [0.72323404] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Idm has correlation [0.73274899] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Idmn has correlation [0.73762013] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Idn has correlation [0.74859853] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Imc1 has correlation [0.74862146] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_Imc2 has correlation [0.78692583] with UPDRS-III percent improvement
# Feature wavelet-HLL_glcm_InverseVariance has correlation [0.88843956] with UPDRS-III percent improvement

# %%
k = 0
fig,ax = plt.subplots(3,4)
for i in np.arange(0,3):
    for j in np.arange(0,4):
        ax[i][j].scatter(X_t[:,high_corr[0][k]],np.asarray(per_change_train))
        lr_rho_stim = linregress(X_t[:,high_corr[0][k]],np.asarray(per_change_train))
        ax[i][j].plot(np.asarray(X_t[:,high_corr[0][k]]),np.asarray(X_t[:,high_corr[0][k]])*lr_rho_stim.slope+lr_rho_stim.intercept,'-r')
        print(np.corrcoef(np.asarray(X_t[:,high_corr[0][k]])),np.asarray(X_t[:,high_corr[0][k]])*lr_rho_stim.slope+lr_rho_stim.intercept)
        text = f"$y={lr_rho_stim.slope:0.3f}\;x{lr_rho_stim.intercept:+0.3f}$\n$r = {lr_rho_stim.rvalue:0.3f}$"
        ax[i][j].text(0.1,0.05, text, transform=ax[i][j].transAxes,fontsize=12)
        if i < 2:
            ax[i][j].set_xticks([])
        if j > 0:
            ax[i][j].set_yticks([])
        if j == 0:
            ax[i][j].set_ylabel(r'$\rho_{stim}$')
        ax[i][j].set_ylim([0.5,1])
        ax[i][j].set_title(high_corr_keys[k])
       
        k = k+1
fig.set_size_inches(30,20)
plt.show()
# Out:
# 1.0 [0.7532597  0.74944032 0.75113287 0.75037122 0.75226496 0.74876148
#  0.74811742 0.75767247 0.7515819  0.76073264 0.75690166 0.75409864]
# 1.0 [0.75218588 0.75287241 0.75325932 0.75477902 0.75160892 0.75253104
#  0.75419575 0.75268838 0.75284034 0.75237965 0.7523525  0.75264208]
# 1.0 [0.80363331 0.77798456 0.719495   0.70175439 0.72785856 0.78755881
#  0.77492649 0.80122765 0.69627454 0.71258523 0.73567563 0.79536111]
# 1.0 [0.79920065 0.77548302 0.7147997  0.70345836 0.73069736 0.78984611
#  0.7731243  0.79776599 0.70729129 0.70394944 0.73928341 0.79943564]
# 1.0 [0.79292667 0.7778871  0.70734875 0.70165473 0.73215219 0.79646465
#  0.78162438 0.79739556 0.70572428 0.69159396 0.7484083  0.80115471]
# 1.0 [0.8077714  0.77708988 0.72357661 0.70538115 0.72558986 0.78209358
#  0.76998477 0.8000768  0.70028466 0.71901945 0.73086508 0.79260204]
# 1.0 [0.80637795 0.77691199 0.7225511  0.70422519 0.72661196 0.7839755
#  0.7711405  0.80083159 0.69896804 0.71722462 0.7321043  0.79341254]
# 1.0 [0.75677965 0.75801912 0.75232363 0.74458483 0.75364032 0.75592929
#  0.74798466 0.75707508 0.75028778 0.75150859 0.74963041 0.75657193]
# 1.0 [0.77228219 0.77055062 0.74805242 0.72586692 0.75053051 0.76328256
#  0.74197956 0.7703214  0.73876838 0.74569035 0.73972209 0.76728829]
# 1.0 [0.70537765 0.74141738 0.7411274  0.7652197  0.71986729 0.78881786
#  0.82477009 0.79050142 0.7078629  0.73061921 0.75660467 0.76214971]
# 1.0 [0.74924666 0.75656044 0.72416198 0.74376053 0.70838485 0.7963402
#  0.83043708 0.7891438  0.69217912 0.70116809 0.74754544 0.79540709]
# 1.0 [0.80926544 0.77275944 0.73997102 0.72629003 0.72225639 0.75843652
#  0.75462256 0.78379986 0.72371572 0.74358705 0.72317645 0.77645481]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = plt.subplots()
plt.style.use('dark_background')
im1 = ax.pcolor(np.squeeze(X_thc))
plt.xticks(np.arange(0,high_corr[0].__len__()),high_corr_keys,rotation=45,ha='right');
fig.colorbar(im1);
plt.xlabel('Feature')

plt.ylabel('Subject ID');
fig.set_size_inches(20,20)
fig.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tidx = 0
if retrain == 1:
    #fig,ax = plt.subplots(1,1)
    for j in complete_cases:
            # Remove the test case
            X_j = np.delete(np.squeeze(X_thc),tidx,0)
            per_change_train_j = np.delete(per_change_train,tidx,0)
            # Debug
            print('Excluding subject',str(j),'at index',str(tidx),'in target vector','from training feature vector of shape',str(X_t.shape),'by deleting row',str(tidx),'to create new training feature vector of shape',str(X_j.shape))
            if (sum(sum(np.isnan(X))))>0:
                print('NaN detected in feature vector')

            # Cross-validation for model selection
            cv = KFold((X_j.shape[0]-2))
            # Identify most important features
            # Do not assume data is centered,fit_intercept=True
            clf_in = RidgeCV(fit_intercept=True).fit(X_j,np.ravel(per_change_train_j))

            clf_alphas[tidx] = clf_in.alpha_
            ut[tidx] = clf_in.predict(X_thc[tidx,:].reshape(1,-1))
            print('Predicted percentage change of',ut[tidx],'for case',complete_cases[tidx],'with alpha',clf_in.alpha_)
            print('True percentage change',per_change_train[tidx])
            tidx = tidx+1
# Out:
# Excluding subject 1 at index 0 in target vector from training feature vector of shape (12, 3378) by deleting row 0 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7568209618887997 for case 1 with alpha 10.0
# True percentage change 0.8307692307692308
# Excluding subject 11 at index 1 in target vector from training feature vector of shape (12, 3378) by deleting row 1 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7651805885779706 for case 11 with alpha 10.0
# True percentage change 0.7368421052631579
# Excluding subject 13 at index 2 in target vector from training feature vector of shape (12, 3378) by deleting row 2 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.738969571596315 for case 13 with alpha 10.0
# True percentage change 0.7037037037037037
# Excluding subject 15 at index 3 in target vector from training feature vector of shape (12, 3378) by deleting row 3 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7454757843631058 for case 15 with alpha 10.0
# True percentage change 0.6865671641791045
# Excluding subject 25 at index 4 in target vector from training feature vector of shape (12, 3378) by deleting row 4 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7414304612851862 for case 25 with alpha 10.0
# True percentage change 0.7
# Excluding subject 27 at index 5 in target vector from training feature vector of shape (12, 3378) by deleting row 5 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7759969076834989 for case 27 with alpha 10.0
# True percentage change 0.7441860465116279
# Excluding subject 28 at index 6 in target vector from training feature vector of shape (12, 3378) by deleting row 6 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7490233355120942 for case 28 with alpha 10.0
# True percentage change 0.8709677419354839
# Excluding subject 29 at index 7 in target vector from training feature vector of shape (12, 3378) by deleting row 7 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7620720980240724 for case 29 with alpha 10.0
# True percentage change 0.8571428571428571
# Excluding subject 34 at index 8 in target vector from training feature vector of shape (12, 3378) by deleting row 8 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7306586587792867 for case 34 with alpha 10.0
# True percentage change 0.691358024691358
# Excluding subject 35 at index 9 in target vector from training feature vector of shape (12, 3378) by deleting row 9 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7426529337518463 for case 35 with alpha 10.0
# True percentage change 0.675
# Excluding subject 43 at index 10 in target vector from training feature vector of shape (12, 3378) by deleting row 10 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7303462123031375 for case 43 with alpha 10.0
# True percentage change 0.8653846153846154
# Excluding subject 52 at index 11 in target vector from training feature vector of shape (12, 3378) by deleting row 11 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.8232725542447857 for case 52 with alpha 1.0
# True percentage change 0.6724137931034483

# %%
tidx = 0
if retrain == 1:
    #fig,ax = plt.subplots(1,1)
    for j in complete_cases:
            # Remove the test case
            X_j = np.delete(np.squeeze(X_thc),tidx,0)
            per_change_train_j = np.delete(per_change_train,tidx,0)
            # Debug
            print('Excluding subject',str(j),'at index',str(tidx),'in target vector','from training feature vector of shape',str(X_t.shape),'by deleting row',str(tidx),'to create new training feature vector of shape',str(X_j.shape))
            if (sum(sum(np.isnan(X))))>0:
                print('NaN detected in feature vector')

            # Cross-validation for model selection
            cv = KFold((X_j.shape[0]-2))
            # Identify most important features
            # Do not assume data is centered,fit_intercept=True
            clf_in = RidgeCV(fit_intercept=True).fit(X_j,np.ravel(per_change_train_j))

            clf_alphas[tidx] = clf_in.alpha_
            ut[tidx] = clf_in.predict(X_thc[tidx,:].reshape(1,-1))
            print('Predicted percentage change of',ut[tidx],'for case',complete_cases[tidx],'with alpha',clf_in.alpha_)
            print('True percentage change',per_change_train[tidx])

            clf = Ridge(alpha=np.median(clf_alphas),fit_intercept=True).fit(X_j,np.ravel(per_change_train_j))
            ut_clf[tidx] = clf.predict(X_thc[tidx,:].reshape(1,-1))

            tidx = tidx+1
# Out:
# Excluding subject 1 at index 0 in target vector from training feature vector of shape (12, 3378) by deleting row 0 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7568209618887997 for case 1 with alpha 10.0
# True percentage change 0.8307692307692308
# Excluding subject 11 at index 1 in target vector from training feature vector of shape (12, 3378) by deleting row 1 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7651805885779706 for case 11 with alpha 10.0
# True percentage change 0.7368421052631579
# Excluding subject 13 at index 2 in target vector from training feature vector of shape (12, 3378) by deleting row 2 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.738969571596315 for case 13 with alpha 10.0
# True percentage change 0.7037037037037037
# Excluding subject 15 at index 3 in target vector from training feature vector of shape (12, 3378) by deleting row 3 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7454757843631058 for case 15 with alpha 10.0
# True percentage change 0.6865671641791045
# Excluding subject 25 at index 4 in target vector from training feature vector of shape (12, 3378) by deleting row 4 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7414304612851862 for case 25 with alpha 10.0
# True percentage change 0.7
# Excluding subject 27 at index 5 in target vector from training feature vector of shape (12, 3378) by deleting row 5 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7759969076834989 for case 27 with alpha 10.0
# True percentage change 0.7441860465116279
# Excluding subject 28 at index 6 in target vector from training feature vector of shape (12, 3378) by deleting row 6 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7490233355120942 for case 28 with alpha 10.0
# True percentage change 0.8709677419354839
# Excluding subject 29 at index 7 in target vector from training feature vector of shape (12, 3378) by deleting row 7 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7620720980240724 for case 29 with alpha 10.0
# True percentage change 0.8571428571428571
# Excluding subject 34 at index 8 in target vector from training feature vector of shape (12, 3378) by deleting row 8 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7306586587792867 for case 34 with alpha 10.0
# True percentage change 0.691358024691358
# Excluding subject 35 at index 9 in target vector from training feature vector of shape (12, 3378) by deleting row 9 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7426529337518463 for case 35 with alpha 10.0
# True percentage change 0.675
# Excluding subject 43 at index 10 in target vector from training feature vector of shape (12, 3378) by deleting row 10 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.7303462123031375 for case 43 with alpha 10.0
# True percentage change 0.8653846153846154
# Excluding subject 52 at index 11 in target vector from training feature vector of shape (12, 3378) by deleting row 11 to create new training feature vector of shape (11, 12)
# Predicted percentage change of 0.8232725542447857 for case 52 with alpha 1.0
# True percentage change 0.6724137931034483

# %%
if retrain == 1:
    with open('lasso_pred.npy','wb') as f:
        np.save(f,ut)
else:
    with open('lasso_pred.npy','rb') as f:
        ut = np.load(f)

# %%
[fig,ax] = plt.subplots(1,2,sharex=True,sharey=True)
ax[0].hist([lct_change],bins=np.linspace(0,1))
ax[0].set_title('Medication response')
ax[0].set_xlabel('Improvement')
ax[0].set_ylabel('Frequency')
ax[1].hist([ut],bins=np.linspace(0,1))
ax[1].set_title('Lasso prediction')
ax[1].set_xlabel('Improvement')
ax[1].set_ylabel('Frequency')
fig.set_size_inches(12,6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = per_change[np.asarray(complete_cases).astype(int)-1]
y = ut_clf

slope,intercept = np.polyfit(x,y,1)  # linear model adjustment
y_model = np.polyval([slope,intercept],x)   # modeling...

x_mean = np.mean(x)
y_mean = np.mean(y)
n = x.size                        # number of samples
m = 2                             # number of parameters
dof = n-m                       # degrees of freedom
t = stats.t.ppf(0.975,dof)       # Students statistic of interval confidence
residual_ut = y-y_model
std_error = (np.sum(residual_ut**2)/dof)**(1/2)   # Standard deviation of the error

# Pearson's correlation coefficient
numerator = np.sum((x-x_mean)*(y-y_mean))
denominator = (np.sum((x-x_mean)**2)*np.sum((y-y_mean)**2))**.5
correlation_coef = numerator/denominator
r = correlation_coef
tr = r*np.sqrt(n-2)/(np.sqrt(1-r**2))
# p-value for 2-sided test
pv = 2*(1-stats.t.cdf(abs(tr), dof))
# # mean squared error
MSE = 1/n*np.sum((y-y_model)**2)

# to plot the adjusted model
x_line = np.linspace(0,np.max(x),100)
y_line = np.polyval([slope,intercept],x_line)

# confidence interval
ci = t*std_error*(1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5
# predicting interval
pi = t*std_error*(1+1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5  


plt.rcParams.update({'font.size': 14})
[fig,ax] = plt.subplots(1,2,sharex=True,sharey=True);

ax[0].plot(x,y,'o',color = 'white')
ax[0].plot(x_line,y_line,color = 'red')
ax[0].fill_between(x_line,y_line+pi,y_line-pi,color = 'red',label = '95% prediction interval')
ax[0].fill_between(x_line,y_line+ci,y_line-ci,color = 'orange',label = '95% confidence interval')

ax[0].set_xlabel('UPDRS-III pre/post DBS percent improvement')
ax[0].set_ylabel('Percent improvement')
ax[0].set_title('Lasso prediction')

ax[0].text(0.01,0.1,'$y$ = '+ str(np.round(slope,2))+'$x$'+'+'+str(np.round(intercept,3)),color='w')
ax[0].text(0.01,0.005,'$r$ = '+str(np.round(r,2))+', $p$ = '+str(round(pv,3)),color='w')

ax[0].margins(x=0)
fig.set_size_inches(20,10)
ax[0].legend(bbox_to_anchor=(1,1),fontsize=12)


## Medication response
x = per_change[np.asarray(complete_cases).astype(int)-1]
y = lct_change[np.asarray(complete_cases).astype(int)-1]

# Fit and evaluate linear model
slope,intercept = np.polyfit(x,y,1)
y_model = np.polyval([slope,intercept],x)   

# Prepare correlation stats
x_mean = np.mean(x)
y_mean = np.mean(y)
# Sample size
n = x.size         
# Parameters assuming a normal distribution              
m = 2
# Degrees of freedom                            
dof = n-m
# Students statistic of interval confidence                      
t = stats.t.ppf(0.975,dof)      
# Standard deviation of the error
residual_lct = y-y_model
std_error = (np.sum(residual_lct**2)/dof)**(1/2)   

# Pearson's correlation coefficient
numerator = np.sum((x-x_mean)*(y-y_mean))
denominator = (np.sum((x-x_mean)**2)*np.sum((y-y_mean)**2))**.5
correlation_coef = numerator/denominator
r = correlation_coef
tr = r*np.sqrt(n-2)/(np.sqrt(1-r**2))
# p-value for 2-sided test
pv = 2*(1-stats.t.cdf(abs(tr), dof))
# # mean squared error
MSE = 1/n*np.sum((y-y_model)**2)

# to plot the adjusted model
x_line = np.linspace(0,np.max(x),100)
y_line = np.polyval([slope,intercept],x_line)

# confidence interval
ci = t*std_error*(1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5
# predicting interval
pi = t*std_error*(1+1/n+(x_line-x_mean)**2/np.sum((x-x_mean)**2))**.5  



ax[1].plot(x,y,'o',color = 'white')
ax[1].plot(x_line,y_line,color = 'red')
ax[1].fill_between(x_line,y_line+pi,y_line-pi,color = 'red',label = '95% prediction interval')
ax[1].fill_between(x_line,y_line+ci,y_line-ci,color = 'orange',label = '95% confidence interval')

ax[1].set_xlabel('UPDRS-III pre/post DBS percent improvement')
ax[1].set_ylabel('Percent improvement')
ax[1].set_title('Medication response')


ax[1].text(0.01,0.1,'$y$ = '+ str(np.round(slope,2))+'$x$'+'+'+str(np.round(intercept,3)),color='w')
ax[1].text(0.01,0.005,'$r$ = '+str(np.round(r,2))+', $p$ = '+str(round(pv,3)),color='w')

ax[1].margins(x=0)
fig.set_size_inches(20,10)
ax[1].legend(bbox_to_anchor=(1,1),fontsize=12)
fig.suptitle('UPDRS-III Improvement')
# Out:
# Text(0.5, 0.98, 'UPDRS-III Improvement')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
[fig,ax] = plt.subplots(1,2,sharex=False,sharey=True)
ax[0].hist([residual_lct])
ax[0].set_title('Medication response residuals')
ax[0].set_xlabel('Residual')
ax[0].set_ylabel('Frequency')
ax[1].hist([residual_ut])
ax[1].set_title('Lasso prediction residuals')
ax[1].set_xlabel('Residual')
ax[1].set_ylabel('Frequency')
fig.set_size_inches(12,6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
